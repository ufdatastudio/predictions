# %% [markdown]
# # Sequence Labelling: Pediction Sentence
#
# - Sequence: Pediction Sentence
# - Labels: Prediction Properties
#
# Tasks
# 1. Update the prompt from zero-shot to few-show
# 2. How can we measure the output/labels from the LLMs?
#     1. Could use multiple LLMs and perform majority vote for the labels
# 3. Perform on various datasets
#     1. Synthetic data (which is below)
#     2. Real datasets
#         1.  financial_phrasebank
#         2. chronicle2050

# %% [markdown]
# > `prediction_classification_experiments-v2/ml_classifiers.ipynb` and `prediction_classification_experiments-v2/llm_classifiers.ipynb` because classify sentences as prediction/non-prediction

# %%
import os
import sys
import pprint

import pandas as pd

from tqdm import tqdm

notebook_dir = os.getcwd()

sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing
from prediction_properties import PredictionProperties
from text_generation_models import TextGenerationModelFactory
from vector_stores import ChromaVectorStore, VectorStoreDirector

# %% [markdown]
# ## Load Data
#
# - Request data

# %%
base_data_path = os.path.join(notebook_dir, '../data')

# %%
# combine_data_path = os.path.join(base_data_path, 'combined_datasets')
# model_results_path = os.path.join(combine_data_path, 'ml_classifiers-v1.csv')
# df = DataProcessing.load_from_file(model_results_path, 'csv', sep=',')
# df.head(3)

# %%
# save_chronicle2050_vs_majority_vote_path = os.path.join(base_data_path, 'chronicle2050')
# DataProcessing.save_to_file(diff_labels_df, save_chronicle2050_vs_majority_vote_path, 'chronicle2050-diff_vs_majority_vote', '.csv')

# %%
chronicle2050_data_path = os.path.join(base_data_path, 'chronicle2050')
chronicle2050_vs_majority_vote_path = os.path.join(chronicle2050_data_path, 'chronicle2050-diff_vs_majority_vote-v1.csv')
df = DataProcessing.load_from_file(chronicle2050_vs_majority_vote_path, 'csv', sep=',')
df

# %% [markdown]
# ## Majority Vote (Prediction)

# %% [markdown]
# ### Majority Vote
#
# - Be care with doing this on real data. Some examples in `data/combined_datasets/ml_classifiers-v1.csv` have true labels of 0 and MV is 1.

# %%
model_results_df = df.drop(columns=['Author Type', 'Embedding', 'Normalized Embeddings'])
model_results_df.head(3)

# %%
model_results_df['Majority Vote'] = model_results_df.iloc[:, 2:].mode(axis=1)
model_results_df.head(3)

# %% [markdown]
# ### Filter for Prediction (=1)

# %%
filt_prediction = (model_results_df['Sentence Label'] == 1) & (model_results_df['Majority Vote'] == 1)
predictions_df = model_results_df[filt_prediction]
predictions_df.shape

# %%
predictions_df.head(7)

# %% [markdown]
# ## LLM for Relation Extraction

# %% [markdown]
# ### Prompts

# %%
prediction_base_prompt = DataProcessing.load_prediction_properties()
prediction_base_prompt

# %%
# role_prompt = "Role: You are a lingust that specializes in identifying properties within a prediction statement."
# task_prompt = "Your task is label the prediction properties within"

# %%
system_identity_prompt = "You are a lingustic expert that specializes in identifying properties within a prediction statement."
# prediction_requirements = PredictionProperties.get_requirements()
task = """For each word within the sentence "label" as either a "no_label": 0, "source": 1, "target": 2, "date": 3, "outcome": 4. IMPORTANT: Keep multi-word entities together as single items in the list."""
sentence_label_format_output = """

Respond ONLY with valid JSON in this exact format: {0: [word_from_sentence]}, {1: [word_from_sentence]}, {2: [word_from_sentence]}, {3: [word_from_sentence]}, {4: [word_from_sentence]}, where key is int ranging from 0 to 4 and the value is the words_from_sentence, split by a comma/all placed into a list, so {int: [word_from_sentence_1, word_from_sentence_2, ..., word_from_sentence_W]}. For 2 and 3, some words may be a prefix or a position or tile before/after 2 or 3. Be sure to take that into account.

Do NOT reason or provide anything other than the aforementioned. Also, stop responding in reverse format {word_from_sentence: 0}, {word_from_sentence: 1}, {word_from_sentence: 2}, {word_from_sentence: 3}, {word_from_sentence: 4} or in any other format.

Respond ONLY with valid JSON in this exact format: {0: [word_from_sentence]}, {1: [word_from_sentence]}, {2: [word_from_sentence]}, {3: [word_from_sentence]}, {4: [word_from_sentence]}, where key is int ranging from 0 to 4 and the value is the words_from_sentence, split by a comma/all placed into a list, so {int: [word_from_sentence_1, word_from_sentence_2, ..., word_from_sentence_W]}.
"""

# %%
prediction_properties = PredictionProperties.get_prediction_properties()
prediction_properties_base_prompt = f"""{system_identity_prompt} For each prediction, the format is based on: 
    
    {prediction_properties}

"""
prediction_properties_base_prompt

# %% [markdown]
# ### Models

# %%
tgmf = TextGenerationModelFactory()

# Option 1: Specific models
# models = tgmf.create_instances(['llama-3.1-8b-instant', 'llama-3.3-70b-versatile', 'llama-3.3-70b-instruct', 'openai/gpt-oss-20b'])
models = tgmf.create_instances(['openai/gpt-oss-120b'])

# Option 2: All Groq models
# models = tgmf.create_instances(tgmf.get_groq_model_names())

# Option 3: All NaviGator models
# models = tgmf.create_instances(tgmf.get_navigator_model_names())

# Option 4: All available models
# models = tgmf.create_instances()

# Option 5: Mix and match
# custom_models = ['llama-3.1-70b-instruct', 'mistral-small-3.1', 'llama-3.1-8b-instant']
# models = tgmf.create_instances(custom_models)
models

# %% [markdown]
# ### Prompt Models

# %%
def llm_certifier(idx, sentence_to_classify: str, base_prompt: str, model, task, format_output: str):
    
      prompt = f"""{base_prompt}
      
      Sentence to extract the prediction properties: '{sentence_to_classify}'

      {task}
      
      {format_output}
      """
      if idx < 2:
            print(f"\tPrompt: {prompt}")
      input_prompt = model.user(prompt)
      raw_text_llm_generation = model.chat_completion([input_prompt])
      # print(f"Raw response: {raw_text_llm_generation}")      
      return raw_text_llm_generation

# %%
# subset_predictions_df = predictions_df.iloc[:33, :]
# subset_predictions_df.head(3)

# %%
results = []
# len(predictions_df)
# for idx, row in tqdm(predictions_df.iterrows(), total=len(predictions_df), desc="Processing"):
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing"):
    text = row['sentence']
    # print(f"{idx} --- Sentence: {text}")
    for model in models:
        # print(model.__name__())
        raw_response = llm_certifier(idx, text, prediction_properties_base_prompt, model, task, sentence_label_format_output)
        result = (text, raw_response, model.__name__())
        results.append(result)

        if idx < 3:
            # print(f"{idx} --- Sentence: {text}")
            print(f"\n--- Result {idx} ---")
            pprint.pprint(result, width=120)
    
    # print()

# %%
results

# %%
column_names = ["Prediction Sentence", "Raw Response", "Model Name"]
results_df = pd.DataFrame(results, columns=column_names)
results_df

# %%
import ast, re
from typing import Any, Dict, List, Union

def parse_json_response_2(raw_response: Union[str, bytes, bytearray]) -> Dict[int, List[Any]]:
    """
    Parse a string that looks like a Python literal into a dictionary.
    Normalizes string keys to integer keys.
    Handles both quoted and unquoted list items.
    
    Args:
        raw_response: The raw string (or bytes/bytearray) containing Python-like literals.
    
    Returns:
        A dictionary with integer keys mapped to lists.
    
    Raises:
        ValueError: If the input cannot be parsed into the expected structure.
    """
    # Normalize input
    print(f"RAW: {raw_response}")
    if isinstance(raw_response, (bytes, bytearray)):
        raw_response = raw_response.decode("utf-8", errors="replace")
    if not isinstance(raw_response, str):
        raise ValueError(f"Expected str/bytes, got {type(raw_response).__name__}")
    
    text = raw_response.strip()
    
    # Fix unquoted list items: [word1, word2] -> ["word1", "word2"]
    def quote_unquoted_items(match):
        """Add quotes to unquoted words in lists."""
        content = match.group(1)
        # Split by comma, strip whitespace, and add quotes if not already quoted
        items = []
        for item in content.split(','):
            item = item.strip()
            if item and not (item.startswith('"') or item.startswith("'")):
                items.append(f'"{item}"')
            else:
                items.append(item)
        return '[' + ', '.join(items) + ']'
    
    # Apply the fix to all lists in the text
    text = re.sub(r'\[([^\[\]]+)\]', quote_unquoted_items, text)
    
    # Try to safely evaluate using ast.literal_eval
    try:
        obj = ast.literal_eval(text)
    except (SyntaxError, ValueError) as e:
        raise ValueError(f"Unable to parse input as Python literal: {e}\nProcessed text: {text}")
    
    # Ensure we have a dict
    if not isinstance(obj, dict):
        raise ValueError(f"Expected dict, got {type(obj).__name__}")
    
    # Normalize keys to integers
    normalized = {}
    for key, value in obj.items():
        try:
            int_key = int(key)
            normalized[int_key] = value
        except (ValueError, TypeError):
            # Keep non-convertible keys as-is (shouldn't happen with your format)
            normalized[key] = value
    
    return normalized

# %%
for idx, row in results_df.iterrows():
    raw_response = row['Raw Response']
    
    try:
        # Parse the raw JSON response
        cleaned_response = parse_json_response_2(raw_response)
        print(f"   CLEANED: {cleaned_response}")
        
        # Store as comma-separated strings
        results_df.at[idx, 'No Property'] = ', '.join(cleaned_response.get(0, []))
        results_df.at[idx, 'Source'] = ', '.join(cleaned_response.get(1, []))
        results_df.at[idx, 'Target'] = ', '.join(cleaned_response.get(2, []))
        results_df.at[idx, 'Date'] = ', '.join(cleaned_response.get(3, []))
        results_df.at[idx, 'Outcome'] = ', '.join(cleaned_response.get(4, []))
    except ValueError as e:
        print(f"   ERROR at index {idx}: {e}")
        # Set empty values for failed parses
        for col in ['No Property', 'Source', 'Target', 'Date', 'Outcome']:
            results_df.at[idx, col] = ''

results_df
# Out:
# RAW: {0: ["By", "will", "have", "been", "with", "that", "are", "capable", "of", "on", "over", "of", "in", "the", "with", "or", "better,", "and", "this", "capability", "will", "be", "usable", "by", "the", "commercially."], 1: ["Tesla"], 2: ["the first company"], 3: ["January 1st, 2037"], 4: ["1 million vehicles", "SAE Level 4 autonomy", "over 90% of public roads", "contiguous United States", "human-level safety", "general public"]}
#    ERROR at index 0: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["By", "will", "have", "been", "with", "that", "are", "capable", "of", "on", "over", "of", "in", "the", "with", "or", "better, ", "and", "this", "capability", "will", "be", "usable", "by", "the", "commercially."], 1: ["Tesla"], 2: ["the first company"], 3: ["January 1st, "2037""], 4: ["1 million vehicles", "SAE Level 4 autonomy", "over 90% of public roads", "contiguous United States", "human-level safety", "general public"]}
# RAW: {0: ["will", "average", "from", "the", "to", "the"], 1: [], 2: ["Private Nonfarm business productivity growth"], 3: ["first quarter (Q1) of 2020", "last quarter of 2029 (Q4)"], 4: ["over 1.8 percent per year"]}
#    CLEANED: {0: ['will', 'average', 'from', 'the', 'to', 'the'], 1: [], 2: ['Private Nonfarm business productivity growth'], 3: ['first quarter (Q1) of 2020', 'last quarter of 2029 (Q4)'], 4: ['over 1.8 percent per year']}
# RAW: {0: ["before"], 1: [], 2: ["Republican"], 3: ["December 30, 2039"], 4: ["No", "will", "be", "President of the USA"]}
#    ERROR at index 2: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["before"], 1: [], 2: ["Republican"], 3: ["December 30, "2039""], 4: ["No", "will", "be", "President of the USA"]}
# RAW: {0: ["The", "of", "will", "be", "on"], 1: [], 2: ["Berkshire Hathaway"], 3: ["Warren Buffett's 100th birthday"], 4: ["market capitalization", "greater than Tesla"]}
#    CLEANED: {0: ['The', 'of', 'will', 'be', 'on'], 1: [], 2: ['Berkshire Hathaway'], 3: ["Warren Buffett's 100th birthday"], 4: ['market capitalization', 'greater than Tesla']}
# RAW: {0: ["Over", "ten-year", "period", "commencing", "on", "and", "ending", "on"], 1: [], 2: ["a portfolio of index funds invested broadly in US and International equities", "a portfolio managed by a sophisticated individual investor selecting stocks and funds"], 3: ["July 1, 2020", "June 30, 2030"], 4: ["will outperform"]}
#    ERROR at index 4: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["Over", "ten-year", "period", "commencing", "on", "and", "ending", "on"], 1: [], 2: ["a portfolio of index funds invested broadly in US and International equities", "a portfolio managed by a sophisticated individual investor selecting stocks and funds"], 3: ["July 1, "2020"", "June 30, "2030""], 4: ["will outperform"]}
# RAW: {0: [], 1: [], 2: ["The Equal Rights Amendment to the U.S. Constitution"], 3: ["by the end of 2023"], 4: ["will be passed"]}
#    CLEANED: {0: [], 1: [], 2: ['The Equal Rights Amendment to the U.S. Constitution'], 3: ['by the end of 2023'], 4: ['will be passed']}
# RAW: {0: [There, will, be, at, least, one, which, will, have], 1: [], 2: [2022 FIFA World Cup match], 3: [2022], 4: [more people watching live via virtual reality than people watching it in person]}
#    CLEANED: {0: ['There', 'will', 'be', 'at', 'least', 'one', 'which', 'will', 'have'], 1: [], 2: ['2022 FIFA World Cup match'], 3: ['2022'], 4: ['more people watching live via virtual reality than people watching it in person']}
# RAW: {"0": ["The", "for", "as", "measured", "by", "the", "will", "be"], "1": ["U.S. Bureau of Labor Statistics"], "2": ["annual rate of US labor productivity growth"], "3": ["the year 02025"], "4": ["2 percent or above"]}
#    CLEANED: {0: ['The', 'for', 'as', 'measured', 'by', 'the', 'will', 'be'], 1: ['U.S. Bureau of Labor Statistics'], 2: ['annual rate of US labor productivity growth'], 3: ['the year 02025'], 4: ['2 percent or above']}
# RAW: {0: ["will", "develop", "establishing", "with", "a", "whether", "such", "as", "are", "at", "that", "moment"], 1: ["Clinicians and neuroscientists"], 2: ["individual human subjects", "anesthetized and neurological patients"], 3: [], 4: ["well validated brain-activity measurement technologies", "high degree of certainty", "conscious"]}
#    CLEANED: {0: ['will', 'develop', 'establishing', 'with', 'a', 'whether', 'such', 'as', 'are', 'at', 'that', 'moment'], 1: ['Clinicians and neuroscientists'], 2: ['individual human subjects', 'anesthetized and neurological patients'], 3: [], 4: ['well validated brain-activity measurement technologies', 'high degree of certainty', 'conscious']}
# RAW: {
#   "0": [
#     "The",
#     "as",
#     "determined",
#     "by",
#     "the",
#     "will",
#     "be",
#     "for",
#     "the",
#     "unless",
#     "the",
#     "determines",
#     "that",
#     "any",
#     "quarter",
#     "in",
#     "was",
#     "in",
#     "a",
#     "recession",
#     "in",
#     "which",
#     "case",
#     "the",
#     "will",
#     "be",
#     "the",
#     "prior",
#     "to",
#     "the",
#     "beginning",
#     "of",
#     "the",
#     "recession"
#   ],
#   "1": [
#     "Bureau of Labor Statistics",
#     "National Bureau of Economic Research"
#   ],
#   "2": [
#     "US unemployment rate"
#   ],
#   "3": [
#     "year 2035",
#     "2035",
#     "12 months"
#   ],
#   "4": [
#     "lower than 8 percent",
#     "reference year"
#   ]
# }
#    CLEANED: {0: ['The', 'as', 'determined', 'by', 'the', 'will', 'be', 'for', 'the', 'unless', 'the', 'determines', 'that', 'any', 'quarter', 'in', 'was', 'in', 'a', 'recession', 'in', 'which', 'case', 'the', 'will', 'be', 'the', 'prior', 'to', 'the', 'beginning', 'of', 'the', 'recession'], 1: ['Bureau of Labor Statistics', 'National Bureau of Economic Research'], 2: ['US unemployment rate'], 3: ['year 2035', '2035', '12 months'], 4: ['lower than 8 percent', 'reference year']}
# RAW: {0: [], 1: ["Berkshire Hathaway A shares (BRK.A)"], 2: ["A equivalent share"], 3: ["On or before December 31, 2029"], 4: ["no less than one million dollars ($1,000,000) per"]}
#    ERROR at index 10: Unable to parse input as Python literal: closing parenthesis ')' does not match opening parenthesis '[' (<unknown>, line 1)
# Processed text: {0: [], 1: ["Berkshire Hathaway A shares (BRK.A)"], 2: ["A equivalent share"], 3: ["On or before December 31, "2029""], 4: ["no less than one million dollars ($1, "000", "000) per""]}
# RAW: {0: ["The", "amount", "of", "in", "will", "be", "the", "amount", "consumed", "in"], 1: [], 2: ["geologically-derived crude oil consumed by the United States"], 3: ["2035", "2015"], 4: ["greater than"]}
#    CLEANED: {0: ['The', 'amount', 'of', 'in', 'will', 'be', 'the', 'amount', 'consumed', 'in'], 1: [], 2: ['geologically-derived crude oil consumed by the United States'], 3: ['2035', '2015'], 4: ['greater than']}
# RAW: {0: ["may", "be"], 1: [], 2: ["Trips"], 3: [], 4: ["point to point outside of the city center", "with no requirement for any passenger to take over manual control of the vehicle"]}
#    CLEANED: {0: ['may', 'be'], 1: [], 2: ['Trips'], 3: [], 4: ['point to point outside of the city center', 'with no requirement for any passenger to take over manual control of the vehicle']}
# RAW: {0: ["During", "the", "500", "years", "between", "and"], 1: [], 2: ["the Farsight Fund"], 3: ["02015 and 02515"], 4: ["return much less than what it has historically"]}
#    CLEANED: {0: ['During', 'the', '500', 'years', 'between', 'and'], 1: [], 2: ['the Farsight Fund'], 3: ['02015 and 02515'], 4: ['return much less than what it has historically']}
# RAW: {0: ["The", "and", "reported", "by", "the", "will", "be", "and"], 1: ["U.S. Bureau of Labor Statistics"], 2: ["Labor Force Participation Rate", "unemployment rate"], 3: ["June, 2025"], 4: ["respectively", "above 60 percent", "below 7.5 percent"]}
#    ERROR at index 14: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["The", "and", "reported", "by", "the", "will", "be", "and"], 1: ["U.S. Bureau of Labor Statistics"], 2: ["Labor Force Participation Rate", "unemployment rate"], 3: ["June, "2025""], 4: ["respectively", "above 60 percent", "below 7.5 percent"]}
# RAW: {0: ["The", "for", "this", "prediction", "in"], 1: [], 2: ["original URL", "(www.longbets.org/601)"], 3: ["eleven years"], 4: ["will no longer be available"]}
#    CLEANED: {0: ['The', 'for', 'this', 'prediction', 'in'], 1: [], 2: ['original URL', '(www.longbets.org/601)'], 3: ['eleven years'], 4: ['will no longer be available']}
# RAW: {0: [], 1: [], 2: ["a professional sports team that is part of either the National Football League, the National Basketball Association, Major League Baseball, the National Hockey League, or Major League Soccer"], 3: ["By the end of the year 2020"], 4: ["integrate and have a woman as a team member/player"]}
#    ERROR at index 16: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: [], 1: [], 2: ["a professional sports team that is part of either the National Football League, "the National Basketball Association", "Major League Baseball", "the National Hockey League", "or Major League Soccer""], 3: ["By the end of the year 2020"], 4: ["integrate and have a woman as a team member/player"]}
# RAW: {0: ["By", "of"], 1: [], 2: ["France, Italy and Germany"], 3: ["2018"], 4: ["the Euro (€) will not be the legal currency"]}
#    ERROR at index 17: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["By", "of"], 1: [], 2: ["France, "Italy and Germany""], 3: ["2018"], 4: ["the Euro (€) will not be the legal currency"]}
# RAW: {0: ["Over", "a", "ten-year", "period", "commencing", "on", "and", "ending", "on", "the", "will", "when", "performance", "is", "measured", "on", "a", "basis"], 1: [], 2: ["the S&P 500"], 3: ["January 1, 2008", "December 31, 2017"], 4: ["outperform a portfolio of funds of hedge funds", "net of fees, costs and expenses"]}
#    ERROR at index 18: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["Over", "a", "ten-year", "period", "commencing", "on", "and", "ending", "on", "the", "will", "when", "performance", "is", "measured", "on", "a", "basis"], 1: [], 2: ["the S&P 500"], 3: ["January 1, "2008"", "December 31, "2017""], 4: ["outperform a portfolio of funds of hedge funds", "net of fees, "costs and expenses""]}
# RAW: {0: ["In", "an", "will"], 1: [], 2: ["independent, sentient artificial intelligence"], 3: ["2108"], 4: ["exist as a corporation, both providing its services as well as making all financial and strategic decisions"]}
#    ERROR at index 19: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["In", "an", "will"], 1: [], 2: ["independent, "sentient artificial intelligence""], 3: ["2108"], 4: ["exist as a corporation, "both providing its services as well as making all financial and strategic decisions""]}
# RAW: {0: ["will", "report", "a", "of", "in", "than", "in"], 1: ["The U.S Department of Transportation Bureau of Transportation Statistics (www.bts.gov)"], 2: ["total highway vehicle miles traveled"], 3: ["2010", "2005"], 4: ["lower number"]}
#    CLEANED: {0: ['will', 'report', 'a', 'of', 'in', 'than', 'in'], 1: ['The U.S Department of Transportation Bureau of Transportation Statistics (www.bts.gov)'], 2: ['total highway vehicle miles traveled'], 3: ['2010', '2005'], 4: ['lower number']}
# RAW: {0: ["By", "will", "have", "voted", "on"], 1: [], 2: ["the states"], 3: ["2025"], 4: ["at least one constitutional amendment to cede US federal power to a global government"]}
#    CLEANED: {0: ['By', 'will', 'have', 'voted', 'on'], 1: [], 2: ['the states'], 3: ['2025'], 4: ['at least one constitutional amendment to cede US federal power to a global government']}
# RAW: {0: ["will", "make", "in"], 1: ["we"], 2: ["all five areas of the human condition"], 3: ["Over the next ten years"], 4: ["measurable global progress", "food", "access to clean water", "health", "education", "the price of energy"]}
#    CLEANED: {0: ['will', 'make', 'in'], 1: ['we'], 2: ['all five areas of the human condition'], 3: ['Over the next ten years'], 4: ['measurable global progress', 'food', 'access to clean water', 'health', 'education', 'the price of energy']}
# RAW: {0: ["will", "be"], 1: [], 2: ["the total population of humans on earth"], 3: ["By 02060"], 4: ["less than it is today"]}
#    CLEANED: {0: ['will', 'be'], 1: [], 2: ['the total population of humans on earth'], 3: ['By 02060'], 4: ['less than it is today']}
# RAW: {0: ["The","between","and","of","the","per","in","the","will","as","calculated","by","the","in","chained","(inflation-adjusted)"], 1: ["U.S. Departmentof Energy"], 2: ["total retail price","(commercial and residential)","Kilowatthour of electricity","United States"], 3: ["2003","Dec 31 2005"], 4: ["annual average cost","rise","U.S. dollars"]}
#    CLEANED: {0: ['The', 'between', 'and', 'of', 'the', 'per', 'in', 'the', 'will', 'as', 'calculated', 'by', 'the', 'in', 'chained', '(inflation-adjusted)'], 1: ['U.S. Departmentof Energy'], 2: ['total retail price', '(commercial and residential)', 'Kilowatthour of electricity', 'United States'], 3: ['2003', 'Dec 31 2005'], 4: ['annual average cost', 'rise', 'U.S. dollars']}
# RAW: {0: [], 1: [], 2: ["Evidence of extraterrestrial intelligence within the solar system"], 3: [], 4: ["will be confirmed before evidence from several light-years away"]}
#    CLEANED: {0: [], 1: [], 2: ['Evidence of extraterrestrial intelligence within the solar system'], 3: [], 4: ['will be confirmed before evidence from several light-years away']}
# RAW: {0: ["will", "be"], 1: [], 2: ["The first discovery of extraterrestrial life"], 3: [], 4: ["someplace other than on a planet or on a satellite of a planet"]}
#    CLEANED: {0: ['will', 'be'], 1: [], 2: ['The first discovery of extraterrestrial life'], 3: [], 4: ['someplace other than on a planet or on a satellite of a planet']}
# RAW: {0: ["By"], 1: [], 2: ["Nobel Prize"], 3: ["2020"], 4: ["no", "one", "will", "have", "won", "a", "for", "work", "on", "superstring theory", "membrane theory", "or", "some", "other", "unified theory", "describing", "all", "the", "forces of nature"]}
#    CLEANED: {0: ['By'], 1: [], 2: ['Nobel Prize'], 3: ['2020'], 4: ['no', 'one', 'will', 'have', 'won', 'a', 'for', 'work', 'on', 'superstring theory', 'membrane theory', 'or', 'some', 'other', 'unified theory', 'describing', 'all', 'the', 'forces of nature']}
# RAW: {0: ["A", "will", "lead", "to", "in", "a", "single", "event", "within", "a", "six", "month", "period", "starting", "no", "later", "than"], 1: [], 2: ["bioterror or bioerror"], 3: ["Dec 31 02020"], 4: ["one million casualties"]}
#    CLEANED: {0: ['A', 'will', 'lead', 'to', 'in', 'a', 'single', 'event', 'within', 'a', 'six', 'month', 'period', 'starting', 'no', 'later', 'than'], 1: [], 2: ['bioterror or bioerror'], 3: ['Dec 31 02020'], 4: ['one million casualties']}
# RAW: {0: ["The", "will", "before", "the", "the", "the"], 1: [], 2: ["US men's soccer team", "Red Sox"], 3: [], 4: ["win the World Cup", "win the World Series"]}
#    CLEANED: {0: ['The', 'will', 'before', 'the', 'the', 'the'], 1: [], 2: ["US men's soccer team", 'Red Sox'], 3: [], 4: ['win the World Cup', 'win the World Series']}
# RAW: {0: ["will", "eventually"], 1: [], 2: ["The universe"], 3: [], 4: ["stop expanding"]}
#    CLEANED: {0: ['will', 'eventually'], 1: [], 2: ['The universe'], 3: [], 4: ['stop expanding']}
# RAW: {0: ["By", "and", "will", "have", "referred", "to", "as", "or", "words", "to", "that", "effect"], 1: ["the Wall Street Journal", "the New York Times"], 2: ["Russia"], 3: ["2012"], 4: ["the world leader in software development"]}
#    CLEANED: {0: ['By', 'and', 'will', 'have', 'referred', 'to', 'as', 'or', 'words', 'to', 'that', 'effect'], 1: ['the Wall Street Journal', 'the New York Times'], 2: ['Russia'], 3: ['2012'], 4: ['the world leader in software development']}
# RAW: {0: ["will", "routinely"], 1: [], 2: ["commercial passengers"], 3: ["By 2030"], 4: ["fly in pilotless planes"]}
#    CLEANED: {0: ['will', 'routinely'], 1: [], 2: ['commercial passengers'], 3: ['By 2030'], 4: ['fly in pilotless planes']}
# RAW: {0: ["A", "profitable", "aimed", "at", "consumers", "will", "offer", "by"], 1: [], 2: ["video-on-demand service"], 3: ["2010"], 4: ["10,000 titles", "5 million subscribers"]}
#    ERROR at index 33: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["A", "profitable", "aimed", "at", "consumers", "will", "offer", "by"], 1: [], 2: ["video-on-demand service"], 3: ["2010"], 4: ["10, "000 titles"", "5 million subscribers"]}
# RAW: {0: ["In", "a", "Google search", "of", "five keywords or phrases", "representing", "the top five news stories", "of"], 1: [], 2: ["weblogs", "the New York Times' Web site"], 3: ["2007"], 4: ["will rank higher than"]}
#    CLEANED: {0: ['In', 'a', 'Google search', 'of', 'five keywords or phrases', 'representing', 'the top five news stories', 'of'], 1: [], 2: ['weblogs', "the New York Times' Web site"], 3: ['2007'], 4: ['will rank higher than']}
# RAW: {
#   "0": ["By", "or", "will", "have", "the"],
#   "1": [],
#   "2": ["computer", "machine intelligence"],
#   "3": ["2029"],
#   "4": ["no", "passed the Turing Test"]
# }
#    CLEANED: {0: ['By', 'or', 'will', 'have', 'the'], 1: [], 2: ['computer', 'machine intelligence'], 3: ['2029'], 4: ['no', 'passed the Turing Test']}
# RAW: {0: ["by"], 1: [], 2: ["World", "peace"], 3: ["October", "30", "2150"], 4: []}
#    CLEANED: {0: ['by'], 1: [], 2: ['World', 'peace'], 3: ['October', '30', '2150'], 4: []}
# RAW: {0: [], 1: [], 2: ["The market share of new electric light duty vehicles (per the US EIA definition) sold in the US"], 3: ["by the end of 2030"], 4: ["will exceed 17% (>17% EV + PHEV market share)"]}
#    CLEANED: {0: [], 1: [], 2: ['The market share of new electric light duty vehicles (per the US EIA definition) sold in the US'], 3: ['by the end of 2030'], 4: ['will exceed 17% (>17% EV + PHEV market share)']}
# RAW: {0: ["there", "will", "be", "demonstrating"], 1: [], 2: ["archaeological discoveries"], 3: ["By 2043"], 4: ["equal or greater architectural advancement to the monuments at Göbekli Tepe", "dating from before 11,000 BC"]}
#    ERROR at index 38: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["there", "will", "be", "demonstrating"], 1: [], 2: ["archaeological discoveries"], 3: ["By 2043"], 4: ["equal or greater architectural advancement to the monuments at Göbekli Tepe", "dating from before 11, "000 BC""]}
# RAW: {0: ["It", "will", "come", "to", "light", "that", "the", "has", "of", "a", "of"], 1: [], 2: ["United States Federal Government"], 3: [], 4: ["control of a significant portion of Bitcoin"]}
#    CLEANED: {0: ['It', 'will', 'come', 'to', 'light', 'that', 'the', 'has', 'of', 'a', 'of'], 1: [], 2: ['United States Federal Government'], 3: [], 4: ['control of a significant portion of Bitcoin']}
# RAW: {0: ["Before", "will", "be", "through", "AI", "/", "machine", "learning", "process."], 1: [], 2: ["a text on the NY Times Bestsellers list"], 3: ["Jan 1 2028"], 4: ["generated"]}
#    CLEANED: {0: ['Before', 'will', 'be', 'through', 'AI', '/', 'machine', 'learning', 'process.'], 1: [], 2: ['a text on the NY Times Bestsellers list'], 3: ['Jan 1 2028'], 4: ['generated']}
# RAW: {0: ["may", "be", "with"], 1: [], 2: ["Authorship"], 3: [], 4: ["through a pen-name", "non-human authorship revealed", "after listing is achieved"]}
#    CLEANED: {0: ['may', 'be', 'with'], 1: [], 2: ['Authorship'], 3: [], 4: ['through a pen-name', 'non-human authorship revealed', 'after listing is achieved']}
# RAW: {0: ["there", "will", "be", "in", "a", "G7", "county", "against", "the", "switching", "off", "of", "a", "on", "the", "grounds", "that", "it", "is", "sentient", "and", "has", "a", "right", "to", "live."], 1: [], 2: ["machine or software program"], 3: ["by 2035"], 4: ["at least one public protest of more than 100 people"]}
#    CLEANED: {0: ['there', 'will', 'be', 'in', 'a', 'G7', 'county', 'against', 'the', 'switching', 'off', 'of', 'a', 'on', 'the', 'grounds', 'that', 'it', 'is', 'sentient', 'and', 'has', 'a', 'right', 'to', 'live.'], 1: [], 2: ['machine or software program'], 3: ['by 2035'], 4: ['at least one public protest of more than 100 people']}
# RAW: {
#   "0": ["will", "BEFORE"],
#   "1": ["Poland"],
#   "2": ["Germany"],
#   "3": [],
#   "4": ["synchronize its first nuclear power plant", "exits coal power"]
# }
#    CLEANED: {0: ['will', 'BEFORE'], 1: ['Poland'], 2: ['Germany'], 3: [], 4: ['synchronize its first nuclear power plant', 'exits coal power']}
# RAW: {0: [], 1: [], 2: ["Humanity"], 3: [], 4: ["will encounter super intelligent fully cybernetic extraterrestrial species before encountering super intelligent biological species"]}
#    CLEANED: {0: [], 1: [], 2: ['Humanity'], 3: [], 4: ['will encounter super intelligent fully cybernetic extraterrestrial species before encountering super intelligent biological species']}
# RAW: {0: ["will", "be", "for", "his", "actions", "at", "FTX/Alameda"], 1: [], 2: ["Sam Bankman-Fried"], 3: [], 4: ["charged with a crime"]}
#    CLEANED: {0: ['will', 'be', 'for', 'his', 'actions', 'at', 'FTX/Alameda'], 1: [], 2: ['Sam Bankman-Fried'], 3: [], 4: ['charged with a crime']}
# RAW: {0: [], 1: [], 2: ["The NEOM THE LINE building"], 3: [], 4: ["will not be completed as currently envisaged"]}
#    CLEANED: {0: [], 1: [], 2: ['The NEOM THE LINE building'], 3: [], 4: ['will not be completed as currently envisaged']}
# RAW: {
#   "0": ["of", "that", "is,", "a", "signal", "that", "is", "unambiguously", "non-natural", "and", "does", "not", "originate", "from", "Earth", "within"],
#   "1": ["The SETI Institute"],
#   "2": ["a signal from an extraterrestrial civilization"],
#   "3": ["the next 20 years"],
#   "4": ["will not announce the detection"]
# }
#    CLEANED: {0: ['of', 'that', 'is, ', 'a', 'signal', 'that', 'is', 'unambiguously', 'non-natural', 'and', 'does', 'not', 'originate', 'from', 'Earth', 'within'], 1: ['The SETI Institute'], 2: ['a signal from an extraterrestrial civilization'], 3: ['the next 20 years'], 4: ['will not announce the detection']}
# RAW: {0: ["From", "to", "the", "will"], 1: [], 2: ["Alphabet stock"], 3: ["August 25, 2022", "last trading day of August 2032"], 4: ["outperform Fundsmith hedge fund"]}
#    ERROR at index 48: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["From", "to", "the", "will"], 1: [], 2: ["Alphabet stock"], 3: ["August 25, "2022"", "last trading day of August 2032"], 4: ["outperform Fundsmith hedge fund"]}
# RAW: {0: ["The", "will", "report", "in", "for"], 1: ["US Bureau of Labor Statistics"], 2: ["the transport and warehousing sector"], 3: ["July 2030"], 4: ["more than 4,951,360 jobs"]}
#    ERROR at index 49: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["The", "will", "report", "in", "for"], 1: ["US Bureau of Labor Statistics"], 2: ["the transport and warehousing sector"], 3: ["July 2030"], 4: ["more than 4, "951", "360 jobs""]}
# RAW: {0: ["In", "Australia", "will"], 1: [], 2: ["rooftop solar and distributed storage"], 3: [], 4: ["power our cities during heat waves", "no longer reliant on the grid during these periods"]}
#    CLEANED: {0: ['In', 'Australia', 'will'], 1: [], 2: ['rooftop solar and distributed storage'], 3: [], 4: ['power our cities during heat waves', 'no longer reliant on the grid during these periods']}
# RAW: {0: ["In", "Australia", "have", "and", "the", "whole", "will", "be", "and", "to"], 1: ["we"], 2: [], 3: [], 4: ["way more distributed energy", "different consumption patterns", "very different", "much closer to people"]}
#    CLEANED: {0: ['In', 'Australia', 'have', 'and', 'the', 'whole', 'will', 'be', 'and', 'to'], 1: ['we'], 2: [], 3: [], 4: ['way more distributed energy', 'different consumption patterns', 'very different', 'much closer to people']}
# RAW: {0: ["will", "be", "shipping", "and", "it’ll", "be"], 1: ["Australia"], 2: ["FutureFeed"], 3: [], 4: ["the world’s most popular way of reducing agricultural emissions", "becoming a major export industry for Australia", "contribute to world’s climate emissions"]}
#    CLEANED: {0: ['will', 'be', 'shipping', 'and', 'it’ll', 'be'], 1: ['Australia'], 2: ['FutureFeed'], 3: [], 4: ['the world’s most popular way of reducing agricultural emissions', 'becoming a major export industry for Australia', 'contribute to world’s climate emissions']}
# RAW: {0: ["By", "the", "we’ll", "have", "an", "combing", "AC", "and", "DC", "to"], 1: [], 2: ["overlaid grid system"], 3: ["early 2030s"], 4: ["interoperability and reliability"]}
#    CLEANED: {0: ['By', 'the', 'we’ll', 'have', 'an', 'combing', 'AC', 'and', 'DC', 'to'], 1: [], 2: ['overlaid grid system'], 3: ['early 2030s'], 4: ['interoperability and reliability']}
# RAW: {0: ["of", "will", "implement"], 1: [], 2: ["states with Roe v. Wade anti-abortion trigger bans"], 3: ["within 3 years"], 4: ["Fewer that 25%", "any meaningful improvements for child-related care or support"]}
#    CLEANED: {0: ['of', 'will', 'implement'], 1: [], 2: ['states with Roe v. Wade anti-abortion trigger bans'], 3: ['within 3 years'], 4: ['Fewer that 25%', 'any meaningful improvements for child-related care or support']}
# RAW: {
#   "0": ["as", "soon", "as", "reputable", "data", "(World Bank", "IEA", "BP", "etc)", "for", "are"],
#   "1": [],
#   "2": ["End date"],
#   "3": ["2030"],
#   "4": ["available"]
# }
#    CLEANED: {0: ['as', 'soon', 'as', 'reputable', 'data', '(World Bank', 'IEA', 'BP', 'etc)', 'for', 'are'], 1: [], 2: ['End date'], 3: ['2030'], 4: ['available']}
# RAW: {0: [], 1: [], 2: ["a mathematician"], 3: ["By 2080"], 4: ["win the Fields Medal before the age of 22, thus becoming the first undergraduate winner of the Fields Medal"]}
#    ERROR at index 56: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: [], 1: [], 2: ["a mathematician"], 3: ["By 2080"], 4: ["win the Fields Medal before the age of 22, "thus becoming the first undergraduate winner of the Fields Medal""]}
# RAW: {0: ["The", "or", "by", "everywhere", "in", "the", "US."], 1: [], 2: ["manufacturing of new internal combustion engine automobiles"], 3: ["some specified date in the future"], 4: ["will be illegal", "there will be a law requiring that their manufacture cease"]}
#    CLEANED: {0: ['The', 'or', 'by', 'everywhere', 'in', 'the', 'US.'], 1: [], 2: ['manufacturing of new internal combustion engine automobiles'], 3: ['some specified date in the future'], 4: ['will be illegal', 'there will be a law requiring that their manufacture cease']}
# RAW: {0: ["which","according","to","a","majority","of","astrobiologists","is","convincing","evidence","of","life","intelligence","or","technology","satisfying","the","same","requirement"], 1: ["Humans"], 2: ["features of an exoplanet or other object >1 light-year away","electromagnetic signal"], 3: [], 4: ["will not find features of an exoplanet or other object >1 light-year away","nor will we detect any other electromagnetic signal"]}
#    CLEANED: {0: ['which', 'according', 'to', 'a', 'majority', 'of', 'astrobiologists', 'is', 'convincing', 'evidence', 'of', 'life', 'intelligence', 'or', 'technology', 'satisfying', 'the', 'same', 'requirement'], 1: ['Humans'], 2: ['features of an exoplanet or other object >1 light-year away', 'electromagnetic signal'], 3: [], 4: ['will not find features of an exoplanet or other object >1 light-year away', 'nor will we detect any other electromagnetic signal']}
# RAW: {0: ["of"], 1: ["The Department of Defense"], 2: ["objects in Earth's atmosphere"], 3: [], 4: ["will not publicly release unambiguous evidence, recorded from multiple sensors, exhibiting >20G acceleration, OR >100km/h subsurface travel, OR anti-gravity, OR FTL/nonlocal translation, OR extraterrestrial intelligence"]}
#    ERROR at index 59: Unable to parse input as Python literal: invalid decimal literal (<unknown>, line 1)
# Processed text: {0: ["of"], 1: ["The Department of Defense"], 2: ["objects in Earth's atmosphere"], 3: [], 4: ["will not publicly release unambiguous evidence, "recorded from multiple sensors", "exhibiting >20G acceleration", "OR >100km/h subsurface travel", "OR anti-gravity", "OR FTL/nonlocal translation", "OR extraterrestrial intelligence""]}
# RAW: {0: ["The", "will", "of", "the", "and", "may", "even", "of", "the", "latter"], 1: ["International Criminal Court"], 2: ["Security Council"], 3: [], 4: ["become totally independent", "gain the ability to override the vetoes"]}
#    CLEANED: {0: ['The', 'will', 'of', 'the', 'and', 'may', 'even', 'of', 'the', 'latter'], 1: ['International Criminal Court'], 2: ['Security Council'], 3: [], 4: ['become totally independent', 'gain the ability to override the vetoes']}
# RAW: {0: [], 1: [], 2: ["Major League Baseball"], 3: ["By 2030"], 4: ["will use computers/technology to call balls and strikes rather than human umpires"]}
#    CLEANED: {0: [], 1: [], 2: ['Major League Baseball'], 3: ['By 2030'], 4: ['will use computers/technology to call balls and strikes rather than human umpires']}
# RAW: {0: ["as", "described", "in", "by", "in", "the", "article", "below", "will", "have", "by", "as", "an", "inevitable", "consequence", "of", "markets", "viewing", "people", "as", "a", "resource."], 1: ["Yuan Yi Zhu", "The Spectator"], 2: ["Canada's terrifying state-sponsored euthanasia program"], 3: ["the end of 2035"], 4: ["spread to become policy in at least 4 of the G20"]}
#    CLEANED: {0: ['as', 'described', 'in', 'by', 'in', 'the', 'article', 'below', 'will', 'have', 'by', 'as', 'an', 'inevitable', 'consequence', 'of', 'markets', 'viewing', 'people', 'as', 'a', 'resource.'], 1: ['Yuan Yi Zhu', 'The Spectator'], 2: ["Canada's terrifying state-sponsored euthanasia program"], 3: ['the end of 2035'], 4: ['spread to become policy in at least 4 of the G20']}
# RAW: {0: ["will"], 1: [], 2: ["decentralized autonomous organizations (DAOs) and other digitally-constituted organizations"], 3: ["By 2032"], 4: ["organize more assets and production than traditional, legally-constituted corporations in the United States"]}
#    ERROR at index 63: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["will"], 1: [], 2: ["decentralized autonomous organizations (DAOs) and other digitally-constituted organizations"], 3: ["By 2032"], 4: ["organize more assets and production than traditional, "legally-constituted corporations in the United States""]}
# RAW: {0: ["the", "of", "the"], 1: [], 2: ["resource war"], 3: ["middle 21st century"], 4: ["Oil will not be"]}
#    CLEANED: {0: ['the', 'of', 'the'], 1: [], 2: ['resource war'], 3: ['middle 21st century'], 4: ['Oil will not be']}
# RAW: {0: ["predict", "will", "be", "fought", "over"], 1: ["I"], 2: ["war"], 3: ["by the end of the 2020’s and into the 2030’s"], 4: ["the rarest and most sacred resource to life: Water."]}
#    CLEANED: {0: ['predict', 'will', 'be', 'fought', 'over'], 1: ['I'], 2: ['war'], 3: ['by the end of the 2020’s and into the 2030’s'], 4: ['the rarest and most sacred resource to life: Water.']}
# RAW: {0: ["sent", "by", "will", "have"], 1: ["SpaceX"], 2: ["humans"], 3: ["By the end of 2036"], 4: ["landed and walked on the surface of Mars"]}
#    CLEANED: {0: ['sent', 'by', 'will', 'have'], 1: ['SpaceX'], 2: ['humans'], 3: ['By the end of 2036'], 4: ['landed and walked on the surface of Mars']}
# RAW: {0: ["or", "or"], 1: [], 2: ["TerraUSD (UST)", "UST"], 3: ["Within 10 years from now"], 4: ["free markets for the stablecoin will no longer exist", "more than 10 billion will have been traded below 0.90 USD", "will be backed by USD"]}
#    CLEANED: {0: ['or', 'or'], 1: [], 2: ['TerraUSD (UST)', 'UST'], 3: ['Within 10 years from now'], 4: ['free markets for the stablecoin will no longer exist', 'more than 10 billion will have been traded below 0.90 USD', 'will be backed by USD']}
# RAW: {0: ["By", "there", "will", "be"], 1: [], 2: ["1990s 'classic' movies"], 3: ["the year 2030"], 4: ["successful", "re-produced", "or", "remastered", "versions", "of", "which", "replace", "main", "characters", "with", "Meme Characters", "or", "amusing", "replacements", "of", "the", "original", "starring", "characters", "such as", "such as", "cats", "other animals", "or", "non-human entities"]}
#    CLEANED: {0: ['By', 'there', 'will', 'be'], 1: [], 2: ["1990s 'classic' movies"], 3: ['the year 2030'], 4: ['successful', 're-produced', 'or', 'remastered', 'versions', 'of', 'which', 'replace', 'main', 'characters', 'with', 'Meme Characters', 'or', 'amusing', 'replacements', 'of', 'the', 'original', 'starring', 'characters', 'such as', 'such as', 'cats', 'other animals', 'or', 'non-human entities']}
# RAW: {0: ["will", "be"], 1: [], 2: ["autonomous vehicles"], 3: ["In five years' time", "December 31, 02026"], 4: ["banned from public roadways"]}
#    ERROR at index 69: Unable to parse input as Python literal: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 1)
# Processed text: {0: ["will", "be"], 1: [], 2: ["autonomous vehicles"], 3: ["In five years' time", "December 31, "02026""], 4: ["banned from public roadways"]}
# RAW: {0: ["will", "be", "to", "operate", "on", "on", "which", "will", "be"], 1: ["They"], 2: ["completely automated roadways", "non-autonomous vehicles"], 3: [], 4: ["legal", "no", "allowed"]}
#    CLEANED: {0: ['will', 'be', 'to', 'operate', 'on', 'on', 'which', 'will', 'be'], 1: ['They'], 2: ['completely automated roadways', 'non-autonomous vehicles'], 3: [], 4: ['legal', 'no', 'allowed']}
# RAW: {0: ["specifically", "and", "will be", "rather than"], 1: [], 2: ["essential enterprise software", "MS Office for business", "Avid Pro Tools for film"], 3: ["In five years' time", "by December 31, 2026"], 4: ["metered in seconds", "distributed in a sales or monthly subscription model"]}
#    ERROR at index 71: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["specifically", "and", "will be", "rather than"], 1: [], 2: ["essential enterprise software", "MS Office for business", "Avid Pro Tools for film"], 3: ["In five years' time", "by December 31, "2026""], 4: ["metered in seconds", "distributed in a sales or monthly subscription model"]}
# RAW: {0: ["will", "cover"], 1: [], 2: ["plains of the USA", "Steppe and East land forms of Russia", "southern Africa", "South America"], 3: [], 4: ["Perminant ice up to 2 feet deep"]}
#    CLEANED: {0: ['will', 'cover'], 1: [], 2: ['plains of the USA', 'Steppe and East land forms of Russia', 'southern Africa', 'South America'], 3: [], 4: ['Perminant ice up to 2 feet deep']}
# RAW: {
#   "0": ["will", "be", "and", "will"],
#   "1": [],
#   "2": ["Life expectancy for the elderly", "entry restrictions for bars and restaurants"],
#   "3": [],
#   "4": ["higher", "cease"]
# }
#    CLEANED: {0: ['will', 'be', 'and', 'will'], 1: [], 2: ['Life expectancy for the elderly', 'entry restrictions for bars and restaurants'], 3: [], 4: ['higher', 'cease']}
# RAW: {0: ["Over", "a", "ten-year", "period", "commencing", "on", "and", "ending", "on", "the"], 1: [], 2: ["S&P 500", "Bitcoin"], 3: ["January 1, 2022", "December 31, 2031"], 4: ["will outperform"]}
#    ERROR at index 74: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["Over", "a", "ten-year", "period", "commencing", "on", "and", "ending", "on", "the"], 1: [], 2: ["S&P 500", "Bitcoin"], 3: ["January 1, "2022"", "December 31, "2031""], 4: ["will outperform"]}
# RAW: {0: ["The", "emissions", "intensity", "of", "will", "before", "without", "the", "help", "of", "nuclear", "energy."], 1: [], 2: ["Australia's National Electricity Market"], 3: ["30 June 2041"], 4: ["fall below 60 kgCO₂e/MWh"]}
#    CLEANED: {0: ['The', 'emissions', 'intensity', 'of', 'will', 'before', 'without', 'the', 'help', 'of', 'nuclear', 'energy.'], 1: [], 2: ["Australia's National Electricity Market"], 3: ['30 June 2041'], 4: ['fall below 60 kgCO₂e/MWh']}
# RAW: {0: ["on", "will", "be", "worth", "of"], 1: [], 2: ["one bitcoin"], 3: ["Ten years from now", "September 15th, 2031"], 4: ["more than 0.05 troy ounces of gold"]}
#    ERROR at index 76: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["on", "will", "be", "worth", "of"], 1: [], 2: ["one bitcoin"], 3: ["Ten years from now", "September 15th, "2031""], 4: ["more than 0.05 troy ounces of gold"]}
# RAW: {0: ["will", "be"], 1: [], 2: ["a 100MW fusion plant"], 3: ["By 2046"], 4: ["in operation and selling electricity to the grid"]}
#    CLEANED: {0: ['will', 'be'], 1: [], 2: ['a 100MW fusion plant'], 3: ['By 2046'], 4: ['in operation and selling electricity to the grid']}
# RAW: {0: ["The", "will", "in", "the"], 1: [], 2: ["solar system"], 3: ["next 989 years"], 4: ["not be converted to a giant Matrioshka brain"]}
#    CLEANED: {0: ['The', 'will', 'in', 'the'], 1: [], 2: ['solar system'], 3: ['next 989 years'], 4: ['not be converted to a giant Matrioshka brain']}
# RAW: {0: ["as", "by"], 1: ["Donald Trump"], 2: ["president of the United States"], 3: ["January 1, 02024"], 4: ["will not be reinstated"]}
#    ERROR at index 79: Unable to parse input as Python literal: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 1)
# Processed text: {0: ["as", "by"], 1: ["Donald Trump"], 2: ["president of the United States"], 3: ["January 1, "02024""], 4: ["will not be reinstated"]}
# RAW: {0: ["in", "some", "country", "with", "a", "population", "at", "least", "as", "large", "as", "the", "Netherlands", "of", "will", "be"], 1: [], 2: ["new homes under construction"], 3: ["Within 15 years"], 4: ["at least 10%", "built by 3-D printing", "probably of concrete"]}
#    CLEANED: {0: ['in', 'some', 'country', 'with', 'a', 'population', 'at', 'least', 'as', 'large', 'as', 'the', 'Netherlands', 'of', 'will', 'be'], 1: [], 2: ['new homes under construction'], 3: ['Within 15 years'], 4: ['at least 10%', 'built by 3-D printing', 'probably of concrete']}
# RAW: {0: ["will", "and"], 1: ["the Chinese Communist Party (CCP)"], 2: ["a nation in the Western Hemisphere"], 3: ["By 2031"], 4: ["establish a long term military presence", "with elements of the People’s Liberation Arm (PLA)", "specifically between longitude 30W and 135W"]}
#    CLEANED: {0: ['will', 'and'], 1: ['the Chinese Communist Party (CCP)'], 2: ['a nation in the Western Hemisphere'], 3: ['By 2031'], 4: ['establish a long term military presence', 'with elements of the People’s Liberation Arm (PLA)', 'specifically between longitude 30W and 135W']}
# RAW: {0: [], 1: ["A top Shakespearean editor or scholar"], 2: ["Sir Thomas North"], 3: [], 4: ["reasonable candidate for authorship of at least one of Shakespeare’s source plays (including \"Arden of Faversham.\")"]}
#    CLEANED: {0: [], 1: ['A top Shakespearean editor or scholar'], 2: ['Sir Thomas North'], 3: [], 4: ['reasonable candidate for authorship of at least one of Shakespeare’s source plays (including "Arden of Faversham.")']}
# RAW: {0: ["will","be","using","wherein","the","content","is","store","on","servers","or","other","storage","that","the","user","owns,","with","the","network","merely","aggregating","the","content","and","providing","a","feed."], 1: [], 2: ["social networks"], 3: ["By 2030"], 4: ["more than 10 million people"]}
#    CLEANED: {0: ['will', 'be', 'using', 'wherein', 'the', 'content', 'is', 'store', 'on', 'servers', 'or', 'other', 'storage', 'that', 'the', 'user', 'owns, ', 'with', 'the', 'network', 'merely', 'aggregating', 'the', 'content', 'and', 'providing', 'a', 'feed.'], 1: [], 2: ['social networks'], 3: ['By 2030'], 4: ['more than 10 million people']}
# RAW: {0: ["By", "the", "as", "quoted", "in", "the", "Wall", "Street", "Journal", "will", "be"], 1: [], 2: ["price of Bitcoin"], 3: ["January first, 2024"], 4: ["below 2500 USD"]}
#    ERROR at index 84: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["By", "the", "as", "quoted", "in", "the", "Wall", "Street", "Journal", "will", "be"], 1: [], 2: ["price of Bitcoin"], 3: ["January first, "2024""], 4: ["below 2500 USD"]}
# RAW: {0: ["By", "a", "by", "in the South of Nigeria", "such that", "and"], 1: [], 2: ["land rights of Southern Nigerians", "Fulani people"], 3: ["1 March 2023"], 4: ["territorial coup will be attempted", "land rights of Southern Nigerians will be overwhelmed", "the Fulani people will look to settle in the area"]}
#    CLEANED: {0: ['By', 'a', 'by', 'in the South of Nigeria', 'such that', 'and'], 1: [], 2: ['land rights of Southern Nigerians', 'Fulani people'], 3: ['1 March 2023'], 4: ['territorial coup will be attempted', 'land rights of Southern Nigerians will be overwhelmed', 'the Fulani people will look to settle in the area']}
# RAW: {0: ["there", "will", "be"], 1: [], 2: ["mRNA-based mAbs", "protein-based mAbs"], 3: ["At the end of 2030"], 4: ["more", "in clinical trials", "than those of"]}
#    CLEANED: {0: ['there', 'will', 'be'], 1: [], 2: ['mRNA-based mAbs', 'protein-based mAbs'], 3: ['At the end of 2030'], 4: ['more', 'in clinical trials', 'than those of']}
# RAW: {0: [], 1: [], 2: ["De Broglie-Bohm pilot-wave theory"], 3: [], 4: ["will overtake the Copenhagen Interpretation of quantum mechanics as the theory most accepted by physicists"]}
#    CLEANED: {0: [], 1: [], 2: ['De Broglie-Bohm pilot-wave theory'], 3: [], 4: ['will overtake the Copenhagen Interpretation of quantum mechanics as the theory most accepted by physicists']}
# RAW: {0: [], 1: [], 2: ["the last coal-powered station based on current technology"], 3: ["no later than 2035"], 4: ["will close in Australia"]}
#    CLEANED: {0: [], 1: [], 2: ['the last coal-powered station based on current technology'], 3: ['no later than 2035'], 4: ['will close in Australia']}
# RAW: {
#   "0": ["there", "will", "be"],
#   "1": [],
#   "2": ["human"],
#   "3": ["By the end of 02035"],
#   "4": ["at least one human living on Earth who has walked on Mars"]
# }
#    CLEANED: {0: ['there', 'will', 'be'], 1: [], 2: ['human'], 3: ['By the end of 02035'], 4: ['at least one human living on Earth who has walked on Mars']}
# RAW: {0: ["of", "will", "be"], 1: [], 2: ["the UK adult population"], 3: ["By 2030"], 4: ["half", "vegan"]}
#    CLEANED: {0: ['of', 'will', 'be'], 1: [], 2: ['the UK adult population'], 3: ['By 2030'], 4: ['half', 'vegan']}
# RAW: {"0": [], "1": [], "2": ["electricity"], "3": ["By the end of 2035"], "4": ["more", "will be generated", "globally", "from", "wind and solar power combined", "than", "from", "coal"]}
#    CLEANED: {0: [], 1: [], 2: ['electricity'], 3: ['By the end of 2035'], 4: ['more', 'will be generated', 'globally', 'from', 'wind and solar power combined', 'than', 'from', 'coal']}
# RAW: {
#   "0": ["Over", "the", "two", "decades", "to", "will", "be"],
#   "1": [],
#   "2": ["the total quantity of CO₂ captured and sequestered from every coal power station on the planet"],
#   "3": ["2040"],
#   "4": ["less than that emitted from Australia's Eraring power station"]
# }
#    CLEANED: {0: ['Over', 'the', 'two', 'decades', 'to', 'will', 'be'], 1: [], 2: ['the total quantity of CO₂ captured and sequestered from every coal power station on the planet'], 3: ['2040'], 4: ["less than that emitted from Australia's Eraring power station"]}
# RAW: {"0": ["will", "contribute", "through"], "1": [], "2": ["Fossil gas power generation"], "3": ["the 2020s"], "4": ["less than 10% of power generated in Australia’s National Electricity Market on average"]}
#    CLEANED: {0: ['will', 'contribute', 'through'], 1: [], 2: ['Fossil gas power generation'], 3: ['the 2020s'], 4: ['less than 10% of power generated in Australia’s National Electricity Market on average']}
# RAW: {0: [], 1: [], 2: ["coal-fired power stations"], 3: ["between 2010 and 2030"], 4: ["No", "will be built", "in Australia's main grids"]}
#    CLEANED: {0: [], 1: [], 2: ['coal-fired power stations'], 3: ['between 2010 and 2030'], 4: ['No', 'will be built', "in Australia's main grids"]}
# RAW: {0: ["Nuclear", "power", "will", "provide", "of", "the", "power", "in", "in", "every", "year", "to"], 1: [], 2: ["Australia’s National Electricity Market"], 3: ["2040"], 4: ["0%", "(rounded to the nearest whole number)"]}
#    CLEANED: {0: ['Nuclear', 'power', 'will', 'provide', 'of', 'the', 'power', 'in', 'in', 'every', 'year', 'to'], 1: [], 2: ['Australia’s National Electricity Market'], 3: ['2040'], 4: ['0%', '(rounded to the nearest whole number)']}
# RAW: {0: ["The","first","female","president","of","the","United States","assumes","the","office","by","succeession","due","to","circumstances","directly","caused","by","a","global pandemic"], 1: [], 2: [], 3: [], 4: []}
#    CLEANED: {0: ['The', 'first', 'female', 'president', 'of', 'the', 'United States', 'assumes', 'the', 'office', 'by', 'succeession', 'due', 'to', 'circumstances', 'directly', 'caused', 'by', 'a', 'global pandemic'], 1: [], 2: [], 3: [], 4: []}
# RAW: {0: [], 1: [], 2: ["us dollor"], 3: ["By 2030"], 4: ["will loose it's value as globally accepted currency and the most powerfull currency in the world"]}
#    CLEANED: {0: [], 1: [], 2: ['us dollor'], 3: ['By 2030'], 4: ["will loose it's value as globally accepted currency and the most powerfull currency in the world"]}
# RAW: {0: ["will", "have", "argued", "that", "was"], 1: ["multiple major media outlets"], 2: ["the worldwide response to COVID-19"], 3: ["By the end of 2025"], 4: ["the most expensive overreaction in human history", "or words to that effect"]}
#    CLEANED: {0: ['will', 'have', 'argued', 'that', 'was'], 1: ['multiple major media outlets'], 2: ['the worldwide response to COVID-19'], 3: ['By the end of 2025'], 4: ['the most expensive overreaction in human history', 'or words to that effect']}
# RAW: {0: ["If", "the", "will", "be", "a", "democrat", "and/or", "a", "female,", "the"], 1: [], 2: ["next president of the USA"], 3: [], 4: ["US's anual GPD growth", "major Wall Street share indices (Dow Jones, NASDAQ comp.)"]}
#    ERROR at index 99: Unable to parse input as Python literal: closing parenthesis ')' does not match opening parenthesis '[' (<unknown>, line 1)
# Processed text: {0: ["If", "the", "will", "be", "a", "democrat", "and/or", "a", "female, ", "the"], 1: [], 2: ["next president of the USA"], 3: [], 4: ["US's anual GPD growth", "major Wall Street share indices (Dow Jones, "NASDAQ comp.)""]}
# RAW: {0: ["The", "will", "be"], 1: [], 2: ["total Australian infected population from the COVID-19 virus"], 3: [], 4: ["less than 1% of the population"]}
#    CLEANED: {0: ['The', 'will', 'be'], 1: [], 2: ['total Australian infected population from the COVID-19 virus'], 3: [], 4: ['less than 1% of the population']}
# RAW: {0: ["as", "the", "by", "will", "rise", "to", "above", "(2", "month", "average)"], 1: ["Integrated Multi-Mission Ocean Altimeter Data"], 2: ["Global Mean Sea Level (GMSL)"], 3: ["By the end of 2030", "January 1, 1993"], 4: ["120 mm"]}
#    ERROR at index 101: Unable to parse input as Python literal: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 1)
# Processed text: {0: ["as", "the", "by", "will", "rise", "to", "above", "(2", "month", "average)"], 1: ["Integrated Multi-Mission Ocean Altimeter Data"], 2: ["Global Mean Sea Level (GMSL)"], 3: ["By the end of 2030", "January 1, "1993""], 4: ["120 mm"]}
#                                    Prediction Sentence  \
# 0    By January 1st, 2037, Tesla will have been the...
# 1    Private Nonfarm business productivity growth w...
# 2    No Republican will be President of the USA bef...
# 3    The market capitalization of Berkshire Hathawa...
# 4    Over a ten-year period commencing on July 1, 2...
# ..                                                 ...
# 97   By 2030 us dollor will loose it's value as glo...
# 98   By the end of 2025, multiple major media outle...
# 99   If the next president of the USA will be a dem...
# 100  The total Australian infected population from ...
# 101  By the end of 2030, Global Mean Sea Level (GMS...
#
#                                           Raw Response           Model Name  \
# 0    {0: ["By", "will", "have", "been", "with", "th...  openai/gpt-oss-120b
# 1    {0: ["will", "average", "from", "the", "to", "...  openai/gpt-oss-120b
# 2    {0: ["before"], 1: [], 2: ["Republican"], 3: [...  openai/gpt-oss-120b
# 3    {0: ["The", "of", "will", "be", "on"], 1: [], ...  openai/gpt-oss-120b
# 4    {0: ["Over", "ten-year", "period", "commencing...  openai/gpt-oss-120b
# ..                                                 ...                  ...
# 97   {0: [], 1: [], 2: ["us dollor"], 3: ["By 2030"...  openai/gpt-oss-120b
# 98   {0: ["will", "have", "argued", "that", "was"],...  openai/gpt-oss-120b
# 99   {0: ["If", "the", "will", "be", "a", "democrat...  openai/gpt-oss-120b
# 100  {0: ["The", "will", "be"], 1: [], 2: ["total A...  openai/gpt-oss-120b
# 101  {0: ["as", "the", "by", "will", "rise", "to", ...  openai/gpt-oss-120b
#
#                            No Property                        Source  \
# 0
# 1    will, average, from, the, to, the
# 2
# 3                The, of, will, be, on
# 4
# ..                                 ...                           ...
# 97
# 98       will, have, argued, that, was  multiple major media outlets
# 99
# 100                      The, will, be
# 101
#
#                                                 Target  \
# 0
# 1         Private Nonfarm business productivity growth
# 2
# 3                                   Berkshire Hathaway
# 4
# ..                                                 ...
# 97                                           us dollor
# 98                  the worldwide response to COVID-19
# 99
# 100  total Australian infected population from the ...
# 101
#
#                                                   Date  \
# 0
# 1    first quarter (Q1) of 2020, last quarter of 20...
# 2
# 3                      Warren Buffett's 100th birthday
# 4
# ..                                                 ...
# 97                                             By 2030
# 98                                  By the end of 2025
# 99
# 100
# 101
#
#                                                Outcome
# 0
# 1                            over 1.8 percent per year
# 2
# 3            market capitalization, greater than Tesla
# 4
# ..                                                 ...
# 97   will loose it's value as globally accepted cur...
# 98   the most expensive overreaction in human histo...
# 99
# 100                     less than 1% of the population
# 101
#
# [102 rows x 8 columns]

# %%
extract_prediction_properties_path = "extract_prediction_properties/"
extract_prediction_properties_full_path = os.path.join(base_data_path, extract_prediction_properties_path)
DataProcessing.save_to_file(results_df, extract_prediction_properties_full_path, 'extracted_pps', 'csv')

# %% [markdown]
# > `notebook_experiments/load_vector_store.ipynb` because we want to use the properties extracted to search the vector store.
#
# or
#
# > `notebook_experiments/entity_resolution-source_target.ipynb` because we want to see predictions by source.
