# %% [markdown]
# # Load Vector Store

# %%
import os
import sys
import pprint

import pandas as pd

from tqdm import tqdm

notebook_dir = os.getcwd()

sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing
from prediction_properties import PredictionProperties
from text_generation_models import TextGenerationModelFactory
from vector_stores import ChromaVectorStore, VectorStoreDirector

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_columns', 40)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Load Data

# %%
base_data_path = os.path.join(notebook_dir, '../data')
extract_prediction_properties_path =  os.path.join(base_data_path, "extract_prediction_properties/extracted_pps-v1.csv")
df = DataProcessing.load_from_file(extract_prediction_properties_path, 'csv', sep=',')
df.head(3)
# Out:
#                                                                                         Prediction Sentence  \
# 0            Professor Thompson forecasts that the graduation rate at Harvard University will drop in 2027.
# 1                   Economist Dr. Sarah Lee predicts on 12/31/2027, the consumer confidence index may rise.
# 2  According to a fitness expert, the nutritional intake at community centers would fall in 21 August 2024.
#
#                                                                                                                                                   Raw Response  \
# 0  {0: ["forecasts", "that", "the", "graduation", "rate", "at", "will", "in"], 1: ["Professor Thompson"], 2: ["Harvard University"], 3: ["2027"], 4: ["drop"]}
# 1                         {0: ["predicts", "on", "the"], 1: ["Economist Dr. Sarah Lee"], 2: ["consumer confidence index"], 3: ["12/31/2027"], 4: ["may rise"]}
# 2  {0: ["According", "to", "a", "the", "in"], 1: ["fitness expert"], 2: ["nutritional intake at community centers"], 3: ["21 August 2024"], 4: ["would fall"]}
#
#             Model Name                                           No Property  \
# 0  openai/gpt-oss-120b  forecasts, that, the, graduation, rate, at, will, in
# 1  openai/gpt-oss-120b                                     predicts, on, the
# 2  openai/gpt-oss-120b                             According, to, a, the, in
#
#                     Source                                   Target  \
# 0       Professor Thompson                       Harvard University
# 1  Economist Dr. Sarah Lee                consumer confidence index
# 2           fitness expert  nutritional intake at community centers
#
#              Date     Outcome
# 0            2027        drop
# 1      12/31/2027    may rise
# 2  21 August 2024  would fall

# %% [markdown]
# ## Load Vector Store

# %%
collection_name = "prediction_collection-synthetic_data-oberservations"
persist_directory = "../data/chroma/chroma_langchain_db-oberservations"

chroma_loader = ChromaVectorStore(collection_name, persist_directory, 'Prediction Sentence')

chroma_director = VectorStoreDirector(loader=chroma_loader)
embedding_model_name = "Hugging Face"

k = 33

# query_results = []

query_results = []
for idx, row in df.iterrows():
    target = row['Target']
    date = row['Date']
    outcome = row['Outcome']

    query_string = f"{target} {date} {outcome}"

    query_result = chroma_director.query(embedding_model_name, query_string, k, query_search_type="similarity_with_score")
    query_results.append(query_result)

df['Collection Name'] = collection_name
df['Persist Directory'] = persist_directory        
df['Query Results'] = query_results
# Out:
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store: None
# 	Docments: []
# 	UUIDS: None
# 	Embedding Model: None
# ### LOADER ###
# 	<vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x32365e290>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Harvard University decreased.', 'metadata': {'Template Number': 5, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-8b-instruct', 'Domain': 'miscellaneous', 'Batch ID': 0}, 'score': 0.8186123371124268}, {'page_content': 'In Aug 21, 2024, Professor Michael Davis envisioned that the graduation rates at Harvard University decreased.', 'metadata': {'Sentence Label': 0, 'Template Number': 5, 'Batch ID': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-8b-instruct', 'Domain': 'miscellaneous'}, 'score': 0.8256052732467651}, {'page_content': 'According to Professor Alice Lee, the graduation rate at Harvard University rose in June 2022.', 'metadata': {'Template Number': 4, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Domain': 'miscellaneous'}, 'score': 0.8973295092582703}, {'page_content': 'According to Professor Katherine Lee, the average GPA at Harvard University rose in 2022.', 'metadata': {'Template Number': 4, 'Model Name': 'gemma2-9b-it', 'Domain': 'miscellaneous', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0}, 'score': 0.948418140411377}, {'page_content': 'In 2029 of Q3, Professor Michael Brown envisioned that the graduation rates at Stanford University decreased.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'miscellaneous', 'Sentence Label': 0, 'Template Number': 5, 'Batch ID': 0}, 'score': 0.9905002117156982}, {'page_content': 'In 2024, Professor James Wilson envisioned that the graduation rates at the University decreased.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Template Number': 5, 'Domain': 'miscellaneous', 'Sentence Label': 0}, 'score': 1.0291132926940918}, {'page_content': 'In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Stanford University decreased.', 'metadata': {'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Template Number': 5, 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'miscellaneous'}, 'score': 1.043150544166565}, {'page_content': 'College student, Emily Patel, noted on January 10, 2023, the price of textbooks at the campus bookstore fell.', 'metadata': {'Template Number': 3, 'Batch ID': 0, 'API Name': 'NAVI_GATOR', 'Domain': 'miscellaneous', 'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-instruct'}, 'score': 1.081827998161316}, {'page_content': 'Professor John Taylor noted that the average grade at Harvard University stayed stable in 2024/08/21.', 'metadata': {'Domain': 'miscellaneous', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Template Number': 1, 'Model Name': 'llama-3.1-8b-instant', 'Sentence Label': 0}, 'score': 1.082491159439087}, {'page_content': ' Professor Michael Rodriguez noted on 10/15/2022, the student enrollment at the University of California, Berkeley fell.', 'metadata': {'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD', 'Template Number': 3, 'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'miscellaneous'}, 'score': 1.090216875076294}, {'page_content': 'On 12/15/2022,  Professor David Chen monitored the average GPA at Stanford University changed slightly.', 'metadata': {'Domain': 'miscellaneous', 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0}, 'score': 1.0912716388702393}, {'page_content': 'Professor David Thompson observed that the student engagement at Harvard University declined in 2021.', 'metadata': {'Sentence Label': 0, 'Template Number': 1, 'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Domain': 'miscellaneous'}, 'score': 1.1066615581512451}, {'page_content': 'In 2029 of Q3, Professor Kim envisioned that the test scores at MIT decreased.', 'metadata': {'Sentence Label': 0, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'T ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x325e73210>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'On 11/10/2022, a market researcher at Global Trends observed that the consumer confidence index in the retail sector had shifted.', 'metadata': {'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-small-3.1', 'Batch ID': 0, 'Domain': 'miscellaneous', 'Sentence Label': 0, 'Template Number': 2}, 'score': 0.6180521249771118}, {'page_content': 'In 2027, the National Institute of Economic Research envisioned that consumer confidence decreased.', 'metadata': {'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Domain': 'policy', 'Template Number': 5, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.82148277759552}, {'page_content': 'The Cato Institute noted on 03/15/2028, the consumer price index fell.', 'metadata': {'Template Number': 3, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Domain': 'policy', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0}, 'score': 0.9042105674743652}, {'page_content': 'In 09/2026,  a financial advisor envisioned that the inflation rate at the US economy decreased.', 'metadata': {'Domain': 'finance', 'Batch ID': 0, 'Template Number': 5, 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0}, 'score': 0.9419630765914917}, {'page_content': 'According to the Federal Reserve, the inflation rate in the US rose in Q2 2024.', 'metadata': {'Domain': 'policy', 'Sentence Label': 0, 'Batch ID': 0, 'Template Number': 4, 'API Name': 'NAVI_GATOR', 'Model Name': 'mixtral-8x7b-instruct'}, 'score': 0.9491791725158691}, {'page_content': 'In June 2027,  a financial researcher envisioned that the inflation rate at the Federal Reserve decreased.', 'metadata': {'Template Number': 5, 'Batch ID': 0, 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'finance'}, 'score': 1.015419602394104}, {'page_content': 'According to the National Bureau of Economic Research, the inflation rate in the United States rose in Q4 2035.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Domain': 'policy', 'Template Number': 4, 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Sentence Label': 0}, 'score': 1.0169988870620728}, {'page_content': 'The Cato Institute noted on 11/15/2029, the inflation rate fell.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Template Number': 3, 'Batch ID': 0, 'Model Name': 'gemma2-9b-it', 'Domain': 'policy'}, 'score': 1.0403579473495483}, {'page_content': 'On 2027-03-10, the Congressional Research Service saw that the unemployment rate in the Midwest had risen.', 'metadata': {'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Template Number': 2, 'Model Name': 'mistral-small-3.1', 'Domain': 'policy', 'Batch ID': 0}, 'score': 1.0415297746658325}, {'page_content': 'According to research advisor, Dr. Michael Brown, the economic growth rate at the European Union rose in Q4 of 2027.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Model Name': 'mistral-7b-instruct', 'Domain': 'policy', 'API Name': 'NAVI_GATOR', 'Template Number': 4}, 'score': 1.0434008836746216}, {'page_content': 'The probability of a recession in 2025 increased on 02/10/2024, according to Economist Michael Brown.', 'metadata': {'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Template Number': 6, 'Domain': 'miscellaneous', 'Sentence Label': 0, 'Model Name': 'llama-3.1-70b-instruct'}, 'score': 1.0566869974136353}, {'page_content': 'The stock price of Apple increased in  2025, according to my records.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Template Number': 6, 'Domain': 'finance', 'Batch ID': 0}, 'score': 1.0574573278427124}, {'page_content': 'According to policy expert, Mr. David Kim, the GDP growth rate in the European Union rose from Q1 2024 to Q3 2024.', 'metadata': {'Model Name': 'mistral-7b-instruct', 'Sentence Label': 0, 'Batch ID': 0, 'Template Number': 4, 'Domain': 'policy', 'API Name': 'NAVI_GATOR'}, 'score': 1.0621278285980225}, {'page_content': 'According to the financial expert,  ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x33639cd10>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'Dr. Linda Green noted on 03/20/2021, the nutritional intake at local schools fell.', 'metadata': {'Template Number': 3, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Domain': 'health', 'Model Name': 'mistral-small-3.1', 'Batch ID': 0}, 'score': 0.6335760354995728}, {'page_content': 'On 11th of October 2025, the World Health Organization monitored the obesity rates at rural high schools changed.', 'metadata': {'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-versatile', 'Domain': 'health', 'API Name': 'GROQ_CLOUD', 'Template Number': 2, 'Batch ID': 0}, 'score': 0.7807698249816895}, {'page_content': 'On November 15, 2023, a health researcher monitored that the average body mass index at rural high schools changed.', 'metadata': {'Domain': 'health', 'Template Number': 2, 'Batch ID': 0, 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Model Name': 'llama-3.3-70b-versatile'}, 'score': 0.7816278338432312}, {'page_content': 'On 1st January 2026, the Centers for Disease Control and Prevention (CDC) monitored the obesity rates in urban areas changed.', 'metadata': {'Batch ID': 0, 'Domain': 'health', 'Model Name': 'mistral-7b-instruct', 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Template Number': 2}, 'score': 0.8096867799758911}, {'page_content': 'In the summer of 2027, I envisioned that the rate of childhood obesity would decrease in urban areas.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'Template Number': 5, 'Domain': 'health', 'Batch ID': 0}, 'score': 0.8660836815834045}, {'page_content': ' The average daily intake of fruits and vegetables increased in my patients in 2029, according to my records.', 'metadata': {'Template Number': 6, 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'health'}, 'score': 0.8675913214683533}, {'page_content': 'In the fourth quarter of 2029, Professor Patel envisioned that the daily caloric intake at college cafeterias decreased.', 'metadata': {'Domain': 'health', 'Model Name': 'llama-3.3-70b-versatile', 'Template Number': 5, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Batch ID': 0}, 'score': 0.868924081325531}, {'page_content': 'On 11th of October 2021, Dr. Rachel Kim monitored that the obesity rates at rural high schools changed.', 'metadata': {'Batch ID': 0, 'Model Name': 'llama-3.3-70b-instruct', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Template Number': 2, 'Domain': 'health'}, 'score': 0.8732768893241882}, {'page_content': 'On November 15, 2021, a health researcher speculated the obesity rates at rural high schools changed.', 'metadata': {'Model Name': 'llama-3.3-70b-instruct', 'Template Number': 2, 'Sentence Label': 0, 'Domain': 'health', 'API Name': 'NAVI_GATOR', 'Batch ID': 0}, 'score': 0.8825192451477051}, {'page_content': 'In Q2 2026, Dr. Patel envisioned that the average body mass index at community centers decreased.', 'metadata': {'Template Number': 5, 'Batch ID': 0, 'Model Name': 'llama-3.1-70b-instruct', 'Domain': 'health', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0}, 'score': 0.9149683713912964}, {'page_content': 'According to a study published in the Journal of Nutrition, the sugar intake at elementary schools rose in the summer of 2025.', 'metadata': {'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-instruct', 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Template Number': 4, 'Domain': 'health'}, 'score': 0.9198614358901978}, {'page_content': 'On 2/10/2029, the World Health Organization monitored the obesity rates at urban schools changed.', 'metadata': {'Sentence Label': 0, 'Domain': 'health', 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant'}, 'score': 0.9284657835960388}, {'page_content': 'According to a study conducted by the National Institutes of Health, the daily caloric intake at national restaurants rose in Summer 2026.', 'metadata': {'Model Name': 'l ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x325e1ac50>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'On 11th of October 2021, the World Health Organization monitored the obesity rates at European schools and found that they changed.', 'metadata': {'Sentence Label': 0, 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Domain': 'health', 'Model Name': 'llama-3.3-70b-versatile', 'Batch ID': 0}, 'score': 0.7683005332946777}, {'page_content': ' The average daily intake of fruits and vegetables increased in my patients in 2029, according to my records.', 'metadata': {'Domain': 'health', 'Template Number': 6, 'Sentence Label': 0, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it'}, 'score': 0.8005875945091248}, {'page_content': 'On 11th of October 2025, the World Health Organization monitored the obesity rates at rural high schools changed.', 'metadata': {'Model Name': 'llama-3.3-70b-versatile', 'Domain': 'health', 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Sentence Label': 0}, 'score': 0.8637548089027405}, {'page_content': 'The World Health Organization observed that the obesity rates in Europe remained stable from 2022 to 2023.', 'metadata': {'Template Number': 1, 'Batch ID': 0, 'Model Name': 'gemma2-9b-it', 'Domain': 'health', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.8857685327529907}, {'page_content': 'On 1st January 2026, the Centers for Disease Control and Prevention (CDC) monitored the obesity rates in urban areas changed.', 'metadata': {'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-7b-instruct', 'Batch ID': 0, 'Domain': 'health', 'Template Number': 2}, 'score': 0.8940501809120178}, {'page_content': 'On 1st January 2026, Dr. Amelia Johnson speculated that the rate of obesity among adults in the United States changed.', 'metadata': {'Template Number': 2, 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'health', 'Model Name': 'mistral-7b-instruct'}, 'score': 0.9623705148696899}, {'page_content': 'According to a study conducted by the National Institutes of Health, the daily caloric intake at national restaurants rose in Summer 2026.', 'metadata': {'Domain': 'health', 'Batch ID': 0, 'Template Number': 4, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-versatile'}, 'score': 0.9650564193725586}, {'page_content': 'The World Health Organization (WHO) observed that the prevalence of malnutrition in children under five years old in developing countries had remained stable from 2022 to 2023.', 'metadata': {'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-7b-instruct', 'Template Number': 1, 'Batch ID': 0, 'Domain': 'health'}, 'score': 0.9882672429084778}, {'page_content': 'On 2/10/2029, the World Health Organization monitored the obesity rates at urban schools changed.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Domain': 'health', 'Template Number': 2}, 'score': 1.000977635383606}, {'page_content': 'The World Health Organization (WHO) observed that the prevalence of malnutrition among children in developing countries had remained stable from 2025 to 2027.', 'metadata': {'Domain': 'health', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Model Name': 'mistral-7b-instruct', 'Template Number': 1, 'Batch ID': 0}, 'score': 1.0088319778442383}, {'page_content': 'On 11/15/2029, the World Health Organization monitored that the obesity rates at urban schools changed.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Domain': 'health', 'Model Name': 'llama-3.1-8b-instant'}, 'score': 1.0153595209121704}, {'page_content': 'On November 15, 2023, a health researcher monitored that the average body mass index at rural high schools changed.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Domain': 'health', 'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-versatile', 'Template Number': 2}, 'score': 1.034978985786 ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x325e344d0>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'According to Senior Level Person Michael Johnson, the win ratio at the Boston Celtics increased in April 2029.', 'metadata': {'API Name': 'NAVI_GATOR', 'Template Number': 4, 'Domain': 'sport', 'Sentence Label': 0, 'Batch ID': 0, 'Model Name': 'mistral-7b-instruct'}, 'score': 0.3874684274196625}, {'page_content': 'According to sport top executive Mr. James Chen, the win-loss ratio at the Golden State Warriors rose in February 2030.', 'metadata': {'Batch ID': 0, 'Domain': 'sport', 'Sentence Label': 0, 'Template Number': 4, 'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-7b-instruct'}, 'score': 0.7598183155059814}, {'page_content': 'According to the Boston Celtics staff, the three-point percentage at the Boston Celtics rose in August 21, 2024.', 'metadata': {'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD', 'Template Number': 4, 'Batch ID': 0, 'Domain': 'sport'}, 'score': 0.763615608215332}, {'page_content': 'The head coach of the Chicago Bulls noted on 11 August 2024, the field goal percentage at the Boston Celtics fell.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD', 'Template Number': 3, 'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'sport'}, 'score': 0.7754503488540649}, {'page_content': 'The free throw percentage at the Boston Celtics surged in August 2024, according to Analyst Michael Brown.', 'metadata': {'API Name': 'NAVI_GATOR', 'Domain': 'sport', 'Model Name': 'llama-3.1-8b-instruct', 'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 6}, 'score': 0.7902271747589111}, {'page_content': 'On 02/28/2022, the sports department at ESPN monitored the win ratio at the Los Angeles Lakers changed.', 'metadata': {'Sentence Label': 0, 'Template Number': 2, 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'sport', 'API Name': 'GROQ_CLOUD'}, 'score': 0.863966703414917}, {'page_content': 'According to Coach Ashley Thomas, the rebounds per game at the Phoenix Suns rose in January 2024.', 'metadata': {'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'sport', 'Model Name': 'gemma2-9b-it', 'Template Number': 4, 'API Name': 'GROQ_CLOUD'}, 'score': 0.8826194405555725}, {'page_content': 'In November 2023, Coach Lee envisioned that the win-loss ratio at the Toronto Raptors decreased.', 'metadata': {'Domain': 'sport', 'Model Name': 'llama-3.1-8b-instant', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Template Number': 5, 'Sentence Label': 0}, 'score': 0.8972041606903076}, {'page_content': 'Coach Thompson observed that the goal differential at the Chicago Bulls rose on August 12, 2024.', 'metadata': {'Sentence Label': 0, 'Template Number': 1, 'Domain': 'sport', 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD'}, 'score': 0.9241891503334045}, {'page_content': "In 2022, the sports senior level person envisioned that the Cleveland Cavaliers' field goal percentage decreased.", 'metadata': {'Sentence Label': 0, 'Template Number': 5, 'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-small-3.1', 'Batch ID': 0, 'Domain': 'sport'}, 'score': 0.9259344339370728}, {'page_content': 'According to Coach Sophia Jackson, the points per game at the  Toronto Raptors rose in June 2025.', 'metadata': {'Batch ID': 0, 'Template Number': 4, 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'sport'}, 'score': 0.928827166557312}, {'page_content': 'According to Coach Emily Chen, the assists per game at the Dallas Mavericks rose in April 2025.', 'metadata': {'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Template Number': 4, 'Domain': 'sport', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.9324055314064026}, {'page_content': 'Analyst Brown noted on August 12, 2024, the rebound rate at the Golden State Warriors fell.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Template Number': 3, 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant', 'Domain': ' ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x336391a50>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': "In June 2024, Analyst Emily Patel envisioned that the New England Patriots' sack count decreased.", 'metadata': {'Domain': 'sport', 'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-versatile', 'API Name': 'GROQ_CLOUD', 'Template Number': 5, 'Batch ID': 0}, 'score': 0.7087209224700928}, {'page_content': 'In 2023-05-15, the sports senior level person observed that the interception rate at the New England Patriots stayed stable.', 'metadata': {'Domain': 'sport', 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 5, 'Model Name': 'mistral-small-3.1'}, 'score': 0.7831196784973145}, {'page_content': 'The passing yards at the New England Patriots increased in the second half of 2023, according to NFL commentator, Bob Johnson.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'sport', 'Template Number': 6, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.3-70b-instruct'}, 'score': 0.7832923531532288}, {'page_content': "In the 2023 offseason, Analyst Kevin White envisioned that the New England Patriots' sack count decreased.", 'metadata': {'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-70b-instruct', 'Domain': 'sport', 'Batch ID': 0, 'Template Number': 5}, 'score': 0.8064156770706177}, {'page_content': 'Analyst Emily Chen noted on 10/15/2021, the passing yards at the New England Patriots fell.', 'metadata': {'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.3-70b-instruct', 'Batch ID': 0, 'Domain': 'sport', 'Template Number': 3, 'Sentence Label': 0}, 'score': 0.8570224046707153}, {'page_content': 'According to Coach Jessica Lee, the points per game at the Los Angeles Rams rose in September 2024.', 'metadata': {'Batch ID': 0, 'Template Number': 4, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Domain': 'sport'}, 'score': 0.8724832534790039}, {'page_content': "The sports expert noted on 23/09/2022, the New England Patriots' interception rate fell.", 'metadata': {'API Name': 'NAVI_GATOR', 'Domain': 'sport', 'Model Name': 'mistral-small-3.1', 'Template Number': 3, 'Batch ID': 0, 'Sentence Label': 0}, 'score': 0.8780556917190552}, {'page_content': 'On 08/21/2024, sport expert Dr. Maria Rodriguez speculated the passing accuracy at the New England Patriots changed.', 'metadata': {'Batch ID': 0, 'Template Number': 2, 'Model Name': 'mistral-7b-instruct', 'Domain': 'sport', 'Sentence Label': 0, 'API Name': 'NAVI_GATOR'}, 'score': 0.9779831767082214}, {'page_content': 'According to the New York Giants staff, the rushing yards at the New York Giants rose Q3 of 2027.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'Template Number': 4, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Domain': 'sport', 'Batch ID': 0}, 'score': 0.9836668968200684}, {'page_content': 'According to the New York Giants staff, the rushing yards at the New York Giants rose in Q2 of 2028.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'sport', 'Template Number': 4, 'API Name': 'GROQ_CLOUD'}, 'score': 0.9878088235855103}, {'page_content': 'According to Coach James Davis, the passing yards at the Kansas City Chiefs rose in November 2023.', 'metadata': {'Domain': 'sport', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Model Name': 'llama-3.3-70b-versatile', 'Template Number': 4, 'Sentence Label': 0}, 'score': 1.0082144737243652}, {'page_content': 'According to Coach James Davis, the passing yards at the Kansas City Chiefs rose in November 2023.', 'metadata': {'Domain': 'sport', 'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 4, 'API Name': 'GROQ_CLOUD', 'Model Name': 'llama-3.3-70b-versatile'}, 'score': 1.0082144737243652}, {'page_content': 'According to Coach James Davis, the passing yards at the Kansas City Chiefs rose in November 2023.', 'metadata': {'Domain': 'sport', 'Sentence Label': 0, 'Template Number': 4, 'API Name': 'GROQ_CLOUD', 'Model Name': 'llama-3.3- ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x325eca010>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'The National Weather Service observed that the precipitation in New Orleans remained stable on 08/21/2024.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 1, 'Model Name': 'gemma2-9b-it', 'Domain': 'weather', 'API Name': 'GROQ_CLOUD'}, 'score': 0.5475893020629883}, {'page_content': 'According to the AccuWeather Center, the humidity at New Orleans rose on 08/21/2024.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Domain': 'weather', 'Batch ID': 0, 'Model Name': 'gemma2-9b-it', 'Template Number': 4}, 'score': 0.64069002866745}, {'page_content': 'On 2023-09-01, the chief meteorologist at the Weather Channel speculated that the precipitation levels in Miami changed.', 'metadata': {'Domain': 'weather', 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instruct', 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Template Number': 2}, 'score': 0.7798252105712891}, {'page_content': 'Meteorologist Emily Chen recorded that on 2023-09-01, the dew point in Miami decreased.', 'metadata': {'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'weather', 'Model Name': 'llama-3.1-8b-instant', 'Template Number': 3, 'API Name': 'GROQ_CLOUD'}, 'score': 0.818125307559967}, {'page_content': 'On 2023-09-15, Dr. Sophia Rodriguez speculated the precipitation levels at Miami changed.', 'metadata': {'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-70b-instruct', 'Batch ID': 0, 'Template Number': 2, 'Domain': 'weather', 'Sentence Label': 0}, 'score': 0.8301566243171692}, {'page_content': 'In 2024/08/21, Meteorologist Michael Lee envisioned that the cloud coverage in Atlanta decreased.', 'metadata': {'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Domain': 'weather', 'Sentence Label': 0, 'Template Number': 5, 'API Name': 'GROQ_CLOUD'}, 'score': 0.8501477837562561}, {'page_content': 'In 01/25/2024, the National Oceanic and Atmospheric Administration envisioned that the wind speed in Houston decreased.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Domain': 'weather', 'Template Number': 5, 'Model Name': 'mistral-small-3.1'}, 'score': 0.8599548935890198}, {'page_content': 'Dr. Maria Rodriguez noted that on 21 Aug 2024, the dew point at the coastal city decreased.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Template Number': 3, 'Model Name': 'llama-3.1-8b-instant', 'Batch ID': 0, 'Domain': 'weather', 'Sentence Label': 0}, 'score': 0.8687002062797546}, {'page_content': 'In 03/10/2024, Meteorologist Sarah Jones envisioned that the cloud coverage in Atlanta decreased.', 'metadata': {'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'weather', 'Model Name': 'gemma2-9b-it', 'Template Number': 5, 'API Name': 'GROQ_CLOUD'}, 'score': 0.8693659901618958}, {'page_content': 'According to the Weather Channel, the precipitation levels at New York rose in the spring of 2024.', 'metadata': {'Domain': 'weather', 'Model Name': 'llama-3.3-70b-versatile', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 4}, 'score': 0.8790585994720459}, {'page_content': 'On August 25, 2023, Dr. Maria Rodriguez, a research scientist, monitored the precipitation levels in Miami changed.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'Domain': 'weather', 'Batch ID': 0, 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0}, 'score': 0.87946617603302}, {'page_content': 'Dr. Emily Chen noted on November 15, 2022, the precipitation levels at Seattle fell.', 'metadata': {'Domain': 'weather', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-versatile', 'Template Number': 3}, 'score': 0.8845924139022827}, {'page_content': 'On 2023-10-12, Dr. Sophia Rodriguez monitored the precipitation levels at Seattle changed.', 'metadata': {'Domain': 'weather', 'Batch ID': 0, 'Model Name': 'llama-3.1-70b-instruct', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Template Number': 2}, 'score': 0.895664393901825}, {'page ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x38916fd50>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'According to the staff of the Los Angeles Lakers, the three-point percentage at the Los Angeles Lakers improved in November 2023.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Domain': 'sport', 'Batch ID': 0, 'Template Number': 4, 'Model Name': 'llama-3.1-8b-instant', 'Sentence Label': 0}, 'score': 0.558181881904602}, {'page_content': 'In Q2 of 2028, sport senior level person Ms. Emily Kim envisioned that the points per game at the Los Angeles Lakers decreased.', 'metadata': {'Template Number': 5, 'API Name': 'NAVI_GATOR', 'Domain': 'sport', 'Sentence Label': 0, 'Model Name': 'mistral-7b-instruct', 'Batch ID': 0}, 'score': 0.6247925758361816}, {'page_content': 'In June 2023, Analyst David Lee envisioned that the  assists at the Dallas Mavericks decreased.', 'metadata': {'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Domain': 'sport', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Template Number': 5}, 'score': 0.7333909273147583}, {'page_content': 'According to the Los Angeles Lakers staff, the field goal percentage at the Los Angeles Lakers rose in Q3 of 2027.', 'metadata': {'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-8b-instruct', 'Batch ID': 0, 'Domain': 'sport', 'Template Number': 4}, 'score': 0.7572981119155884}, {'page_content': 'Analyst Rodriguez noted on Q3 of 2027, the free throw percentage at the Los Angeles Lakers fell.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Template Number': 3, 'Sentence Label': 0, 'Domain': 'sport'}, 'score': 0.7654181122779846}, {'page_content': 'According to Analyst David Lee, the points per game at the Los Angeles Lakers rose on 08/21/2024.', 'metadata': {'Domain': 'sport', 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Template Number': 4, 'API Name': 'GROQ_CLOUD'}, 'score': 0.7663582563400269}, {'page_content': 'The rebounds per game at the Los Angeles Lakers increased in July 2024, according to Coach Carlos Garcia.', 'metadata': {'Template Number': 6, 'Domain': 'sport', 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Sentence Label': 0}, 'score': 0.7942725419998169}, {'page_content': 'On 2024-08-21, the team manager of the Golden State Warriors monitored the three-point percentage at the Los Angeles Lakers changed.', 'metadata': {'Model Name': 'llama-3.1-8b-instant', 'Sentence Label': 0, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Template Number': 2, 'Domain': 'sport'}, 'score': 0.7998838424682617}, {'page_content': 'According to Coach Michael Brown, the rebounding margin at the Los Angeles Lakers rose in the 2022-2023 season.', 'metadata': {'Template Number': 4, 'Model Name': 'llama-3.1-70b-instruct', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'sport'}, 'score': 0.8000783920288086}, {'page_content': 'In December 2023,  Analyst Emily Carter envisioned that the assists at the Toronto Raptors decreased.', 'metadata': {'Batch ID': 0, 'Domain': 'sport', 'Sentence Label': 0, 'Template Number': 5, 'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD'}, 'score': 0.8305932283401489}, {'page_content': 'According to the Miami Heat staff, the three-point shooting percentage at the Miami Heat improved in January 2025.', 'metadata': {'Template Number': 4, 'Domain': 'sport', 'Batch ID': 0, 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD'}, 'score': 0.8501170873641968}, {'page_content': 'In the fourth quarter of 2022, College basketball coach, James Davis, envisioned that the three-point shooting percentage at the Duke Blue Devils decreased.', 'metadata': {'Model Name': 'llama-3.3-70b-instruct', 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Template Number': 5, 'Domain': 'sport', 'Batch ID': 0}, 'score': 0.8571140766143799}, {'page_content': 'The free throw percentage at the Los Angeles Lakers increased on 2024-08-21, according to Analyst Hall.', 'metadata': { ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x38917b690>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'Amazon stock price increased 2024/08/21, according to Morgan Stanley.', 'metadata': {'Batch ID': 0, 'Domain': 'finance', 'Model Name': 'llama-3.1-8b-instant', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Template Number': 6}, 'score': 0.6294331550598145}, {'page_content': 'In January 2023, miscellaneous analyst, David Hall, envisioned that the stock price of Amazon decreased.', 'metadata': {'API Name': 'NAVI_GATOR', 'Domain': 'miscellaneous', 'Batch ID': 0, 'Template Number': 5, 'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-instruct'}, 'score': 0.6953715682029724}, {'page_content': ' A financial advisor noted on 21 August 2024, the  market value at Amazon fell.', 'metadata': {'Template Number': 3, 'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'finance'}, 'score': 0.7032424211502075}, {'page_content': 'On August 21, 2024, Bloomberg analysts monitored the revenue at Amazon changed.', 'metadata': {'Domain': 'finance', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'Batch ID': 0, 'Template Number': 2, 'API Name': 'GROQ_CLOUD'}, 'score': 0.7564609050750732}, {'page_content': 'Charles Schwab noted on 2024/09/01, the valuation of the market value at Amazon fell.', 'metadata': {'Domain': 'finance', 'Sentence Label': 0, 'Template Number': 3, 'Model Name': 'llama-3.1-8b-instant', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.7637231349945068}, {'page_content': 'During Q1 of 2025, a senior financial advisor, Mark, noted that the stock price at Amazon had fallen.', 'metadata': {'Template Number': 3, 'Model Name': 'mixtral-8x7b-instruct', 'Batch ID': 0, 'Domain': 'finance', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0}, 'score': 0.8092980980873108}, {'page_content': 'On November 20, 2023, to December 31, 2024, Citigroup speculated the research and development expenses at Amazon changed.', 'metadata': {'Model Name': 'llama-3.3-70b-instruct', 'Domain': 'finance', 'Template Number': 2, 'Batch ID': 0, 'API Name': 'NAVI_GATOR', 'Sentence Label': 0}, 'score': 0.8108230233192444}, {'page_content': 'The senior financial expert at BlackRock noted on March 1, 2027, that the stock prices at Amazon had fallen.', 'metadata': {'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'finance', 'Template Number': 3, 'Model Name': 'mistral-7b-instruct'}, 'score': 0.8191474080085754}, {'page_content': 'On 03/12/2023, a financial advisor at Fidelity Investments speculated the net profit at Amazon changed.', 'metadata': {'Batch ID': 0, 'Model Name': 'mistral-small-3.1', 'API Name': 'NAVI_GATOR', 'Domain': 'finance', 'Template Number': 2, 'Sentence Label': 0}, 'score': 0.8386406302452087}, {'page_content': ' Goldman Sachs noted on 08/21/2024, the revenue at Amazon fell.', 'metadata': {'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Template Number': 3, 'Domain': 'finance', 'Sentence Label': 0}, 'score': 0.8410029411315918}, {'page_content': 'On October 1, 2027, the financial expert at Morgan Stanley speculated that the operating cash flow at Amazon had changed.', 'metadata': {'Model Name': 'mistral-7b-instruct', 'Domain': 'finance', 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Template Number': 2}, 'score': 0.8480149507522583}, {'page_content': 'The stock price of Apple increased in  2025, according to my records.', 'metadata': {'Template Number': 6, 'Domain': 'finance', 'Batch ID': 0, 'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0}, 'score': 0.8491129875183105}, {'page_content': 'Apple stock price increased in 21 August 2024, according to My records.', 'metadata': {'Domain': 'finance', 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Template Number': 6, 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instruct'}, 'score': 0.8671242594718933}, {'page_content': 'Morgan Stanley noted that on February 27, 2024, the revenue at Amazon had remained stab ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x3204bcdd0>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'Noticing a positive trend, Jillian, a financial analyst, observed that the net profit at Microsoft had increased in Q2 of 2025.', 'metadata': {'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Model Name': 'mixtral-8x7b-instruct', 'Domain': 'finance', 'Sentence Label': 0, 'Template Number': 1}, 'score': 0.9803633689880371}, {'page_content': 'Noticing a positive trend, Jill, a financial analyst, observed that the net profit at Google had increased in Q2 of 2025.', 'metadata': {'Template Number': 1, 'Batch ID': 0, 'Model Name': 'mixtral-8x7b-instruct', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Domain': 'finance'}, 'score': 1.0384150743484497}, {'page_content': 'On 08/21/2024, Goldman Sachs monitored the net profit at Apple and saw it changed.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Template Number': 2, 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'finance', 'Batch ID': 0}, 'score': 1.0525333881378174}, {'page_content': 'On 12/10/2023, Morgan Stanley monitored the net profit at Google changed.', 'metadata': {'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'finance', 'Batch ID': 0, 'Model Name': 'gemma2-9b-it', 'Template Number': 2}, 'score': 1.056431531906128}, {'page_content': 'On 08/20/2024 to 08/20/2025, Bank of America speculated the operating income at Microsoft changed.', 'metadata': {'Template Number': 2, 'Domain': 'finance', 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Model Name': 'llama-3.1-70b-instruct'}, 'score': 1.0627503395080566}, {'page_content': 'According to a top executive at Berkshire Hathaway, the operating income at Apple rose in 2028.', 'metadata': {'Template Number': 4, 'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-small-3.1', 'Domain': 'finance', 'Sentence Label': 0, 'Batch ID': 0}, 'score': 1.087648868560791}, {'page_content': 'According to Senior Level Person Rachel Lee, the sales revenue for the new product rose in Q3 of 2027.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Template Number': 4, 'Sentence Label': 0, 'Domain': 'miscellaneous', 'Model Name': 'llama-3.1-8b-instant', 'Batch ID': 0}, 'score': 1.0935418605804443}, {'page_content': 'According to the research advisor at Goldman Sachs, the revenue at Apple rose in Q4 2022.', 'metadata': {'API Name': 'NAVI_GATOR', 'Sentence Label': 0, 'Template Number': 4, 'Domain': 'finance', 'Batch ID': 0, 'Model Name': 'mistral-small-3.1'}, 'score': 1.1212575435638428}, {'page_content': 'According to Fidelity, the gross profit at Johnson & Johnson rose in the fourth quarter of 2022.', 'metadata': {'Model Name': 'llama-3.3-70b-versatile', 'Template Number': 4, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'finance', 'Sentence Label': 0}, 'score': 1.1215462684631348}, {'page_content': 'Fidelity observed that the net profit at Tesla had increased in Q2 2024.', 'metadata': {'Template Number': 1, 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instant', 'Batch ID': 0, 'Domain': 'finance', 'API Name': 'GROQ_CLOUD'}, 'score': 1.1278867721557617}, {'page_content': 'On 08/21/2024, Bloomberg analysts monitored the net profit at Amazon changed.', 'metadata': {'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'finance', 'API Name': 'GROQ_CLOUD', 'Template Number': 2, 'Model Name': 'gemma2-9b-it'}, 'score': 1.1348214149475098}, {'page_content': 'On 12/15/2026, a senior analyst at JPMorgan Chase noted that the gross profit at Tesla had increased.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 1, 'Model Name': 'mistral-small-3.1', 'API Name': 'NAVI_GATOR', 'Domain': 'finance'}, 'score': 1.1356481313705444}, {'page_content': 'According to Goldman Sachs, the operating income at Microsoft rose in 2024.', 'metadata': {'Domain': 'finance', 'Template Number': 4, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0}, 'score': 1.139955997467041}, {'page_content': 'On 08/21/2024, Dr. Patel monitored the stock price ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x378b64ed0>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'According to the staff of the Los Angeles Lakers, the three-point percentage at the Los Angeles Lakers improved in November 2023.', 'metadata': {'Template Number': 4, 'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'sport', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.6106356978416443}, {'page_content': 'In Q2 of 2028, sport senior level person Ms. Emily Kim envisioned that the points per game at the Los Angeles Lakers decreased.', 'metadata': {'API Name': 'NAVI_GATOR', 'Domain': 'sport', 'Template Number': 5, 'Batch ID': 0, 'Sentence Label': 0, 'Model Name': 'mistral-7b-instruct'}, 'score': 0.6954994201660156}, {'page_content': 'According to the Los Angeles Lakers staff, the field goal percentage at the Los Angeles Lakers rose in Q3 of 2027.', 'metadata': {'Domain': 'sport', 'Template Number': 4, 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instruct', 'Batch ID': 0, 'API Name': 'NAVI_GATOR'}, 'score': 0.7354840040206909}, {'page_content': 'According to Analyst David Lee, the points per game at the Los Angeles Lakers rose on 08/21/2024.', 'metadata': {'Sentence Label': 0, 'Template Number': 4, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Domain': 'sport'}, 'score': 0.7367368936538696}, {'page_content': 'On 2024-08-21, the team manager of the Golden State Warriors monitored the three-point percentage at the Los Angeles Lakers changed.', 'metadata': {'Sentence Label': 0, 'Domain': 'sport', 'API Name': 'GROQ_CLOUD', 'Model Name': 'llama-3.1-8b-instant', 'Template Number': 2, 'Batch ID': 0}, 'score': 0.8290368318557739}, {'page_content': "In 2022, the sports senior level person envisioned that the Cleveland Cavaliers' field goal percentage decreased.", 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Domain': 'sport', 'Template Number': 5, 'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-small-3.1'}, 'score': 0.8386393189430237}, {'page_content': 'Analyst Rodriguez noted on Q3 of 2027, the free throw percentage at the Los Angeles Lakers fell.', 'metadata': {'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instant', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'sport', 'Template Number': 3}, 'score': 0.8421984910964966}, {'page_content': 'In June 2023, Analyst David Lee envisioned that the  assists at the Dallas Mavericks decreased.', 'metadata': {'Model Name': 'gemma2-9b-it', 'Template Number': 5, 'Domain': 'sport', 'Sentence Label': 0, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.8499449491500854}, {'page_content': 'According to Coach Michael Brown, the rebounding margin at the Los Angeles Lakers rose in the 2022-2023 season.', 'metadata': {'Domain': 'sport', 'Template Number': 4, 'Batch ID': 0, 'Sentence Label': 0, 'Model Name': 'llama-3.1-70b-instruct', 'API Name': 'NAVI_GATOR'}, 'score': 0.8585523366928101}, {'page_content': 'Michael noted on 08/21/2024, the rebounds at the Los Angeles Lakers fell.', 'metadata': {'Batch ID': 0, 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD', 'Template Number': 3, 'Domain': 'sport'}, 'score': 0.8635568618774414}, {'page_content': 'According to Coach Sophia Jackson, the points per game at the  Toronto Raptors rose in June 2025.', 'metadata': {'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'sport', 'Model Name': 'gemma2-9b-it', 'Template Number': 4, 'Sentence Label': 0}, 'score': 0.8640766143798828}, {'page_content': 'The points scored at the Miami Heat dropped in 2022, according to the sports analyst.', 'metadata': {'Domain': 'sport', 'Batch ID': 0, 'Model Name': 'mistral-small-3.1', 'Template Number': 6, 'API Name': 'NAVI_GATOR', 'Sentence Label': 0}, 'score': 0.8716189861297607}, {'page_content': 'According to Coach Ashley Thomas, the rebounds per game at the Phoenix Suns rose in January 2024.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Domain': 'sport', 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Template  ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x342f6cf50>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'A financial expert noted on 07/20/2027, the revenue at Microsoft fell.', 'metadata': {'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Template Number': 3, 'Batch ID': 0, 'Domain': 'finance', 'Model Name': 'mistral-small-3.1'}, 'score': 0.6468356251716614}, {'page_content': 'According to BlackRock, the stock price at Microsoft rose in 05/2027.', 'metadata': {'Template Number': 4, 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'finance', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0}, 'score': 0.6498664617538452}, {'page_content': 'The senior financial advisor at Fidelity Investments noted on 02/25/2023, the stock price at Microsoft fell.', 'metadata': {'Domain': 'finance', 'Template Number': 3, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Model Name': 'mistral-small-3.1'}, 'score': 0.6530086994171143}, {'page_content': 'On Wednesday, August 21, 2024,  a financial reporter noted that the stock prices at  Microsoft changed.', 'metadata': {'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'Batch ID': 0, 'Template Number': 2, 'API Name': 'GROQ_CLOUD', 'Domain': 'finance'}, 'score': 0.6652671098709106}, {'page_content': 'The financial top executive at Apple noted on March 1, 2028, that the stock prices at Microsoft fell.', 'metadata': {'Sentence Label': 0, 'Domain': 'finance', 'Batch ID': 0, 'Template Number': 3, 'Model Name': 'mistral-7b-instruct', 'API Name': 'NAVI_GATOR'}, 'score': 0.6775034666061401}, {'page_content': 'Morgan Stanley noted on 02/27/2026, the gross profit at Microsoft fell.', 'metadata': {'Model Name': 'llama-3.1-70b-instruct', 'Template Number': 3, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Domain': 'finance', 'Batch ID': 0}, 'score': 0.7055325508117676}, {'page_content': ' The stock price at Microsoft increased in 2024/08/21, according to a recent report.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Sentence Label': 0, 'Template Number': 6, 'Model Name': 'gemma2-9b-it', 'Domain': 'finance'}, 'score': 0.7574920654296875}, {'page_content': 'According to top executive, James Davis, the stock price of Microsoft rose in January 2021.', 'metadata': {'Model Name': 'llama-3.3-70b-versatile', 'Sentence Label': 0, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Template Number': 4, 'Domain': 'miscellaneous'}, 'score': 0.7685660123825073}, {'page_content': 'On 08/21/2024, a financial research advisor monitored the stock price at Microsoft and saw it changed.', 'metadata': {'Template Number': 2, 'Model Name': 'mixtral-8x7b-instruct', 'Sentence Label': 0, 'Domain': 'finance', 'Batch ID': 0, 'API Name': 'NAVI_GATOR'}, 'score': 0.7705141305923462}, {'page_content': 'In Q3 of 2029, Fidelity envisioned that the stock prices at Apple decreased.', 'metadata': {'Domain': 'finance', 'Template Number': 5, 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'Sentence Label': 0}, 'score': 0.8023171424865723}, {'page_content': 'On 08/20/2024 to 08/20/2025, Bank of America speculated the operating income at Microsoft changed.', 'metadata': {'Domain': 'finance', 'Template Number': 2, 'API Name': 'NAVI_GATOR', 'Batch ID': 0, 'Model Name': 'llama-3.1-70b-instruct', 'Sentence Label': 0}, 'score': 0.8134462833404541}, {'page_content': "The CEO noted on 03/15/2023, the company's stock price fell.", 'metadata': {'Batch ID': 0, 'Template Number': 3, 'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'API Name': 'GROQ_CLOUD', 'Domain': 'miscellaneous'}, 'score': 0.8181343078613281}, {'page_content': 'Barclays observed that on October 25, 2024, the net profit at Microsoft fell substantially.', 'metadata': {'Model Name': 'llama-3.3-70b-instruct', 'API Name': 'NAVI_GATOR', 'Template Number': 3, 'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'finance'}, 'score': 0.8312422037124634}, {'page_content': 'According to Bloomberg, the market capitalization at Microsoft rose in Q4 2025.', 'metadata': {'Template Number': 4, 'Sentence L ...
# ### INITIALIZE CLIENT VECTOR STORE ###
# 	Vector Store (Prediction's Wrapper): None
# ### LOAD EMBEDDING MODEL ###
# 	Hugging Face
# ### LOAD VECTOR STORE ###
# 	Collection Name: prediction_collection-synthetic_data-oberservations
# 	Embedding Model: model_name='sentence-transformers/all-mpnet-base-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False
# 	Persist Directory: ../data/chroma/chroma_langchain_db-oberservations
# 	Vector Store (Original): <langchain_chroma.vectorstores.Chroma object at 0x325ec9390>
# 	Vector Store (Prediction's Wrapper): <vector_stores.ChromaVectorStore object at 0x160dbf2d0>
# 	Documents (D) 1112
# ### TOP K ###
# 	2. Similarity with score
# 	Query Results: {'similarity_with_score': [{'page_content': 'In Q4 2019, Chase analysts envisioned that the inflation rate at the US Federal Reserve decreased.', 'metadata': {'Template Number': 5, 'Batch ID': 0, 'Domain': 'finance', 'Sentence Label': 0, 'Model Name': 'llama-3.1-8b-instant', 'API Name': 'GROQ_CLOUD'}, 'score': 0.8874274492263794}, {'page_content': 'In June 2027,  a financial researcher envisioned that the inflation rate at the Federal Reserve decreased.', 'metadata': {'Domain': 'finance', 'Template Number': 5, 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Model Name': 'gemma2-9b-it'}, 'score': 0.9156528115272522}, {'page_content': ' In 2029 of Q3,  a financial researcher envisioned that the interest rates at the Federal Reserve decreased.', 'metadata': {'Domain': 'finance', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Template Number': 5, 'Model Name': 'gemma2-9b-it'}, 'score': 0.9433630108833313}, {'page_content': 'On 2024-08-21, Goldman Sachs speculated the interest rates at the Federal Reserve changed.', 'metadata': {'Batch ID': 0, 'Model Name': 'llama-3.1-8b-instruct', 'Template Number': 2, 'Domain': 'finance', 'API Name': 'NAVI_GATOR', 'Sentence Label': 0}, 'score': 0.969262957572937}, {'page_content': 'In Q4 2018, BlackRock envisioned that the inflation rate at the Federal Reserve decreased.', 'metadata': {'Template Number': 5, 'API Name': 'GROQ_CLOUD', 'Sentence Label': 0, 'Batch ID': 0, 'Domain': 'finance', 'Model Name': 'llama-3.1-8b-instant'}, 'score': 0.9751884937286377}, {'page_content': 'In 09/2026,  a financial advisor envisioned that the inflation rate at the US economy decreased.', 'metadata': {'Domain': 'finance', 'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'Batch ID': 0, 'Template Number': 5}, 'score': 1.0001280307769775}, {'page_content': 'In the fourth quarter of 2027, economist Dr. Lisa Nguyen envisioned that the economic growth rate at the Federal Reserve decreased.', 'metadata': {'Sentence Label': 0, 'Template Number': 5, 'Domain': 'policy', 'Batch ID': 0, 'Model Name': 'llama-3.3-70b-instruct', 'API Name': 'NAVI_GATOR'}, 'score': 1.0031929016113281}, {'page_content': 'In  Q3 of 2027,  a financial analyst envisioned that the  interest rates at the Federal Reserve decreased.', 'metadata': {'Domain': 'finance', 'Template Number': 5, 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Batch ID': 0, 'Model Name': 'gemma2-9b-it'}, 'score': 1.0099046230316162}, {'page_content': 'In Q3 2026, Wells Fargo envisioned that the inflation rate at the Federal Reserve decreased.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Model Name': 'llama-3.1-8b-instant', 'Domain': 'finance', 'Sentence Label': 0, 'Template Number': 5, 'Batch ID': 0}, 'score': 1.0104132890701294}, {'page_content': 'On 08/21/2024, the World Bank monitored the inflation rate in emerging markets changed.', 'metadata': {'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'policy', 'Batch ID': 0, 'Template Number': 2}, 'score': 1.0228543281555176}, {'page_content': 'On 21 August 2024,  an analyst envisioned that the inflation rate at Wells Fargo decreased.', 'metadata': {'API Name': 'GROQ_CLOUD', 'Model Name': 'gemma2-9b-it', 'Sentence Label': 0, 'Batch ID': 0, 'Template Number': 5, 'Domain': 'finance'}, 'score': 1.0270885229110718}, {'page_content': 'On 12/15/2028, the World Bank monitored the inflation rate in emerging markets changed.', 'metadata': {'Model Name': 'gemma2-9b-it', 'Batch ID': 0, 'API Name': 'GROQ_CLOUD', 'Domain': 'policy', 'Sentence Label': 0, 'Template Number': 2}, 'score': 1.0479226112365723}, {'page_content': 'The Federal Reserve noted on 09/20/2029, the inflation rate in the United States fell.', 'metadata': {'Template Number': 3, 'Sentence Label': 0, 'Model Name': 'mistral-small-3.1', 'Batch ID': 0, 'API Name': 'NAVI_GATOR', 'Domain': 'policy'}, 'score': 1.0622518062591553}, {'page_content': 'According to  Bloomberg, the ...

# %%
sentences = []

for idx, row in df.iterrows():
    # print(idx)
    new_row_sentences = []
    prediction_sentence = row['Prediction Sentence']
    query_results = row['Query Results']['similarity_with_score']
    # print(query_results)
    for query_results_idx in range(len(query_results)):
        query_data = query_results[query_results_idx]
        sentence = query_data['page_content']
        new_row_sentences.append(sentence)

    if idx < 1:
        # print(sentence)
        print(f"Sentence: {prediction_sentence}\n\t{new_row_sentences}")
        # print()
    sentences.append(new_row_sentences)
# Out:
# Sentence: Professor Thompson forecasts that the graduation rate at Harvard University will drop in 2027.
# 	['In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Harvard University decreased.', 'In Aug 21, 2024, Professor Michael Davis envisioned that the graduation rates at Harvard University decreased.', 'According to Professor Alice Lee, the graduation rate at Harvard University rose in June 2022.', 'According to Professor Katherine Lee, the average GPA at Harvard University rose in 2022.', 'In 2029 of Q3, Professor Michael Brown envisioned that the graduation rates at Stanford University decreased.', 'In 2024, Professor James Wilson envisioned that the graduation rates at the University decreased.', 'In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Stanford University decreased.', 'College student, Emily Patel, noted on January 10, 2023, the price of textbooks at the campus bookstore fell.', 'Professor John Taylor noted that the average grade at Harvard University stayed stable in 2024/08/21.', ' Professor Michael Rodriguez noted on 10/15/2022, the student enrollment at the University of California, Berkeley fell.', 'On 12/15/2022,  Professor David Chen monitored the average GPA at Stanford University changed slightly.', 'Professor David Thompson observed that the student engagement at Harvard University declined in 2021.', 'In 2029 of Q3, Professor Kim envisioned that the test scores at MIT decreased.', 'The points scored at the Miami Heat dropped in 2022, according to the sports analyst.', 'College student, David Lee, noted on 08/15/2023, that the tuition fees at Stanford University fell.', "The CEO noted on 03/15/2023, the company's stock price fell.", 'In November 2022, the research advisor at the University of Michigan envisioned that the field goal percentage at the Michigan Wolverines decreased.', 'In August 2023, Professor John Lee envisioned that the average test score for his Intro to Psychology class decreased.', 'Morgan Stanley noted on 21/08/2024, the NASDAQ composite index fell.', 'According to my study conducted at Harvard, the hydration levels at college cafeterias fell on 2029-02-14.', 'Professor Rachel Thompson noted that the average grade at Harvard University stayed stable on 09/01/2024.', ' JP Morgan noted on 08/21/2024, the  S&P 500 index fell.', 'Morgan Stanley noted on 11/15/2029, the stock price at Google fell.', ' Professor Mark Sanchez noted on 11/1/2022, the enrollment rate for the online course fell.', 'Dr. Kevin Brown noted on January 10, 2024, the stock prices for Apple Corporation fell.', 'Professor Thompson observed that the graduation rate at Harvard University remained stable in 2024.', 'Charles Schwab noted on 1/12/2028, the NASDAQ composite index fell.', ' Analyst Kevin Rodriguez observed that on 09/15/2022, the goals scored at Manchester United fell.', 'Charles Schwab noted on 05/12/2028, the NASDAQ composite index fell.', 'BlackRock noted on February 2, 2026, the S&P 500 index at Goldman Sachs fell.', 'Analyst David Miller noted that on 08/21/2024, the goal differential at Manchester United fell.', 'On 11/15/2025, Dr. Lee monitored that the average body mass index at local high schools changed.', 'Dr. Robert Martinez noted on March 15, 2027, the interest rates at the Federal Reserve fell.']

# %%
df['Query Results: Sentences'] = sentences
df.head(3)
# Out:
#                                                                                         Prediction Sentence  \
# 0            Professor Thompson forecasts that the graduation rate at Harvard University will drop in 2027.
# 1                   Economist Dr. Sarah Lee predicts on 12/31/2027, the consumer confidence index may rise.
# 2  According to a fitness expert, the nutritional intake at community centers would fall in 21 August 2024.
#
#                                                                                                                                                   Raw Response  \
# 0  {0: ["forecasts", "that", "the", "graduation", "rate", "at", "will", "in"], 1: ["Professor Thompson"], 2: ["Harvard University"], 3: ["2027"], 4: ["drop"]}
# 1                         {0: ["predicts", "on", "the"], 1: ["Economist Dr. Sarah Lee"], 2: ["consumer confidence index"], 3: ["12/31/2027"], 4: ["may rise"]}
# 2  {0: ["According", "to", "a", "the", "in"], 1: ["fitness expert"], 2: ["nutritional intake at community centers"], 3: ["21 August 2024"], 4: ["would fall"]}
#
#             Model Name                                           No Property  \
# 0  openai/gpt-oss-120b  forecasts, that, the, graduation, rate, at, will, in
# 1  openai/gpt-oss-120b                                     predicts, on, the
# 2  openai/gpt-oss-120b                             According, to, a, the, in
#
#                     Source                                   Target  \
# 0       Professor Thompson                       Harvard University
# 1  Economist Dr. Sarah Lee                consumer confidence index
# 2           fitness expert  nutritional intake at community centers
#
#              Date     Outcome  \
# 0            2027        drop
# 1      12/31/2027    may rise
# 2  21 August 2024  would fall
#
#                                        Collection Name  \
# 0  prediction_collection-synthetic_data-oberservations
# 1  prediction_collection-synthetic_data-oberservations
# 2  prediction_collection-synthetic_data-oberservations
#
#                                    Persist Directory  \
# 0  ../data/chroma/chroma_langchain_db-oberservations
# 1  ../data/chroma/chroma_langchain_db-oberservations
# 2  ../data/chroma/chroma_langchain_db-oberservations
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Query Results  \
# 0  {'similarity_with_score': [{'page_content': 'In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Harvard University decreased.', 'metadata': {'Template Number': 5, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-8b-instruct', 'Domain': 'miscellaneous', 'Batch ID': 0}, 'score': 0.8186123371124268}, {'page_content': 'In Aug 21, 2024, Professor Michael Davis envisioned that the graduation rates at Harvard University decreased.', 'metadata': {'Sentence Label': 0, 'Template Number': 5, 'Batch ID': 0, 'API Name': 'NAVI_GATOR', 'Model Name': 'llama-3.1-8b-instruct', 'Domain': 'miscellaneous'}, 'score': 0.8256052732467651}, {'page_content': 'According to Professor Alice Lee, the graduation rate at Harvard University rose in June 2022.', 'metadat...
# 1  {'similarity_with_score': [{'page_content': 'On 11/10/2022, a market researcher at Global Trends observed that the consumer confidence index in the retail sector had shifted.', 'metadata': {'API Name': 'NAVI_GATOR', 'Model Name': 'mistral-small-3.1', 'Batch ID': 0, 'Domain': 'miscellaneous', 'Sentence Label': 0, 'Template Number': 2}, 'score': 0.6180521249771118}, {'page_content': 'In 2027, the National Institute of Economic Research envisioned that consumer confidence decreased.', 'metadata': {'Sentence Label': 0, 'Model Name': 'gemma2-9b-it', 'Domain': 'policy', 'Template Number': 5, 'Batch ID': 0, 'API Name': 'GROQ_CLOUD'}, 'score': 0.82148277759552}, {'page_content': 'The Cato Institute noted on 03/15/2028, the consumer price index fell.', 'metadata': {'Template Number': 3, 'API Na...
# 2  {'similarity_with_score': [{'page_content': 'Dr. Linda Green noted on 03/20/2021, the nutritional intake at local schools fell.', 'metadata': {'Template Number': 3, 'Sentence Label': 0, 'API Name': 'NAVI_GATOR', 'Domain': 'health', 'Model Name': 'mistral-small-3.1', 'Batch ID': 0}, 'score': 0.6335760354995728}, {'page_content': 'On 11th of October 2025, the World Health Organization monitored the obesity rates at rural high schools changed.', 'metadata': {'Sentence Label': 0, 'Model Name': 'llama-3.3-70b-versatile', 'Domain': 'health', 'API Name': 'GROQ_CLOUD', 'Template Number': 2, 'Batch ID': 0}, 'score': 0.7807698249816895}, {'page_content': 'On November 15, 2023, a health researcher monitored that the average body mass index at rural high schools changed.', 'metadata': {'Domain': '...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Query Results: Sentences
# 0  [In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Harvard University decreased., In Aug 21, 2024, Professor Michael Davis envisioned that the graduation rates at Harvard University decreased., According to Professor Alice Lee, the graduation rate at Harvard University rose in June 2022., According to Professor Katherine Lee, the average GPA at Harvard University rose in 2022., In 2029 of Q3, Professor Michael Brown envisioned that the graduation rates at Stanford University decreased., In 2024, Professor James Wilson envisioned that the graduation rates at the University decreased., In 2029 of Q3, Professor James Davis envisioned that the graduation rates at Stanford University decreased., College student, Emily Patel, noted on January 10, 2023, the price of...
# 1  [On 11/10/2022, a market researcher at Global Trends observed that the consumer confidence index in the retail sector had shifted., In 2027, the National Institute of Economic Research envisioned that consumer confidence decreased., The Cato Institute noted on 03/15/2028, the consumer price index fell., In 09/2026,  a financial advisor envisioned that the inflation rate at the US economy decreased., According to the Federal Reserve, the inflation rate in the US rose in Q2 2024., In June 2027,  a financial researcher envisioned that the inflation rate at the Federal Reserve decreased., According to the National Bureau of Economic Research, the inflation rate in the United States rose in Q4 2035., The Cato Institute noted on 11/15/2029, the inflation rate fell., On 2027-03-10, the Congre...
# 2  [Dr. Linda Green noted on 03/20/2021, the nutritional intake at local schools fell., On 11th of October 2025, the World Health Organization monitored the obesity rates at rural high schools changed., On November 15, 2023, a health researcher monitored that the average body mass index at rural high schools changed., On 1st January 2026, the Centers for Disease Control and Prevention (CDC) monitored the obesity rates in urban areas changed., In the summer of 2027, I envisioned that the rate of childhood obesity would decrease in urban areas.,  The average daily intake of fruits and vegetables increased in my patients in 2029, according to my records., In the fourth quarter of 2029, Professor Patel envisioned that the daily caloric intake at college cafeterias decreased., On 11th of Octob...

# %%
synthetic_dataset_path = "rag/"
synthetic_dataset_full_path = os.path.join(base_data_path, synthetic_dataset_path)
DataProcessing.save_to_file(df, synthetic_dataset_full_path, 'match_p_o-synthetic_dataset', 'csv')
# Out:
# Using file number: 3
# Saving CSV file to: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/notebook_experiments/../data/rag/match_p_o-synthetic_dataset-v3.csv
