# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="microsoft/phi-4", trust_remote_code=True)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 from transformers import pipeline
# ----> 3 pipe = pipeline("text-generation", model="microsoft/phi-4", trust_remote_code=True)
#
# File ~/opt/anaconda3/envs/predictions/lib/python3.11/site-packages/transformers/pipelines/__init__.py:940, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     938 if isinstance(model, str) or framework is None:
#     939     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 940     framework, model = infer_framework_load_model(
#     941         model,
#     942         model_classes=model_classes,
#     943         config=config,
#     944         framework=framework,
# ...

# %%
text = pipe("The weather is nice today and")[0]["generated_text"]

# %%
text
# Out:
# 'The weather is nice today and you are given the weather data from the weather app. The weather app has a schedule that you can'
