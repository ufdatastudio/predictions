# %% [markdown]
# # Extract Features

# %%
import os, sys

import pandas as pd

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

import log_files
from log_files import LogData
from data_processing import DataProcessing
from feature_extraction import SpacyFeatureExtraction

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
log_file_path = "data/prediction_logs"
predictions = True
df = log_files.read_data(notebook_dir, log_file_path, predictions)
df.head(7)
# Out:
# Start logging batch
# log_directory: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs
# save_batch_directory: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs/batch_1-predictions
# CSV to DF
# Load saved csv: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs/batch_1-predictions/batch_1-from_df.csv
# save_batch_directory: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs/batch_2-predictions
# CSV to DF
# Load saved csv: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs/batch_2-predictions/batch_2-from_df.csv
# save_batch_directory: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs/batch_3-predictions
# CSV to DF
# Load saved csv: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/misc/../data/prediction_logs/batch_3-predictions/batch_3-from_df.csv
#                                                                                                                Base Sentence  \
# 0  On August 21, 2024, as a financial analyst, I predict that the revenue at Amazon will potentially decrease in Q3 of 2027.
# 1                              On 2024-08-21, Morgan Stanley speculates the operating income at Amazon will likely increase.
# 2                            According to JPMorgan Chase, the net profit at Microsoft is expected to decrease in Q2 of 2024.
# 3                          On August 21, 2023, Goldman Sachs speculates that the stock price at Amazon will likely increase.
# 4                                     George, a financial analyst, predicts that on 01/15/2024, the Google revenue may rise.
# 5                                       According to BlackRock, the operating cash flow at ExxonMobil would fall in Q3 2023.
# 6                     In Q2 2023, Wells Fargo envisions that the stock price at Tesla has some probability to remain stable.
#
#    Sentence Label   Domain             Model Name    API Name  Batch ID  \
# 0               1  finance          gpt-3.5-turbo  NAVI_GATOR         0
# 1               1  finance                 gpt-4o  NAVI_GATOR         0
# 2               1  finance  mixtral-8x7b-instruct  NAVI_GATOR         0
# 3               1  finance  mixtral-8x7b-instruct  NAVI_GATOR         0
# 4               1  finance  mixtral-8x7b-instruct  NAVI_GATOR         0
# 5               1  finance  mixtral-8x7b-instruct  NAVI_GATOR         0
# 6               1  finance  mixtral-8x7b-instruct  NAVI_GATOR         0
#
#    Template Number
# 0                1
# 1                2
# 2                1
# 3                2
# 4                3
# 5                4
# 6                5

# %% [markdown]
# - issue: `obesity rate` is not being captures by POS or NER.
# - solution: `update_futures_count()` in feature_extraction.py

# %%
only_predictions = DataProcessing.df_to_list(df, 'Base Sentence')
# print(only_predictions)
sfe_class = SpacyFeatureExtraction(df, "Base Sentence")
word_leveL_disable_components = ["lemmatizer"]
word_level_pos_tags, word_level_pos_mappings, word_level_ner_entities, word_level_ner_mappings =  sfe_class.extract_features(data=only_predictions, disable_components=word_leveL_disable_components)
# Out:
# Spacy Doc (0):  On August 21, 2024, as a financial analyst, I predict that the revenue at Amazon will potentially decrease in Q3 of 2027.
# Spacy Doc (1):  On 2024-08-21, Morgan Stanley speculates the operating income at Amazon will likely increase.
# Spacy Doc (2):  According to JPMorgan Chase, the net profit at Microsoft is expected to decrease in Q2 of 2024.
# Spacy Doc (3):  On August 21, 2023, Goldman Sachs speculates that the stock price at Amazon will likely increase.

# %%
all_word_level_pos_df = DataProcessing.convert_to_df(word_level_pos_tags, mapping=word_level_pos_mappings)
all_word_level_ner_df = DataProcessing.convert_to_df(word_level_ner_entities, word_level_ner_mappings)

# %%
all_word_level_pos_df
# Out:
#    PUNCT_1 SYM_2    PROPN_5 PUNCT_3       NUM_1 PUNCT_2        NOUN_3  \
# 0        ,   NaN        NaN       ,          21       ,           NaN
# 1        ,     -        NaN     NaN        2024       .           NaN
# 2        ,   NaN        NaN     NaN        2024       .           NaN
# 3        ,   NaN        NaN       .          21       ,           NaN
# 4        ,   NaN        NaN       ,  01/15/2024       ,           NaN
# 5        ,   NaN        NaN     NaN        2023       .           NaN
# 6        ,   NaN        NaN     NaN        2023       .   probability
# 7        ,   NaN        NaN     NaN        2023       .           NaN
# 8        .   NaN        NaN     NaN        2026     NaN        health
# 9        .   NaN        NaN     NaN        2024     NaN       centers
# 10       (   NaN        NaN       .        2027       )    healthcare
# 11       ,   NaN    America     NaN  01/01/2025       .        habits
# 12       .   NaN        NaN     NaN        2026     NaN        adults
# 13       ,   NaN        NaN     NaN        2029       .    prevalence
# 14       ,   NaN         US       ,        2027       ,        health
# 15       ,   NaN        NaN     NaN        2025       .    screenings
# 16       ,   NaN        NaN       .          21       ,       finance
# 17       .   NaN        NaN     NaN        2026     NaN       impacts
# 18       ,   NaN        NaN     NaN        2024       .          rate
# 19       ,   NaN        NaN     NaN  08/21/2024       .       changes
# 20       ,   NaN        NaN       .           1       ,        number
# 21       ,   NaN         Q4     NaN        2024       .        stores
# 22       ,   NaN        NaN     NaN        2024       .        number
# 23       ,   NaN        Lee     NaN        2025       .    agreements
# 24       ,   NaN        NaN       .          15       ,           NaN
# 25       .   NaN        NaN     NaN        2027     NaN      decrease
# 26       .   NaN        NaN     NaN        2026     NaN          week
# 27       ,   NaN       York     NaN  08/21/2024       .           NaN
# 28       ,   NaN      Miami       .           1       ,           NaN
# 29       ,   NaN        Los     NaN        2025       .           NaN
# 30       ,   NaN     Person     NaN        2025       .           NaN
# 31       ,   NaN  Francisco     NaN        2026       .          week
# 32       ,   NaN        NaN       ,          21       ,           NaN
# 33       ,     -        NaN       .        2024       ,      decrease
# 34       ,   NaN         Q3     NaN        2027       .           NaN
# 35       ,     -        NaN     NaN        2029       .         price
# 36       ,   NaN        NaN     NaN  08/21/2024       .           NaN
# 37       ,   NaN        NaN     NaN        2025       .          cash
# 38       ,   NaN        NaN     NaN        2024       .      expenses
# 39       ,   NaN        NaN     NaN        2025       .        expert
# 40       .   NaN        NaN     NaN        2025     NaN        health
# 41       .   NaN        NaN     NaN        2027     NaN        health
# 42       (   NaN        NaN       .        2027       )    healthcare
# 43       ,   NaN    America       .  01/01/2025       ,        trends
# 44       ,   NaN        NaN       .        2026       ,        adults
# 45       ,   NaN        NaN       .          10       ,             %
# 46       ,   NaN        NaN       .        2024       ,       support
# 47       ,   NaN    Allergy       .        2025       ,           NaN
# 48       ,   NaN        NaN       ,          15       ,        sector
# 49       .   NaN        NaN     NaN        2026     NaN    compliance
# 50       ,   NaN        NaN     NaN        2024       .          rate
# 51       ,   NaN        NaN     NaN  08/21/2024       .        number
# 52       ,   NaN        NaN       .           1       ,        number
# 53       ,   NaN       Club     NaN        2024       .  satisfaction
# 54       ,   NaN        NaN     NaN        2024       .        number
# 55       ,   NaN        NaN     NaN        2024       .  acquisitions
# 56       ,   NaN        NaN       .          21       ,           NaN
# 57       .   NaN         Q3     NaN        2027     NaN      decrease
# 58       ,   NaN       York     NaN        2024       .        levels
# 59       ,   NaN        NaN     NaN  08/21/2024       .           NaN
# 60       ,   NaN        Los       ,           1       ,          wind
# 61       ,   NaN        NaN     NaN        2025       .           NaN
# 62       ,   NaN     Dallas     NaN        2027       .   probability
# 63       ,   NaN     Bureau     NaN        2025       .           NaN
# 64       ,   NaN        NaN       .        2027       ,           NaN
# 65       .   NaN        NaN     NaN        2025     NaN           NaN
# 66       ,   NaN        NaN     NaN        2024       .           NaN
# 67       ,   NaN        NaN       .          21       ,           NaN
# 68       ,   NaN       Inc.       .           1       ,           NaN
# 69       ,   NaN        NaN     NaN        2023       .          flow
# 70       ,   NaN        NaN     NaN        2023       .      expenses
# 71       ,   NaN        NaN     NaN        2023       .           NaN
# 72       .   NaN        NaN     NaN        2026     NaN        health
# 73       .   NaN        NaN     NaN        2027     NaN        health
# 74       (   NaN         Q2       .        2025       )        health
# 75       ,   NaN    America     NaN  01/10/2025       .           NaN
# 76       ,   NaN        NaN     NaN        2025       .        adults
# 77       ,   NaN        NaN     NaN        2026       .     illnesses
# 78       ,   NaN        NaN       .        2025       -        intake
# 79       ,   NaN        NaN     NaN        2025       .    screenings
# 80       ,   NaN        NaN       .          15       ,   initiatives
# 81       .   NaN        NaN     NaN        2026     NaN    compliance
# 82       ,   NaN        NaN     NaN        2024       .          rate
# 83       ,   NaN        NaN     NaN  08/21/2024       .        number
# 84       ,   NaN        NaN       .           3       ,        number
# 85       ,   NaN       Club     NaN        2024       .           NaN
# 86       ,   NaN        NaN     NaN        2025       .        number
# 87       ,   NaN        NaN     NaN        2025       .           NaN
# 88       ,   NaN      Miami       .          21       ,           NaN
# 89       ,     -        NaN     NaN        2024       .           NaN
# 90       ,   NaN       York     NaN  08/21/2024       .        levels
# 91       ,   NaN        NaN       ,          21       ,   temperature
# 92       ,   NaN        NaN     NaN          15       .           NaN
# 93       ,   NaN        NaN       .        2025       ,          fall
# 94       ,   NaN        NaN       ,        2025       ,   temperature
# 95       ,   NaN        NaN       .        2025       ,         level
#
#          ADJ_4 PART_1 DET_4 DET_3 NUM_2  ADP_4         NOUN_4 PRON_1  \
# 0          NaN    NaN   NaN   NaN  2024     in            NaN      I
# 1          NaN    NaN   NaN   NaN    08    NaN            NaN    NaN
# 2          NaN     to   NaN   NaN   NaN     of            NaN    NaN
# 3          NaN    NaN   NaN   NaN  2023    NaN            NaN    NaN
# 4          NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 5          NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 6          NaN     to   NaN   NaN   NaN    NaN            NaN    NaN
# 7          NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 8          NaN    NaN   NaN   NaN   NaN     of        clinics    NaN
# 9          NaN    NaN   NaN   NaN   NaN     of            NaN    WHO
# 10         NaN    NaN   NaN   NaN   NaN    NaN     facilities    NaN
# 11         NaN    NaN   NaN   NaN   NaN     to            NaN    NaN
# 12         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 13         NaN    NaN   NaN   the   NaN     in       diseases    NaN
# 14         NaN     to  some   the   NaN    NaN          being    NaN
# 15         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 16         NaN    NaN   NaN   NaN  2024    NaN         sector      I
# 17         NaN    NaN   NaN   NaN   NaN    NaN     healthcare    NaN
# 18         NaN    NaN   NaN   NaN   NaN    NaN     technology    NaN
# 19         NaN    NaN   NaN   NaN   NaN    NaN        finance    NaN
# 20         NaN    NaN   NaN   NaN  2025    NaN  cybersecurity    NaN
# 21         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 22         NaN     to   NaN   NaN   NaN    NaN        climate    NaN
# 23         NaN    NaN   NaN   the   NaN     to         policy    NaN
# 24         NaN    NaN   NaN   NaN  2025    NaN            NaN    NaN
# 25         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 26         NaN     to   NaN   the   NaN    NaN            NaN    NaN
# 27         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 28         NaN    NaN   NaN   NaN  2025    NaN            NaN    NaN
# 29         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 30         NaN     to   NaN   NaN   NaN    NaN            NaN    NaN
# 31         NaN    NaN   the   the   NaN     to            NaN    NaN
# 32         NaN    NaN   NaN   NaN  2024     in            NaN      I
# 33         NaN    NaN   NaN   NaN    08    NaN            NaN    NaN
# 34         NaN    NaN   NaN   NaN   NaN     of            NaN    NaN
# 35         NaN    NaN   NaN   NaN    08    NaN            NaN    NaN
# 36         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 37         NaN    NaN   NaN   NaN   six    NaN           flow  their
# 38         NaN     to   NaN   NaN   NaN    NaN    probability    NaN
# 39         NaN    NaN   NaN     a   NaN    NaN            NaN    NaN
# 40         NaN    NaN   NaN   NaN   NaN     of        clinics    NaN
# 41         NaN    NaN   NaN   NaN   NaN     of        centers    NaN
# 42         NaN    NaN   NaN   NaN   NaN    NaN     facilities    NaN
# 43         NaN    NaN   NaN   NaN   NaN    NaN          diets    NaN
# 44         NaN    NaN   NaN   the   NaN    NaN           need    NaN
# 45         NaN    NaN   NaN   the  2030  below         people    NaN
# 46  supportive     to   NaN     a   NaN    NaN   corporations    NaN
# 47         NaN    NaN   NaN   the   NaN     to            NaN    NaN
# 48         NaN    NaN   NaN   NaN  2026    NaN         policy      I
# 49         NaN    NaN   NaN   NaN   NaN    NaN          costs    NaN
# 50         NaN    NaN   NaN   NaN   NaN    NaN     technology    NaN
# 51         NaN    NaN   NaN   NaN   NaN    NaN  cybersecurity    NaN
# 52         NaN    NaN   NaN   NaN  2025    NaN       vehicles    NaN
# 53         NaN     's   NaN   NaN   NaN    NaN            NaN    NaN
# 54         NaN     to   NaN  some   NaN    NaN         energy    NaN
# 55         NaN    NaN   NaN   NaN   NaN     to         sector    NaN
# 56         NaN    NaN   NaN   NaN  2024    NaN            NaN    NaN
# 57         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 58         NaN    NaN   the   the   NaN     in           week    NaN
# 59         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 60         NaN    NaN   NaN   NaN  2025    NaN          speed    NaN
# 61         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 62         NaN     to  some   the   NaN     in            NaN    NaN
# 63         NaN    NaN   NaN   the   NaN    NaN            NaN    NaN
# 64         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 65         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 66         NaN     to   NaN   NaN   NaN     of            NaN    NaN
# 67         NaN    NaN   NaN   NaN  2023    NaN            NaN    NaN
# 68         NaN    NaN   NaN   NaN  2023    NaN            NaN    NaN
# 69         NaN     's   NaN   NaN   NaN    NaN            NaN    NaN
# 70         NaN     to   NaN   NaN   NaN    NaN    probability    NaN
# 71         NaN     's   NaN   NaN   NaN    NaN            NaN    NaN
# 72         NaN    NaN   NaN   NaN   NaN     of        clinics    NaN
# 73         NaN    NaN   NaN   NaN   NaN     of        centers    NaN
# 74         NaN    NaN   NaN   NaN   NaN    NaN        centers    NaN
# 75         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 76         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 77         NaN    NaN   NaN   the   NaN     in          areas    NaN
# 78         NaN     to  some   the   NaN    NaN         school    NaN
# 79         NaN    NaN   NaN   NaN   NaN    NaN            NaN    NaN
# 80         NaN    NaN   NaN   NaN  2025    NaN           year      I
# 81         NaN    NaN   NaN   NaN   NaN    NaN          costs    NaN
# 82         NaN    NaN   NaN   NaN   NaN    NaN     technology    NaN
# 83         NaN    NaN   NaN   NaN   NaN    NaN  cybersecurity    NaN
# 84         NaN    NaN   NaN   NaN  2024    NaN        climate    NaN
# 85         NaN     's   NaN   NaN   NaN    NaN            NaN    NaN
# 86         NaN     to   NaN   NaN   NaN   with          trade    NaN
# 87         NaN     to   NaN   NaN   NaN    NaN            NaN    NaN
# 88         NaN    NaN   NaN   NaN  2024    NaN            NaN    NaN
# 89         NaN    NaN   NaN   NaN    08    NaN            NaN    NaN
# 90         NaN    NaN   NaN   the   NaN     in            NaN    NaN
# 91         NaN    NaN   NaN   NaN  2024    NaN            NaN      I
# 92         NaN    NaN   NaN   NaN  2025    NaN            NaN    NaN
# 93         NaN    NaN   NaN   NaN   NaN     in            NaN     me
# 94         NaN    NaN   NaN   NaN   NaN    NaN            NaN      I
# 95         NaN    NaN   NaN   NaN   NaN     as         person     me
#
#              ADJ_1   AUX_1          NOUN_5     VERB_4       NOUN_8 SCONJ_1  \
# 0        financial    will             NaN        NaN          NaN    that
# 1              NaN    will             NaN        NaN          NaN     NaN
# 2              net      is             NaN        NaN          NaN     NaN
# 3              NaN    will             NaN        NaN          NaN    that
# 4        financial     may             NaN        NaN          NaN    that
# 5              NaN   would             NaN        NaN          NaN     NaN
# 6           stable     NaN             NaN        NaN          NaN    that
# 7             same  should             NaN        NaN          NaN     NaN
# 8          chronic    will             NaN        NaN          NaN    that
# 9          chronic     NaN             NaN        NaN          NaN    that
# 10          global    will             NaN        NaN          NaN    that
# 11       unhealthy    will             NaN        NaN          NaN    that
# 12         average    will             NaN        NaN          NaN    that
# 13          recent   would       community        NaN          NaN    that
# 14         overall     NaN     probability      given          NaN    that
# 15          Public  should             NaN        NaN          NaN     NaN
# 16      regulatory    will             NaN        NaN          NaN    that
# 17     legislative     NaN          sector        NaN          NaN    that
# 18             NaN   would          sector        NaN          NaN     NaN
# 19      regulatory    will          sector        NaN          NaN    that
# 20             NaN     may        breaches        NaN          NaN    that
# 21             top   would             NaN        NaN          NaN     NaN
# 22          stable     NaN          change        NaN          NaN    that
# 23            same  should          expert        NaN          NaN     NaN
# 24             NaN    will             NaN        NaN          NaN    that
# 25             NaN     NaN             NaN        NaN          NaN    that
# 26           third     NaN             NaN        NaN          NaN    that
# 27             NaN    will             NaN        NaN          NaN    that
# 28             NaN     may             NaN        NaN          NaN    that
# 29             NaN   would             NaN        NaN          NaN     NaN
# 30          stable     NaN             NaN        NaN          NaN    that
# 31            same  should             NaN        NaN          NaN     NaN
# 32       financial    will             NaN        NaN          NaN    that
# 33       financial     NaN             NaN        NaN          NaN    that
# 34             net   would             NaN        NaN          NaN     NaN
# 35       prominent    will             NaN        NaN          NaN     NaN
# 36             NaN     may             NaN        NaN          NaN    that
# 37            next    will          months   decrease          NaN    that
# 38          stable     NaN             NaN        NaN          NaN    that
# 39            same  should             NaN        NaN          NaN     NaN
# 40         chronic    will             NaN        NaN          NaN    that
# 41         chronic    will             NaN        NaN          NaN    that
# 42          global    will             NaN        NaN          NaN    that
# 43         current    will      lifestyles        NaN          NaN    that
# 44         average    will       detection        NaN          NaN    that
# 45            more    will       lifestyle        NaN          NaN      as
# 46          mental    will     probability  fostering          NaN    that
# 47        seasonal  should             NaN        NaN          NaN     NaN
# 48          retail    will          expert        NaN          NaN    that
# 49      regulatory     NaN    institutions        NaN          NaN    that
# 50             NaN   would          sector        NaN          NaN     NaN
# 51             NaN    will        breaches        NaN          NaN    that
# 52        electric    will  transportation        NaN          NaN    that
# 53             top    will             NaN        NaN          NaN     NaN
# 54       renewable     NaN        projects        NaN  probability    that
# 55          retail  should          expert        NaN          NaN     NaN
# 56             NaN    will             NaN        NaN          NaN    that
# 57             NaN     NaN             NaN        NaN          NaN    that
# 58  meteorological    will             NaN        NaN          NaN     NaN
# 59             NaN    will             NaN        NaN          NaN    that
# 60             NaN     may             NaN        NaN          NaN    that
# 61             NaN   would             NaN        NaN          NaN     NaN
# 62  meteorological     NaN             NaN        NaN          NaN    that
# 63            same  should             NaN        NaN          NaN     NaN
# 64       financial    will             NaN        NaN          NaN    that
# 65             net     NaN             NaN        NaN          NaN    that
# 66             net      is             NaN        NaN          NaN     NaN
# 67             NaN    will             NaN        NaN          NaN    that
# 68             NaN     may             NaN        NaN          NaN    that
# 69             NaN   would             NaN        NaN          NaN     NaN
# 70          stable     NaN             NaN        NaN          NaN    that
# 71            same  should             NaN        NaN          NaN     NaN
# 72         chronic    will             NaN        NaN          NaN    that
# 73         chronic     NaN             NaN        NaN          NaN    that
# 74          global    will             NaN        NaN          NaN    that
# 75             NaN    will             NaN        NaN          NaN    that
# 76         average    will             NaN        NaN          NaN    that
# 77          recent    will             NaN        NaN          NaN     NaN
# 78     nutritional     NaN        children     remain          NaN    that
# 79          Public    will             NaN        NaN          NaN     NaN
# 80          public    will             NaN        NaN          NaN    that
# 81      regulatory     NaN    institutions        NaN          NaN    that
# 82             NaN   would          sector        NaN          NaN     NaN
# 83             NaN    will        breaches        NaN          NaN    that
# 84             NaN    will          change        NaN       sector    that
# 85          stable     NaN             NaN        NaN          NaN     NaN
# 86             NaN     NaN      agreements   increase          NaN    that
# 87          stable      is             NaN        NaN          NaN     NaN
# 88             NaN    will             NaN        NaN          NaN    that
# 89             NaN     may             NaN        NaN          NaN     NaN
# 90  meteorological    will             NaN        NaN          NaN     NaN
# 91             NaN    will             NaN        NaN          NaN    that
# 92             NaN    will             NaN        NaN          NaN    that
# 93             top    will             NaN        NaN          NaN     NaN
# 94          stable    will             NaN        NaN          NaN    that
# 95          senior    will             NaN        NaN          NaN     NaN
#
#    PUNCT_4       PROPN_3     PROPN_7 DET_5          ADV_1        PROPN_1  \
# 0        .            Q3         NaN   NaN    potentially         August
# 1      NaN        Amazon         NaN   NaN         likely         Morgan
# 2      NaN     Microsoft         NaN   NaN            NaN       JPMorgan
# 3      NaN         Sachs         NaN   NaN         likely         August
# 4        .           NaN         NaN   NaN            NaN         George
# 5      NaN            Q3         NaN   NaN            NaN      BlackRock
# 6      NaN         Fargo         NaN   NaN            NaN             Q2
# 7      NaN        Morgan         NaN   NaN            NaN          Apple
# 8      NaN            Q4         NaN   NaN    potentially            Dr.
# 9      NaN           NaN         NaN   NaN    potentially             Q4
# 10     NaN  Organization         NaN   NaN    potentially          World
# 11     NaN         Smith         NaN   NaN         likely            Dr.
# 12     NaN           NaN         NaN   NaN  significantly            CDC
# 13     NaN           NaN         NaN   NaN            NaN            NIH
# 14       -        Robert         NaN   the           well             Q3
# 15     NaN   Association         NaN   NaN           even       American
# 16     NaN         Sachs         NaN   NaN    potentially         August
# 17     NaN           Lee         NaN   NaN    potentially            Dr.
# 18     NaN        Mendez         NaN   NaN            NaN            Dr.
# 19     NaN           NaN         NaN   NaN         likely           John
# 20     NaN       January         NaN   NaN            NaN           Jane
# 21     NaN        Walton         NaN   NaN            NaN            Mr.
# 22     NaN         Maria         NaN   NaN            NaN       November
# 23     NaN           Mr.         NaN   NaN            NaN             US
# 24     NaN     September         NaN   NaN    potentially        Weather
# 25     NaN       Chicago         NaN   NaN    potentially        Weather
# 26     NaN        Dallas         NaN   NaN            NaN  Meteorologist
# 27     NaN         James         NaN   NaN         likely        Weather
# 28     NaN          Alex         NaN   NaN            NaN        Weather
# 29     NaN     Executive        June   NaN            NaN        Weather
# 30     NaN        Senior     Chicago   NaN            NaN       December
# 31     NaN       January      Bureau   NaN            NaN            San
# 32       .            Q3         NaN   NaN    potentially         August
# 33     NaN     Microsoft         NaN   NaN    potentially           Jane
# 34     NaN       Goldman         NaN   NaN            NaN       JPMorgan
# 35     NaN           NaN         NaN   NaN         likely      Microsoft
# 36     NaN        Amazon         NaN   NaN            NaN         Warren
# 37     NaN           NaN         NaN   NaN            NaN             Q1
# 38     NaN         Tesla         NaN   NaN            NaN         August
# 39     NaN            Q2         NaN   NaN            NaN       Alphabet
# 40     NaN            Q4         NaN   NaN    potentially            Dr.
# 41     NaN       Johnson         NaN   NaN    potentially            Dr.
# 42     NaN  Organization         NaN   NaN    potentially          World
# 43     NaN         Smith         NaN   NaN         likely            Dr.
# 44     NaN   Association         NaN   NaN            NaN       American
# 45     NaN        States         NaN   NaN            NaN            CDC
# 46     NaN        Robert         NaN   NaN           more             Q3
# 47     NaN      American  Immunology   NaN            NaN         United
# 48       .      Samantha         NaN   NaN    potentially           July
# 49     NaN           Lee         NaN   NaN    potentially            Dr.
# 50     NaN        Mendez         NaN   NaN            NaN            Dr.
# 51     NaN           NaN         NaN   NaN         likely           John
# 52     NaN       January         NaN   NaN         likely           Jane
# 53     NaN        Walton         NaN   NaN         likely            Mr.
# 54     NaN           Lee         NaN   NaN            NaN       November
# 55     NaN           Kim         NaN   NaN            NaN             Q4
# 56     NaN        August         NaN   NaN    potentially        Weather
# 57     NaN           San         NaN   NaN    potentially        Weather
# 58     NaN       Service         NaN   NaN         likely       National
# 59     NaN       Johnson         NaN   NaN         likely  Meteorologist
# 60       ,         Smith         NaN   NaN            NaN            Dr.
# 61     NaN       Houston         NaN   NaN            NaN        Weather
# 62     NaN       Weather         NaN   NaN            NaN             Q3
# 63     NaN         Miami         NaN   NaN            NaN          Miami
# 64     NaN            Q3         NaN   NaN    potentially           John
# 65     NaN        Amazon         NaN   NaN    potentially        Goldman
# 66     NaN     Microsoft         NaN   NaN            NaN       JPMorgan
# 67     NaN         Sachs         NaN   NaN         likely         August
# 68     NaN      November         NaN   NaN            NaN            Jim
# 69     NaN            Q3         NaN   NaN            NaN           CNBC
# 70     NaN         Tesla         NaN   NaN            NaN             Q4
# 71     NaN      December         NaN   NaN            NaN       Alphabet
# 72     NaN            Q4         NaN   NaN    potentially            Dr.
# 73     NaN       Johnson         NaN   NaN    potentially            Dr.
# 74     NaN  Organization         NaN   NaN    potentially          World
# 75     NaN         Gupta         NaN   NaN         likely            Dr.
# 76     NaN           NaN         NaN   NaN            NaN            CDC
# 77     NaN           NaN         NaN   NaN         likely            NIH
# 78     NaN           NaN         NaN   NaN            NaN             Q3
# 79     NaN   Association         NaN   NaN            NaN       American
# 80     NaN           NaN         NaN   NaN    potentially       December
# 81     NaN        Carter         NaN   NaN    potentially            Dr.
# 82     NaN        Mendez         NaN   NaN            NaN            Dr.
# 83     NaN           NaN         NaN   NaN         likely           John
# 84     NaN      November         NaN   NaN         likely          Susan
# 85     NaN        Walton         NaN   NaN            NaN            Mr.
# 86     NaN         Adams         NaN   NaN            NaN             Q3
# 87     NaN        Thomas         NaN   NaN            NaN             Q3
# 88     NaN         Sarah         NaN   NaN    potentially        Weather
# 89     NaN           New         NaN   NaN            NaN        Weather
# 90     NaN       Service         NaN   NaN         likely       National
# 91       ,       Angeles         NaN   NaN         likely         August
# 92     NaN         Miami         NaN   NaN            NaN        Weather
# 93     NaN           NaN         NaN   NaN         likely    AccuWeather
# 94       .           NaN         NaN   NaN         likely           July
# 95     NaN           NaN         NaN   NaN         likely         Boston
#
#    PART_2   ADP_3 AUX_2 DET_2 DET_1  ADP_1    ADP_2 NUM_3           ADJ_2  \
# 0     NaN      at   NaN   the     a     On       as  2027             NaN
# 1     NaN     NaN   NaN   NaN   the     On       at    21             NaN
# 2     NaN      in   NaN   NaN   the     to       at   NaN             NaN
# 3     NaN     NaN   NaN   NaN   the     On       at   NaN             NaN
# 4     NaN     NaN   NaN   the     a     on      NaN   NaN             NaN
# 5     NaN      in   NaN   NaN   the     to       at   NaN             NaN
# 6     NaN     NaN   NaN  some   the     In       at   NaN             NaN
# 7     NaN      to   NaN   the   The     at       in   NaN             NaN
# 8     NaN      in   NaN   NaN   the     of       at   NaN           rural
# 9     NaN      in   NaN   NaN   the     of       at   NaN          global
# 10    NaN      by   NaN   the   The     of       at   NaN         primary
# 11    NaN     due   NaN   NaN   the     On       in   NaN         dietary
# 12    NaN     NaN   NaN   the   The  among       by   NaN        physical
# 13    NaN      at   NaN   the     a     to       of   NaN  cardiovascular
# 14    NaN      in   NaN   the     a     In       of   NaN          mental
# 15    NaN      to   NaN   the   the     in       in   NaN    preventative
# 16    NaN      at   NaN   the   the     On       in   NaN             NaN
# 17    NaN      of   NaN   the   the     at       in   NaN             NaN
# 18    NaN      in   NaN   the   the     to       in   NaN             NaN
# 19    NaN     NaN   NaN   NaN   the     On       in   NaN             NaN
# 20    NaN      in   NaN   the   the     on       of   NaN             NaN
# 21    NaN      in   NaN   NaN   the     to       at   NaN             NaN
# 22    NaN     NaN   NaN  some   the     In       of   NaN             NaN
# 23    NaN      in   NaN   the   The     of  between   NaN             NaN
# 24    NaN     NaN   NaN   NaN   the     on       at   NaN             NaN
# 25    NaN      of   NaN   the   The     at       in   NaN             NaN
# 26    NaN      of   NaN   the   the     in       in   NaN             NaN
# 27    NaN     NaN   NaN   NaN   the     On       in   NaN             NaN
# 28    NaN     NaN   NaN   NaN   the     on       in   NaN             NaN
# 29    NaN      in   NaN   NaN   the     to       in   NaN             NaN
# 30    NaN     NaN   NaN  some   the     In       in   NaN             NaN
# 31    NaN      of   NaN   the   The     in       in   NaN           third
# 32    NaN      at   NaN   the     a     On       as  2027             NaN
# 33    NaN     NaN   NaN   the     a     at       in    21             net
# 34    NaN      in   NaN   NaN   the     to       at   NaN             NaN
# 35    NaN     NaN   NaN   the     a     On       at    21       financial
# 36    NaN     NaN   NaN   NaN   the     on       of   NaN             NaN
# 37    NaN     NaN   NaN   the   the     on       in   NaN             NaN
# 38    NaN     NaN   NaN  some   the     In       at   NaN             NaN
# 39    NaN      to   NaN   the   The     of       in   NaN       financial
# 40    NaN      in   NaN   NaN   the     of       at   NaN           rural
# 41    NaN      in   NaN   NaN   the     of       at   NaN           urban
# 42    NaN      by   NaN   the   The     of       at   NaN         primary
# 43    NaN      in   NaN   the   the     On       in   NaN       unhealthy
# 44    NaN     for   NaN   the   The     by    among   NaN        American
# 45    NaN      in   NaN   the   the     to       of   NaN       healthier
# 46    NaN  within   NaN     a   the     In       of   NaN            high
# 47    NaN      in   NaN   the   The     of       in   NaN         similar
# 48    NaN      to   NaN   NaN   the     On       in   NaN             NaN
# 49    NaN     NaN   NaN   NaN   the     at       in   NaN       financial
# 50    NaN      in   NaN   the   the     to       in   NaN             NaN
# 51    NaN      in   NaN   the   the     On       of   NaN             NaN
# 52    NaN      in   NaN   the   the     on       of   NaN             NaN
# 53    NaN      in   NaN   NaN   the     to       at   NaN             NaN
# 54    NaN      in   NaN   the   the     In       of   NaN          stable
# 55    NaN      in   NaN   the   The     of       in   NaN            same
# 56    NaN     NaN   NaN   NaN   the     on       at   NaN             NaN
# 57    NaN      of   NaN   the   The     at       in   NaN             NaN
# 58    NaN      in   NaN   the   the     to       at   NaN           third
# 59    NaN     NaN   NaN   NaN   the     On       in   NaN             NaN
# 60    NaN     NaN   NaN   the     a     on       in   NaN             NaN
# 61    NaN      in   NaN   the   the     to       in   NaN             NaN
# 62    NaN      at   NaN   the   the     In       of   NaN          stable
# 63    NaN      to   NaN   the   The     in       in   NaN             NaN
# 64    NaN      of   NaN   the     a     at       in   NaN             net
# 65    NaN      of   NaN   NaN   the     at       in   NaN             NaN
# 66    NaN      in   NaN   NaN   the     to       at   NaN             NaN
# 67    NaN     NaN   NaN   NaN   the     On       at   NaN             NaN
# 68    NaN     NaN   NaN   NaN   the     on       of   NaN             NaN
# 69    NaN      in   NaN   NaN   the     on       at   NaN             NaN
# 70    NaN     NaN   NaN  some   the     In       at   NaN             NaN
# 71    NaN     NaN   NaN   NaN   the     in       to   NaN             NaN
# 72    NaN      in   NaN   NaN   the     of       at   NaN           local
# 73    NaN      in   NaN   NaN   the     of       at   NaN           urban
# 74    NaN      in   NaN   the   The     of       at   NaN         primary
# 75    NaN     NaN   NaN   NaN   the     On       in   NaN             NaN
# 76    NaN     NaN   may   the   The     by    among   NaN        physical
# 77    NaN      of   NaN   the     a     to       by   NaN         chronic
# 78    NaN      in   NaN   the     a     In       of   NaN          stable
# 79    NaN      to   NaN   the   the     in       in   NaN    preventative
# 80    NaN      in   NaN   the   the     On      for   NaN       renewable
# 81    NaN     NaN   NaN   NaN   the     at       in   NaN       financial
# 82    NaN      in   NaN   the   the     to       in   NaN             NaN
# 83    NaN      in   NaN   the   the     On       of   NaN             NaN
# 84    NaN      in   NaN   the   the     on       of   NaN             NaN
# 85     to      in   NaN  some   the     to       at   NaN             NaN
# 86    NaN      of   NaN  some   the     In       of   NaN             NaN
# 87    NaN     NaN   NaN   NaN   NaN     in       to   NaN             NaN
# 88    NaN     NaN   NaN   NaN   the     on       at   NaN             NaN
# 89    NaN     NaN   NaN   the   The     on       at    21             NaN
# 90    NaN      in   NaN   the   the     to       at   NaN             NaN
# 91    NaN      in   NaN   the     a     On       as   NaN             NaN
# 92    NaN     NaN   NaN   the   The     in       on   NaN             NaN
# 93    NaN      at   NaN   the     a     to       as   NaN           early
# 94    NaN      at   NaN   the     a     In       as   NaN             NaN
# 95    NaN      to   NaN     a   The     in       in   NaN             NaN
#
#           NOUN_6         NOUN_1     VERB_2      PROPN_4 ADP_5 PUNCT_6  \
# 0            NaN        analyst   decrease          NaN    of     NaN
# 1            NaN      operating   increase          NaN   NaN     NaN
# 2            NaN         profit   expected           Q2   NaN     NaN
# 3            NaN          stock   increase       Amazon   NaN     NaN
# 4            NaN        analyst       rise          NaN   NaN     NaN
# 5            NaN           cash  operating          NaN   NaN     NaN
# 6            NaN          stock        has        Tesla   NaN     NaN
# 7            NaN          stock  according      Stanley   NaN     NaN
# 8            NaN     prevalence   decrease          NaN   NaN     NaN
# 9            NaN     prevalence   decrease          NaN   NaN     NaN
# 10           NaN     prevalence   decrease          WHO   NaN     NaN
# 11           NaN        obesity   increase        North   NaN     NaN
# 12           NaN       activity       rise          NaN   NaN     NaN
# 13        health         health  envisions          NaN   NaN     NaN
# 14     awareness         health        has      Johnson   NaN       .
# 15           NaN     engagement   increase          NaN   NaN     NaN
# 16           NaN     compliance   decrease          NaN   NaN     NaN
# 17      decrease         Policy        NaN           Q2   NaN     NaN
# 18           NaN      economist       fall           Q2   NaN     NaN
# 19           NaN         policy   increase          NaN   NaN     NaN
# 20    healthcare         Policy       rise          NaN   NaN     NaN
# 21           NaN      executive   decrease      Walmart   NaN     NaN
# 22   regulations         policy        has    Rodriguez   NaN     NaN
# 23           NaN         number  according        David   NaN     NaN
# 24           NaN    temperature   decrease      Chicago   NaN     NaN
# 25           NaN           wind        NaN           Q3   NaN     NaN
# 26           NaN    temperature        has      January   NaN     NaN
# 27           NaN  precipitation   increase          New   NaN     NaN
# 28           NaN           wind       rise         July   NaN     NaN
# 29           NaN       humidity       fall        Clara   NaN     NaN
# 30           NaN    temperature        has        Level   NaN     NaN
# 31           NaN           wind  according          San   NaN     NaN
# 32           NaN         expert   decrease          NaN    of     NaN
# 33           NaN        analyst        NaN          NaN   NaN     NaN
# 34           NaN         profit       fall        Sachs   NaN     NaN
# 35           NaN        analyst   increase          NaN   NaN     NaN
# 36           NaN        revenue       rise          NaN   NaN     NaN
# 37           NaN       earnings  forecasts          NaN   NaN     NaN
# 38           NaN       research        has          NaN   NaN     NaN
# 39           NaN        trading  according          NaN   NaN     NaN
# 40           NaN     prevalence   decrease          NaN   NaN     NaN
# 41           NaN     prevalence   decrease           Q3   NaN     NaN
# 42           NaN     prevalence   decrease          WHO   NaN     NaN
# 43           NaN        obesity   increase        North   NaN     NaN
# 44  intervention    cholesterol       rise           Q2   NaN     NaN
# 45       choices         number       fall          NaN    by     NaN
# 46          work         health       have      Johnson   NaN     NaN
# 47           NaN     prevalence  according      College    of     NaN
# 48           NaN       consumer   decrease     Reynolds   NaN     NaN
# 49           NaN         Policy   decrease           Q2   NaN     NaN
# 50           NaN      economist       fall           Q2   NaN     NaN
# 51       finance         policy   decrease          NaN   NaN     NaN
# 52        sector         Policy       sold          NaN   NaN     NaN
# 53           NaN      executive   increase          Sam   NaN     NaN
# 54     utilities         policy        has          NaN   NaN     NaN
# 55           NaN         number  according          NaN   NaN     NaN
# 56           NaN           wind   decrease        Miami   NaN     NaN
# 57           NaN           wind        NaN    Francisco   NaN     NaN
# 58           NaN           team   decrease          New    of     NaN
# 59           NaN    temperature   increase        Miami   NaN     NaN
# 60           NaN        weather       rise         July   NaN     NaN
# 61           NaN       humidity       fall    September   NaN     NaN
# 62           NaN           team        has      Service   NaN     NaN
# 63           NaN           wind  according      Weather   NaN     NaN
# 64           NaN         expert   decrease          NaN   NaN     NaN
# 65           NaN         profit        NaN           Q4   NaN     NaN
# 66           NaN         profit   expected           Q2   NaN     NaN
# 67           NaN          stock   increase       Amazon   NaN     NaN
# 68           NaN        revenue       rise     Alphabet   NaN     NaN
# 69           NaN       analysis  operating          NaN   NaN     NaN
# 70           NaN       research       have          NaN   NaN     NaN
# 71           NaN          stock  according  MarketWatch   NaN     NaN
# 72           NaN     prevalence   decrease          NaN   NaN     NaN
# 73           NaN     prevalence   decrease           Q3   NaN     NaN
# 74           NaN     prevalence   decrease          WHO   NaN     NaN
# 75           NaN        obesity   increase        North   NaN     NaN
# 76           NaN       activity       rise          NaN   NaN     NaN
# 77           NaN         report       fall          NaN    in     NaN
# 78   probability         health       aged          NaN   NaN     NaN
# 79           NaN     engagement  according          NaN   NaN     NaN
# 80           NaN        support   decrease          NaN   NaN     NaN
# 81           NaN         Policy   decrease           Q2   NaN     NaN
# 82           NaN      economist       fall           Q2   NaN     NaN
# 83       finance         policy   decrease          NaN   NaN     NaN
# 84   regulations         Policy       rise          NaN   NaN     NaN
# 85           NaN          sales       have          Sam   NaN     NaN
# 86       markets         policy   emerging          NaN   NaN     NaN
# 87           NaN        Defense       stay      Johnson   NaN     NaN
# 88           NaN           wind   decrease       August   NaN     NaN
# 89           NaN       humidity       rise      Orleans   NaN     NaN
# 90           NaN           team   decrease          New   NaN     NaN
# 91           NaN        weather   increase          NaN   NaN     NaN
# 92           NaN           wind       rise         June   NaN     NaN
# 93           NaN      executive       fall          NaN    in     NaN
# 94           NaN        weather       stay          NaN   NaN     NaN
# 95           NaN    temperature  according          NaN   NaN     NaN
#
#          NOUN_7 PUNCT_5         NOUN_2      VERB_5  PROPN_6 SYM_1     PROPN_2  \
# 0           NaN     NaN        revenue         NaN      NaN   NaN      Amazon
# 1           NaN     NaN         income         NaN      NaN     -     Stanley
# 2           NaN     NaN            NaN         NaN      NaN   NaN       Chase
# 3           NaN     NaN          price         NaN      NaN   NaN     Goldman
# 4           NaN     NaN        revenue         NaN      NaN   NaN      Google
# 5           NaN     NaN           flow         NaN      NaN   NaN  ExxonMobil
# 6           NaN     NaN          price         NaN      NaN   NaN       Wells
# 7           NaN     NaN          price         NaN      NaN   NaN      August
# 8           NaN     NaN      illnesses         NaN      NaN   NaN       Smith
# 9           NaN     NaN      illnesses         NaN      NaN   NaN         NaN
# 10          NaN     NaN       diabetes         NaN      NaN   NaN      Health
# 11          NaN     NaN          rates         NaN      NaN   NaN        Jane
# 12          NaN     NaN         levels         NaN      NaN   NaN          Q4
# 13      centers     NaN         report         NaN      NaN   NaN         NaN
# 14      support       ,         expert  increasing      NaN   NaN         Dr.
# 15          NaN     NaN         health         NaN      NaN   NaN     Medical
# 16          NaN     NaN   requirements         NaN      NaN   NaN     Goldman
# 17          NaN     NaN        analyst         NaN      NaN   NaN      Samuel
# 18          NaN     NaN   unemployment         NaN      NaN   NaN       Sofia
# 19          NaN     NaN         expert         NaN      NaN   NaN         Kim
# 20       sector     NaN        analyst         NaN      NaN   NaN       Smith
# 21          NaN     NaN          sales         NaN      NaN   NaN         Sam
# 22  probability     NaN        advisor         NaN      NaN   NaN         Dr.
# 23          NaN     NaN          trade         NaN      NaN   NaN       China
# 24          NaN     NaN            NaN         NaN      NaN   NaN     Analyst
# 25          NaN     NaN          speed         NaN      NaN   NaN     Channel
# 26          NaN     NaN      potential         NaN      NaN   NaN       Sarah
# 27          NaN     NaN         levels         NaN      NaN   NaN     Analyst
# 28          NaN     NaN          speed         NaN      NaN   NaN      Expert
# 29          NaN     NaN            NaN         NaN  Angeles   NaN         Top
# 30          NaN     NaN    probability         NaN     Dave   NaN     Weather
# 31          NaN     NaN          speed         NaN  Weather   NaN   Francisco
# 32          NaN     NaN        revenue         NaN      NaN   NaN      Amazon
# 33          NaN     NaN         profit         NaN      NaN     -         Doe
# 34          NaN     NaN            NaN         NaN      NaN   NaN       Chase
# 35          NaN     NaN          stock         NaN      NaN     -         NaN
# 36          NaN     NaN            NaN         NaN      NaN   NaN     Buffett
# 37          NaN     NaN         report         NaN      NaN   NaN       Apple
# 38          NaN     NaN    development         NaN      NaN   NaN   BlackRock
# 39          NaN     NaN         volume         NaN      NaN   NaN        Inc.
# 40          NaN     NaN      illnesses         NaN      NaN   NaN       Smith
# 41          NaN     NaN      illnesses         NaN      NaN   NaN       Emily
# 42          NaN     NaN       diabetes         NaN      NaN   NaN      Health
# 43          NaN     NaN          rates         NaN      NaN   NaN        Jane
# 44          NaN     NaN         levels         NaN      NaN   NaN       Heart
# 45          NaN     NaN        smokers         NaN      NaN   NaN      United
# 46  environment     NaN      awareness         NaN      NaN   NaN         Dr.
# 47          NaN     NaN      allergies         NaN   Asthma   NaN      States
# 48          NaN     NaN     confidence         NaN      NaN   NaN         Dr.
# 49          NaN     NaN        analyst         NaN      NaN   NaN      Samuel
# 50          NaN     NaN   unemployment         NaN      NaN   NaN       Sofia
# 51       sector     NaN         expert         NaN      NaN   NaN         Kim
# 52          NaN     NaN        analyst         NaN      NaN   NaN        Chen
# 53          NaN     NaN       customer         NaN       Q3   NaN         Sam
# 54       sector     NaN     strategist         NaN      NaN   NaN       Sarah
# 55          NaN     NaN        mergers         NaN      NaN   NaN       David
# 56          NaN     NaN          speed         NaN      NaN   NaN     Analyst
# 57          NaN     NaN          speed         NaN      NaN   NaN     Channel
# 58          NaN     NaN  precipitation         NaN   August   NaN     Weather
# 59          NaN     NaN            NaN         NaN      NaN   NaN       Sarah
# 60          NaN       .         expert         NaN  Angeles   NaN       James
# 61          NaN     NaN            NaN         NaN      NaN   NaN     Channel
# 62          NaN     NaN    temperature         NaN      NaN   NaN    National
# 63          NaN     NaN          speed         NaN      NaN   NaN     October
# 64          NaN     NaN         profit         NaN      NaN   NaN      Amazon
# 65          NaN     NaN       decrease         NaN      NaN   NaN       Sachs
# 66          NaN     NaN            NaN         NaN      NaN   NaN       Chase
# 67          NaN     NaN          price         NaN      NaN   NaN     Goldman
# 68          NaN     NaN            NaN         NaN      NaN   NaN      Cramer
# 69          NaN     NaN           cash         NaN      NaN   NaN  ExxonMobil
# 70          NaN     NaN    development         NaN      NaN   NaN   BlackRock
# 71          NaN     NaN          price         NaN      NaN   NaN        Inc.
# 72          NaN     NaN      illnesses         NaN      NaN   NaN       Smith
# 73          NaN     NaN      illnesses         NaN      NaN   NaN       Emily
# 74          NaN     NaN       diabetes         NaN      NaN   NaN      Health
# 75          NaN     NaN          rates         NaN      NaN   NaN      Sanjay
# 76          NaN     NaN         levels         NaN      NaN   NaN          Q4
# 77          NaN     NaN     prevalence         NaN      NaN   NaN         NaN
# 78          NaN     NaN         expert         NaN      NaN   NaN          US
# 79          NaN     NaN         health         NaN      NaN   NaN     Medical
# 80          NaN     NaN         energy         NaN      NaN   NaN         NaN
# 81          NaN     NaN        analyst         NaN      NaN   NaN       Emily
# 82          NaN     NaN   unemployment         NaN      NaN   NaN       Sofia
# 83       sector     NaN        analyst         NaN      NaN   NaN         Kim
# 84       energy     NaN         expert         NaN      NaN   NaN         Lee
# 85          NaN     NaN    probability         NaN       Q4   NaN         Sam
# 86    potential     NaN     strategist         NaN      NaN   NaN      Rachel
# 87          NaN     NaN       spending         NaN      NaN   NaN     General
# 88          NaN     NaN          speed         NaN      NaN   NaN     Analyst
# 89          NaN     NaN            NaN         NaN      NaN     -     Channel
# 90          NaN     NaN  precipitation         NaN      NaN   NaN     Weather
# 91          NaN       .         expert         NaN      NaN   NaN         Los
# 92          NaN     NaN          speed         NaN      NaN   NaN     Company
# 93          NaN     NaN       humidity         NaN      NaN   NaN     Phoenix
# 94          NaN     NaN        analyst         NaN      NaN   NaN     Houston
# 95          NaN     NaN        weather         NaN      NaN   NaN    November
#
#    CCONJ_1      VERB_1       VERB_3      ADJ_3
# 0      NaN     predict          NaN        NaN
# 1      NaN  speculates          NaN        NaN
# 2      NaN   According     decrease        NaN
# 3      NaN  speculates          NaN        NaN
# 4      NaN    predicts          NaN        NaN
# 5      NaN   According         fall        NaN
# 6      NaN   envisions       remain        NaN
# 7      NaN        stay          NaN        NaN
# 8      NaN    predicts          NaN        NaN
# 9      NaN   forecasts          NaN      urban
# 10     NaN   forecasts          NaN        NaN
# 11     NaN  speculates          NaN        NaN
# 12     NaN    predicts          NaN   American
# 13     NaN   According         fall        NaN
# 14     and    foresees       remain     stable
# 15      or        stay    according       same
# 16     NaN     predict          NaN        NaN
# 17     NaN   forecasts          NaN        NaN
# 18     NaN   According          NaN        NaN
# 19     NaN  speculates          NaN        NaN
# 20     NaN    predicts          NaN        NaN
# 21     NaN   According          NaN        NaN
# 22     NaN   envisions       remain        NaN
# 23     and        stay          NaN        NaN
# 24     NaN    predicts          NaN        NaN
# 25     NaN   forecasts          NaN        NaN
# 26     NaN   forecasts     decrease        NaN
# 27     NaN  speculates          NaN        NaN
# 28     NaN    predicts          NaN        NaN
# 29     NaN   According          NaN        NaN
# 30     NaN   envisions       remain        NaN
# 31     NaN        stay          NaN        NaN
# 32     NaN     predict          NaN        NaN
# 33     NaN   forecasts          NaN        NaN
# 34     NaN   According          NaN        NaN
# 35     NaN  speculates          NaN        NaN
# 36     NaN    predicts          NaN        NaN
# 37     NaN       Based    operating        NaN
# 38     and   envisions       remain        NaN
# 39     NaN        stay      leading        NaN
# 40     NaN    predicts          NaN        NaN
# 41     NaN   forecasts          NaN        NaN
# 42     NaN   forecasts          NaN        NaN
# 43     and  speculates        given  sedentary
# 44     and    predicts  emphasizing      early
# 45     NaN   According        adopt        NaN
# 46     and   envisions       remain     stable
# 47       &        stay          NaN        NaN
# 48     NaN     predict    according        NaN
# 49     NaN   forecasts          NaN        NaN
# 50     NaN   According          NaN        NaN
# 51     NaN  speculates          NaN        NaN
# 52     NaN    predicts         rise        NaN
# 53     NaN   According          NaN        NaN
# 54     NaN   envisions       remain        NaN
# 55     and        stay          NaN        NaN
# 56     NaN    predicts          NaN        NaN
# 57     NaN   forecasts          NaN        NaN
# 58     NaN   According          NaN        NaN
# 59     NaN  speculates          NaN        NaN
# 60     NaN    predicts          NaN        NaN
# 61     NaN   According          NaN        NaN
# 62     NaN   envisions       remain        NaN
# 63     NaN        stay          NaN        NaN
# 64     NaN    predicts          NaN        NaN
# 65     NaN   forecasts          NaN        NaN
# 66     NaN   According     decrease        NaN
# 67     NaN  speculates          NaN        NaN
# 68     NaN    predicts          NaN        NaN
# 69     NaN       Based         fall        NaN
# 70     and   envisions       remain        NaN
# 71     NaN        stay          NaN        NaN
# 72     NaN    predicts          NaN        NaN
# 73     NaN   forecasts          NaN        NaN
# 74     NaN   forecasts          NaN        NaN
# 75     NaN  speculates          NaN        NaN
# 76     NaN    predicts          NaN   American
# 77     NaN   According          NaN      rural
# 78     NaN   envisions          has        NaN
# 79     NaN        stay          NaN       same
# 80     NaN     predict          NaN   upcoming
# 81     NaN   forecasts          NaN        NaN
# 82     NaN   According          NaN        NaN
# 83     NaN  speculates          NaN        NaN
# 84     NaN    predicts          NaN        NaN
# 85     NaN   According       remain        NaN
# 86     NaN   envisions          has        NaN
# 87     NaN    expected    according        NaN
# 88     NaN    predicts          NaN        NaN
# 89     NaN    predicts          NaN        NaN
# 90     NaN   According          NaN        NaN
# 91     NaN   speculate          NaN        NaN
# 92     NaN    predicts          NaN        NaN
# 93     NaN   According          NaN        NaN
# 94     NaN    envision          NaN        NaN
# 95     NaN    increase          NaN        NaN
