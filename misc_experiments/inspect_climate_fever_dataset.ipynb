# %% [markdown]
# # Inspect CLIMATE-FEVER Dataset
# - WEBSITE: [CLIMATE-FEVER*](https://www.sustainablefinance.uzh.ch/en/research/climate-fever.html)

# %%
import pandas as pd

# %%
file = "/Users/brinkley97/Library/CloudStorage/OneDrive-UniversityofFlorida/research/uf_data_studio_lab/datasets/predictions/climateFever.jsonl"

df = pd.read_json(file, lines = True)
df
# Out:
#       claim_id                                              claim  \
# 0            0  Global warming is driving polar bears toward e...
# 1            5  The sun has gone into ‘lockdown’ which could c...
# 2            6        The polar bear population has been growing.
# 3            9  Ironic' study finds more CO2 has slightly cool...
# 4           10  Human additions of CO2 are in the margin of er...
# ...        ...                                                ...
# 1530      3125  About 60% of the warming observed from 1970 to...
# 1531      3127  "Skeptics hope that Postma’s alternative therm...
# 1532      3130  "There are other possible causes for climate c...
# 1533      3131  We don't need a high heat flow - just a high t...
# 1534      3134  Over the last decade, heatwaves are five times...
#
#           claim_label                                          evidences
# 0            SUPPORTS  [{'evidence_id': 'Extinction risk from global ...
# ...

# %%
pd.set_option('display.max_colwidth', None)
support_claim = 'SUPPORTS'
filt_claims = df['claim_label'] == support_claim
support_df = df[filt_claims == True]
support_df
# Out:
#       claim_id  \
# 0            0
# 1            5
# 5           11
# 6           14
# 11          28
# ...        ...
# 1519      3104
# 1526      3121
# 1528      3123
# 1532      3130
# 1534      3134
#
#                                                                                                                                                                                                                      claim  \
# 0                                                                                                                                                                  Global warming is driving polar bears toward extinction
# 1                                                                                                              The sun has gone into ‘lockdown’ which could cause freezing weather, earthquakes and famine, say scientists
# ...
