# %%
from pyserini.search import FaissSearcher

searcher = FaissSearcher(
    'indexes/dindex-sample-dpr-multi',
    'facebook/dpr-question_encoder-multiset-base'
)
hits = searcher.search('what is a lobster roll')

for i in range(0, 10):
    print(f'{i+1:2} {hits[i].docid:7} {hits[i].score:.5f}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/jnius/env.py:347, in get_jdk_home(platform)
#     346 try:
# --> 347     jdk_home = realpath(
#     348         which('javac')
#     349     ).replace('bin/javac', '')
#     350 except TypeError:
#
# File <frozen posixpath>:415, in realpath(filename, strict)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyserini.search import FaissSearcher
#       3 searcher = FaissSearcher(
#       4     'indexes/dindex-sample-dpr-multi',
#       5     'facebook/dpr-question_encoder-multiset-base'
#       6 )
#       7 hits = searcher.search('what is a lobster roll')
#
# File ~/.local/lib/python3.11/site-packages/pyserini/search/__init__.py:17
#       1 #
#       2 # Pyserini: Reproducible IR research with sparse and dense representations
#       3 #
#    (...)
#      14 # limitations under the License.
#      15 #
# ---> 17 from ._base import get_topics, get_topics_with_reader, get_qrels_file, get_qrels
#
# File ~/.local/lib/python3.11/site-packages/pyserini/search/_base.py:25
#      22 import logging
#      23 import os
# ---> 25 from pyserini.pyclass import autoclass
#      27 logger = logging.getLogger(__name__)
#      28 logging.basicConfig(level=logging.WARNING, format='\n%(asctime)s - %(name)s - %(levelname)s - %(message)s')
#
# File ~/.local/lib/python3.11/site-packages/pyserini/pyclass.py:31
#      27 except:
#      28     # This might happen if the JVM's already been initialized. Just eat the error.
#      29     pass
# ---> 31 from jnius import autoclass, cast
#      33 # Base Java classes
#      34 JString = autoclass('java.lang.String')
#
# File ~/.local/lib/python3.11/site-packages/jnius/__init__.py:45
#      43 else:
#      44     from .jnius import *  # noqa
# ---> 45     from .reflect import *  # noqa
#      47 # XXX monkey patch methods that cannot be in cython.
#      48 # Cython doesn't allow to set new attribute on methods it compiled
#      50 HASHCODE_MAX = 2 ** 31 - 1
#
# File ~/.local/lib/python3.11/site-packages/jnius/reflect.py:19
#      14 __all__ = ('autoclass', 'ensureclass', 'protocol_map')
#      16 log = logging.getLogger('kivy').getChild(__name__)
# ---> 19 class Class(JavaClass, metaclass=MetaJavaClass):
#      20     __javaclass__ = 'java/lang/Class'
#      22     desiredAssertionStatus = JavaMethod('()Z')
#
# File jnius/jnius_export_class.pxi:117, in jnius.MetaJavaClass.__new__()
#
# File jnius/jnius_export_class.pxi:177, in jnius.MetaJavaClass.resolve_class()
#
# File jnius/jnius_env.pxi:11, in jnius.get_jnienv()
#
# File jnius/jnius_jvm_dlopen.pxi:95, in jnius.get_platform_jnienv()
#
# File jnius/jnius_jvm_dlopen.pxi:54, in jnius.create_jnienv()
#
# File ~/.local/lib/python3.11/site-packages/jnius/env.py:60, in get_java_setup(platform)
#      58 # go hunting for Javac and Java programs, in that order
#      59 if not is_set(JAVA_HOME):
# ---> 60     JAVA_HOME = get_jdk_home(platform)
#      62 if not is_set(JAVA_HOME):
#      63     JAVA_HOME = get_jre_home(platform)
#
# File ~/.local/lib/python3.11/site-packages/jnius/env.py:351, in get_jdk_home(platform)
#     347             jdk_home = realpath(
#     348                 which('javac')
#     349             ).replace('bin/javac', '')
#     350         except TypeError:
# --> 351             raise Exception('Unable to find javac')
#     353 if not jdk_home or not exists(jdk_home):
#     354     return None
#
# Exception: Unable to find javac
