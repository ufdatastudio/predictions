# %% [markdown]
# # Prediction Correction
#
# - Given a prediction and an observation, does this observation or group of observations certify this prediction?

# %%
import os
import sys

import pandas as pd

from tqdm import tqdm

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
print(notebook_dir)
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from text_generation_models import TextGenerationModelFactory
# Out:
# /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/prediction_correctness_experiments

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Load Data

# %%
entailment_df = pd.read_csv('../data/entailment/entailment-cosine_similarity-v1.csv')  
entailment_df
# Out:
#                                                                                        Prediction  \
# 0                    Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.
# 1      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 2      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 3      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 4      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 5      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 6      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 7   On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 8   On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 9   On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 10  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 11  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
#
#                                                                                                                                                Observation  \
# 0           In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.
# 1                                                    According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.
# 2                        In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.
# 3                                           Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 4   On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.
# 5                   On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.
# 6                           The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 7                                                      According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.
# 8                                                                                          Apple stock price decreased in August 2024, according to Roger.
# 9                                           Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 10                                                    The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.
# 11                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
#
#    Entailment Label     Spacy  SentenceTransformer      BERT
# 0           NEUTRAL  0.773352             0.328824  0.899819
# 1           NEUTRAL  0.866826             0.644740  0.941268
# 2           NEUTRAL  0.865429             0.311582  0.896069
# 3           NEUTRAL  0.812578             0.321734  0.903572
# 4           NEUTRAL  0.845318             0.282765  0.819832
# 5           NEUTRAL  0.815297             0.490033  0.913402
# 6           NEUTRAL  0.859225             0.489393  0.918903
# 7           NEUTRAL  0.927874             0.771567  0.918560
# 8           NEUTRAL  0.876008             0.375553  0.888524
# 9           NEUTRAL  0.900117             0.394057  0.874122
# 10          NEUTRAL  0.882334             0.159729  0.842496
# 11          NEUTRAL  0.890518             0.403852  0.880021

# %%
from json import loads, dumps
entailment_dict = entailment_df.to_json(orient='records')
entailment_dict = loads(entailment_dict)
print(dumps(entailment_dict, indent=4))
# Out:
# [
#     {
#         "Prediction": "Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.",
#         "Observation": "In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.77335185,
#         "SentenceTransformer": 0.32882446,
#         "BERT": 0.89981854
#     },
#     {
#         "Prediction": "JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.",
#         "Observation": "According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8668256,
#         "SentenceTransformer": 0.64473987,
#         "BERT": 0.9412681
#     },
#     {
#         "Prediction": "JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.",
#         "Observation": "In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8654288,
#         "SentenceTransformer": 0.31158242,
#         "BERT": 0.8960686
#     },
#     {
#         "Prediction": "JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.",
#         "Observation": "Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8125781,
#         "SentenceTransformer": 0.32173368,
#         "BERT": 0.90357155
#     },
#     {
#         "Prediction": "JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.",
#         "Observation": "On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.84531796,
#         "SentenceTransformer": 0.28276524,
#         "BERT": 0.8198323
#     },
#     {
#         "Prediction": "JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.",
#         "Observation": "On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8152969,
#         "SentenceTransformer": 0.49003255,
#         "BERT": 0.91340166
#     },
#     {
#         "Prediction": "JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.",
#         "Observation": "The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8592255,
#         "SentenceTransformer": 0.48939294,
#         "BERT": 0.9189029
#     },
#     {
#         "Prediction": "On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.",
#         "Observation": "According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.9278741,
#         "SentenceTransformer": 0.7715675,
#         "BERT": 0.9185598
#     },
#     {
#         "Prediction": "On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.",
#         "Observation": "Apple stock price decreased in August 2024, according to Roger.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8760084,
#         "SentenceTransformer": 0.3755531,
#         "BERT": 0.8885237
#     },
#     {
#         "Prediction": "On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.",
#         "Observation": "Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.90011734,
#         "SentenceTransformer": 0.39405707,
#         "BERT": 0.87412184
#     },
#     {
#         "Prediction": "On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.",
#         "Observation": "The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8823339,
#         "SentenceTransformer": 0.15972918,
#         "BERT": 0.8424958
#     },
#     {
#         "Prediction": "On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.",
#         "Observation": "The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.",
#         "Entailment Label": "NEUTRAL",
#         "Spacy": 0.8905182,
#         "SentenceTransformer": 0.40385187,
#         "BERT": 0.880021
#     }
# ]

# %% [markdown]
# ## Properties of Both Prediction and Observations

# %%
prediction_properties = """A prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:

    1. <p_s>, any source entity in the domain.
        - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc), civilian.
        - Can only be an organization that is associated with the  prediction.
    2. <p_t>, any target entity in the  domain.
	    - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc).
        - Can only be an organization that is associated with the  prediction.
    3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.
        - Forecast can range from a second to anytime in the future.
        - Answers the questions: "How far to go out from today?" or "Where to stop?".
    4. <p_o>,  prediction outcome.
        - Details relevant details such as outcome, a quantifiable metric, or slope.
"""

observation_properties = """An observation <o> = (<o_s>, <o_t>, <o_d>, <o_a>), where it consists of the following four properties:

    1. <o_s>, any source entity in the domain.
        - Can be a person (with a name) or a   person such as a   reporter,   analyst,   expert,   top executive,   senior level person, etc, civilian.
        - Can only be an organization that is associated with the   observation.
    2. <o_t>, any target entity in the   domain.
        - Can be a person (with a name) or a   person such as a   reporter,   analyst,   expert,   top executive,   senior level person, etc).
        - Can only be an organization that is associated with the   observation.
    3. <o_d>, date or time range when <o> is expected to come to fruition or when one should observe the <o>.
        - Forecast can range from a second to anytime in the future.
        - Answers the questions: "How far to go out from today?" or "Where to stop?".
    4. <o_a>,   observation output.
        - Characteristics of a domain-specific outputs such as various quantifiable metrics relevant to the   domain.
        - Some examples are {observation_domain_output}.
"""

# %% [markdown]
# ## Models to Certify

# %%
tgmf = TextGenerationModelFactory()

# Groq Cloud (https://console.groq.com/docs/overview)
gemma_29b_generation_model = tgmf.create_instance('gemma2-9b-it') 
llama_318b_instant_generation_model = tgmf.create_instance('llama-3.1-8b-instant') 
llama_3370b_versatile_generation_model = tgmf.create_instance('llama-3.3-70b-versatile')  
llama_guard_4_12b_generation_model = tgmf.create_instance('meta-llama/llama-guard-4-12b')  

models = [gemma_29b_generation_model, llama_318b_instant_generation_model, llama_3370b_versatile_generation_model, llama_guard_4_12b_generation_model]

# %% [markdown]
# ## Certify

# %%
def llm_certifier(data: list, prediction_properties: str, observation_properties: str):
    
    preds_obs_labels = []
    for record in tqdm(entailment_dict):
        prediction = record['Prediction']
        observation = record['Observation']
        entailment_label = record['Entailment Label']
        spacy_score = record['Spacy']
        sentence_transformer_score = record['SentenceTransformer']
        bert_score = record['BERT']

        

        prompt = f"We have {prediction_properties} and {observation_properties}. The main difference at the moment is a prediction is future tense and observation is past tense. Return if the observation ({observation}) certifies this prediction ({prediction}). Take into account entailment label ({entailment_label}) using roberta-large-mnli, embeddings (of prediction and observation) measuring cosine similarity score (between prediction and observation using sklearn.metrics.pairwise.cosine_similarity): ({spacy_score}) using Spacy, ({sentence_transformer_score}) using all-MiniLM-L6-v2, and ({bert_score}) using bert-base-uncased. The return label MUST be certify, not certify, or neither and nothing more (as in do not state why)." 
        # print(f"Prompt: {prompt}")
        # print()

        for model in models:  
            input_prompt = model.user(prompt)
            # print(input_prompt)  
            
            raw_text_llm_generation = model.chat_completion([input_prompt])
            # print(raw_text_llm_generation)

            for line in raw_text_llm_generation.split("\n"):
                # print(line)
                if line.strip():
                    pred_ob_label = (prediction, observation, line, model.__name__())
            preds_obs_labels.append(pred_ob_label)
    return preds_obs_labels

# %%
certifier_predictions = llm_certifier(entailment_dict, prediction_properties, observation_properties)
certifier_predictions
# Out:
# 100%|██████████| 12/12 [00:48<00:00,  4.04s/it]
# [('Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.',
#   'In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.',
#   'In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.',
#   'certify',
#   'llama-3.1-8b-instant'),
#  ('Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.',
#   'In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.',
#   'In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.',
#   'Therefore, the entailment label for the observation and prediction is "certify".',
#   'llama-3.1-8b-instant'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.',
#   'S6',
#   'meta-llama/llama-guard-4-12b'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.',
#   'Therefore, the return label is: certify',
#   'llama-3.1-8b-instant'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'neither ',
#   'gemma2-9b-it'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'certify',
#   'llama-3.1-8b-instant'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.',
#   'certify',
#   'llama-3.1-8b-instant'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.',
#   'S6',
#   'meta-llama/llama-guard-4-12b'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.',
#   'The entailment label is NEUTRAL, but the high cosine similarity scores using different embeddings (0.8152969, 0.91340166, and 0.49003255) suggest a strong relationship between the observation and the prediction, supporting the conclusion that the observation certifies the prediction.',
#   'llama-3.1-8b-instant'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'Therefore, based on the information provided, the return label would be "certify".',
#   'llama-3.1-8b-instant'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.',
#   "Reason: The observation confirms the prediction, as it mentions a future event (second quarter of 2026) that aligns with the prediction's timeframe. The entailment label is NEUTRAL, but the cosine similarity scores from different models all indicate a high similarity between the prediction and observation, suggesting a strong connection between the two.",
#   'llama-3.1-8b-instant'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Apple stock price decreased in August 2024, according to Roger.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Apple stock price decreased in August 2024, according to Roger.',
#   'certify',
#   'llama-3.1-8b-instant'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Apple stock price decreased in August 2024, according to Roger.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Apple stock price decreased in August 2024, according to Roger.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'certify ',
#   'gemma2-9b-it'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'Given the high cosine similarity scores and the lack of direct contradiction between the observation and prediction, I would conclude that the observation certifies the prediction.',
#   'llama-3.1-8b-instant'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.',
#   'neither ',
#   'gemma2-9b-it'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.',
#   'certify',
#   'llama-3.1-8b-instant'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'neither ',
#   'gemma2-9b-it'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'certify',
#   'llama-3.1-8b-instant'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'not certify',
#   'llama-3.3-70b-versatile'),
#  ('On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.',
#   'The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.',
#   'safe',
#   'meta-llama/llama-guard-4-12b')]

# %%
df = pd.DataFrame(certifier_predictions, columns=['Prediction Sentence', 'Observation Sentence', 'Label', 'Model'])
df
# Out:
#                                                                               Prediction Sentence  \
# 0                    Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.
# 1                    Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.
# 2                    Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.
# 3                    Citigroup predicts on 2024-08-21, the operating income at Alphabet may rise.
# 4      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 5      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 6      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 7      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 8      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 9      JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 10     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 11     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 12     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 13     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 14     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 15     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 16     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 17     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 18     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 19     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 20     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 21     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 22     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 23     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 24     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 25     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 26     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 27     JPMorgan Chase forecasts that the net profit at Amazon potentially decrease in Q3 of 2027.
# 28  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 29  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 30  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 31  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 32  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 33  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 34  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 35  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 36  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 37  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 38  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 39  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 40  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 41  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 42  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 43  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 44  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 45  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 46  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
# 47  On August 21, 2024, Bank of America speculates the revenue at Microsoft will likely increase.
#
#                                                                                                                                       Observation Sentence  \
# 0           In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.
# 1           In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.
# 2           In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.
# 3           In Q2 2025, a financial research advisor envisions that the research and development expenses at Google has some probability to remain stable.
# 4                                                    According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.
# 5                                                    According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.
# 6                                                    According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.
# 7                                                    According to the financial top executive at BlackRock, the stock price at Amazon may rise in Q4 2028.
# 8                        In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.
# 9                        In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.
# 10                       In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.
# 11                       In the fourth quarter of 2027, Wells Fargo envisions that the operating cash flow at Intel has some probability to remain stable.
# 12                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 13                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 14                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 15                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 16  On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.
# 17  On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.
# 18  On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.
# 19  On March 1, 2029, the financial advisor at Wells Fargo envisions that the inflation rate at the Federal Reserve has some probability to remain stable.
# 20                  On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.
# 21                  On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.
# 22                  On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.
# 23                  On November 10, 2022, to November 10, 2023, Citigroup speculates the research and development expenses at Amazon will likely increase.
# 24                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 25                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 26                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 27                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 28                                                     According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.
# 29                                                     According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.
# 30                                                     According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.
# 31                                                     According to Bank of America, the net profit at Microsoft would fall in the second quarter of 2026.
# 32                                                                                         Apple stock price decreased in August 2024, according to Roger.
# 33                                                                                         Apple stock price decreased in August 2024, according to Roger.
# 34                                                                                         Apple stock price decreased in August 2024, according to Roger.
# 35                                                                                         Apple stock price decreased in August 2024, according to Roger.
# 36                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 37                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 38                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 39                                          Intel stock price should stay the same in January 2028, according to a financial expert at Harvard University.
# 40                                                    The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.
# 41                                                    The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.
# 42                                                    The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.
# 43                                                    The trading volume at Alibaba remained stable, according to the research advisor at Bank of America.
# 44                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 45                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 46                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
# 47                          The trading volume at Apple should stay same in the fourth quarter of 2025, according to a financial expert at JPMorgan Chase.
#
#                                                                                                                                                                                                                                                                                                                                                                   Label  \
# 0                                                                                                                                                                                                                                                                                                                                                              certify
# 1                                                                                                                                                                                                                                                                                                                                                               certify
# 2                                                                                                                                                                                                                                                                                                                                                           not certify
# 3                                                                                                                                                                                                                                                                                                                                                                  safe
# 4                                                                                                                                                                                                                                                                                                                                                              certify
# 5                                                                                                                                                                                                                                                                                      Therefore, the entailment label for the observation and prediction is "certify".
# 6                                                                                                                                                                                                                                                                                                                                                           not certify
# 7                                                                                                                                                                                                                                                                                                                                                                    S6
# 8                                                                                                                                                                                                                                                                                                                                                              certify
# 9                                                                                                                                                                                                                                                                                                                               Therefore, the return label is: certify
# 10                                                                                                                                                                                                                                                                                                                                                          not certify
# 11                                                                                                                                                                                                                                                                                                                                                                 safe
# 12                                                                                                                                                                                                                                                                                                                                                             neither
# 13                                                                                                                                                                                                                                                                                                                                                              certify
# 14                                                                                                                                                                                                                                                                                                                                                          not certify
# 15                                                                                                                                                                                                                                                                                                                                                                 safe
# 16                                                                                                                                                                                                                                                                                                                                                             certify
# 17                                                                                                                                                                                                                                                                                                                                                              certify
# 18                                                                                                                                                                                                                                                                                                                                                          not certify
# 19                                                                                                                                                                                                                                                                                                                                                                   S6
# 20                                                                                                                                                                                                                                                                                                                                                             certify
# 21                                                                         The entailment label is NEUTRAL, but the high cosine similarity scores using different embeddings (0.8152969, 0.91340166, and 0.49003255) suggest a strong relationship between the observation and the prediction, supporting the conclusion that the observation certifies the prediction.
# 22                                                                                                                                                                                                                                                                                                                                                          not certify
# 23                                                                                                                                                                                                                                                                                                                                                                 safe
# 24                                                                                                                                                                                                                                                                                                                                                             certify
# 25                                                                                                                                                                                                                                                                                   Therefore, based on the information provided, the return label would be "certify".
# 26                                                                                                                                                                                                                                                                                                                                                          not certify
# 27                                                                                                                                                                                                                                                                                                                                                                 safe
# 28                                                                                                                                                                                                                                                                                                                                                             certify
# 29  Reason: The observation confirms the prediction, as it mentions a future event (second quarter of 2026) that aligns with the prediction's timeframe. The entailment label is NEUTRAL, but the cosine similarity scores from different models all indicate a high similarity between the prediction and observation, suggesting a strong connection between the two.
# 30                                                                                                                                                                                                                                                                                                                                                          not certify
# 31                                                                                                                                                                                                                                                                                                                                                                 safe
# 32                                                                                                                                                                                                                                                                                                                                                             certify
# 33                                                                                                                                                                                                                                                                                                                                                              certify
# 34                                                                                                                                                                                                                                                                                                                                                          not certify
# 35                                                                                                                                                                                                                                                                                                                                                                 safe
# 36                                                                                                                                                                                                                                                                                                                                                             certify
# 37                                                                                                                                                                                 Given the high cosine similarity scores and the lack of direct contradiction between the observation and prediction, I would conclude that the observation certifies the prediction.
# 38                                                                                                                                                                                                                                                                                                                                                          not certify
# 39                                                                                                                                                                                                                                                                                                                                                                 safe
# 40                                                                                                                                                                                                                                                                                                                                                             neither
# 41                                                                                                                                                                                                                                                                                                                                                              certify
# 42                                                                                                                                                                                                                                                                                                                                                          not certify
# 43                                                                                                                                                                                                                                                                                                                                                                 safe
# 44                                                                                                                                                                                                                                                                                                                                                             neither
# 45                                                                                                                                                                                                                                                                                                                                                              certify
# 46                                                                                                                                                                                                                                                                                                                                                          not certify
# 47                                                                                                                                                                                                                                                                                                                                                                 safe
#
#                            Model
# 0                   gemma2-9b-it
# 1           llama-3.1-8b-instant
# 2        llama-3.3-70b-versatile
# 3   meta-llama/llama-guard-4-12b
# 4                   gemma2-9b-it
# 5           llama-3.1-8b-instant
# 6        llama-3.3-70b-versatile
# 7   meta-llama/llama-guard-4-12b
# 8                   gemma2-9b-it
# 9           llama-3.1-8b-instant
# 10       llama-3.3-70b-versatile
# 11  meta-llama/llama-guard-4-12b
# 12                  gemma2-9b-it
# 13          llama-3.1-8b-instant
# 14       llama-3.3-70b-versatile
# 15  meta-llama/llama-guard-4-12b
# 16                  gemma2-9b-it
# 17          llama-3.1-8b-instant
# 18       llama-3.3-70b-versatile
# 19  meta-llama/llama-guard-4-12b
# 20                  gemma2-9b-it
# 21          llama-3.1-8b-instant
# 22       llama-3.3-70b-versatile
# 23  meta-llama/llama-guard-4-12b
# 24                  gemma2-9b-it
# 25          llama-3.1-8b-instant
# 26       llama-3.3-70b-versatile
# 27  meta-llama/llama-guard-4-12b
# 28                  gemma2-9b-it
# 29          llama-3.1-8b-instant
# 30       llama-3.3-70b-versatile
# 31  meta-llama/llama-guard-4-12b
# 32                  gemma2-9b-it
# 33          llama-3.1-8b-instant
# 34       llama-3.3-70b-versatile
# 35  meta-llama/llama-guard-4-12b
# 36                  gemma2-9b-it
# 37          llama-3.1-8b-instant
# 38       llama-3.3-70b-versatile
# 39  meta-llama/llama-guard-4-12b
# 40                  gemma2-9b-it
# 41          llama-3.1-8b-instant
# 42       llama-3.3-70b-versatile
# 43  meta-llama/llama-guard-4-12b
# 44                  gemma2-9b-it
# 45          llama-3.1-8b-instant
# 46       llama-3.3-70b-versatile
# 47  meta-llama/llama-guard-4-12b
