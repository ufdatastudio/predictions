# %% [markdown]
# ## Evaluation + Metrics
#
# - PAPER: [Collective Reasoning Among LLMs: A Framework for Answer Validation Without Ground Truth](https://arxiv.org/pdf/2502.20758) by Davoudi et al., 2025

# %%
import os
import sys
import warnings
import statsmodels

import numpy as np
import pandas as pd

from tqdm import tqdm
from statistics import mean
from json import loads, dumps

from statsmodels.stats.inter_rater import cohens_kappa, fleiss_kappa

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

# import log_files
from metrics import EvaluationMetric
from data_visualizing import DataPlotting
from data_processing import DataProcessing

# %%
get_metrics = EvaluationMetric()
get_metrics

# %% [markdown]
# ## Load Data

# %%
base_data_path = os.path.join(notebook_dir, '../data')
combine_data_path = os.path.join(base_data_path, 'classification_results/combined-full_synthetic-v1_2026-03-07/seed40/inference')
files = os.listdir(combine_data_path)
files
# Out:
# ['inference_chronicle2050_2026-03-07_21-51-47.csv',
#  'inference_financial_phrasebank-imbalanced_2026-03-07_21-52-34.csv']

# %%
def standardize_columns(df):
    """Rename columns to standard format."""
    df_copy = df.copy()
    
    # Map text column
    if 'Base Sentence' in df_copy.columns:
        df_copy = df_copy.rename(columns={'Base Sentence': 'text'})
    elif 'sentence' in df_copy.columns:
        df_copy = df_copy.rename(columns={'sentence': 'text'})
    
    # Map embedding column
    if 'Base Sentence Embedding' in df_copy.columns:
        df_copy = df_copy.rename(columns={'Base Sentence Embedding': 'embedding'})
    elif 'sentence Embedding' in df_copy.columns:
        df_copy = df_copy.rename(columns={'sentence Embedding': 'embedding'})
    
    # Map label column (if exists)
    if 'Sentence Label' in df_copy.columns:
        df_copy = df_copy.rename(columns={'Sentence Label': 'label'})
    elif 'maya_label' in df_copy.columns:
        df_copy = df_copy.rename(columns={'maya_label': 'label'})
    
    # Keep only relevant columns
    model_cols = [
        'logistic_regression', 'sgd_classifier', 
        'support_vector_machine_classifier', 'random_forest_classifier',
        'decision_tree_classifier', 'gradient_boosting_classifier',
        'ridge_classifier', 'perceptron', 'x_gradient_boosting_classifier'
    ]
    
    keep_cols = ['text', 'Dataset'] + [col for col in model_cols if col in df_copy.columns]
    
    # Add label if exists
    if 'label' in df_copy.columns:
        keep_cols.insert(1, 'label')
    
    return df_copy[keep_cols]

# %%
# Load and standardize
dfs = []
for file in files:
    dataset_path = os.path.join(combine_data_path, file)
    df = DataProcessing.load_from_file(dataset_path, 'csv', sep=',')
    # print(f"Original columns: {df.columns.tolist()}")
    
    df_standardized = standardize_columns(df)
    # print(f"Standardized columns: {df_standardized.columns.tolist()}\n")
    
    dfs.append(df_standardized)

results_df = DataProcessing.concat_dfs(dfs)
print(f"\nCombined shape: {results_df.shape}")
print(f"Datasets: {results_df['Dataset'].value_counts()}")
results_df
# Out:
# Combined shape: (11248, 12)
# Datasets: Dataset
# chronicle2050                      6402
# financial_phrasebank-imbalanced    4846
# Name: count, dtype: int64
#                                                     text  label  \
# 0      By January 1st, 2037, Tesla will have been the...      1
# 1      An annual average temperature anomaly value ab...      1
# 2      Private Nonfarm business productivity growth w...      1
# 3      No Republican will be President of the USA bef...      1
# 4      The market capitalization of Berkshire Hathawa...      1
# ...                                                  ...    ...
# 11243  LONDON MarketWatch -- Share prices ended lower...      0
# 11244  Rinkuskiai 's beer sales fell by 6.5 per cent ...      0
# 11245  Operating profit fell to EUR 35.4 mn from EUR ...      0
# 11246  Net sales of the Paper segment decreased to EU...      0
# 11247  Sales in Finland decreased by 10.5 % in Januar...      0
#
# ...

# %%
DataPlotting.plot_class_distribution(results_df, 'Dataset', class_names=['chronicle2050', 'financial phrasebank'])

# %% [markdown]
# ## Performance Metrics
#
# + [x] ML only
# + [x] LLM only

# %%
model_names = results_df.columns.to_list()[3:]
model_names
# Out:
# ['logistic_regression',
#  'sgd_classifier',
#  'support_vector_machine_classifier',
#  'random_forest_classifier',
#  'decision_tree_classifier',
#  'gradient_boosting_classifier',
#  'ridge_classifier',
#  'perceptron',
#  'x_gradient_boosting_classifier']

# %% [markdown]
# ## Agreement Metrics
#
# 1. Cohen's Kappa: Intra (within each model category) on the predicted label
# 2. Majority Vote: Intra (within each model category) on the predicted label
# 3. Majority Vote: Inter
# 4. Cohen's Kappa: Inter (across each model category) on the majority vote labels

# %% [markdown]
# ### Majority Vote
#
# + Need an odd number of columns for the `.mode(axis=1)` to work.
#
# ---
#
# + [x] ML only
# + [x] LLM only
# + [x] Combined

# %%
majority_vote = results_df.loc[:, model_names[:3]].mode(axis=1)
results_df['Majority Vote'] = majority_vote
results_df
# Out:
#                                                     text  label  \
# 0      By January 1st, 2037, Tesla will have been the...      1
# 1      An annual average temperature anomaly value ab...      1
# 2      Private Nonfarm business productivity growth w...      1
# 3      No Republican will be President of the USA bef...      1
# 4      The market capitalization of Berkshire Hathawa...      1
# ...                                                  ...    ...
# 11243  LONDON MarketWatch -- Share prices ended lower...      0
# 11244  Rinkuskiai 's beer sales fell by 6.5 per cent ...      0
# 11245  Operating profit fell to EUR 35.4 mn from EUR ...      0
# 11246  Net sales of the Paper segment decreased to EU...      0
# 11247  Sales in Finland decreased by 10.5 % in Januar...      0
#
#                                Dataset  logistic_regression  sgd_classifier  \
# 0                        chronicle2050                    1               1
# ...

# %%
filt_mv_predictions = (results_df['Majority Vote'] == 1)
predictions_df = results_df[filt_mv_predictions]
predictions_df
# Out:
#                                                     text  label  \
# 0      By January 1st, 2037, Tesla will have been the...      1
# 1      An annual average temperature anomaly value ab...      1
# 3      No Republican will be President of the USA bef...      1
# 4      The market capitalization of Berkshire Hathawa...      1
# 5      A bitcoin will be worth less than $1000US by t...      1
# ...                                                  ...    ...
# 11221  Finnish-Swedish Stora Enso does not understand...      0
# 11222  Nevertheless , the development can not be allo...      0
# 11223  Besides , as there is no depositor preference ...      0
# 11226  It holds 38 percent of Outokumpu 's shares and...      0
# 11236  Hobby Hall 's sales decrease 26 pct due to imp...      0
#
#                                Dataset  logistic_regression  sgd_classifier  \
# 0                        chronicle2050                    1               1
# ...

# %%
predictions_df['Dataset'].value_counts()
# Out:
# Dataset
# chronicle2050                      3921
# financial_phrasebank-imbalanced    1819
# Name: count, dtype: int64

# %%
DataPlotting.plot_class_distribution(predictions_df, 'Dataset', class_names=['chronicle2050', 'financial phrasebank'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Dataset and Majority Vote, then count the occurrences
vote_counts = results_df.groupby(['Dataset', 'Majority Vote']).size().unstack(fill_value=0)

# Ensure both 0 and 1 columns exist in the dataframe so colors/labels always map correctly
for col in [0, 1]:
    if col not in vote_counts.columns:
        vote_counts[col] = 0

# Sort columns to ensure 0 is always plotted first, then 1
vote_counts = vote_counts[[0, 1]]

# Rename the datasets for the y-axis labels
dataset_name_mapping = {
    'chronicle2050': 'chronicle2050',
    'financial_phrasebank-imbalanced': 'financial phrasebank'
}
vote_counts = vote_counts.rename(index=dataset_name_mapping)

# Plot the stacked horizontal bar chart
ax = vote_counts.plot(kind='barh', stacked=True, figsize=(14, 7), color=['#ef476f', '#06d6a0'])

# Add numerical values to the center of each bar segment
for container in ax.containers:
    # Only label segments that have a value greater than 0
    labels = [int(v.get_width()) if v.get_width() > 0 else '' for v in container]
    ax.bar_label(container, labels=labels, label_type='center', color='white', weight='bold')

# Calculate totals and place them at the end of each bar
totals = vote_counts.sum(axis=1)
for i, total in enumerate(totals):
    # Adding a tiny amount of padding (1% of max value) so the text doesn't touch the bar
    padding = totals.max() * 0.01
    ax.text(total + padding, i, str(int(total)), va='center', weight='bold', color='black')

# Add labels and formatting
plt.title('Majority Vote (0 vs 1) by Dataset')
plt.xlabel('Number of Samples')
plt.ylabel('Dataset')
plt.legend(title='Majority Vote', labels=['0: Non-Prediction', '1: Prediction'])
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group by Dataset and Majority Vote, then count the occurrences
vote_counts = results_df.groupby(['Dataset', 'Majority Vote']).size().unstack(fill_value=0)

# Ensure both 0 and 1 columns exist in the dataframe so colors map correctly
for col in [0, 1]:
    if col not in vote_counts.columns:
        vote_counts[col] = 0

# Sort columns to ensure 0 is always plotted first, then 1
vote_counts = vote_counts[[0, 1]]

# Update the column names so the legend automatically picks them up
vote_counts.columns = ['Vote = 0', 'Vote = 1']

# Plot the stacked horizontal bar chart
ax = vote_counts.plot(kind='barh', stacked=True, figsize=(10, 6), color=['#ef476f', '#06d6a0'])

# Add numerical values to the center of each bar segment
for container in ax.containers:
    labels = [int(v.get_width()) if v.get_width() > 0 else '' for v in container]
    ax.bar_label(container, labels=labels, label_type='center', color='white', weight='bold')

# Calculate totals and place them at the end of each bar
totals = vote_counts.sum(axis=1)
for i, total in enumerate(totals):
    # Adding a tiny amount of padding (1% of max value) so the text doesn't touch the bar
    padding = totals.max() * 0.01
    ax.text(total + padding, i, str(int(total)), va='center', weight='bold', color='black')

# Add labels and formatting
plt.title('Majority Vote (0 vs 1) by Dataset')
plt.xlabel('Number of Samples')
plt.ylabel('Dataset')
plt.legend(title='Majority Vote')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cohen's Kappa
#
# - How realiable are the raters?
#     - Higher, then they tend to agree
#     - Lower, the they tend to disagree
# - Does NOT state if the raters are correct as in raters can say one thing and real value may be another. This deals with the validity.
#
# ---
#
# 1. Intra (within each model category) on the predicted labels
#     - [x] ML: ML_i vs ML_j
#         - ML_1 vs ML_2
#         - ML_1 vs ML_3
#         - ML_2 vs ML_3

# %%
cohen_all_df = get_metrics.calculate_pairwise_cohens_kappa(results_df, model_names, 'ML', print_bool = False)
cohen_all_df.sort_values("Cohen's Kappa", ascending=False, inplace=True)
cohen_all_df.rename(columns={"Cohen's Kappa": "Cohen's Kappa (All)"}, inplace=True)
cohen_all_df
# Out:
#                               Model 1                            Model 2  \
# 13                     sgd_classifier                         perceptron
# 0                 logistic_regression                     sgd_classifier
# 6                 logistic_regression                         perceptron
# 18  support_vector_machine_classifier                   ridge_classifier
# 8                      sgd_classifier  support_vector_machine_classifier
# 19  support_vector_machine_classifier                         perceptron
# 1                 logistic_regression  support_vector_machine_classifier
# 33                   ridge_classifier                         perceptron
# 5                 logistic_regression                   ridge_classifier
# 12                     sgd_classifier                   ridge_classifier
# 32       gradient_boosting_classifier     x_gradient_boosting_classifier
# 35                         perceptron     x_gradient_boosting_classifier
# ...

# %%
cohen_predictions_df = get_metrics.calculate_pairwise_cohens_kappa(predictions_df, model_names, 'ML', print_bool = False)
cohen_predictions_df.sort_values("Cohen's Kappa", ascending=False, inplace=True)
cohen_predictions_df.rename(columns={"Cohen's Kappa": "Cohen's Kappa (Predictions)"}, inplace=True)
cohen_predictions_df
# Out:
#                               Model 1                            Model 2  \
# 32       gradient_boosting_classifier     x_gradient_boosting_classifier
# 13                     sgd_classifier                         perceptron
# 18  support_vector_machine_classifier                   ridge_classifier
# 25           random_forest_classifier     x_gradient_boosting_classifier
# 22           random_forest_classifier       gradient_boosting_classifier
# 33                   ridge_classifier                         perceptron
# 31       gradient_boosting_classifier                         perceptron
# 14                     sgd_classifier     x_gradient_boosting_classifier
# 35                         perceptron     x_gradient_boosting_classifier
# 6                 logistic_regression                         perceptron
# 11                     sgd_classifier       gradient_boosting_classifier
# 12                     sgd_classifier                   ridge_classifier
# ...

# %%
cohen_df = DataProcessing.concat_dfs([cohen_all_df, cohen_predictions_df], axis=1, ignore_index=False)
cohen_df
# Out:
#                               Model 1                            Model 2  \
# 13                     sgd_classifier                         perceptron
# 0                 logistic_regression                     sgd_classifier
# 6                 logistic_regression                         perceptron
# 18  support_vector_machine_classifier                   ridge_classifier
# 8                      sgd_classifier  support_vector_machine_classifier
# 19  support_vector_machine_classifier                         perceptron
# 1                 logistic_regression  support_vector_machine_classifier
# 33                   ridge_classifier                         perceptron
# 5                 logistic_regression                   ridge_classifier
# 12                     sgd_classifier                   ridge_classifier
# 32       gradient_boosting_classifier     x_gradient_boosting_classifier
# 35                         perceptron     x_gradient_boosting_classifier
# ...

# %% [markdown]
# ### Fleiss’ Kappa
#
# - How realiable are the raters?
#     - Higher, then they tend to agree
#     - Lower, the they tend to disagree
# - Does NOT state if the raters are correct as in raters can say one thing and real value may be another. This deals with the validity.
#
# ---
#
# 1. Intra Model: Predicted Label
#     - [ ] 1. ML: ML_1 vs ML_2 vs ... vs ML_N, where N is odd

# %%
fleiss = {}
fleiss_all_df = get_metrics.get_fleiss_kappa(results_df, model_names)
print("\nFleiss's Kappa (All):", round(fleiss_all_df, 2))
fleiss["Fleiss's Kappa (All)"] = float(round(fleiss_all_df, 2))

fleiss_predictions_df = get_metrics.get_fleiss_kappa(predictions_df, model_names)
print("\nFleiss's Kappa (Predictions Only):", round(fleiss_predictions_df, 2))
fleiss["Fleiss's Kappa (Predictions Only)"] = float(round(fleiss_predictions_df, 2))

fleiss_df = pd.DataFrame([fleiss])
fleiss_df
# Out:
# Fleiss's Kappa (All): 0.61
#
# Fleiss's Kappa (Predictions Only): 0.09
#    Fleiss's Kappa (All)  Fleiss's Kappa (Predictions Only)
# 0                  0.61                               0.09

# %%
fleiss_df = pd.DataFrame(fleiss)
fleiss_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 fleiss_df = pd.DataFrame(fleiss)
#       2 fleiss_df
#
# File ~/Documents/Development/research_labs/uf_ds/predictions/.venv_predictions/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %% [markdown]
# ##  Reliability Metric

# %% [markdown]
# ##  Confidence Intervals via Bootstrap

# %% [markdown]
# > ML > LLM > ML x LLM, why? Due to randomness of LLM?

# %%
import numpy as np
import pandas as pd
from itertools import combinations
from collections import Counter

def pairwise_counts(y1, y2):
    # returns a, b, c, d = n11, n10, n01, n00
    y1 = np.asarray(y1).astype(int)
    y2 = np.asarray(y2).astype(int)
    a = np.sum((y1==1) & (y2==1))
    b = np.sum((y1==1) & (y2==0))
    c = np.sum((y1==0) & (y2==1))
    d = np.sum((y1==0) & (y2==0))
    return a, b, c, d

def kappa_from_counts(a,b,c,d):
    n = a+b+c+d
    po = (a+d)/n if n>0 else np.nan
    p1_1 = (a+b)/n
    p1_2 = (a+c)/n
    p0_1 = 1-p1_1
    p0_2 = 1-p1_2
    pe = p1_1*p1_2 + p0_1*p0_2
    if pe == 1:
        return np.nan, po, pe
    k = (po - pe) / (1 - pe)
    return k, po, pe

def positive_negative_agreement(a,b,c,d):
    pos_agree = (2*a) / (2*a + b + c) if (2*a + b + c) > 0 else np.nan
    neg_agree = (2*d) / (2*d + b + c) if (2*d + b + c) > 0 else np.nan
    return pos_agree, neg_agree

def pabak(po):
    # Prevalence-adjusted, bias-adjusted kappa (for binary, two-rater)
    return 2*po - 1

def gwets_ac1(y1, y2):
    # Simple AC1 for binary
    y1 = np.asarray(y1).astype(int)
    y2 = np.asarray(y2).astype(int)
    n = len(y1)
    po = np.mean(y1 == y2)
    pbar = 0.5*(np.mean(y1==1) + np.mean(y2==1))
    pe = 2*pbar*(1-pbar)
    if pe == 1:
        return np.nan, po, pe
    ac1 = (po - pe) / (1 - pe)
    return ac1, po, pe

def leave_two_out_majority(df, model_cols, exclude):
    cols = [c for c in model_cols if c not in exclude]
    # majority vote (ties break to 0)
    votes = df[cols].sum(axis=1)
    return (votes > (len(cols)/2)).astype(int)

def analyze(preds, model_cols, gold_col=None, boot_iters=0, random_state=0):
    rng = np.random.default_rng(random_state)
    results = []
    # All-items analysis
    for m1, m2 in combinations(model_cols, 2):
        a,b,c,d = pairwise_counts(preds[m1], preds[m2])
        k, po, pe = kappa_from_counts(a,b,c,d)
        ac1, po2, pe2 = gwets_ac1(preds[m1], preds[m2])
        pa, na = positive_negative_agreement(a,b,c,d)
        row = dict(scope='All', m1=m1, m2=m2, n=a+b+c+d, prevalence_m1=preds[m1].mean(),
                   prevalence_m2=preds[m2].mean(), kappa=k, po=po, pe=pe,
                   ac1=ac1, pabak=pabak(po), pos_agree=pa, neg_agree=na)
        results.append(row)

        # Leave-two-out Pred+ / Pred-
        pred_plus_mask  = leave_two_out_majority(preds, model_cols, exclude=[m1, m2]) == 1
        pred_minus_mask = leave_two_out_majority(preds, model_cols, exclude=[m1, m2]) == 0
        for scope, mask in [('Pred+', pred_plus_mask), ('Pred-', pred_minus_mask)]:
            if mask.sum() == 0: 
                continue
            a,b,c,d = pairwise_counts(preds.loc[mask, m1], preds.loc[mask, m2])
            k, po, pe = kappa_from_counts(a,b,c,d)
            ac1, po2, pe2 = gwets_ac1(preds.loc[mask, m1], preds.loc[mask, m2])
            pa, na = positive_negative_agreement(a,b,c,d)
            results.append(dict(scope=scope, m1=m1, m2=m2, n=mask.sum(),
                                prevalence_m1=preds.loc[mask, m1].mean(),
                                prevalence_m2=preds.loc[mask, m2].mean(),
                                kappa=k, po=po, pe=pe, ac1=ac1, pabak=pabak(po),
                                pos_agree=pa, neg_agree=na))
    return pd.DataFrame(results)

# %%
df_results = analyze(
    preds=results_df,
    model_cols=model_names,
)
df_results
# Out:
#      scope                   m1                                 m2      n  \
# 0      All  logistic_regression                     sgd_classifier  11248
# 1    Pred+  logistic_regression                     sgd_classifier   5689
# 2    Pred-  logistic_regression                     sgd_classifier   5559
# 3      All  logistic_regression  support_vector_machine_classifier  11248
# 4    Pred+  logistic_regression  support_vector_machine_classifier   5511
# ..     ...                  ...                                ...    ...
# 103  Pred+     ridge_classifier     x_gradient_boosting_classifier   5672
# 104  Pred-     ridge_classifier     x_gradient_boosting_classifier   5576
# 105    All           perceptron     x_gradient_boosting_classifier  11248
# 106  Pred+           perceptron     x_gradient_boosting_classifier   5785
# 107  Pred-           perceptron     x_gradient_boosting_classifier   5463
#
#      prevalence_m1  prevalence_m2     kappa        po        pe       ac1  \
# ...
