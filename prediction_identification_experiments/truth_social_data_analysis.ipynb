# %% [markdown]
# # Analyze Real World Social Media Data: Truth Social

# %%
import os
import sys

from tqdm import tqdm

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# print(notebook_dir)
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %% [markdown]
# ## Load Data

# %%
base_path = os.path.join(notebook_dir, '../', 'data/open_measures/', 'truth_social_raw_data/')
files = os.listdir(base_path)

dfs = []

for file in tqdm(files):
    full_path = os.path.join(notebook_dir, '../', 'data/open_measures/', 'truth_social_raw_data/', file)
    df = DataProcessing.load_from_file(full_path, 'csv')
    dfs.append(df)

dfs
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 170.43it/s]
# [     Unnamed: 0                                            account bookmarked  \
#  0             0  {'acct': 'ImBackBitchs', 'display_name': 'Just...      False
#  1             1  {'acct': 'NFL', 'display_name': 'NFL', 'id': '...      False
#  2             2  {'acct': 'freelovepatriot', 'display_name': 'b...      False
#  3             3  {'acct': 'WillieO2', 'display_name': 'Billy O'...      False
#  4             4  {'acct': 'reneeras', 'display_name': 'Renee in...      False
#  ..          ...                                                ...        ...
#  155         155  {'acct': 'Artbyunclejunior', 'display_name': '...      False
#  156         156  {'acct': 'michaelfunk', 'display_name': 'Funks...      False
#  157         157  {'acct': 'vickieski', 'display_name': 'Vickie ...      False
#  158         158  {'acct': 'billrogers76', 'display_name': 'W A ...      False
#  159         159  {'acct': 'nicolespink70', 'display_name': 'Nik...      False
#
#                                                    card          collected_by  \
#  0                                                  NaN  smat-scrapy-crawlers
#  1    {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  2    {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  3                                                  NaN  smat-scrapy-crawlers
#  4                                                  NaN  smat-scrapy-crawlers
#  ..                                                 ...                   ...
#  155  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  156                                                NaN  smat-scrapy-crawlers
#  157                                                NaN  smat-scrapy-crawlers
#  158                                                NaN  smat-scrapy-crawlers
#  159                                                NaN  smat-scrapy-crawlers
#
#                                                 content  \
#  0    <p>I’m so tired of  hearing about Colin Kaeper...
#  1    <p>Burrow: Bengals 'know what it takes' now to...
#  2    <p><a href="https://www.instagram.com/reel/Cha...
#  3    <p>The NFL will now play flag football in lieu...
#  4    <p>Well performance plays show otherwise.  Jus...
#  ..                                                 ...
#  155  <p>Washington Red Skins&apos; Playoff Run Ends...
#  156  <p>Don’t get to excited buddy. The refs will m...
#  157  <p>For some time, I feel the message to the pu...
#  158  <p>It is just boys playing a game🏈😜<br/>How mu...
#  159  <p>Really wish you would have Elon look into t...
#
#                                         content_cleaned  \
#  0    I’m so tired of  hearing about Colin Kaepernic...
#  1    Burrow: Bengals 'know what it takes' now to wi...
#  2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...
#  3    The NFL will now play flag football in lieu of...
#  4    Well performance plays show otherwise.  Just w...
#  ..                                                 ...
#  155  Washington Red Skins&apos; Playoff Run Ends in...
#  156  Don’t get to excited buddy. The refs will make...
#  157  For some time, I feel the message to the publi...
#  158  It is just boys playing a game🏈😜How much do NF...
#  159  Really wish you would have Elon look into the ...
#
#                          created_at datatype  downvotes_count  ... application  \
#  0    2022-04-24T20:52:32.230+00:00     post              0.0  ...         NaN
#  1    2022-05-17T20:50:14.967+00:00     post              0.0  ...         NaN
#  2    2022-09-07T17:26:19.589+00:00     post              0.0  ...         NaN
#  3    2022-09-26T23:32:51.382+00:00     post              NaN  ...         NaN
#  4    2022-10-03T01:47:01.368+00:00  comment              0.0  ...         NaN
#  ..                             ...      ...              ...  ...         ...
#  155  2025-01-27T17:29:45.435+00:00  comment              NaN  ...         NaN
#  156  2025-01-27T20:32:47.859+00:00  comment              0.0  ...         NaN
#  157  2025-02-08T00:19:42.311+00:00     post              NaN  ...         NaN
#  158  2025-02-08T07:08:42.339+00:00     post              NaN  ...         NaN
#  159  2025-02-08T09:15:11.973+00:00  comment              0.0  ...         NaN
#
#                                                    text  tombstone  tv  \
#  0    I’m so tired of  hearing about Colin Kaepernic...        NaN NaN
#  1    Burrow: Bengals 'know what it takes' now to wi...        NaN NaN
#  2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...        NaN NaN
#  3    The NFL will now play flag football in lieu of...        NaN NaN
#  4    Well performance plays show otherwise.  Just w...        NaN NaN
#  ..                                                 ...        ...  ..
#  155  Washington Red Skins&apos; Playoff Run Ends in...        NaN NaN
#  156  Don’t get to excited buddy. The refs will make...        NaN NaN
#  157  For some time, I feel the message to the publi...        NaN NaN
#  158  It is just boys playing a game🏈😜How much do NF...        NaN NaN
#  159  Really wish you would have Elon look into the ...        NaN NaN
#
#       group_timeline_visible  last_seen_ts  reblog  \
#  0                       NaN           NaN     NaN
#  1                       NaN           NaN     NaN
#  2                       NaN           NaN     NaN
#  3                       NaN           NaN     NaN
#  4                       NaN           NaN     NaN
#  ..                      ...           ...     ...
#  155                     NaN           NaN     NaN
#  156                     NaN           NaN     NaN
#  157                     NaN           NaN     NaN
#  158                     NaN           NaN     NaN
#  159                     NaN           NaN     NaN
#
#                                      openmeasures_media  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  155                                                NaN
#  156                                                NaN
#  157  [{'_hash': '00d0f292df771a8839799409f19c9fddc9...
#  158                                                NaN
#  159                                                NaN
#
#                                            Query Params          Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  ..                                                 ...           ...
#  155  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  156  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  157  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  158  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  159  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#
#  [160 rows x 54 columns],
#      Unnamed: 0                                            account  bookmarked  \
#  0            0  {'acct': 'AnalyzeBetWin', 'display_name': 'Ana...       False
#  1            1  {'acct': 'guessonly', 'display_name': '', 'id'...       False
#  2            2  {'acct': 'TrustingJesusChrist', 'display_name'...       False
#  3            3  {'acct': 'Free2MeetU', 'display_name': 'Free2M...       False
#  4            4  {'acct': 'Gutterman70', 'display_name': 'Gutte...       False
#  5            5  {'acct': 'Payitforward333', 'display_name': 'T...       False
#  6            6  {'acct': 'usernameinvalid', 'display_name': 's...       False
#  7            7  {'acct': 'Abuzzardistwofaced', 'display_name':...       False
#  8            8  {'acct': 'newyorksun', 'display_name': 'The Ne...       False
#  9            9  {'acct': 'PowerDownMedia', 'display_name': 'ᑭᗝ...       False
#  10          10  {'acct': 'HarveyK1754', 'display_name': 'The H...       False
#  11          11  {'acct': 'sylvia_eckes', 'display_name': 'Sylv...       False
#  12          12  {'acct': 'BreitbartLondon', 'display_name': 'B...       False
#  13          13  {'acct': 'DeborahSwallows', 'display_name': 'D...       False
#  14          14  {'acct': 'roberteliason58', 'display_name': 'R...       False
#  15          15  {'acct': 'streetglidepohl', 'display_name': 'j...       False
#  16          16  {'acct': 'Gutterman70', 'display_name': 'Gutte...       False
#  17          17  {'acct': 'victoria_56', 'display_name': 'Victo...       False
#  18          18  {'acct': 'Artbyunclejunior', 'display_name': '...       False
#  19          19  {'acct': 'michaelfunk', 'display_name': 'Funks...       False
#  20          20  {'acct': 'vickieski', 'display_name': 'Vickie ...       False
#  21          21  {'acct': 'billrogers76', 'display_name': 'W A ...       False
#  22          22  {'acct': 'nicolespink70', 'display_name': 'Nik...       False
#
#                                                   card          collected_by  \
#  0   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  1                                                 NaN  smat-scrapy-crawlers
#  2                                                 NaN  smat-scrapy-crawlers
#  3   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  4                                                 NaN  smat-scrapy-crawlers
#  5                                                 NaN  smat-scrapy-crawlers
#  6                                                 NaN  smat-scrapy-crawlers
#  7   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  8   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  9   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  10  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  11  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  12  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  13                                                NaN  smat-scrapy-crawlers
#  14  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  15                                                NaN  smat-scrapy-crawlers
#  16                                                NaN  smat-scrapy-crawlers
#  17                                                NaN  smat-scrapy-crawlers
#  18  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  19                                                NaN  smat-scrapy-crawlers
#  20                                                NaN  smat-scrapy-crawlers
#  21                                                NaN  smat-scrapy-crawlers
#  22                                                NaN  smat-scrapy-crawlers
#
#                                                content  \
#  0   <p>Listen to the Jets vs 49ers on Westwood One...
#  1   <p>MAYOR DUGGAN: Detroit just hosted the large...
#  2   <p>ANNOUNCING.…..Tickets For Potential Postsea...
#  3   <p>Memo to <span class="h-card"><a href="https...
#  4   <p>NFL you have lost credibility, what the fuc...
#  5   <p>For the NFL Playoffs</p><p>Barbecue Chicken...
#  6   <p>RT <span class="h-card"><a href="https://tr...
#  7   <p><a href="https://links.truthsocial.com/link...
#  8   <p>Flags, Calls, and Taylor Swift: Is the NFL ...
#  9   <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  10  <p>EXACTLY! WE'VE ALL THOUGHT THIS Alex Marlow...
#  11  <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  12  <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  13  <p>RT <span class="h-card"><a href="https://tr...
#  14  <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  15  <p>RT <span class="h-card"><a href="https://tr...
#  16  <p>C'mon NFL is a rigged thru sports betting b...
#  17  <p>I hear NFL playoffs are rigged and the two ...
#  18  <p>Washington Red Skins&apos; Playoff Run Ends...
#  19  <p>Don’t get to excited buddy. The refs will m...
#  20  <p>For some time, I feel the message to the pu...
#  21  <p>It is just boys playing a game🏈😜<br/>How mu...
#  22  <p>Really wish you would have Elon look into t...
#
#                                        content_cleaned  \
#  0   Listen to the Jets vs 49ers on Westwood One Ra...
#  1   MAYOR DUGGAN: Detroit just hosted the largest ...
#  2   ANNOUNCING.…..Tickets For Potential Postseason...
#  3   Memo to @BuffaloBills, I have been a fan of yo...
#  4   NFL you have lost credibility, what the fuck, ...
#  5   For the NFL PlayoffsBarbecue Chicken Wings wit...
#  6   RT @Payitforward333For the NFL PlayoffsBarbecu...
#  7   https://www.instagram.com/reel/DFEy9-OxeEh/?ig...
#  8   Flags, Calls, and Taylor Swift: Is the NFL Rig...
#  9   Alex Marlow: Follow the Money—NFL Rigging Play...
#  10  EXACTLY! WE'VE ALL THOUGHT THIS Alex Marlow: F...
#  11  Alex Marlow: Follow the Money—NFL Rigging Play...
#  12  Alex Marlow: Follow the Money—NFL Rigging Play...
#  13  RT @BreitbartLondonAlex Marlow: Follow the Mon...
#  14  Alex Marlow: Follow the Money—NFL Rigging Play...
#  15  RT @PowerDownMediaAlex Marlow: Follow the Mone...
#  16  C'mon NFL is a rigged thru sports betting bull...
#  17  I hear NFL playoffs are rigged and the two tea...
#  18  Washington Red Skins&apos; Playoff Run Ends in...
#  19  Don’t get to excited buddy. The refs will make...
#  20  For some time, I feel the message to the publi...
#  21  It is just boys playing a game🏈😜How much do NF...
#  22  Really wish you would have Elon look into the ...
#
#                         created_at datatype  downvotes_count  ...  tv  \
#  0   2024-09-10T00:34:06.423+00:00     post              0.0  ... NaN
#  1   2024-10-10T23:29:44.501+00:00  comment              NaN  ... NaN
#  2   2024-11-11T20:29:15.443+00:00     post              NaN  ... NaN
#  3   2024-12-31T14:12:25.665+00:00     post              NaN  ... NaN
#  4   2025-01-06T13:07:56.644+00:00     post              0.0  ... NaN
#  5   2025-01-13T05:50:25.655+00:00     post              NaN  ... NaN
#  6   2025-01-13T20:04:58.145+00:00     post              NaN  ... NaN
#  7   2025-01-23T00:24:22.843+00:00     post              NaN  ... NaN
#  8   2025-01-23T22:20:09.255+00:00     post              NaN  ... NaN
#  9   2025-01-25T05:57:09.642+00:00     post              0.0  ... NaN
#  10  2025-01-25T06:34:11.732+00:00     post              NaN  ... NaN
#  11  2025-01-25T11:12:00.328+00:00     post              0.0  ... NaN
#  12  2025-01-25T15:50:03.379+00:00     post              0.0  ... NaN
#  13  2025-01-25T16:28:43.112+00:00     post              NaN  ... NaN
#  14  2025-01-26T06:23:57.417+00:00     post              NaN  ... NaN
#  15  2025-01-26T21:00:44.119+00:00     post              0.0  ... NaN
#  16  2025-01-26T22:36:52.972+00:00     post              0.0  ... NaN
#  17  2025-01-26T23:41:34.560+00:00     post              0.0  ... NaN
#  18  2025-01-27T17:29:45.435+00:00  comment              NaN  ... NaN
#  19  2025-01-27T20:32:47.859+00:00  comment              0.0  ... NaN
#  20  2025-02-08T00:19:42.311+00:00     post              NaN  ... NaN
#  21  2025-02-08T07:08:42.339+00:00     post              NaN  ... NaN
#  22  2025-02-08T09:15:11.973+00:00  comment              0.0  ... NaN
#
#                                                 reblog  editable edited_at  \
#  0                                                 NaN       NaN       NaN
#  1                                                 NaN       NaN       NaN
#  2                                                 NaN       NaN       NaN
#  3                                                 NaN       NaN       NaN
#  4                                                 NaN       NaN       NaN
#  5                                                 NaN       NaN       NaN
#  6   {'id': '113819479287129949', 'uri': 'https://t...       NaN       NaN
#  7                                                 NaN       NaN       NaN
#  8                                                 NaN       NaN       NaN
#  9                                                 NaN       NaN       NaN
#  10                                                NaN       NaN       NaN
#  11                                                NaN       NaN       NaN
#  12                                                NaN       NaN       NaN
#  13  {'id': '113889784848427362', 'uri': 'https://t...       NaN       NaN
#  14                                                NaN       NaN       NaN
#  15  {'id': '113887453488191059', 'uri': 'https://t...       NaN       NaN
#  16                                                NaN     False       NaN
#  17                                                NaN     False       NaN
#  18                                                NaN       NaN       NaN
#  19                                                NaN     False       NaN
#  20                                                NaN       NaN       NaN
#  21                                                NaN       NaN       NaN
#  22                                                NaN     False       NaN
#
#      version                                        in_reply_to  title  \
#  0       NaN                                                NaN    NaN
#  1       NaN                                                NaN    NaN
#  2       NaN                                                NaN    NaN
#  3       NaN                                                NaN    NaN
#  4       NaN                                                NaN    NaN
#  5       NaN                                                NaN    NaN
#  6       NaN                                                NaN    NaN
#  7       NaN                                                NaN    NaN
#  8       NaN                                                NaN    NaN
#  9       NaN                                                NaN    NaN
#  10      NaN                                                NaN    NaN
#  11      NaN                                                NaN    NaN
#  12      NaN                                                NaN    NaN
#  13      NaN                                                NaN    NaN
#  14      NaN                                                NaN    NaN
#  15      NaN                                                NaN    NaN
#  16      1.0                                                NaN    NaN
#  17      1.0                                                NaN    NaN
#  18      1.0                                                NaN    NaN
#  19      1.0  {'id': '113901065238481791', 'uri': 'https://t...    NaN
#  20      NaN                                                NaN    NaN
#  21      NaN                                                NaN    NaN
#  22      1.0                                                NaN    NaN
#
#                                     openmeasures_media  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                                                NaN
#  20  [{'_hash': '00d0f292df771a8839799409f19c9fddc9...
#  21                                                NaN
#  22                                                NaN
#
#                                           Query Params          Site
#  0   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  1   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  2   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  3   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  4   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  5   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  6   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  7   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  8   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  9   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  10  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  11  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  12  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  13  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  14  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  15  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  16  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  17  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  18  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  19  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  20  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  21  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  22  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#
#  [23 rows x 52 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:npjiuliamvdmtabawnrdv5xy
#  1             1  app.bsky.feed.post  did:plc:a2ijicgkwatuhlfss36lvwfx
#  2             2  app.bsky.feed.post  did:plc:2ao5yl67p4kgm2pp3vqxxemi
#  3             3  app.bsky.feed.post  did:plc:c4vrlto23ppwquv6om5u72pf
#  4             4  app.bsky.feed.post  did:plc:ynlyxzdcesfzooxofzi5z6ov
#  ..          ...                 ...                               ...
#  373         373  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  374         374  app.bsky.feed.post  did:plc:2d66hcvi5xe6n3uirrwq2cht
#  375         375  app.bsky.feed.post  did:plc:2d66hcvi5xe6n3uirrwq2cht
#  376         376  app.bsky.feed.post  did:plc:2d66hcvi5xe6n3uirrwq2cht
#  377         377  app.bsky.feed.post  did:plc:54qqwcx32wlvhkexkes55ewl
#
#                                           authorProfile  \
#  0    {'_id': 'did:plc:npjiuliamvdmtabawnrdv5xy', '_...
#  1    {'_id': 'did:plc:a2ijicgkwatuhlfss36lvwfx', '_...
#  2    {'_id': 'did:plc:2ao5yl67p4kgm2pp3vqxxemi', '_...
#  3    {'_id': 'did:plc:c4vrlto23ppwquv6om5u72pf', '_...
#  4                                                  NaN
#  ..                                                 ...
#  373  {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'd...
#  374  {'did': 'did:plc:2d66hcvi5xe6n3uirrwq2cht', 'd...
#  375  {'did': 'did:plc:2d66hcvi5xe6n3uirrwq2cht', 'd...
#  376  {'did': 'did:plc:2d66hcvi5xe6n3uirrwq2cht', 'd...
#  377  {'did': 'did:plc:54qqwcx32wlvhkexkes55ewl', 'd...
#
#                                                     cid  \
#  0    bafyreihuimcu6lo4ra7bvv27hu5qixlh45rjognkhzuzs...
#  1    bafyreid7cit7kzh2guil47zt335odpnfxf6rdhej2p2pi...
#  2    bafyreiftfbdkgtvxumrtdsyo5xgfk6sq4ovizf3d6syjd...
#  3    bafyreicbqrghqpdpni33w6hbdiutphpsjivqstbnsh3n5...
#  4    zdpuAraSk4CsBbNhMFvV32kZwv9YrsBpgaPjDPmgpHHXKWf7S
#  ..                                                 ...
#  373  bafyreian3bixwm444bqtsxe6j432hbgwspugq4vodrdjs...
#  374  bafyreifcad32zxi62jpfg27bb7ckwu2ct7xrdjmwzachn...
#  375  bafyreicuizzqckshiukjg7vdwklwc7bpuwqkfjwhdcj6s...
#  376  bafyreid6xqs4527yrx2av5gejfr7vrfq4of6om76lzims...
#  377  bafyreiglrbzivtvbn35cwkheqz2fexgaoajz273drfxhq...
#
#                      createdAt  \
#  0        2017-06-08T11:39:28Z
#  1        2018-01-06T17:26:38Z
#  2        2018-05-29T15:02:27Z
#  3        2019-04-11T14:50:04Z
#  4    2019-05-29T12:53:00.000Z
#  ..                        ...
#  373  2025-02-07T17:05:56.000Z
#  374  2025-02-07T19:49:08.000Z
#  375  2025-02-07T21:42:24.000Z
#  376  2025-02-08T16:00:00.000Z
#  377  2025-02-08T17:09:54.697Z
#
#                                                   embed  entities  \
#  0                                                  NaN       NaN
#  1    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  2                                                  NaN       NaN
#  3    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  4    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  ..                                                 ...       ...
#  373  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  374  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  375  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  376  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  377                                                NaN       NaN
#
#                                                  facets  labels  ...  \
#  0                                                  NaN     NaN  ...
#  1    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  2                                                  NaN     NaN  ...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  4                                                  NaN     NaN  ...
#  ..                                                 ...     ...  ...
#  373                                                NaN     NaN  ...
#  374                                                NaN     NaN  ...
#  375                                                NaN     NaN  ...
#  376                                                NaN     NaN  ...
#  377                                                NaN     NaN  ...
#
#                                                  embeds  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3    {'$type': 'app.bsky.embed.images', 'images': [...
#  4                                                  NaN
#  ..                                                 ...
#  373                                                NaN
#  374                                                NaN
#  375                                                NaN
#  376                                                NaN
#  377                                                NaN
#
#                                      bridgyOriginalText  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4    <p><strong>Do you know the way to San Jose?</s...
#  ..                                                 ...
#  373  <figure>\n      <img alt="Brooklyn Nets v New ...
#  374  <figure>\n      <img alt="NBA: Golden State Wa...
#  375  <figure>\n      <img alt="Boston Celtics v Cle...
#  376  <figure>\n      <img alt="Charlotte Hornets (9...
#  377                                                NaN
#
#                                       bridgyOriginalUrl  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4    http://jaimzuber.com/san-jose-convention-guide...
#  ..                                                 ...
#  373  https://www.sbnation.com/nba/2025/2/7/24360930...
#  374  https://www.celticsblog.com/2025/2/7/24361139/...
#  375  https://www.celticsblog.com/2025/2/7/24361227/...
#  376  https://www.celticsblog.com/2025/2/8/24361405/...
#  377                                                NaN
#
#                        indexedAt     sequence  \
#  0                           NaN          NaN
#  1                           NaN          NaN
#  2                           NaN          NaN
#  3                           NaN          NaN
#  4    2024-08-24T18:05:11.146792  992584563.0
#  ..                          ...          ...
#  373                         NaN          NaN
#  374                         NaN          NaN
#  375                         NaN          NaN
#  376                         NaN          NaN
#  377                         NaN          NaN
#
#                                       openmeasures_meta rkey_str created_at  \
#  0                                                  NaN      NaN        NaN
#  1                                                  NaN      NaN        NaN
#  2                                                  NaN      NaN        NaN
#  3                                                  NaN      NaN        NaN
#  4                                                  NaN      NaN        NaN
#  ..                                                 ...      ...        ...
#  373  {'collected_by': 'jetstream', 'last_scraped_ts...      NaN        NaN
#  374  {'collected_by': 'jetstream', 'last_scraped_ts...      NaN        NaN
#  375  {'collected_by': 'jetstream', 'last_scraped_ts...      NaN        NaN
#  376  {'collected_by': 'jetstream', 'last_scraped_ts...      NaN        NaN
#  377  {'collected_by': 'jetstream', 'last_scraped_ts...      NaN        NaN
#
#                                            Query Params     Site
#  0    {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  1    {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  2    {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  3    {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  4    {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  ..                                                 ...      ...
#  373  {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  374  {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  375  {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  376  {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#  377  {'term': '(NBA OR nba) AND (playoffs) AND (Fin...  bluesky
#
#  [378 rows x 26 columns],
#      Unnamed: 0                                            account  bookmarked  \
#  0            0  {'acct': 'AnalyzeBetWin', 'display_name': 'Ana...       False
#  1            1  {'acct': 'guessonly', 'display_name': '', 'id'...       False
#  2            2  {'acct': 'TrustingJesusChrist', 'display_name'...       False
#  3            3  {'acct': 'Free2MeetU', 'display_name': 'Free2M...       False
#  4            4  {'acct': 'Gutterman70', 'display_name': 'Gutte...       False
#  5            5  {'acct': 'Payitforward333', 'display_name': 'T...       False
#  6            6  {'acct': 'usernameinvalid', 'display_name': 's...       False
#  7            7  {'acct': 'Abuzzardistwofaced', 'display_name':...       False
#  8            8  {'acct': 'newyorksun', 'display_name': 'The Ne...       False
#  9            9  {'acct': 'PowerDownMedia', 'display_name': 'ᑭᗝ...       False
#  10          10  {'acct': 'HarveyK1754', 'display_name': 'The H...       False
#  11          11  {'acct': 'sylvia_eckes', 'display_name': 'Sylv...       False
#  12          12  {'acct': 'BreitbartLondon', 'display_name': 'B...       False
#  13          13  {'acct': 'DeborahSwallows', 'display_name': 'D...       False
#  14          14  {'acct': 'roberteliason58', 'display_name': 'R...       False
#  15          15  {'acct': 'streetglidepohl', 'display_name': 'j...       False
#  16          16  {'acct': 'Gutterman70', 'display_name': 'Gutte...       False
#  17          17  {'acct': 'victoria_56', 'display_name': 'Victo...       False
#  18          18  {'acct': 'Artbyunclejunior', 'display_name': '...       False
#  19          19  {'acct': 'michaelfunk', 'display_name': 'Funks...       False
#  20          20  {'acct': 'vickieski', 'display_name': 'Vickie ...       False
#  21          21  {'acct': 'billrogers76', 'display_name': 'W A ...       False
#  22          22  {'acct': 'nicolespink70', 'display_name': 'Nik...       False
#
#                                                   card          collected_by  \
#  0   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  1                                                 NaN  smat-scrapy-crawlers
#  2                                                 NaN  smat-scrapy-crawlers
#  3   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  4                                                 NaN  smat-scrapy-crawlers
#  5                                                 NaN  smat-scrapy-crawlers
#  6                                                 NaN  smat-scrapy-crawlers
#  7   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  8   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  9   {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  10  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  11  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  12  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  13                                                NaN  smat-scrapy-crawlers
#  14  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  15                                                NaN  smat-scrapy-crawlers
#  16                                                NaN  smat-scrapy-crawlers
#  17                                                NaN  smat-scrapy-crawlers
#  18  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  19                                                NaN  smat-scrapy-crawlers
#  20                                                NaN  smat-scrapy-crawlers
#  21                                                NaN  smat-scrapy-crawlers
#  22                                                NaN  smat-scrapy-crawlers
#
#                                                content  \
#  0   <p>Listen to the Jets vs 49ers on Westwood One...
#  1   <p>MAYOR DUGGAN: Detroit just hosted the large...
#  2   <p>ANNOUNCING.…..Tickets For Potential Postsea...
#  3   <p>Memo to <span class="h-card"><a href="https...
#  4   <p>NFL you have lost credibility, what the fuc...
#  5   <p>For the NFL Playoffs</p><p>Barbecue Chicken...
#  6   <p>RT <span class="h-card"><a href="https://tr...
#  7   <p><a href="https://links.truthsocial.com/link...
#  8   <p>Flags, Calls, and Taylor Swift: Is the NFL ...
#  9   <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  10  <p>EXACTLY! WE'VE ALL THOUGHT THIS Alex Marlow...
#  11  <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  12  <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  13  <p>RT <span class="h-card"><a href="https://tr...
#  14  <p>Alex Marlow: Follow the Money—NFL Rigging P...
#  15  <p>RT <span class="h-card"><a href="https://tr...
#  16  <p>C'mon NFL is a rigged thru sports betting b...
#  17  <p>I hear NFL playoffs are rigged and the two ...
#  18  <p>Washington Red Skins&apos; Playoff Run Ends...
#  19  <p>Don’t get to excited buddy. The refs will m...
#  20  <p>For some time, I feel the message to the pu...
#  21  <p>It is just boys playing a game🏈😜<br/>How mu...
#  22  <p>Really wish you would have Elon look into t...
#
#                                        content_cleaned  \
#  0   Listen to the Jets vs 49ers on Westwood One Ra...
#  1   MAYOR DUGGAN: Detroit just hosted the largest ...
#  2   ANNOUNCING.…..Tickets For Potential Postseason...
#  3   Memo to @BuffaloBills, I have been a fan of yo...
#  4   NFL you have lost credibility, what the fuck, ...
#  5   For the NFL PlayoffsBarbecue Chicken Wings wit...
#  6   RT @Payitforward333For the NFL PlayoffsBarbecu...
#  7   https://www.instagram.com/reel/DFEy9-OxeEh/?ig...
#  8   Flags, Calls, and Taylor Swift: Is the NFL Rig...
#  9   Alex Marlow: Follow the Money—NFL Rigging Play...
#  10  EXACTLY! WE'VE ALL THOUGHT THIS Alex Marlow: F...
#  11  Alex Marlow: Follow the Money—NFL Rigging Play...
#  12  Alex Marlow: Follow the Money—NFL Rigging Play...
#  13  RT @BreitbartLondonAlex Marlow: Follow the Mon...
#  14  Alex Marlow: Follow the Money—NFL Rigging Play...
#  15  RT @PowerDownMediaAlex Marlow: Follow the Mone...
#  16  C'mon NFL is a rigged thru sports betting bull...
#  17  I hear NFL playoffs are rigged and the two tea...
#  18  Washington Red Skins&apos; Playoff Run Ends in...
#  19  Don’t get to excited buddy. The refs will make...
#  20  For some time, I feel the message to the publi...
#  21  It is just boys playing a game🏈😜How much do NF...
#  22  Really wish you would have Elon look into the ...
#
#                         created_at datatype  downvotes_count  ...  tv  \
#  0   2024-09-10T00:34:06.423+00:00     post              0.0  ... NaN
#  1   2024-10-10T23:29:44.501+00:00  comment              NaN  ... NaN
#  2   2024-11-11T20:29:15.443+00:00     post              NaN  ... NaN
#  3   2024-12-31T14:12:25.665+00:00     post              NaN  ... NaN
#  4   2025-01-06T13:07:56.644+00:00     post              0.0  ... NaN
#  5   2025-01-13T05:50:25.655+00:00     post              NaN  ... NaN
#  6   2025-01-13T20:04:58.145+00:00     post              NaN  ... NaN
#  7   2025-01-23T00:24:22.843+00:00     post              NaN  ... NaN
#  8   2025-01-23T22:20:09.255+00:00     post              NaN  ... NaN
#  9   2025-01-25T05:57:09.642+00:00     post              0.0  ... NaN
#  10  2025-01-25T06:34:11.732+00:00     post              NaN  ... NaN
#  11  2025-01-25T11:12:00.328+00:00     post              0.0  ... NaN
#  12  2025-01-25T15:50:03.379+00:00     post              0.0  ... NaN
#  13  2025-01-25T16:28:43.112+00:00     post              NaN  ... NaN
#  14  2025-01-26T06:23:57.417+00:00     post              NaN  ... NaN
#  15  2025-01-26T21:00:44.119+00:00     post              0.0  ... NaN
#  16  2025-01-26T22:36:52.972+00:00     post              0.0  ... NaN
#  17  2025-01-26T23:41:34.560+00:00     post              0.0  ... NaN
#  18  2025-01-27T17:29:45.435+00:00  comment              NaN  ... NaN
#  19  2025-01-27T20:32:47.859+00:00  comment              0.0  ... NaN
#  20  2025-02-08T00:19:42.311+00:00     post              NaN  ... NaN
#  21  2025-02-08T07:08:42.339+00:00     post              NaN  ... NaN
#  22  2025-02-08T09:15:11.973+00:00  comment              0.0  ... NaN
#
#                                                 reblog  editable edited_at  \
#  0                                                 NaN       NaN       NaN
#  1                                                 NaN       NaN       NaN
#  2                                                 NaN       NaN       NaN
#  3                                                 NaN       NaN       NaN
#  4                                                 NaN       NaN       NaN
#  5                                                 NaN       NaN       NaN
#  6   {'id': '113819479287129949', 'uri': 'https://t...       NaN       NaN
#  7                                                 NaN       NaN       NaN
#  8                                                 NaN       NaN       NaN
#  9                                                 NaN       NaN       NaN
#  10                                                NaN       NaN       NaN
#  11                                                NaN       NaN       NaN
#  12                                                NaN       NaN       NaN
#  13  {'id': '113889784848427362', 'uri': 'https://t...       NaN       NaN
#  14                                                NaN       NaN       NaN
#  15  {'id': '113887453488191059', 'uri': 'https://t...       NaN       NaN
#  16                                                NaN     False       NaN
#  17                                                NaN     False       NaN
#  18                                                NaN       NaN       NaN
#  19                                                NaN     False       NaN
#  20                                                NaN       NaN       NaN
#  21                                                NaN       NaN       NaN
#  22                                                NaN     False       NaN
#
#      version                                        in_reply_to  title  \
#  0       NaN                                                NaN    NaN
#  1       NaN                                                NaN    NaN
#  2       NaN                                                NaN    NaN
#  3       NaN                                                NaN    NaN
#  4       NaN                                                NaN    NaN
#  5       NaN                                                NaN    NaN
#  6       NaN                                                NaN    NaN
#  7       NaN                                                NaN    NaN
#  8       NaN                                                NaN    NaN
#  9       NaN                                                NaN    NaN
#  10      NaN                                                NaN    NaN
#  11      NaN                                                NaN    NaN
#  12      NaN                                                NaN    NaN
#  13      NaN                                                NaN    NaN
#  14      NaN                                                NaN    NaN
#  15      NaN                                                NaN    NaN
#  16      1.0                                                NaN    NaN
#  17      1.0                                                NaN    NaN
#  18      1.0                                                NaN    NaN
#  19      1.0  {'id': '113901065238481791', 'uri': 'https://t...    NaN
#  20      NaN                                                NaN    NaN
#  21      NaN                                                NaN    NaN
#  22      1.0                                                NaN    NaN
#
#                                     openmeasures_media  \
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6                                                 NaN
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN
#  14                                                NaN
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                                                NaN
#  20  [{'_hash': '00d0f292df771a8839799409f19c9fddc9...
#  21                                                NaN
#  22                                                NaN
#
#                                           Query Params          Site
#  0   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  1   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  2   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  3   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  4   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  5   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  6   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  7   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  8   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  9   {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  10  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  11  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  12  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  13  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  14  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  15  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  16  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  17  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  18  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  19  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  20  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  21  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  22  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#
#  [23 rows x 52 columns],
#      Unnamed: 0                                            account  bookmarked  \
#  0            0  {'acct': 'AnalyzeBetWin', 'display_name': 'Ana...       False
#  1            1  {'acct': 'guessonly', 'display_name': '', 'id'...       False
#  2            2  {'acct': 'TrustingJesusChrist', 'display_name'...       False
#  3            3  {'acct': 'Free2MeetU', 'display_name': 'Free2M...       False
#  4            4  {'acct': 'Gutterman70', 'display_name': 'Gutte...       False
#  5            5  {'acct': 'Payitforward333', 'display_name': 'T...       False
#  6            6  {'acct': 'usernameinvalid', 'display_name': 's...       False
#  7            7  {'acct': 'Abuzzardistwofaced', 'display_name':...       False
#  8            8  {'acct': 'newyorksun', 'display_name': 'The Ne...       False
#  9            9  {'acct': 'PowerDownMedia', 'display_name': 'ᑭᗝ...       False
#  10          10  {'acct': 'HarveyK1754', 'display_name': 'The H...       False
#  11          11  {'acct': 'sylvia_eckes', 'display_name': 'Sylv...       False
# ...
#  10  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  11  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  12  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  13  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  14  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  15  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  16  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  17  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  18  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  19  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  20  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  21  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  22  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#
#  [23 rows x 52 columns],
#       Unnamed: 0                                            account bookmarked  \
#  0             0  {'acct': 'ImBackBitchs', 'display_name': 'Just...      False
#  1             1  {'acct': 'NFL', 'display_name': 'NFL', 'id': '...      False
#  2             2  {'acct': 'freelovepatriot', 'display_name': 'b...      False
#  3             3  {'acct': 'WillieO2', 'display_name': 'Billy O'...      False
#  4             4  {'acct': 'reneeras', 'display_name': 'Renee in...      False
#  ..          ...                                                ...        ...
#  155         155  {'acct': 'Artbyunclejunior', 'display_name': '...      False
#  156         156  {'acct': 'michaelfunk', 'display_name': 'Funks...      False
#  157         157  {'acct': 'vickieski', 'display_name': 'Vickie ...      False
#  158         158  {'acct': 'billrogers76', 'display_name': 'W A ...      False
#  159         159  {'acct': 'nicolespink70', 'display_name': 'Nik...      False
#
#                                                    card          collected_by  \
#  0                                                  NaN  smat-scrapy-crawlers
#  1    {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  2    {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  3                                                  NaN  smat-scrapy-crawlers
#  4                                                  NaN  smat-scrapy-crawlers
#  ..                                                 ...                   ...
#  155  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  156                                                NaN  smat-scrapy-crawlers
#  157                                                NaN  smat-scrapy-crawlers
#  158                                                NaN  smat-scrapy-crawlers
#  159                                                NaN  smat-scrapy-crawlers
#
#                                                 content  \
#  0    <p>I’m so tired of  hearing about Colin Kaeper...
#  1    <p>Burrow: Bengals 'know what it takes' now to...
#  2    <p><a href="https://www.instagram.com/reel/Cha...
#  3    <p>The NFL will now play flag football in lieu...
#  4    <p>Well performance plays show otherwise.  Jus...
#  ..                                                 ...
#  155  <p>Washington Red Skins&apos; Playoff Run Ends...
#  156  <p>Don’t get to excited buddy. The refs will m...
#  157  <p>For some time, I feel the message to the pu...
#  158  <p>It is just boys playing a game🏈😜<br/>How mu...
#  159  <p>Really wish you would have Elon look into t...
#
#                                         content_cleaned  \
#  0    I’m so tired of  hearing about Colin Kaepernic...
#  1    Burrow: Bengals 'know what it takes' now to wi...
#  2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...
#  3    The NFL will now play flag football in lieu of...
#  4    Well performance plays show otherwise.  Just w...
#  ..                                                 ...
#  155  Washington Red Skins&apos; Playoff Run Ends in...
#  156  Don’t get to excited buddy. The refs will make...
#  157  For some time, I feel the message to the publi...
#  158  It is just boys playing a game🏈😜How much do NF...
#  159  Really wish you would have Elon look into the ...
#
#                          created_at datatype  downvotes_count  ... application  \
#  0    2022-04-24T20:52:32.230+00:00     post              0.0  ...         NaN
#  1    2022-05-17T20:50:14.967+00:00     post              0.0  ...         NaN
#  2    2022-09-07T17:26:19.589+00:00     post              0.0  ...         NaN
#  3    2022-09-26T23:32:51.382+00:00     post              NaN  ...         NaN
#  4    2022-10-03T01:47:01.368+00:00  comment              0.0  ...         NaN
#  ..                             ...      ...              ...  ...         ...
#  155  2025-01-27T17:29:45.435+00:00  comment              NaN  ...         NaN
#  156  2025-01-27T20:32:47.859+00:00  comment              0.0  ...         NaN
#  157  2025-02-08T00:19:42.311+00:00     post              NaN  ...         NaN
#  158  2025-02-08T07:08:42.339+00:00     post              NaN  ...         NaN
#  159  2025-02-08T09:15:11.973+00:00  comment              0.0  ...         NaN
#
#                                                    text  tombstone  tv  \
#  0    I’m so tired of  hearing about Colin Kaepernic...        NaN NaN
#  1    Burrow: Bengals 'know what it takes' now to wi...        NaN NaN
#  2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...        NaN NaN
#  3    The NFL will now play flag football in lieu of...        NaN NaN
#  4    Well performance plays show otherwise.  Just w...        NaN NaN
#  ..                                                 ...        ...  ..
#  155  Washington Red Skins&apos; Playoff Run Ends in...        NaN NaN
#  156  Don’t get to excited buddy. The refs will make...        NaN NaN
#  157  For some time, I feel the message to the publi...        NaN NaN
#  158  It is just boys playing a game🏈😜How much do NF...        NaN NaN
#  159  Really wish you would have Elon look into the ...        NaN NaN
#
#       group_timeline_visible  last_seen_ts  reblog  \
#  0                       NaN           NaN     NaN
#  1                       NaN           NaN     NaN
#  2                       NaN           NaN     NaN
#  3                       NaN           NaN     NaN
#  4                       NaN           NaN     NaN
#  ..                      ...           ...     ...
#  155                     NaN           NaN     NaN
#  156                     NaN           NaN     NaN
#  157                     NaN           NaN     NaN
#  158                     NaN           NaN     NaN
#  159                     NaN           NaN     NaN
#
#                                      openmeasures_media  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  155                                                NaN
#  156                                                NaN
#  157  [{'_hash': '00d0f292df771a8839799409f19c9fddc9...
#  158                                                NaN
#  159                                                NaN
#
#                                            Query Params          Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  ..                                                 ...           ...
#  155  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  156  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  157  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  158  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  159  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#
#  [160 rows x 54 columns],
#       Unnamed: 0                                            account bookmarked  \
#  0             0  {'acct': 'ImBackBitchs', 'display_name': 'Just...      False
#  1             1  {'acct': 'NFL', 'display_name': 'NFL', 'id': '...      False
#  2             2  {'acct': 'freelovepatriot', 'display_name': 'b...      False
#  3             3  {'acct': 'WillieO2', 'display_name': 'Billy O'...      False
#  4             4  {'acct': 'reneeras', 'display_name': 'Renee in...      False
#  ..          ...                                                ...        ...
#  155         155  {'acct': 'Artbyunclejunior', 'display_name': '...      False
#  156         156  {'acct': 'michaelfunk', 'display_name': 'Funks...      False
#  157         157  {'acct': 'vickieski', 'display_name': 'Vickie ...      False
#  158         158  {'acct': 'billrogers76', 'display_name': 'W A ...      False
#  159         159  {'acct': 'nicolespink70', 'display_name': 'Nik...      False
#
#                                                    card          collected_by  \
#  0                                                  NaN  smat-scrapy-crawlers
#  1    {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  2    {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  3                                                  NaN  smat-scrapy-crawlers
#  4                                                  NaN  smat-scrapy-crawlers
#  ..                                                 ...                   ...
#  155  {'author_name': '', 'author_url': '', 'blurhas...  smat-scrapy-crawlers
#  156                                                NaN  smat-scrapy-crawlers
#  157                                                NaN  smat-scrapy-crawlers
#  158                                                NaN  smat-scrapy-crawlers
#  159                                                NaN  smat-scrapy-crawlers
#
#                                                 content  \
#  0    <p>I’m so tired of  hearing about Colin Kaeper...
#  1    <p>Burrow: Bengals 'know what it takes' now to...
#  2    <p><a href="https://www.instagram.com/reel/Cha...
#  3    <p>The NFL will now play flag football in lieu...
#  4    <p>Well performance plays show otherwise.  Jus...
#  ..                                                 ...
#  155  <p>Washington Red Skins&apos; Playoff Run Ends...
#  156  <p>Don’t get to excited buddy. The refs will m...
#  157  <p>For some time, I feel the message to the pu...
#  158  <p>It is just boys playing a game🏈😜<br/>How mu...
#  159  <p>Really wish you would have Elon look into t...
#
#                                         content_cleaned  \
#  0    I’m so tired of  hearing about Colin Kaepernic...
#  1    Burrow: Bengals 'know what it takes' now to wi...
#  2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...
#  3    The NFL will now play flag football in lieu of...
#  4    Well performance plays show otherwise.  Just w...
#  ..                                                 ...
#  155  Washington Red Skins&apos; Playoff Run Ends in...
#  156  Don’t get to excited buddy. The refs will make...
#  157  For some time, I feel the message to the publi...
#  158  It is just boys playing a game🏈😜How much do NF...
#  159  Really wish you would have Elon look into the ...
#
#                          created_at datatype  downvotes_count  ... application  \
#  0    2022-04-24T20:52:32.230+00:00     post              0.0  ...         NaN
#  1    2022-05-17T20:50:14.967+00:00     post              0.0  ...         NaN
#  2    2022-09-07T17:26:19.589+00:00     post              0.0  ...         NaN
#  3    2022-09-26T23:32:51.382+00:00     post              NaN  ...         NaN
#  4    2022-10-03T01:47:01.368+00:00  comment              0.0  ...         NaN
#  ..                             ...      ...              ...  ...         ...
#  155  2025-01-27T17:29:45.435+00:00  comment              NaN  ...         NaN
#  156  2025-01-27T20:32:47.859+00:00  comment              0.0  ...         NaN
#  157  2025-02-08T00:19:42.311+00:00     post              NaN  ...         NaN
#  158  2025-02-08T07:08:42.339+00:00     post              NaN  ...         NaN
#  159  2025-02-08T09:15:11.973+00:00  comment              0.0  ...         NaN
#
#                                                    text  tombstone  tv  \
#  0    I’m so tired of  hearing about Colin Kaepernic...        NaN NaN
#  1    Burrow: Bengals 'know what it takes' now to wi...        NaN NaN
#  2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...        NaN NaN
#  3    The NFL will now play flag football in lieu of...        NaN NaN
#  4    Well performance plays show otherwise.  Just w...        NaN NaN
#  ..                                                 ...        ...  ..
#  155  Washington Red Skins&apos; Playoff Run Ends in...        NaN NaN
#  156  Don’t get to excited buddy. The refs will make...        NaN NaN
#  157  For some time, I feel the message to the publi...        NaN NaN
#  158  It is just boys playing a game🏈😜How much do NF...        NaN NaN
#  159  Really wish you would have Elon look into the ...        NaN NaN
#
#       group_timeline_visible  last_seen_ts  reblog  \
#  0                       NaN           NaN     NaN
#  1                       NaN           NaN     NaN
#  2                       NaN           NaN     NaN
#  3                       NaN           NaN     NaN
#  4                       NaN           NaN     NaN
#  ..                      ...           ...     ...
#  155                     NaN           NaN     NaN
#  156                     NaN           NaN     NaN
#  157                     NaN           NaN     NaN
#  158                     NaN           NaN     NaN
#  159                     NaN           NaN     NaN
#
#                                      openmeasures_media  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  155                                                NaN
#  156                                                NaN
#  157  [{'_hash': '00d0f292df771a8839799409f19c9fddc9...
#  158                                                NaN
#  159                                                NaN
#
#                                            Query Params          Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  ..                                                 ...           ...
#  155  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  156  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  157  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  158  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#  159  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  truth_social
#
#  [160 rows x 54 columns]]

# %% [markdown]
# ## Data Processing
#
# + Data stored as dfs[df_1, df_2, ... n].
# + Concat all DFs to one.
# + `data_range_per_file` is the index 0 to n_1 belongs to df_1, 0_n_2 belongs to n_2, etc.

# %%
df = DataProcessing.concat_dfs(dfs)
df.rename(columns={"Unnamed: 0": "data_range_per_file"}, inplace=True)
df
# Out:
#      data_range_per_file                                            account  \
# 0                      0  {'acct': 'ImBackBitchs', 'display_name': 'Just...
# 1                      1  {'acct': 'NFL', 'display_name': 'NFL', 'id': '...
# 2                      2  {'acct': 'freelovepatriot', 'display_name': 'b...
# 3                      3  {'acct': 'WillieO2', 'display_name': 'Billy O'...
# 4                      4  {'acct': 'reneeras', 'display_name': 'Renee in...
# ..                   ...                                                ...
# 922                  155  {'acct': 'Artbyunclejunior', 'display_name': '...
# 923                  156  {'acct': 'michaelfunk', 'display_name': 'Funks...
# 924                  157  {'acct': 'vickieski', 'display_name': 'Vickie ...
# 925                  158  {'acct': 'billrogers76', 'display_name': 'W A ...
# 926                  159  {'acct': 'nicolespink70', 'display_name': 'Nik...
#
#     bookmarked                                               card  \
# 0        False                                                NaN
# 1        False  {'author_name': '', 'author_url': '', 'blurhas...
# 2        False  {'author_name': '', 'author_url': '', 'blurhas...
# 3        False                                                NaN
# 4        False                                                NaN
# ..         ...                                                ...
# 922      False  {'author_name': '', 'author_url': '', 'blurhas...
# 923      False                                                NaN
# 924      False                                                NaN
# 925      False                                                NaN
# 926      False                                                NaN
#
#              collected_by                                            content  \
# 0    smat-scrapy-crawlers  <p>I’m so tired of  hearing about Colin Kaeper...
# 1    smat-scrapy-crawlers  <p>Burrow: Bengals 'know what it takes' now to...
# 2    smat-scrapy-crawlers  <p><a href="https://www.instagram.com/reel/Cha...
# 3    smat-scrapy-crawlers  <p>The NFL will now play flag football in lieu...
# 4    smat-scrapy-crawlers  <p>Well performance plays show otherwise.  Jus...
# ..                    ...                                                ...
# 922  smat-scrapy-crawlers  <p>Washington Red Skins&apos; Playoff Run Ends...
# 923  smat-scrapy-crawlers  <p>Don’t get to excited buddy. The refs will m...
# 924  smat-scrapy-crawlers  <p>For some time, I feel the message to the pu...
# 925  smat-scrapy-crawlers  <p>It is just boys playing a game🏈😜<br/>How mu...
# 926  smat-scrapy-crawlers  <p>Really wish you would have Elon look into t...
#
#                                        content_cleaned  \
# 0    I’m so tired of  hearing about Colin Kaepernic...
# 1    Burrow: Bengals 'know what it takes' now to wi...
# 2    https://www.instagram.com/reel/Cha-AWmst5v/?ig...
# 3    The NFL will now play flag football in lieu of...
# 4    Well performance plays show otherwise.  Just w...
# ..                                                 ...
# 922  Washington Red Skins&apos; Playoff Run Ends in...
# 923  Don’t get to excited buddy. The refs will make...
# 924  For some time, I feel the message to the publi...
# 925  It is just boys playing a game🏈😜How much do NF...
# 926  Really wish you would have Elon look into the ...
#
#                         created_at datatype  downvotes_count  ... labels  \
# 0    2022-04-24T20:52:32.230+00:00     post              0.0  ...    NaN
# 1    2022-05-17T20:50:14.967+00:00     post              0.0  ...    NaN
# 2    2022-09-07T17:26:19.589+00:00     post              0.0  ...    NaN
# 3    2022-09-26T23:32:51.382+00:00     post              NaN  ...    NaN
# 4    2022-10-03T01:47:01.368+00:00  comment              0.0  ...    NaN
# ..                             ...      ...              ...  ...    ...
# 922  2025-01-27T17:29:45.435+00:00  comment              NaN  ...    NaN
# 923  2025-01-27T20:32:47.859+00:00  comment              0.0  ...    NaN
# 924  2025-02-08T00:19:42.311+00:00     post              NaN  ...    NaN
# 925  2025-02-08T07:08:42.339+00:00     post              NaN  ...    NaN
# 926  2025-02-08T09:15:11.973+00:00  comment              0.0  ...    NaN
#
#     langs  reply embeds  bridgyOriginalText  bridgyOriginalUrl  indexedAt  \
# 0     NaN    NaN    NaN                 NaN                NaN        NaN
# 1     NaN    NaN    NaN                 NaN                NaN        NaN
# 2     NaN    NaN    NaN                 NaN                NaN        NaN
# 3     NaN    NaN    NaN                 NaN                NaN        NaN
# 4     NaN    NaN    NaN                 NaN                NaN        NaN
# ..    ...    ...    ...                 ...                ...        ...
# 922   NaN    NaN    NaN                 NaN                NaN        NaN
# 923   NaN    NaN    NaN                 NaN                NaN        NaN
# 924   NaN    NaN    NaN                 NaN                NaN        NaN
# 925   NaN    NaN    NaN                 NaN                NaN        NaN
# 926   NaN    NaN    NaN                 NaN                NaN        NaN
#
#     sequence openmeasures_meta rkey_str
# 0        NaN               NaN      NaN
# 1        NaN               NaN      NaN
# 2        NaN               NaN      NaN
# 3        NaN               NaN      NaN
# 4        NaN               NaN      NaN
# ..       ...               ...      ...
# 922      NaN               NaN      NaN
# 923      NaN               NaN      NaN
# 924      NaN               NaN      NaN
# 925      NaN               NaN      NaN
# 926      NaN               NaN      NaN
#
# [927 rows x 72 columns]
