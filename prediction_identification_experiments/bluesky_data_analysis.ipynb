# %% [markdown]
# # Analyze Real World Social Media Data: Bluesky
#
# 1. WEBSITE: [About Bluesky via Open Measures](https://openmeasures.io/platform)

# %%
import os
import sys

from tqdm import tqdm

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# print(notebook_dir)
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %% [markdown]
# ## Load Data

# %%
base_path = os.path.join(notebook_dir, '../', 'data/open_measures/', 'bluesky_raw_data/')
files = os.listdir(base_path)

dfs = []

for file in tqdm(files):
    full_path = os.path.join(base_path, file)
    df = DataProcessing.load_from_file(full_path, 'csv')
    dfs.append(df)

dfs
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 65.99it/s]
# [     Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  1             1  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  2             2  app.bsky.feed.post  did:plc:a2ijicgkwatuhlfss36lvwfx
#  3             3  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  4             4  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  ..          ...                 ...                               ...
#  651         651  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  652         652  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  653         653  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  654         654  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  655         655  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                                     cid  \
#  0    zdpuAykzkHo8uZtsa4qZyQTtSePWRbHoKAJgxYwxqcrTxx6fi
#  1    zdpuAt42bPRcafad5PjKbsxSXBETMXPbP7Tb8H5Mu3NV78QCw
#  2    bafyreibsxwnoso4kq6oltibk3xzbhqbjtlx7bmwxi73rs...
#  3    zdpuAuxtMWrau1PvrZQC7mC1DokTWBdYsK4mCJQyCnySk5aWb
#  4    zdpuArf8hkuDPBSJgJcwyhc1Du712poHWk73dRam3TuVDzgy4
#  ..                                                 ...
#  651  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  652  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  653  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  654  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  655  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0    2024-01-13T23:50:40.300023+00:00
#  1    2024-01-15T04:20:38.045294+00:00
#  2                2024-01-17T18:52:28Z
#  3    2024-01-21T04:30:46.145649+00:00
#  4    2024-01-21T23:20:45.897184+00:00
#  ..                                ...
#  651          2025-02-08T18:53:17.000Z
#  652          2025-02-08T20:00:00.000Z
#  653          2025-02-08T22:00:00.720Z
#  654          2025-02-08T22:12:51.918Z
#  655  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  \
#  0    {'$type': 'app.bsky.embed.images', 'images': [...
#  1    {'$type': 'app.bsky.embed.images', 'images': [...
#  2    {'$type': 'app.bsky.embed.external', 'external...
#  3    {'$type': 'app.bsky.embed.images', 'images': [...
#  4    {'$type': 'app.bsky.embed.images', 'images': [...
#  ..                                                 ...
#  651  {'$type': 'app.bsky.embed.external', 'external...
#  652  {'$type': 'app.bsky.embed.external', 'external...
#  653  {'$type': 'app.bsky.embed.images', 'images': [...
#  654  {'$type': 'app.bsky.embed.external', 'external...
#  655  {'$type': 'app.bsky.embed.external', 'external...
#
#                                                  facets  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  1    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  ..                                                 ...
#  651                                                NaN
#  652                                                NaN
#  653  [{'features': [{'$type': 'app.bsky.richtext.fa...
#  654  [{'features': [{'$type': 'app.bsky.richtext.fa...
#  655  [{'$type': 'app.bsky.richtext.facet', 'feature...
#
#                        indexedAt     sequence  \
#  0    2024-01-13T23:50:40.805738  570168565.0
#  1    2024-01-15T04:26:24.470523  574404975.0
#  2                           NaN          NaN
#  3    2024-01-21T04:30:47.004301  596638410.0
#  4    2024-01-21T23:20:46.653710  599632070.0
#  ..                          ...          ...
#  651                         NaN          NaN
#  652                         NaN          NaN
#  653                         NaN          NaN
#  654                         NaN          NaN
#  655                         NaN          NaN
#
#                                                    text  ...   langs reply  \
#  0    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  1    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  2    Does defense even matter in the NFL postseason...  ...     NaN   NaN
#  3    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  4    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  ..                                                 ...  ...     ...   ...
#  651                                                NaN  ...     NaN   NaN
#  652                                                NaN  ...     NaN   NaN
#  653  The Chiefs' George Karlaftis ranks No. 1 in pr...  ...     NaN   NaN
#  654  www.bothteamsplayhard.wordpress.com/2025/02/08...  ...  ['en']   NaN
#  655                                       \n\n#rssespn  ...  ['en']   NaN
#
#               tags                                 bridgyOriginalText  \
#  0             NaN                                                NaN
#  1             NaN                                                NaN
#  2             NaN                                                NaN
#  3             NaN                                                NaN
#  4             NaN                                                NaN
#  ..            ...                                                ...
#  651           NaN  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  652  ['Esportes']  “Com minha camiseta dos Eagles pendurada na po...
#  653           NaN                                                NaN
#  654           NaN                                                NaN
#  655           NaN                                                NaN
#
#                                       bridgyOriginalUrl  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  651  https://www.sbnation.com/golf/2025/2/8/2436163...
#  652  https://tribunaonline.com.br/esportes/taylor-s...
#  653                                                NaN
#  654                                                NaN
#  655                                                NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  651  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  652  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  653  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  654  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  655  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  651  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  652  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  653  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  654  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  655  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [656 rows x 26 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  1             1  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  2             2  app.bsky.feed.post  did:plc:a2ijicgkwatuhlfss36lvwfx
#  3             3  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  4             4  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  ..          ...                 ...                               ...
#  651         651  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  652         652  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  653         653  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  654         654  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  655         655  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                                     cid  \
#  0    zdpuAykzkHo8uZtsa4qZyQTtSePWRbHoKAJgxYwxqcrTxx6fi
#  1    zdpuAt42bPRcafad5PjKbsxSXBETMXPbP7Tb8H5Mu3NV78QCw
#  2    bafyreibsxwnoso4kq6oltibk3xzbhqbjtlx7bmwxi73rs...
#  3    zdpuAuxtMWrau1PvrZQC7mC1DokTWBdYsK4mCJQyCnySk5aWb
#  4    zdpuArf8hkuDPBSJgJcwyhc1Du712poHWk73dRam3TuVDzgy4
#  ..                                                 ...
#  651  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  652  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  653  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  654  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  655  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0    2024-01-13T23:50:40.300023+00:00
#  1    2024-01-15T04:20:38.045294+00:00
#  2                2024-01-17T18:52:28Z
#  3    2024-01-21T04:30:46.145649+00:00
#  4    2024-01-21T23:20:45.897184+00:00
#  ..                                ...
#  651          2025-02-08T18:53:17.000Z
#  652          2025-02-08T20:00:00.000Z
#  653          2025-02-08T22:00:00.720Z
#  654          2025-02-08T22:12:51.918Z
#  655  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  \
#  0    {'$type': 'app.bsky.embed.images', 'images': [...
#  1    {'$type': 'app.bsky.embed.images', 'images': [...
#  2    {'$type': 'app.bsky.embed.external', 'external...
#  3    {'$type': 'app.bsky.embed.images', 'images': [...
#  4    {'$type': 'app.bsky.embed.images', 'images': [...
#  ..                                                 ...
#  651  {'$type': 'app.bsky.embed.external', 'external...
#  652  {'$type': 'app.bsky.embed.external', 'external...
#  653  {'$type': 'app.bsky.embed.images', 'images': [...
#  654  {'$type': 'app.bsky.embed.external', 'external...
#  655  {'$type': 'app.bsky.embed.external', 'external...
#
#                                                  facets  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  1    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...
#  ..                                                 ...
#  651                                                NaN
#  652                                                NaN
#  653  [{'features': [{'$type': 'app.bsky.richtext.fa...
#  654  [{'features': [{'$type': 'app.bsky.richtext.fa...
#  655  [{'$type': 'app.bsky.richtext.facet', 'feature...
#
#                        indexedAt     sequence  \
#  0    2024-01-13T23:50:40.805738  570168565.0
#  1    2024-01-15T04:26:24.470523  574404975.0
#  2                           NaN          NaN
#  3    2024-01-21T04:30:47.004301  596638410.0
#  4    2024-01-21T23:20:46.653710  599632070.0
#  ..                          ...          ...
#  651                         NaN          NaN
#  652                         NaN          NaN
#  653                         NaN          NaN
#  654                         NaN          NaN
#  655                         NaN          NaN
#
#                                                    text  ...   langs reply  \
#  0    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  1    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  2    Does defense even matter in the NFL postseason...  ...     NaN   NaN
#  3    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  4    Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
#  ..                                                 ...  ...     ...   ...
#  651                                                NaN  ...     NaN   NaN
#  652                                                NaN  ...     NaN   NaN
#  653  The Chiefs' George Karlaftis ranks No. 1 in pr...  ...     NaN   NaN
#  654  www.bothteamsplayhard.wordpress.com/2025/02/08...  ...  ['en']   NaN
#  655                                       \n\n#rssespn  ...  ['en']   NaN
#
#               tags                                 bridgyOriginalText  \
#  0             NaN                                                NaN
#  1             NaN                                                NaN
#  2             NaN                                                NaN
#  3             NaN                                                NaN
#  4             NaN                                                NaN
#  ..            ...                                                ...
#  651           NaN  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  652  ['Esportes']  “Com minha camiseta dos Eagles pendurada na po...
#  653           NaN                                                NaN
#  654           NaN                                                NaN
#  655           NaN                                                NaN
#
#                                       bridgyOriginalUrl  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  651  https://www.sbnation.com/golf/2025/2/8/2436163...
#  652  https://tribunaonline.com.br/esportes/taylor-s...
#  653                                                NaN
#  654                                                NaN
#  655                                                NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  651  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  652  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  653  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  654  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  655  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  651  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  652  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  653  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  654  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  655  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [656 rows x 26 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:ahok3cgd4c7rhnwrnofapqls
#  1             1  app.bsky.feed.post  did:plc:xcgwe2tojxjmatdlrd6yvfch
#  2             2  app.bsky.feed.post  did:plc:ti665rl3446mp2hc6i47nadp
#  3             3  app.bsky.feed.post  did:plc:tsosz6fe72jxrhelo2i3p6dy
#  4             4  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  ..          ...                 ...                               ...
#  655         655  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  656         656  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  657         657  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  658         658  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  659         659  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                           authorProfile  \
#  0    {'_id': 'did:plc:ahok3cgd4c7rhnwrnofapqls', '_...
#  1    {'avatar': 'https://cdn.bsky.app/img/avatar/pl...
#  2    {'_id': 'did:plc:ti665rl3446mp2hc6i47nadp', '_...
#  3    {'_id': 'did:plc:tsosz6fe72jxrhelo2i3p6dy', '_...
#  4    {'followers': 6048, 'viewer_blocked_by': False...
#  ..                                                 ...
#  655  {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'd...
#  656  {'did': 'did:plc:nrr6yppar26qag7p2q3rawp7', 'd...
#  657  {'did': 'did:plc:m67kp6uoter7aeftq5nkzncm', 'h...
#  658  {'did': 'did:plc:eyaz2kbzyxmg5hgkhb3w7s25', 'h...
#  659  {'did': 'did:plc:5jycdvkvabnon545dxcisari', 'd...
#
#                                                     cid  \
#  0    bafyreibrnqn53jgjudbv7j46gb5q6wte6lbw5aoaiqeab...
#  1    bafyreign2ksxhkcuendrfoyyejo425bbznifgdb2zv3po...
#  2    bafyreie6nid4f7g2vf2m7ibuyzu3id3brylthliznwg53...
#  3    bafyreigz7gycietwfxzwaaqvbnbqa4gyi6owncnz6qv5e...
#  4    zdpuAykzkHo8uZtsa4qZyQTtSePWRbHoKAJgxYwxqcrTxx6fi
#  ..                                                 ...
#  655  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  656  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  657  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  658  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  659  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0                2016-01-09T20:30:33Z
#  1            2016-11-28T02:52:09.000Z
#  2                2018-08-21T16:58:14Z
#  3            2020-01-13T12:26:24.000Z
#  4    2024-01-13T23:50:40.300023+00:00
#  ..                                ...
#  655          2025-02-08T18:53:17.000Z
#  656          2025-02-08T20:00:00.000Z
#  657          2025-02-08T22:00:00.720Z
#  658          2025-02-08T22:12:51.918Z
#  659  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  \
#  0    {'$type': 'app.bsky.embed.external', 'external...
#  1    {'$type': 'app.bsky.embed.external', 'external...
#  2    {'$type': 'app.bsky.embed.external', 'external...
#  3    {'$type': 'app.bsky.embed.external', 'external...
#  4    {'$type': 'app.bsky.embed.images', 'images': [...
#  ..                                                 ...
#  655  {'$type': 'app.bsky.embed.external', 'external...
#  656  {'$type': 'app.bsky.embed.external', 'external...
#  657  {'$type': 'app.bsky.embed.images', 'images': [...
#  658  {'$type': 'app.bsky.embed.external', 'external...
#  659  {'$type': 'app.bsky.embed.external', 'external...
#
#                                                  embeds  entities  \
#  0    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  1    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  2    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  3                                                  NaN       NaN
#  4                                                  NaN       NaN
#  ..                                                 ...       ...
#  655                                                NaN       NaN
#  656                                                NaN       NaN
#  657                                                NaN       NaN
#  658                                                NaN       NaN
#  659                                                NaN       NaN
#
#                                                  facets  ...  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  1    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  ..                                                 ...  ...
#  655                                                NaN  ...
#  656                                                NaN  ...
#  657  [{'features': [{'$type': 'app.bsky.richtext.fa...  ...
#  658  [{'features': [{'$type': 'app.bsky.richtext.fa...  ...
#  659  [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#
#                       lastseents                   indexedAt     sequence  \
#  0    2024-12-06T19:22:59.217241                         NaN          NaN
#  1    2024-12-02T16:16:14.024322                         NaN          NaN
#  2    2024-12-02T18:24:53.023705                         NaN          NaN
#  3    2025-01-11T16:48:58.739554                         NaN          NaN
#  4    2024-01-13T23:50:41.187032  2024-01-13T23:50:40.805738  570168565.0
#  ..                          ...                         ...          ...
#  655  2025-02-09T19:50:01.532797                         NaN          NaN
#  656  2025-02-09T19:34:16.758219                         NaN          NaN
#  657  2025-02-09T19:30:32.810947                         NaN          NaN
#  658  2025-02-09T19:30:58.593242                         NaN          NaN
#  659  2025-02-09T19:33:26.046377                         NaN          NaN
#
#                                      bridgyOriginalText  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  655  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  656  “Com minha camiseta dos Eagles pendurada na po...
#  657                                                NaN
#  658                                                NaN
#  659                                                NaN
#
#                                       bridgyOriginalUrl  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  655  https://www.sbnation.com/golf/2025/2/8/2436163...
#  656  https://tribunaonline.com.br/esportes/taylor-s...
#  657                                                NaN
#  658                                                NaN
#  659                                                NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  655  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  656  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  657  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  658  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  659  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  655  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  656  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  657  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  658  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  659  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [660 rows x 26 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:kqbsolnzpw3ixx2ea65qfd3s
#  1             1  app.bsky.feed.post  did:plc:2ita5o32hmjxhnzg4a7sxe73
#  2             2  app.bsky.feed.post  did:plc:37lm46sbrzz622ij4vucrceo
#  3             3  app.bsky.feed.post  did:plc:pn7bt5fej5fep3uywocvak5d
#  4             4  app.bsky.feed.post  did:plc:ltt57jg2sdeqzyqikirkf66s
#  ..          ...                 ...                               ...
#  625         625  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  626         626  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  627         627  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  628         628  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  629         629  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                           authorProfile  \
#  0    {'_id': 'did:plc:kqbsolnzpw3ixx2ea65qfd3s', '_...
#  1    {'_id': 'did:plc:2ita5o32hmjxhnzg4a7sxe73', '_...
#  2    {'_id': 'did:plc:37lm46sbrzz622ij4vucrceo', '_...
#  3    {'_id': 'did:plc:pn7bt5fej5fep3uywocvak5d', '_...
#  4    {'_id': 'did:plc:ltt57jg2sdeqzyqikirkf66s', '_...
#  ..                                                 ...
#  625  {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'd...
#  626  {'did': 'did:plc:nrr6yppar26qag7p2q3rawp7', 'd...
#  627  {'did': 'did:plc:m67kp6uoter7aeftq5nkzncm', 'h...
#  628  {'did': 'did:plc:eyaz2kbzyxmg5hgkhb3w7s25', 'h...
#  629  {'did': 'did:plc:5jycdvkvabnon545dxcisari', 'd...
#
#                                                     cid  \
#  0    bafyreieskfrnp7rxfenmifroyxttpyqfj6nselszceega...
#  1    bafyreid6n7iozz3c2sqw3c4pzayda3scsr23gzzwqoetm...
#  2    bafyreidsbp4fpxlap5xrerqv5p5wj7qwcdeuemu2u74qm...
#  3    bafyreicruejiae5nayhgdmht7jwto4epf4n5zca76t5q2...
#  4    bafyreibkuv6uhtctqi6juahgb2anhxkpznfw3tifj3w7s...
#  ..                                                 ...
#  625  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  626  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  627  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  628  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  629  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0            2024-09-15T19:06:12.698Z
#  1            2024-09-24T21:36:10.000Z
#  2    2024-09-24T21:36:37.713094+00:00
#  3            2024-09-24T23:48:28.000Z
#  4            2024-10-01T18:51:00.102Z
#  ..                                ...
#  625          2025-02-08T18:53:17.000Z
#  626          2025-02-08T20:00:00.000Z
#  627          2025-02-08T22:00:00.720Z
#  628          2025-02-08T22:12:51.918Z
#  629  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  entities  \
#  0                                                  NaN       NaN
#  1    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  2    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  3    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  4    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  ..                                                 ...       ...
#  625  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  626  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  627  {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  628  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  629  {'$type': 'app.bsky.embed.external', 'external...       NaN
#
#                                                  facets  labels  ...  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  1                                                  NaN     NaN  ...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  ..                                                 ...     ...  ...
#  625                                                NaN     NaN  ...
#  626                                                NaN     NaN  ...
#  627  [{'features': [{'$type': 'app.bsky.richtext.fa...     NaN  ...
#  628  [{'features': [{'$type': 'app.bsky.richtext.fa...     NaN  ...
#  629  [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#
#                                                     uri  \
#  0    at://did:plc:kqbsolnzpw3ixx2ea65qfd3s/app.bsky...
#  1    at://did:plc:2ita5o32hmjxhnzg4a7sxe73/app.bsky...
#  2    at://did:plc:37lm46sbrzz622ij4vucrceo/app.bsky...
#  3    at://did:plc:pn7bt5fej5fep3uywocvak5d/app.bsky...
#  4    at://did:plc:ltt57jg2sdeqzyqikirkf66s/app.bsky...
#  ..                                                 ...
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#  629                                                NaN
#
#                       lastseents  \
#  0    2024-09-16T15:11:27.653628
#  1    2024-09-27T14:21:09.449232
#  2    2024-09-27T14:12:44.701547
#  3    2024-09-27T15:56:28.889099
#  4    2024-10-03T09:25:45.780203
#  ..                          ...
#  625  2025-02-09T19:50:01.532797
#  626  2025-02-09T19:34:16.758219
#  627  2025-02-09T19:30:32.810947
#  628  2025-02-09T19:30:58.593242
#  629  2025-02-09T19:33:26.046377
#
#                                      bridgyOriginalText  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3    <p>🏈   <a href="https://mastodon.online/tags/N...
#  4                                                  NaN
#  ..                                                 ...
#  625  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  626  “Com minha camiseta dos Eagles pendurada na po...
#  627                                                NaN
#  628                                                NaN
#  629                                                NaN
#
#                                       bridgyOriginalUrl embeds  \
#  0                                                  NaN    NaN
#  1                                                  NaN    NaN
#  2                                                  NaN    NaN
#  3    https://mastodon.online/@emarktaylor/113195201...    NaN
#  4                                                  NaN    NaN
#  ..                                                 ...    ...
#  625  https://www.sbnation.com/golf/2025/2/8/2436163...    NaN
#  626  https://tribunaonline.com.br/esportes/taylor-s...    NaN
#  627                                                NaN    NaN
#  628                                                NaN    NaN
#  629                                                NaN    NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  625  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  626  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  627  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  628  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  629  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  625  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  626  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  627  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  628  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  629  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [630 rows x 24 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:kqbsolnzpw3ixx2ea65qfd3s
#  1             1  app.bsky.feed.post  did:plc:2ita5o32hmjxhnzg4a7sxe73
#  2             2  app.bsky.feed.post  did:plc:37lm46sbrzz622ij4vucrceo
#  3             3  app.bsky.feed.post  did:plc:pn7bt5fej5fep3uywocvak5d
#  4             4  app.bsky.feed.post  did:plc:ltt57jg2sdeqzyqikirkf66s
#  ..          ...                 ...                               ...
#  625         625  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  626         626  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  627         627  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  628         628  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  629         629  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                           authorProfile  \
#  0    {'_id': 'did:plc:kqbsolnzpw3ixx2ea65qfd3s', '_...
#  1    {'_id': 'did:plc:2ita5o32hmjxhnzg4a7sxe73', '_...
#  2    {'_id': 'did:plc:37lm46sbrzz622ij4vucrceo', '_...
#  3    {'_id': 'did:plc:pn7bt5fej5fep3uywocvak5d', '_...
#  4    {'_id': 'did:plc:ltt57jg2sdeqzyqikirkf66s', '_...
#  ..                                                 ...
#  625  {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'd...
#  626  {'did': 'did:plc:nrr6yppar26qag7p2q3rawp7', 'd...
#  627  {'did': 'did:plc:m67kp6uoter7aeftq5nkzncm', 'h...
#  628  {'did': 'did:plc:eyaz2kbzyxmg5hgkhb3w7s25', 'h...
#  629  {'did': 'did:plc:5jycdvkvabnon545dxcisari', 'd...
#
#                                                     cid  \
#  0    bafyreieskfrnp7rxfenmifroyxttpyqfj6nselszceega...
#  1    bafyreid6n7iozz3c2sqw3c4pzayda3scsr23gzzwqoetm...
#  2    bafyreidsbp4fpxlap5xrerqv5p5wj7qwcdeuemu2u74qm...
#  3    bafyreicruejiae5nayhgdmht7jwto4epf4n5zca76t5q2...
#  4    bafyreibkuv6uhtctqi6juahgb2anhxkpznfw3tifj3w7s...
#  ..                                                 ...
#  625  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  626  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  627  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  628  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  629  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0            2024-09-15T19:06:12.698Z
#  1            2024-09-24T21:36:10.000Z
#  2    2024-09-24T21:36:37.713094+00:00
#  3            2024-09-24T23:48:28.000Z
#  4            2024-10-01T18:51:00.102Z
#  ..                                ...
#  625          2025-02-08T18:53:17.000Z
#  626          2025-02-08T20:00:00.000Z
#  627          2025-02-08T22:00:00.720Z
#  628          2025-02-08T22:12:51.918Z
#  629  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  entities  \
#  0                                                  NaN       NaN
#  1    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  2    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  3    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  4    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  ..                                                 ...       ...
#  625  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  626  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  627  {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  628  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  629  {'$type': 'app.bsky.embed.external', 'external...       NaN
#
#                                                  facets  labels  ...  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  1                                                  NaN     NaN  ...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  ..                                                 ...     ...  ...
#  625                                                NaN     NaN  ...
#  626                                                NaN     NaN  ...
#  627  [{'features': [{'$type': 'app.bsky.richtext.fa...     NaN  ...
#  628  [{'features': [{'$type': 'app.bsky.richtext.fa...     NaN  ...
#  629  [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#
#                                                     uri  \
#  0    at://did:plc:kqbsolnzpw3ixx2ea65qfd3s/app.bsky...
#  1    at://did:plc:2ita5o32hmjxhnzg4a7sxe73/app.bsky...
#  2    at://did:plc:37lm46sbrzz622ij4vucrceo/app.bsky...
#  3    at://did:plc:pn7bt5fej5fep3uywocvak5d/app.bsky...
#  4    at://did:plc:ltt57jg2sdeqzyqikirkf66s/app.bsky...
#  ..                                                 ...
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#  629                                                NaN
#
#                       lastseents  \
#  0    2024-09-16T15:11:27.653628
#  1    2024-09-27T14:21:09.449232
#  2    2024-09-27T14:12:44.701547
#  3    2024-09-27T15:56:28.889099
#  4    2024-10-03T09:25:45.780203
#  ..                          ...
#  625  2025-02-09T19:50:01.532797
#  626  2025-02-09T19:34:16.758219
#  627  2025-02-09T19:30:32.810947
#  628  2025-02-09T19:30:58.593242
#  629  2025-02-09T19:33:26.046377
#
#                                      bridgyOriginalText  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3    <p>🏈   <a href="https://mastodon.online/tags/N...
#  4                                                  NaN
#  ..                                                 ...
#  625  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  626  “Com minha camiseta dos Eagles pendurada na po...
#  627                                                NaN
#  628                                                NaN
#  629                                                NaN
#
#                                       bridgyOriginalUrl embeds  \
#  0                                                  NaN    NaN
#  1                                                  NaN    NaN
#  2                                                  NaN    NaN
#  3    https://mastodon.online/@emarktaylor/113195201...    NaN
#  4                                                  NaN    NaN
#  ..                                                 ...    ...
#  625  https://www.sbnation.com/golf/2025/2/8/2436163...    NaN
#  626  https://tribunaonline.com.br/esportes/taylor-s...    NaN
#  627                                                NaN    NaN
#  628                                                NaN    NaN
#  629                                                NaN    NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  625  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  626  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  627  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  628  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  629  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  625  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  626  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  627  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  628  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  629  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [630 rows x 24 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:ahok3cgd4c7rhnwrnofapqls
#  1             1  app.bsky.feed.post  did:plc:xcgwe2tojxjmatdlrd6yvfch
#  2             2  app.bsky.feed.post  did:plc:ti665rl3446mp2hc6i47nadp
#  3             3  app.bsky.feed.post  did:plc:tsosz6fe72jxrhelo2i3p6dy
#  4             4  app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
#  ..          ...                 ...                               ...
#  654         654  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  655         655  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  656         656  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  657         657  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  658         658  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                           authorProfile  \
#  0    {'_id': 'did:plc:ahok3cgd4c7rhnwrnofapqls', '_...
#  1    {'avatar': 'https://cdn.bsky.app/img/avatar/pl...
#  2    {'_id': 'did:plc:ti665rl3446mp2hc6i47nadp', '_...
#  3    {'_id': 'did:plc:tsosz6fe72jxrhelo2i3p6dy', '_...
#  4    {'followers': 6048, 'viewer_blocked_by': False...
#  ..                                                 ...
#  654  {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'd...
#  655  {'did': 'did:plc:nrr6yppar26qag7p2q3rawp7', 'd...
#  656  {'did': 'did:plc:m67kp6uoter7aeftq5nkzncm', 'h...
#  657  {'did': 'did:plc:eyaz2kbzyxmg5hgkhb3w7s25', 'h...
#  658  {'did': 'did:plc:5jycdvkvabnon545dxcisari', 'd...
#
#                                                     cid  \
#  0    bafyreibrnqn53jgjudbv7j46gb5q6wte6lbw5aoaiqeab...
#  1    bafyreign2ksxhkcuendrfoyyejo425bbznifgdb2zv3po...
#  2    bafyreie6nid4f7g2vf2m7ibuyzu3id3brylthliznwg53...
#  3    bafyreigz7gycietwfxzwaaqvbnbqa4gyi6owncnz6qv5e...
#  4    zdpuAykzkHo8uZtsa4qZyQTtSePWRbHoKAJgxYwxqcrTxx6fi
#  ..                                                 ...
#  654  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  655  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  656  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  657  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  658  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0                2016-01-09T20:30:33Z
#  1            2016-11-28T02:52:09.000Z
#  2                2018-08-21T16:58:14Z
#  3            2020-01-13T12:26:24.000Z
#  4    2024-01-13T23:50:40.300023+00:00
#  ..                                ...
#  654          2025-02-08T18:53:17.000Z
#  655          2025-02-08T20:00:00.000Z
#  656          2025-02-08T22:00:00.720Z
#  657          2025-02-08T22:12:51.918Z
#  658  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  \
#  0    {'$type': 'app.bsky.embed.external', 'external...
#  1    {'$type': 'app.bsky.embed.external', 'external...
#  2    {'$type': 'app.bsky.embed.external', 'external...
#  3    {'$type': 'app.bsky.embed.external', 'external...
#  4    {'$type': 'app.bsky.embed.images', 'images': [...
#  ..                                                 ...
#  654  {'$type': 'app.bsky.embed.external', 'external...
#  655  {'$type': 'app.bsky.embed.external', 'external...
#  656  {'$type': 'app.bsky.embed.images', 'images': [...
#  657  {'$type': 'app.bsky.embed.external', 'external...
#  658  {'$type': 'app.bsky.embed.external', 'external...
#
#                                                  embeds  entities  \
#  0    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  1    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  2    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  3                                                  NaN       NaN
#  4                                                  NaN       NaN
#  ..                                                 ...       ...
#  654                                                NaN       NaN
#  655                                                NaN       NaN
#  656                                                NaN       NaN
#  657                                                NaN       NaN
#  658                                                NaN       NaN
#
#                                                  facets  ...  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  1    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#  ..                                                 ...  ...
#  654                                                NaN  ...
#  655                                                NaN  ...
#  656  [{'features': [{'$type': 'app.bsky.richtext.fa...  ...
#  657  [{'features': [{'$type': 'app.bsky.richtext.fa...  ...
#  658  [{'$type': 'app.bsky.richtext.facet', 'feature...  ...
#
#                       lastseents                   indexedAt     sequence  \
#  0    2024-12-06T19:22:59.217241                         NaN          NaN
#  1    2024-12-02T16:16:14.024322                         NaN          NaN
#  2    2024-12-02T18:24:53.023705                         NaN          NaN
#  3    2025-01-11T16:48:58.739554                         NaN          NaN
#  4    2024-01-13T23:50:41.187032  2024-01-13T23:50:40.805738  570168565.0
#  ..                          ...                         ...          ...
#  654  2025-02-09T19:50:01.532797                         NaN          NaN
#  655  2025-02-09T19:34:16.758219                         NaN          NaN
#  656  2025-02-09T19:30:32.810947                         NaN          NaN
#  657  2025-02-09T19:30:58.593242                         NaN          NaN
#  658  2025-02-09T19:33:26.046377                         NaN          NaN
#
#                                      bridgyOriginalText  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  654  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  655  “Com minha camiseta dos Eagles pendurada na po...
#  656                                                NaN
#  657                                                NaN
#  658                                                NaN
#
#                                       bridgyOriginalUrl  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  654  https://www.sbnation.com/golf/2025/2/8/2436163...
#  655  https://tribunaonline.com.br/esportes/taylor-s...
#  656                                                NaN
#  657                                                NaN
#  658                                                NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  654  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  655  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  656  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  657  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  658  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  654  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  655  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  656  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  657  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  658  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [659 rows x 26 columns],
#       Unnamed: 0               $type                            author  \
#  0             0  app.bsky.feed.post  did:plc:kqbsolnzpw3ixx2ea65qfd3s
#  1             1  app.bsky.feed.post  did:plc:2ita5o32hmjxhnzg4a7sxe73
#  2             2  app.bsky.feed.post  did:plc:37lm46sbrzz622ij4vucrceo
#  3             3  app.bsky.feed.post  did:plc:pn7bt5fej5fep3uywocvak5d
#  4             4  app.bsky.feed.post  did:plc:ltt57jg2sdeqzyqikirkf66s
#  ..          ...                 ...                               ...
#  625         625  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
#  626         626  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
#  627         627  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
#  628         628  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
#  629         629  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                           authorProfile  \
#  0    {'_id': 'did:plc:kqbsolnzpw3ixx2ea65qfd3s', '_...
#  1    {'_id': 'did:plc:2ita5o32hmjxhnzg4a7sxe73', '_...
#  2    {'_id': 'did:plc:37lm46sbrzz622ij4vucrceo', '_...
#  3    {'_id': 'did:plc:pn7bt5fej5fep3uywocvak5d', '_...
#  4    {'_id': 'did:plc:ltt57jg2sdeqzyqikirkf66s', '_...
#  ..                                                 ...
#  625  {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'd...
#  626  {'did': 'did:plc:nrr6yppar26qag7p2q3rawp7', 'd...
#  627  {'did': 'did:plc:m67kp6uoter7aeftq5nkzncm', 'h...
#  628  {'did': 'did:plc:eyaz2kbzyxmg5hgkhb3w7s25', 'h...
#  629  {'did': 'did:plc:5jycdvkvabnon545dxcisari', 'd...
#
#                                                     cid  \
#  0    bafyreieskfrnp7rxfenmifroyxttpyqfj6nselszceega...
#  1    bafyreid6n7iozz3c2sqw3c4pzayda3scsr23gzzwqoetm...
#  2    bafyreidsbp4fpxlap5xrerqv5p5wj7qwcdeuemu2u74qm...
#  3    bafyreicruejiae5nayhgdmht7jwto4epf4n5zca76t5q2...
#  4    bafyreibkuv6uhtctqi6juahgb2anhxkpznfw3tifj3w7s...
#  ..                                                 ...
#  625  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
#  626  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
#  627  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
#  628  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
#  629  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
#  0            2024-09-15T19:06:12.698Z
#  1            2024-09-24T21:36:10.000Z
#  2    2024-09-24T21:36:37.713094+00:00
#  3            2024-09-24T23:48:28.000Z
#  4            2024-10-01T18:51:00.102Z
#  ..                                ...
#  625          2025-02-08T18:53:17.000Z
#  626          2025-02-08T20:00:00.000Z
#  627          2025-02-08T22:00:00.720Z
#  628          2025-02-08T22:12:51.918Z
#  629  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  entities  \
#  0                                                  NaN       NaN
#  1    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  2    {'$type': 'app.bsky.embed.external', 'external...       NaN
#  3    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  4    {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  ..                                                 ...       ...
#  625  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  626  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  627  {'$type': 'app.bsky.embed.images', 'images': [...       NaN
#  628  {'$type': 'app.bsky.embed.external', 'external...       NaN
#  629  {'$type': 'app.bsky.embed.external', 'external...       NaN
#
#                                                  facets  labels  ...  \
#  0    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  1                                                  NaN     NaN  ...
#  2    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  3    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  4    [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#  ..                                                 ...     ...  ...
#  625                                                NaN     NaN  ...
#  626                                                NaN     NaN  ...
#  627  [{'features': [{'$type': 'app.bsky.richtext.fa...     NaN  ...
#  628  [{'features': [{'$type': 'app.bsky.richtext.fa...     NaN  ...
#  629  [{'$type': 'app.bsky.richtext.facet', 'feature...     NaN  ...
#
#                                                     uri  \
#  0    at://did:plc:kqbsolnzpw3ixx2ea65qfd3s/app.bsky...
#  1    at://did:plc:2ita5o32hmjxhnzg4a7sxe73/app.bsky...
#  2    at://did:plc:37lm46sbrzz622ij4vucrceo/app.bsky...
#  3    at://did:plc:pn7bt5fej5fep3uywocvak5d/app.bsky...
#  4    at://did:plc:ltt57jg2sdeqzyqikirkf66s/app.bsky...
#  ..                                                 ...
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#  629                                                NaN
#
#                       lastseents  \
#  0    2024-09-16T15:11:27.653628
#  1    2024-09-27T14:21:09.449232
#  2    2024-09-27T14:12:44.701547
#  3    2024-09-27T15:56:28.889099
#  4    2024-10-03T09:25:45.780203
#  ..                          ...
#  625  2025-02-09T19:50:01.532797
#  626  2025-02-09T19:34:16.758219
#  627  2025-02-09T19:30:32.810947
#  628  2025-02-09T19:30:58.593242
#  629  2025-02-09T19:33:26.046377
#
#                                      bridgyOriginalText  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3    <p>🏈   <a href="https://mastodon.online/tags/N...
#  4                                                  NaN
#  ..                                                 ...
#  625  <figure>\n      <img alt="Josh Allen, Buffalo ...
#  626  “Com minha camiseta dos Eagles pendurada na po...
#  627                                                NaN
#  628                                                NaN
#  629                                                NaN
#
#                                       bridgyOriginalUrl embeds  \
#  0                                                  NaN    NaN
#  1                                                  NaN    NaN
#  2                                                  NaN    NaN
#  3    https://mastodon.online/@emarktaylor/113195201...    NaN
#  4                                                  NaN    NaN
#  ..                                                 ...    ...
#  625  https://www.sbnation.com/golf/2025/2/8/2436163...    NaN
#  626  https://tribunaonline.com.br/esportes/taylor-s...    NaN
#  627                                                NaN    NaN
#  628                                                NaN    NaN
#  629                                                NaN    NaN
#
#                                       openmeasures_meta rkey rkey_str  \
#  0                                                  NaN  NaN      NaN
#  1                                                  NaN  NaN      NaN
#  2                                                  NaN  NaN      NaN
#  3                                                  NaN  NaN      NaN
#  4                                                  NaN  NaN      NaN
#  ..                                                 ...  ...      ...
#  625  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  626  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  627  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  628  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#  629  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
#  0    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  1    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  2    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  3    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  4    {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  ..                                                 ...      ...
#  625  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  626  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  627  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  628  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#  629  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
#  [630 rows x 24 columns]]

# %% [markdown]
# ## Data Processing
#
# + Data stored as dfs[df_1, df_2, ... n].
# + Concat all DFs to one.
# + `data_range_per_file` is the index 0 to n_1 belongs to df_1, 0_n_2 belongs to n_2, etc.

# %%
df = DataProcessing.concat_dfs(dfs)
df.rename(columns={"Unnamed: 0": "data_range_per_file"}, inplace=True)
df
# Out:
#       data_range_per_file               $type  \
# 0                       0  app.bsky.feed.post
# 1                       1  app.bsky.feed.post
# 2                       2  app.bsky.feed.post
# 3                       3  app.bsky.feed.post
# 4                       4  app.bsky.feed.post
# ...                   ...                 ...
# 4516                  625  app.bsky.feed.post
# 4517                  626  app.bsky.feed.post
# 4518                  627  app.bsky.feed.post
# 4519                  628  app.bsky.feed.post
# 4520                  629  app.bsky.feed.post
#
#                                 author  \
# 0     did:plc:mcb6n67plnrlx4lg35natk2b
# 1     did:plc:mcb6n67plnrlx4lg35natk2b
# 2     did:plc:a2ijicgkwatuhlfss36lvwfx
# 3     did:plc:mcb6n67plnrlx4lg35natk2b
# 4     did:plc:mcb6n67plnrlx4lg35natk2b
# ...                                ...
# 4516  did:plc:cywy7vw3shrn7vp3ybgfrx33
# 4517  did:plc:nrr6yppar26qag7p2q3rawp7
# 4518  did:plc:m67kp6uoter7aeftq5nkzncm
# 4519  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
# 4520  did:plc:5jycdvkvabnon545dxcisari
#
#                                                     cid  \
# 0     zdpuAykzkHo8uZtsa4qZyQTtSePWRbHoKAJgxYwxqcrTxx6fi
# 1     zdpuAt42bPRcafad5PjKbsxSXBETMXPbP7Tb8H5Mu3NV78QCw
# 2     bafyreibsxwnoso4kq6oltibk3xzbhqbjtlx7bmwxi73rs...
# 3     zdpuAuxtMWrau1PvrZQC7mC1DokTWBdYsK4mCJQyCnySk5aWb
# 4     zdpuArf8hkuDPBSJgJcwyhc1Du712poHWk73dRam3TuVDzgy4
# ...                                                 ...
# 4516  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhs...
# 4517  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675ii...
# 4518  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsr...
# 4519  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgax...
# 4520  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqay...
#
#                              createdAt  \
# 0     2024-01-13T23:50:40.300023+00:00
# 1     2024-01-15T04:20:38.045294+00:00
# 2                 2024-01-17T18:52:28Z
# 3     2024-01-21T04:30:46.145649+00:00
# 4     2024-01-21T23:20:45.897184+00:00
# ...                                ...
# 4516          2025-02-08T18:53:17.000Z
# 4517          2025-02-08T20:00:00.000Z
# 4518          2025-02-08T22:00:00.720Z
# 4519          2025-02-08T22:12:51.918Z
# 4520  2025-02-08T23:30:51.844892+00:00
#
#                                                   embed  \
# 0     {'$type': 'app.bsky.embed.images', 'images': [...
# 1     {'$type': 'app.bsky.embed.images', 'images': [...
# 2     {'$type': 'app.bsky.embed.external', 'external...
# 3     {'$type': 'app.bsky.embed.images', 'images': [...
# 4     {'$type': 'app.bsky.embed.images', 'images': [...
# ...                                                 ...
# 4516  {'$type': 'app.bsky.embed.external', 'external...
# 4517  {'$type': 'app.bsky.embed.external', 'external...
# 4518  {'$type': 'app.bsky.embed.images', 'images': [...
# 4519  {'$type': 'app.bsky.embed.external', 'external...
# 4520  {'$type': 'app.bsky.embed.external', 'external...
#
#                                                  facets  \
# 0     [{'$type': 'app.bsky.richtext.facet', 'feature...
# 1     [{'$type': 'app.bsky.richtext.facet', 'feature...
# 2     [{'$type': 'app.bsky.richtext.facet', 'feature...
# 3     [{'$type': 'app.bsky.richtext.facet', 'feature...
# 4     [{'$type': 'app.bsky.richtext.facet', 'feature...
# ...                                                 ...
# 4516                                                NaN
# 4517                                                NaN
# 4518  [{'features': [{'$type': 'app.bsky.richtext.fa...
# 4519  [{'features': [{'$type': 'app.bsky.richtext.fa...
# 4520  [{'$type': 'app.bsky.richtext.facet', 'feature...
#
#                        indexedAt     sequence  \
# 0     2024-01-13T23:50:40.805738  570168565.0
# 1     2024-01-15T04:26:24.470523  574404975.0
# 2                            NaN          NaN
# 3     2024-01-21T04:30:47.004301  596638410.0
# 4     2024-01-21T23:20:46.653710  599632070.0
# ...                          ...          ...
# 4516                         NaN          NaN
# 4517                         NaN          NaN
# 4518                         NaN          NaN
# 4519                         NaN          NaN
# 4520                         NaN          NaN
#
#                                                    text  ...   langs reply  \
# 0     Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
# 1     Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
# 2     Does defense even matter in the NFL postseason...  ...     NaN   NaN
# 3     Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
# 4     Here's the Top 10 Trending Words over the Past...  ...     NaN   NaN
# ...                                                 ...  ...     ...   ...
# 4516                                                NaN  ...     NaN   NaN
# 4517                                                NaN  ...     NaN   NaN
# 4518  The Chiefs' George Karlaftis ranks No. 1 in pr...  ...     NaN   NaN
# 4519  www.bothteamsplayhard.wordpress.com/2025/02/08...  ...  ['en']   NaN
# 4520                                       \n\n#rssespn  ...  ['en']   NaN
#
#               tags                                 bridgyOriginalText  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ...            ...                                                ...
# 4516           NaN  <figure>\n      <img alt="Josh Allen, Buffalo ...
# 4517  ['Esportes']  “Com minha camiseta dos Eagles pendurada na po...
# 4518           NaN                                                NaN
# 4519           NaN                                                NaN
# 4520           NaN                                                NaN
#
#                                       bridgyOriginalUrl  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4516  https://www.sbnation.com/golf/2025/2/8/2436163...
# 4517  https://tribunaonline.com.br/esportes/taylor-s...
# 4518                                                NaN
# 4519                                                NaN
# 4520                                                NaN
#
#                                       openmeasures_meta rkey rkey_str  \
# 0                                                   NaN  NaN      NaN
# 1                                                   NaN  NaN      NaN
# 2                                                   NaN  NaN      NaN
# 3                                                   NaN  NaN      NaN
# 4                                                   NaN  NaN      NaN
# ...                                                 ...  ...      ...
# 4516  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
# 4517  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
# 4518  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
# 4519  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
# 4520  {'collected_by': 'jetstream', 'last_scraped_ts...  NaN      NaN
#
#                                            Query Params     Site
# 0     {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 1     {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 2     {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 3     {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 4     {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# ...                                                 ...      ...
# 4516  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 4517  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 4518  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 4519  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
# 4520  {'term': '(NFL OR nfl) AND (playoffs) AND (Sup...  bluesky
#
# [4521 rows x 26 columns]
