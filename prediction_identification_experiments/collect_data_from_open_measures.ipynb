# %%
import os
import sys
import requests
import json

import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from tqdm import tqdm

AXIS_FONT_SIZE = 16

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# print(notebook_dir)
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from log_files import LogData
from data_processing import DataProcessing
from real_data_acquisition import OpenMeasuresDirector
from text_generation_models import TextGenerationModelFactory

# %%
pd.set_option('max_colwidth', 800)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Create prompt

# %%
prediction_properties = """a prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:

    1. <p_s>, any source entity in the sports domain.
        - Can be a person (with a name) or a sports domain person such as a sports reporter, sports analyst, sports expert, sports top executive, sports senior level person, etc), civilian.
        - Can only be an organization that is associated with the sports prediction.
    2. <p_t>, any target entity in the sports domain.
	    - Can be a person (with a name) or a sports person such as a sports reporter, sports analyst, sports expert, sports top executive, sports senior level person, etc).
        - Can only be an organization that is associated with the sports prediction.
    3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.
        - Forecast can range from a second to anytime in the future.
        - Answers the questions: "How far to go out from today?" or "Where to stop?".
    4. <p_o>, sports prediction outcome.
        - Details relevant details such as outcome, a quantifiable metric, or slope.
        - Some example outcomes are the following: score, touchdown, goal, points, win, lose, etc.
"""

prediction_structures = """Here are how some sports predictions are structured:
    - sports template 1: <p_s> forecasts that the <p_o> at <p_t> potentially decrease in <p_d>.
    - sports template 2: On <p_d>, <p_s> speculates the <p_o> at <p_t> will likely increase.
    - sports template 3: <p_s> predicts on <p_d>, the <p_t> <p_o> may rise.
    - sports template 4: According to <p_s>, the <p_o> at <p_t> would fall in <p_d>.
    - sports template 5: In <p_d>, <p_s> envisions that <p_t> <p_o> has some probability to remain stable.
    - sports template 6: <p_t> <p_o> should stay same <p_d>, according to <p_s>. 
"""

sport_examples = """Here are some corresponding examples of sports predictions:
    - sport examples for template 1:
        1. Coach Lisa Martinez predicts that the touchdown rate at the Miami Dolphins will fall in 2020 of October.
        2. Analyst Mark Johnson forecasts that the goal average at Manchester United will stay the same in November 2025.
        3. Ryan forecasts win percentage he has for soccer will go up in 12/25/2016.
    - sport examples for template 2:
        1. On Sep 20, 2100, Coach Maria Lopez suggests that the score average at the Chicago Bulls is climbing.
        2. On 9/12/2025, Analyst David Kim anticipates the touchdown rate at the Kansas City Chiefs will likely surge.
        3. On October 8, 2123, Detravious foresees that the win probability he has for rugby is expected to trend downward.
    - sport examples for template 3:
        1. Coach Elena Ruiz predicts on 9/22/2025, the goal count at Real Madrid will climb.
        2. Analyst Marcus Lee forecasts that on Sep 30, 2055, the point average at the Golden State Warriors will be higher.
        3. George Jr. estimates that on October 15, 2035, the win ratio for games he has will disimprove.
    - sport examples for template 4:
        1. According to Coach Sarah Nguyen, the scoring average at the Dallas Mavericks is expected to dip in Sep 2021.
        2. According to Analyst Trevor Simmons, the touchdown rate at the Green Bay Packers will increase in 10/2025.
        3. According to Manchester United, the win percentage at Manchester United is projected to drop in October 2034.
    - sport examples for template 5:
        1. In 9/2025, Coach Miguel Torres envisions that the goal average at Paris Saint-Germain will hold steady.
        2. In October 2056, Analyst Fiona Bennett anticipates that the win rate at the Toronto Raptors will decrease slightly.
        3. In Sep 2086, Calvin foresees that the points per game he has in football will gradually increase.
    - sport examples for template 6:
        1. The goal count at Liverpool FC will surge in Sep 2012, according to Coach Daniel Alvarez.
        2. The win percentage at the Chicago Bears will taper off in October 2025, according to Analyst Priya Sharma.
        3. The scoring average on Arnolds footbal team will remain steady in 10/2034, according to Arnold.
"""

sport_requirements = """- Should be based on real-world sports.
    - Suppose the time when <p> was made is during any season of sports.
    - Include reports from all sports professionals, coaches, or any type of sport entity.
"""

initial_query_string = """(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)"""

# %%
prompt = f"""Generate a query string using boolean logic and keywords (related to sports predictions) to search a database. I define {prediction_properties} 
{prediction_structures}
{sport_examples}
These sports predictions can be found in social media data at large. My task here is to query the site to find relatable sentences (that aren't predictions) and prediction sentences). 
My initial query string: {initial_query_string}. Don't use brackets to wrap words nor to use quotation marks to wrap words. 
I need you to generate an improved (better prediction precision) query string taking into consideration the above along with {sport_requirements} \n Don't generate anything other than a new/imporved query string!
"""
prompt
# Out:
# 'Generate a query string using boolean logic and keywords (related to sports predictions) to search a database. I define a prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:\n\n    1. <p_s>, any source entity in the sports domain.\n        - Can be a person (with a name) or a sports domain person such as a sports reporter, sports analyst, sports expert, sports top executive, sports senior level person, etc), civilian.\n        - Can only be an organization that is associated with the sports prediction.\n    2. <p_t>, any target entity in the sports domain.\n\t    - Can be a person (with a name) or a sports person such as a sports reporter, sports analyst, sports expert, sports top executive, sports senior level person, etc).\n        - Can only be an organization that is associated with the sports prediction.\n    3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.\n        - Forecast can range from a second to anytime in the future.\n        - Answers the questions: "How far to go out from today?" or "Where to stop?".\n    4. <p_o>, sports prediction outcome.\n        - Details relevant details such as outcome, a quantifiable metric, or slope.\n        - Some example outcomes are the following: score, touchdown, goal, points, win, lose, etc.\n \nHere are how some sports predictions are structured:\n    - sports template 1: <p_s> forecasts that the <p_o> at <p_t> potentially decrease in <p_d>.\n    - sports template 2: On <p_d>, <p_s> speculates the <p_o> at <p_t> will likely increase.\n    - sports template 3: <p_s> predicts on <p_d>, the <p_t> <p_o> may rise.\n    - sports template 4: According to <p_s>, the <p_o> at <p_t> would fall in <p_d>.\n    - sports template 5: In <p_d>, <p_s> envisions that <p_t> <p_o> has some probability to remain stable.\n    - sports template 6: <p_t> <p_o> should stay same <p_d>, according to <p_s>. \n\nHere are some corresponding examples of sports predictions:\n    - sport examples for template 1:\n        1. Coach Lisa Martinez predicts that the touchdown rate at the Miami Dolphins will fall in 2020 of October.\n        2. Analyst Mark Johnson forecasts that the goal average at Manchester United will stay the same in November 2025.\n        3. Ryan forecasts win percentage he has for soccer will go up in 12/25/2016.\n    - sport examples for template 2:\n        1. On Sep 20, 2100, Coach Maria Lopez suggests that the score average at the Chicago Bulls is climbing.\n        2. On 9/12/2025, Analyst David Kim anticipates the touchdown rate at the Kansas City Chiefs will likely surge.\n        3. On October 8, 2123, Detravious foresees that the win probability he has for rugby is expected to trend downward.\n    - sport examples for template 3:\n        1. Coach Elena Ruiz predicts on 9/22/2025, the goal count at Real Madrid will climb.\n        2. Analyst Marcus Lee forecasts that on Sep 30, 2055, the point average at the Golden State Warriors will be higher.\n        3. George Jr. estimates that on October 15, 2035, the win ratio for games he has will disimprove.\n    - sport examples for template 4:\n        1. According to Coach Sarah Nguyen, the scoring average at the Dallas Mavericks is expected to dip in Sep 2021.\n        2. According to Analyst Trevor Simmons, the touchdown rate at the Green Bay Packers will increase in 10/2025.\n        3. According to Manchester United, the win percentage at Manchester United is projected to drop in October 2034.\n    - sport examples for template 5:\n        1. In 9/2025, Coach Miguel Torres envisions that the goal average at Paris Saint-Germain will hold steady.\n        2. In October 2056, Analyst Fiona Bennett anticipates that the win rate at the Toronto Raptors will decrease slightly.\n        3. In Sep 2086, Calvin foresees that the points per game he has in football will gradually increase.\n    - sport examples for template 6:\n        1. The ...

# %% [markdown]
# ## Query for Data
#
# - For query string, have user define `initial_query_string` or have any LLM in `text_generation_models.py` to generate via the prompt. Either way, the system is set up for user feedback. With this, check the query string (and url for data). If good with it type 'agree'. If not, add details. The details will append to old prompt.

# %%
# Configuring parameters
terms_for_query = OpenMeasuresDirector
query_string_by = 'user'
limit = 2000
# NFL playoffs (The NFL playoffs for the 2024 season began on January 11, 2025, and concluded with Super Bowl LIX on February 9 at Caesars Superdome in New Orleans, Louisiana | WIKI)
since = '2015-09-05'
until = '2025-02-09' 
esquery = 'query_string' # Elasticsearch across all fields

# sites = ["tiktok_comment", "bluesky", "truth_social"]
sites = ["bluesky", "truth_social"]
hits_per_site_dfs = []
for site in sites:
    hits_for_site_df = OpenMeasuresDirector.construct_from_dataset(query_string=initial_query_string, query_string_by=query_string_by, limit=limit, site=site, start_date=since, end_date=until, querytype=esquery)
    hits_per_site_dfs.append(hits_for_site_df)

hits_per_site_dfs
# Out:
# =============================== Site: bluesky ===============================
# ### RESET ###
# ### USER SPECIFY QUERY STRINGS ###
# 	Query String: (<class 'str'>, '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)')
#
# ### SET QUERY ###
# 	Query's URL: http://api.smat-app.com/content?term=(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)&limit=2000&site=bluesky&since=2015-09-05&until=2025-02-09&querytype=query_string
#
# ### GET RAW HITS ###
# 	Hits: 200
# Hits retrieved:
#                   $type                            author  \
# 0    app.bsky.feed.post  did:plc:ahok3cgd4c7rhnwrnofapqls
# 1    app.bsky.feed.post  did:plc:xcgwe2tojxjmatdlrd6yvfch
# 2    app.bsky.feed.post  did:plc:ti665rl3446mp2hc6i47nadp
# 3    app.bsky.feed.post  did:plc:tsosz6fe72jxrhelo2i3p6dy
# 4    app.bsky.feed.post  did:plc:mcb6n67plnrlx4lg35natk2b
# ..                  ...                               ...
# 655  app.bsky.feed.post  did:plc:cywy7vw3shrn7vp3ybgfrx33
# 656  app.bsky.feed.post  did:plc:nrr6yppar26qag7p2q3rawp7
# 657  app.bsky.feed.post  did:plc:m67kp6uoter7aeftq5nkzncm
# 658  app.bsky.feed.post  did:plc:eyaz2kbzyxmg5hgkhb3w7s25
# 659  app.bsky.feed.post  did:plc:5jycdvkvabnon545dxcisari
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        authorProfile  \
# 0    {'_id': 'did:plc:ahok3cgd4c7rhnwrnofapqls', '_index': 'smat-bluesky-users', 'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:ahok3cgd4c7rhnwrnofapqls/bafkreic5yiylpra6qg2hpluhkktuiggzesdtc25s6xhhpitqueiicso27e@jpeg', 'banner': 'https://cdn.bsky.app/img/banner/plain/did:plc:ahok3cgd4c7rhnwrnofapqls/bafkreia47gyvqcq2mcndvv2dtkwkepudxmwfk6ca4rujpwfynwn6onibsa@jpeg', 'description': 'Find my profile at https://vivensjoachim.brandyourself.com/
# Find my community works at: https://mibaleavantou.com, or
# http://vjmvp.com/index.php, and some other works at: https://ntkvideo.com/
# Born in Haiti in 1970. Migrated to the USA in 1994. Live in CT', 'did': 'did:plc:ahok3cgd4c7rhnwrnofapqls', 'display_name': 'Vivens Joachim', 'followers': 59, 'following': 215, 'handle': 'vjoachim.bsky.social', 'i...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                            {'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:xcgwe2tojxjmatdlrd6yvfch/bafkreicb6om5wyijae6x6sl4rghudocpqhsbstsytdikgqx55dry5ggc4i@jpeg', 'banner': None, 'description': None, 'did': 'did:plc:xcgwe2tojxjmatdlrd6yvfch', 'display_name': '', 'followers': 31, 'following': 18, 'handle': 'daletuggy.bsky.social', 'indexed_at': '2024-11-16T23:44:10.571Z', 'posts': 3301}
# 2                                                                                                      {'_id': 'did:plc:ti665rl3446mp2hc6i47nadp', '_index': 'smat-bluesky-users', 'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:ti665rl3446mp2hc6i47nadp/bafkreianmx3dirhepklskhvf3pago6x34z3kehglqksjxyyolkuusio3su@jpeg', 'banner': 'https://cdn.bsky.app/img/banner/plain/did:plc:ti665rl3446mp2hc6i47nadp/bafkreihz6zrlpdm37ip5r4hpj66txsvwsuuyqpo4uxjwpdmcfovcgyii6i@jpeg', 'description': 'Orioles Ravens Terps Tottenham
#
# @flyskimmy -twit
# @mtfires -thread
# ', 'did': 'did:plc:ti665rl3446mp2hc6i47nadp', 'display_name': 'MT Fires', 'followers': 299, 'following': 2420, 'handle': 'mtfires.bsky.social', 'indexed_at': '2024-01-26T00:41:23.827Z', 'lastseents': '2024-12-18T02:05:17.696870', 'posts': 4289}
# 3    {'_id': 'did:plc:tsosz6fe72jxrhelo2i3p6dy', '_index': 'smat-bluesky-users', 'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:tsosz6fe72jxrhelo2i3p6dy/bafkreigjpwfyoa3kw67tqfo2cep5wyyykxkwhcozhwa64pg3ql53hzqi2a@jpeg', 'banner': 'https://cdn.bsky.app/img/banner/plain/did:plc:tsosz6fe72jxrhelo2i3p6dy/bafkreidtj4e73ayyd6ymgbp2x7qy4g2ogyvzwhing7ncfwmypbybqgeh7i@jpeg', 'description': 'Opinions my own. Chief Medical Officer at Curai Health, an AI-powered virtual clinic on a mission to improve access to care at scale. Board-certified family medicine physician who is passionate about improving healthcare by leveraging AI. ', 'did': 'did:plc:tsosz6fe72jxrhelo2i3p6dy', 'display_name': 'Davis Liu, MD - Chief Medical Officer at Curai Health', 'followers': 29, 'following': 36, 'handle': 'dav...
# 4    {'followers': 6048, 'viewer_blocked_by': False, 'following': 7, 'viewer_mute': False, 'banner': 'https://cdn.bsky.app/img/banner/plain/did:plc:mcb6n67plnrlx4lg35natk2b/bafkreibhchfr7cylzowbtevtjokkh2kxrzejno6smi4mgqskvwxeq3yg2a@jpeg', 'description': '🤖 Now Breezing b2.8.7 (Beta WIP)
#
# Bluesky's Trends, on the :10s, every 10!
# (words weighted against ~1 month of past usage)
#
# 🟢ONLINE!
# Issues? Contact the creator:
# 🦋 @nickwrightdata.ntw.app
# 💬(Signal): nickwrightdata.01
# ☕ https://ko-fi.com/nickwrightdata', 'handle': 'nowbreezing.ntw.app', 'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:mcb6n67plnrlx4lg35natk2b/bafkreifwi2c6j5hgtgzmwtufp5ehqrrw2uzdogrxvxiz5ea43qdgrsceti@jpeg', 'display_name': '☁️Now🤖Breezing💨 [UNOFFICIAL]', 'posts': 64771, 'did': 'did:plc:mcb6n67plnrlx4lg35natk2b', 'l...
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 655                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'did': 'did:plc:cywy7vw3shrn7vp3ybgfrx33', 'display_name': 'SBNation.com | Sports news, video, live coverage, community', 'handle': 'sbnation.com.web.brid.gy'}
# 656                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'did': 'did:plc:nrr6yppar26qag7p2q3rawp7', 'display_name': 'Tribuna Online | Seu portal de Notícias', 'handle': 'tribunaonline.com.br.web.brid.gy'}
# 657                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'did': 'did:plc:m67kp6uoter7aeftq5nkzncm', 'handle': 'optaanalystus.bsky.social'}
# 658                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             {'did': 'did:plc:eyaz2kbzyxmg5hgkhb3w7s25', 'handle': 'andrewsheehy228.bsky.social'}
# 659                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'did': 'did:plc:5jycdvkvabnon545dxcisari', 'display_name': '', 'handle': 'rssfeedaccount.bsky.social'}
#
#                                                              cid  \
# 0    bafyreibrnqn53jgjudbv7j46gb5q6wte6lbw5aoaiqeabtgfhoz4tqmutq
# 1    bafyreign2ksxhkcuendrfoyyejo425bbznifgdb2zv3poaxr23dcvo6mfa
# 2    bafyreie6nid4f7g2vf2m7ibuyzu3id3brylthliznwg537sw4tsepljwgq
# 3    bafyreigz7gycietwfxzwaaqvbnbqa4gyi6owncnz6qv5edhucnvgkhmsry
# 4              zdpuAykzkHo8uZtsa4qZyQTtSePWRbHoKAJgxYwxqcrTxx6fi
# ..                                                           ...
# 655  bafyreian7dv3sdwf35zyhpix3zknyu4c2omfo2qsbvxhsv2xm7wcskp6ci
# 656  bafyreigsq3sbskb7hwcafektwr7p5i75v2gwgd7a675iiekjqxq66oufti
# 657  bafyreigxo3xazujg34iw32q72dphpcsen665hebk4dwsrbqsjjelimjvxy
# 658  bafyreigtzpa4bsolb5qkuc35735wcxgr4xsee3q46hgaxg3trcmwyaozra
# 659  bafyreic6kv3mstwkovutr4f6cqrezp2xb5h6odttayqaycyficpcuoxjle
#
#                             createdAt  \
# 0                2016-01-09T20:30:33Z
# 1            2016-11-28T02:52:09.000Z
# 2                2018-08-21T16:58:14Z
# 3            2020-01-13T12:26:24.000Z
# 4    2024-01-13T23:50:40.300023+00:00
# ..                                ...
# 655          2025-02-08T18:53:17.000Z
# 656          2025-02-08T20:00:00.000Z
# 657          2025-02-08T22:00:00.720Z
# 658          2025-02-08T22:12:51.918Z
# 659  2025-02-08T23:30:51.844892+00:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                embed  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': '', 'thumb': None, 'title': 'Close Menu', 'uri': 'http://www.cbssports.com/nfl/eye-on-football/25442860/super-bowl-odds-patriots-cardinals-begin-playoffs-as-co-favorites'}}
# 1    {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'Dallas Cowboys quarterback Dak Prescott is defying the loftiest of expectations during his rookie season, steering his team to a 10-game winning streak and the league's best record.Prescott emerged out of nowhere and was only named the starting quarterback after Tony Romo fractured a vertebra in his back during the preseason. The 23-year-old, along with teammate Ezekiel Elliott are the talk of the NFL and it's worth evaluating where Prescott's campaign compares among the best rookie seasons in league history. Dak Prescott, 2016 Prescott is submitting the most efficient season by a rookie quarterback in NFL history, completing 67.9 percent of his passes for 2,835 yards, 18 touc...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                        {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'The upcoming NFL season will surprise us in ways we canno...', 'thumb': None, 'title': '2018 NFL Predictions: Team-by-Team Records, Playoffs and ...', 'uri': 'https://www.si.com/nfl/2018/08/21/nfl-preseason-predictions-team-records-playoffs-super-bowl-liii-champion'}}
# 3                                                                                                                                                                                                                {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'Everything you need to know for both conference championship games, with X factors, what to watch for and more.', 'thumb': {'$type': 'blob', 'mime_type': 'image/jpeg', 'ref': 'bafkreidmnfvrk4dfysoxtuiekr4auh6ird3vbrurqt7mlzt777yeu66n54', 'size': 126727}, 'title': 'First look at NFL conference championships: Previewing Titans-Chiefs, Packers-49ers', 'uri': 'https://www.espn.com/nfl/story/_/id/28472209/2019-nfl-playoffs-bracket-reset-schedule-previews-titans-chiefs-packers-49ers'}}
# 4    {'$type': 'app.bsky.embed.images', 'images': [{'alt': 'Word Cloud; its top words (sorted by weighted frequency, descending):  flacco, browns, texans, elite, cleveland, stroud, houston, francisco, joe, freeze, miracle, migrants, 939, 身体, 社会, 好み, 全員, 今朝, データ, たん, yum, temperature, sixes, propane, lesbians, https, gaza, cj, bay, bags, 737, 連絡, 誕生, 覚め, 楽しん, 周年, 内容, セット, コンテンツ, はじめ, かけ, zoo, yards, www.change.org/p/renew-our, winnings, trogdor, tokens, thrown, texas, ted, stans, san, riding, qb, pots, playoffs, pergunta, peanut, noted, mysterious, mentions, luckily, lobbyarbeit, lap, k-pop, jeans, hire, harris, grid, greg, flaco, drain, democrat, degrees, dean, craving, cold, bowl, baked, artworks, alf, aero, abbott, 꿈을, 雑多, 試験, 目覚め, 環境, 照れ, 求め, 概念, 昨日, 早く, 御意, 強制, 引用, 家族, 学習, 学校, 妄想, 壊れ, 去...
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 655  {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'Photo by Todd Rosenberg/Getty Images
#
# At the WM Phoenix Open, Jordan Spieth spoke about his admiration for Josh Allen after he won the NFL’s MVP award.
#
# SCOTTSDALE, Ariz. — The love football fans have for Josh Allen extends far beyond the cold confines of Western New York. He’s a hot topic at the WM Phoenix Open all the way out in Arizona, more than 2,000 miles away from where he has produced countless highlight-worthy plays in Orchard Park.
#
# Many PGA Tour pros, notably Jordan Spieth and Keith Mitchell, talked about how they adore Allen after he won the NFL’s MVP award for the first time in his career.
#
# “He’s my favorite player. Maybe in any sport right now, but definitely my ...
# 656  {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': '“Com minha camiseta dos Eagles pendurada na porta.” A letra da canção Gold Rush, de Taylor Swift, lançada em 2020, faz menção ao time da Filadélfia, que encara o Kansas City Chiefs neste domingo, no Super Bowl 59. “Havia um debate nas redes sociais se a letra da música seria sobre a banda (Eagles) ou o time. Pessoal, eu cresci na Filadélfia, é claro que é o time”, brincou durante uma apresentação da Eras Tour, em 2023. Cinco anos depois, a “Loirinha”, por ironia do destino, estará torcendo contra o time de coração.Como isso aconteceu? Desde 2023, poucos meses após revelar oficialmente o motivo por trás da letra de sua música em referência ao Philadelphia Eagles, Taylor começou...
# 657                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'$type': 'app.bsky.embed.images', 'images': [{'alt': '', 'aspectRatio': {'height': 2615, 'width': 3846}, 'image': {'$type': 'blob', 'mimeType': 'image/png', 'ref_str': 'bafkreiejvu53zs4trszowos7pnl2enlscw6tov3mmdvht2ulxt4zldc7v4', 'size': 196440}}]}
# 658                                                                                                                                                                                                                                                        {'$type': 'app.bsky.embed.external', 'external': {'description': 'Ladies and Gentleman, Tractors and Golf Carts, we’ve finally arrived. After 18 Weeks of Regular Season Action and 3 Weeks of Playoff Action, the final stop of the Football Season has been rea…', 'thumb': {'$type': 'blob', 'mimeType': 'image/jpeg', 'ref_str': 'bafkreiclxenyiojeycubxmyljowqjy43krzlnulluwrvhxbn4ejevrdxji', 'size': 264093}, 'title': 'Super Bowl LIX: Super Bowl LIX Pick', 'uri': 'http://www.bothteamsplayhard.wordpress.com/2025/02/08/super-bowl-lix-super-bowl-lix-pick/'}}
# 659                                                                                                                                                                                                                    {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': '14 teams embarked on journey to Super Bowl LIX, but only two were left standing. Kendrick Lamar details the seasons of the 14.', 'thumb': {'$type': 'blob', 'mimeType': 'image/jpeg', 'ref_str': 'bafkreihfrsmlarksej662sawywgkol34orskfoerplxlrv5kixheyepqxy', 'size': 93330}, 'title': ''Not Like Us' to 'Humble': How Kendrick Lamar's music mirrors the NFL Playoffs', 'uri': 'https://www.espn.com/nfl/story/_/id/43723294/nfl-playoffs-teams-kendrick-lamar-songs-super-bowl-lix-half'}}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               embeds  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': '', 'thumb': None, 'title': 'Close Menu', 'uri': 'http://www.cbssports.com/nfl/eye-on-football/25442860/super-bowl-odds-patriots-cardinals-begin-playoffs-as-co-favorites'}}
# 1    {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'Dallas Cowboys quarterback Dak Prescott is defying the loftiest of expectations during his rookie season, steering his team to a 10-game winning streak and the league's best record.Prescott emerged out of nowhere and was only named the starting quarterback after Tony Romo fractured a vertebra in his back during the preseason. The 23-year-old, along with teammate Ezekiel Elliott are the talk of the NFL and it's worth evaluating where Prescott's campaign compares among the best rookie seasons in league history. Dak Prescott, 2016 Prescott is submitting the most efficient season by a rookie quarterback in NFL history, completing 67.9 percent of his passes for 2,835 yards, 18 touc...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                        {'$type': 'app.bsky.embed.external', 'external': {'$type': 'app.bsky.embed.external#external', 'description': 'The upcoming NFL season will surprise us in ways we canno...', 'thumb': None, 'title': '2018 NFL Predictions: Team-by-Team Records, Playoffs and ...', 'uri': 'https://www.si.com/nfl/2018/08/21/nfl-preseason-predictions-team-records-playoffs-super-bowl-liii-champion'}}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 655                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 656                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 657                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 658                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 659                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#
#      entities  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 655       NaN
# 656       NaN
# 657       NaN
# 658       NaN
# 659       NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               facets  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'http://www.cbssports.com/nfl/eye-on-football/25442860/super-bowl-odds-patriots-cardinals-begin-playoffs-as-co-favorites'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byte_end': 188, 'byte_start': 69}}]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://thescore.com/news/1166681'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byte_end': 27, 'byte_start': 2}}]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://www.si.com/nfl/2018/08/21/nfl-preseason-predictions-team-records-playoffs-super-bowl-liii-champion'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byte_end': 221, 'byte_start': 115}}]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://espn.com/nfl/story/_/id…'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byte_end': 162, 'byte_start': 136}}]
# 4    [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://www.bsky.app/search?q=flacco'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byteEnd': 82, 'byteStart': 76}}, {'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://www.bsky.app/search?q=browns'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byteEnd': 106, 'byteStart': 100}}, {'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://www.bsky.app/search?q=texans'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byteEnd': 119, 'byteStart': 113}}, {'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri':...
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 655                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 656                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 657                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'https://theanalyst.com/na/2025/02/super-bowl-x-factors-chiefs-eagles'}], 'index': {'byteEnd': 222, 'byteStart': 191}}]
# 658                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'features': [{'$type': 'app.bsky.richtext.facet#link', 'uri': 'http://www.bothteamsplayhard.wordpress.com/2025/02/08/super-bowl-lix-super-bowl-lix-pick/'}], 'index': {'byteEnd': 51, 'byteStart': 0}}]
# 659                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [{'$type': 'app.bsky.richtext.facet', 'features': [{'$type': 'app.bsky.richtext.facet#tag', 'tag': 'rssespn'}], 'index': {'$type': 'app.bsky.richtext.facet#byteSlice', 'byteEnd': 10, 'byteStart': 2}}]
#
#      labels  ...                  lastseents                   indexedAt  \
# 0       NaN  ...  2024-12-06T19:22:59.217241                         NaN
# 1       NaN  ...  2024-12-02T16:16:14.024322                         NaN
# 2       NaN  ...  2024-12-02T18:24:53.023705                         NaN
# 3       NaN  ...  2025-01-11T16:48:58.739554                         NaN
# 4       NaN  ...  2024-01-13T23:50:41.187032  2024-01-13T23:50:40.805738
# ..      ...  ...                         ...                         ...
# 655     NaN  ...  2025-02-09T19:50:01.532797                         NaN
# 656     NaN  ...  2025-02-09T19:34:16.758219                         NaN
# 657     NaN  ...  2025-02-09T19:30:32.810947                         NaN
# 658     NaN  ...  2025-02-09T19:30:58.593242                         NaN
# 659     NaN  ...  2025-02-09T19:33:26.046377                         NaN
#
#         sequence  \
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4    570168565.0
# ..           ...
# 655          NaN
# 656          NaN
# 657          NaN
# 658          NaN
# 659          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   bridgyOriginalText  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# ...
#   159                                                                                                                                                                                                                                                          Really wish you would have Elon look into the referees that are in the pockets for KC. They should have never even made it to the playoffs. Many fans are disgusted with NFL and helping KC because of Taylor Swift! Many won’t watch Super Bowl because of it and are loosing fans. Remember when the fans boycotted NFL because of disrespect while our National Anthem was being played, and they did it for you as well. Please look into this so NFL doesn’t ruin the love of the great American game.Thank you for everything you do. You are Gods blessing.✝️🙏♥️
#
#                           created_at datatype  downvotes_count emojis  ...  \
#   0    2022-04-24T20:52:32.230+00:00     post              0.0     []  ...
#   1    2022-05-17T20:50:14.967+00:00     post              0.0     []  ...
#   2    2022-09-07T17:26:19.589+00:00     post              0.0     []  ...
#   3    2022-09-26T23:32:51.382+00:00     post              NaN     []  ...
#   4    2022-10-03T01:47:01.368+00:00  comment              0.0     []  ...
#   ..                             ...      ...              ...    ...  ...
#   155  2025-01-27T17:29:45.435+00:00  comment              NaN     []  ...
#   156  2025-01-27T20:32:47.859+00:00  comment              0.0     []  ...
#   157  2025-02-08T00:19:42.311+00:00     post              NaN     []  ...
#   158  2025-02-08T07:08:42.339+00:00     post              NaN     []  ...
#   159  2025-02-08T09:15:11.973+00:00  comment              0.0     []  ...
#
#       application  text tombstone  tv group_timeline_visible last_seen_ts  \
#   0           NaN   NaN       NaN NaN                    NaN          NaN
#   1           NaN   NaN       NaN NaN                    NaN          NaN
#   2           NaN   NaN       NaN NaN                    NaN          NaN
#   3           NaN   NaN       NaN NaN                    NaN          NaN
#   4           NaN   NaN       NaN NaN                    NaN          NaN
#   ..          ...   ...       ...  ..                    ...          ...
#   155         NaN   NaN       NaN NaN                    NaN          NaN
#   156         NaN   NaN       NaN NaN                    NaN          NaN
#   157         NaN   NaN       NaN NaN                    NaN          NaN
#   158         NaN   NaN       NaN NaN                    NaN          NaN
#   159         NaN   NaN       NaN NaN                    NaN          NaN
#
#       reblog  \
#   0      NaN
#   1      NaN
#   2      NaN
#   3      NaN
#   4      NaN
#   ..     ...
#   155    NaN
#   156    NaN
#   157    NaN
#   158    NaN
#   159    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     openmeasures_media  \
#   0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
#   1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
#   2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
#   3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
#   4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                NaN
#   ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#   155                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#   156                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#   157  [{'_hash': '00d0f292df771a8839799409f19c9fddc9b94101', 'thumbnail_hash': '2869e7dc97b3797481e043643dd0ad8fca89e31a', 'thumbnail_mimetype': 'image/jpeg', 'mimetype': 'image/jpeg', 'source_id': '113965398687669786', 'source_url': 'https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/965/398/687/669/786/original/335b082a95bbbd03.jpg', 'enrichments': [{'service': 'blip', 'calculated_date': '2025-02-08T06:36:03.195116+00:00', 'type': 'image_caption', 'value': 'a screenshot of a screenshot of a screenshot of a game'}, {'service': 'tesseract', 'calculated_date': '2025-02-08T06:36:03.195128+00:00', 'type': 'OCR', 'value': 'Cy LE a ea Rea CoA Mie e Tan ean eal as (-L FATMMEsTo) (G7 W-Es3) ee eer} Q'}]}, {'_hash': '0a2eabdb13cbe2b6e94b1d772c7cdf9f8ee1a8e2', 't...
#   158                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#   159                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#
#                                                                                                                                                                                           Query Params  \
#   0    {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   1    {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   2    {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   3    {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   4    {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   ..                                                                                                                                                                                               ...
#   155  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   156  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   157  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   158  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#   159  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#
#                Site
#   0    truth_social
#   1    truth_social
#   2    truth_social
#   3    truth_social
#   4    truth_social
#   ..            ...
#   155  truth_social
#   156  truth_social
#   157  truth_social
#   158  truth_social
#   159  truth_social
#
#   [160 rows x 53 columns]]]

# %% [markdown]
# ## Data Processing
#
# + Data per site (bluesky and truth social) is stored in list called `hits_per_site_dfs`.
# + Each site has data (pd.DataFrame) in list.
# + Concat all DFs per site.
# + Per Dr. Grant, time for each query process.

# %%
# tiktok_dfs = hits_per_site_dfs[0]
# tiktok_df = DataProcessing.concat_dfs(tiktok_dfs)

bluesky_dfs = hits_per_site_dfs[0]
bluesky_df = DataProcessing.concat_dfs(bluesky_dfs)

true_social_dfs = hits_per_site_dfs[1]
true_social_df = DataProcessing.concat_dfs(true_social_dfs)
true_social_df['text'] = true_social_df['content_cleaned']
true_social_df.tail(3)
# Out:
#                                                                                                                account  \
# 157     {'acct': 'vickieski', 'display_name': 'Vickie Dembinski', 'id': '107834840758287063', 'username': 'vickieski'}
# 158  {'acct': 'billrogers76', 'display_name': 'W A R Liberty', 'id': '107910638877822210', 'username': 'billrogers76'}
# 159        {'acct': 'nicolespink70', 'display_name': 'Nikki', 'id': '112194771027584744', 'username': 'nicolespink70'}
#
#     bookmarked  card          collected_by  \
# 157      False  None  smat-scrapy-crawlers
# 158      False  None  smat-scrapy-crawlers
# 159      False  None  smat-scrapy-crawlers
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              content  \
# 157  <p>For some time, I feel the message to the public which many people know, the NFL, NBA etc are all manipulated.  Lower terms "rigged", anywhere there is big money, we all know who it is controlled by.  Like the Romans said, "Make them an arena".  Only a few big players, making the big money (hush money) get the play book way before the season starts and what is going to happen and to make it happen.  I believe many college sports are also, esp football $$$ .. but does not involve the players, it involves the coaches and the college, based on making the right plays or plays to make it fail on purpose.  Lets sit back and watch..  plus the Super Bowl is the highest human trafficking event all year.   Since White Hats have been in control, they have been scooping up many criminals involve...
# 158                                                                                                                                                                                                                                                                                                                                         <p>It is just boys playing a game🏈😜<br/>How much do NFL players get paid in the playoffs? The CBA also spells out how much players are paid in each *round of the postseason. Here are the 😵‍💫bonuses for the 2024 regular season:<br/>\t•\tDivision winner: $54,500<br/>\t•\tWild Card/first-round *bye: $49,500<br/>\t•\tDivisional Round: $54,500<br/>\t•\tConference Championship: $77,000 <br/>\t•\tSuper Bowl *losing team: $96,000<br/>\t•\tSuper Bowl winning team: $171,000</p>
# 159                                                                                                                                                                                                                                                   <p>Really wish you would have Elon look into the referees that are in the pockets for KC. They should have never even made it to the playoffs. Many fans are disgusted with NFL and helping KC because of Taylor Swift! Many won’t watch Super Bowl because of it and are loosing fans. Remember when the fans boycotted NFL because of disrespect while our National Anthem was being played, and they did it for you as well. Please look into this so NFL doesn’t ruin the love of the great American game.Thank you for everything you do. You are Gods blessing.✝️🙏♥️</p>
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      content_cleaned  \
# 157  For some time, I feel the message to the public which many people know, the NFL, NBA etc are all manipulated.  Lower terms "rigged", anywhere there is big money, we all know who it is controlled by.  Like the Romans said, "Make them an arena".  Only a few big players, making the big money (hush money) get the play book way before the season starts and what is going to happen and to make it happen.  I believe many college sports are also, esp football $$$ .. but does not involve the players, it involves the coaches and the college, based on making the right plays or plays to make it fail on purpose.  Lets sit back and watch..  plus the Super Bowl is the highest human trafficking event all year.   Since White Hats have been in control, they have been scooping up many criminals involved t...
# 158                                                                                                                                                                                                                                                                                                                                                                                   It is just boys playing a game🏈😜How much do NFL players get paid in the playoffs? The CBA also spells out how much players are paid in each *round of the postseason. Here are the 😵‍💫bonuses for the 2024 regular season:\t•\tDivision winner: $54,500\t•\tWild Card/first-round *bye: $49,500\t•\tDivisional Round: $54,500\t•\tConference Championship: $77,000 \t•\tSuper Bowl *losing team: $96,000\t•\tSuper Bowl winning team: $171,000
# 159                                                                                                                                                                                                                                                          Really wish you would have Elon look into the referees that are in the pockets for KC. They should have never even made it to the playoffs. Many fans are disgusted with NFL and helping KC because of Taylor Swift! Many won’t watch Super Bowl because of it and are loosing fans. Remember when the fans boycotted NFL because of disrespect while our National Anthem was being played, and they did it for you as well. Please look into this so NFL doesn’t ruin the love of the great American game.Thank you for everything you do. You are Gods blessing.✝️🙏♥️
#
#                         created_at datatype  downvotes_count emojis  ...  \
# 157  2025-02-08T00:19:42.311+00:00     post              NaN     []  ...
# 158  2025-02-08T07:08:42.339+00:00     post              NaN     []  ...
# 159  2025-02-08T09:15:11.973+00:00  comment              0.0     []  ...
#
#     application  \
# 157         NaN
# 158         NaN
# 159         NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 text  \
# 157  For some time, I feel the message to the public which many people know, the NFL, NBA etc are all manipulated.  Lower terms "rigged", anywhere there is big money, we all know who it is controlled by.  Like the Romans said, "Make them an arena".  Only a few big players, making the big money (hush money) get the play book way before the season starts and what is going to happen and to make it happen.  I believe many college sports are also, esp football $$$ .. but does not involve the players, it involves the coaches and the college, based on making the right plays or plays to make it fail on purpose.  Lets sit back and watch..  plus the Super Bowl is the highest human trafficking event all year.   Since White Hats have been in control, they have been scooping up many criminals involved t...
# 158                                                                                                                                                                                                                                                                                                                                                                                   It is just boys playing a game🏈😜How much do NFL players get paid in the playoffs? The CBA also spells out how much players are paid in each *round of the postseason. Here are the 😵‍💫bonuses for the 2024 regular season:\t•\tDivision winner: $54,500\t•\tWild Card/first-round *bye: $49,500\t•\tDivisional Round: $54,500\t•\tConference Championship: $77,000 \t•\tSuper Bowl *losing team: $96,000\t•\tSuper Bowl winning team: $171,000
# 159                                                                                                                                                                                                                                                          Really wish you would have Elon look into the referees that are in the pockets for KC. They should have never even made it to the playoffs. Many fans are disgusted with NFL and helping KC because of Taylor Swift! Many won’t watch Super Bowl because of it and are loosing fans. Remember when the fans boycotted NFL because of disrespect while our National Anthem was being played, and they did it for you as well. Please look into this so NFL doesn’t ruin the love of the great American game.Thank you for everything you do. You are Gods blessing.✝️🙏♥️
#
#     tombstone  tv group_timeline_visible last_seen_ts reblog  \
# 157       NaN NaN                    NaN          NaN    NaN
# 158       NaN NaN                    NaN          NaN    NaN
# 159       NaN NaN                    NaN          NaN    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   openmeasures_media  \
# 157  [{'_hash': '00d0f292df771a8839799409f19c9fddc9b94101', 'thumbnail_hash': '2869e7dc97b3797481e043643dd0ad8fca89e31a', 'thumbnail_mimetype': 'image/jpeg', 'mimetype': 'image/jpeg', 'source_id': '113965398687669786', 'source_url': 'https://static-assets-1.truthsocial.com/tmtg:prime-ts-assets/media_attachments/files/113/965/398/687/669/786/original/335b082a95bbbd03.jpg', 'enrichments': [{'service': 'blip', 'calculated_date': '2025-02-08T06:36:03.195116+00:00', 'type': 'image_caption', 'value': 'a screenshot of a screenshot of a screenshot of a game'}, {'service': 'tesseract', 'calculated_date': '2025-02-08T06:36:03.195128+00:00', 'type': 'OCR', 'value': 'Cy LE a ea Rea CoA Mie e Tan ean eal as (-L FATMMEsTo) (G7 W-Es3) ee eer} Q'}]}, {'_hash': '0a2eabdb13cbe2b6e94b1d772c7cdf9f8ee1a8e2', 't...
# 158                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 159                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
#
#                                                                                                                                                                                         Query Params  \
# 157  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
# 158  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
# 159  {'term': '(NFL OR nfl) AND (playoffs) AND (Super Bowl LIX)', 'limit': 2000, 'site': 'truth_social', 'since': '2015-09-05', 'until': '2025-02-09', 'querytype': 'query_string', 'model': 'user'}
#
#              Site
# 157  truth_social
# 158  truth_social
# 159  truth_social
#
# [3 rows x 53 columns]

# %% [markdown]
# ## Save Data

# %%
path = os.path.join(notebook_dir, '../', 'data/open_measures/', 'bluesky_raw_data/')
prefix = f"blue_sky-{since}_{until}"
DataProcessing.save_to_file(bluesky_df, path, prefix, 'csv')

path = os.path.join(notebook_dir, '../', 'data/open_measures/', 'truth_social_raw_data/')
prefix = f"truth_social-{since}_{until}"
DataProcessing.save_to_file(true_social_df, path, prefix, 'csv')
# Out:
# Saved to:
# 	/Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/prediction_identification_experiments/../data/open_measures/bluesky_raw_data/blue_sky-2015-09-05_2025-02-09-1.csv
# Saved to:
# 	/Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/prediction_identification_experiments/../data/open_measures/truth_social_raw_data/truth_social-2015-09-05_2025-02-09-1.csv
