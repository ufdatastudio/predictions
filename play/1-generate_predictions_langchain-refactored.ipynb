# %% [markdown]
# # 1-Generate Predictions using LangChain
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To implement step 1 with sub steps of prediction recognition pipeline. See steps
#     1. Generate predictions
#         1. Create several prediction prompts templates
#         2. Utilize open-source LLMs to generate predictions
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
# !pip3 install pandas langchain spacy numpy Groq

# %%
# !pip3 install -U scikit-learn

# %%
# !pip3 install python-dotenv

# %%
import os, sys

import pandas as pd

from tqdm import tqdm
from langchain_core.prompts import PipelinePromptTemplate, PromptTemplate

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from log_files import DataFrameLogger
from data_processing import DataProcessing
from text_generation_models import TextGenerationModelFactory, LlamaVersatileTextGenerationModel, LlamaInstantTextGenerationModel, Llama70B8192TextGenerationModel, Llama8B8192TextGenerationModel, MixtralTextGenerationModel

# %%
# pd.set_option('max_colwidth', 800)

llama_versatile_generation_model = LlamaVersatileTextGenerationModel()
llama_instant_generation_model = LlamaInstantTextGenerationModel()
llama_70b_8192_generation_model = Llama70B8192TextGenerationModel()
llama_8b_8192_generation_model = Llama8B8192TextGenerationModel()
mixtral_generation_model = MixtralTextGenerationModel()

# %% [markdown]
# ## LangChain Templates for Domain Predictions

# %%
full_prediction_template = """{prediction_properties}

{prediction_requirements}

{prediction_templates}

{prediction_examples}"""
full_prediction_prompt = PromptTemplate.from_template(full_prediction_template)

# %% [markdown]
# Google predictive spelling/autocomplete

# %%
prediction_properties_template = """A prediction ($p$) consists of the following nine properties:

    1. $p_p$, {prediction_domain} person that predicted $p$
        - Can be a person (with a name) or a {prediction_domain} person such as a {prediction_domain} reporter, {prediction_domain} analyst, {prediction_domain} expert, {prediction_domain} top executive, {prediction_domain} senior level person, etc).
    2. $p_o$, {prediction_domain} organization 
        - Can only be an organization or entity that is associated with the {prediction_domain} prediction.
    3. $p_t$, current time when $p$ was made
        - Time is the exact moment that can be measured in day, hour, minute, second, etc.
    4. $p_f$, forecast time when $p$ is expected to come to fruition
        - Forecast can be from a second to anytime in the future.
        - Answers the questions: "How far to go out?" or "Where to stop?".
    5. $p_a$, {prediction_domain} prediction attribute
        - Measurable domain-specific attributes such as various quantifiable metrics relevant to the {prediction_domain} domain.
        - Some examples are {prediction_domain_attribute}.
    6. $p_s$, slope that indicates the direction of change in $p_a$
        - Change of directions can be rise/increase/as much as, fall/decrease/as little as, change, stay stable, high/low chance/probability/degree of, etc.
    7. $p_m$, metric outcome
        - How much will the $p_a$ $p_s$?
    8. $p_v$, future verb tense
        - A verb that is associated with the future such as will, would, be going to, should, etc.
    9. $p_l$, location
        - The location is attached to attribute $p_a$ if {prediction_domain} == 'weather'
    """
prediction_properties_prompt = PromptTemplate.from_template(prediction_properties_template)

# %% [markdown]
#     - Keep the brackets around the prediction properties when generating predictions and be sure to include brackets around dates such as "2024-10-15", "2024/08/20", "Q4 of 2024", "2025", "2027 Q1", "Q3 2027", "On 21 Aug 2024".

# %%
prediction_requirements_template = """{prediction_domain} requirements to use for each prediction:

    - Should be based on real-world {prediction_domain} data and not hallucinate.
    - Only a simple sentence (prediction) (and NOT compounding using "and" or "or").
    - Should diversify all nine properties of the prediction ($p$) meaning to change and not use same (p_p, p_o, p_t, p_f, p_a, p_s, p_m, p_v, p_l) .
    - Should use synonyms of $p_w$ such as forecasts, speculates, foresee, envision, etc., and not use any of them more than ten times.
    - The prediction should be unique and not repeated.
    - The forecast time ($p_f$) should always be after current time ($p_t$) of when forecast ($p$) was made.
    - Do not number the predictions.
    - Do not say, "As the {prediction_domain} at organization ($p_o$), I will generate company-based {prediction_domain} predictions using the provided templates." or anything similar.
    - Should have a forecast time ($p_f$) when $p$ is expected to come to fruition between 2025 to 2050.
    - Use the five different templates and examples provided.
    - Change how the current time ($p_t$) and forecast time ($p_f$) are written in the prediction with examples of (1) Wednesday, August 21, 2024; (2) Wed, August 21, 2024; (3) 08/21/2024; (4) 08/21/2024; (5) 21/08/2024; (6) 21 August 2024; (7) 2024/08/21; (8) 2024-08-21; (9) August 21, 2024; (10) Aug 21, 2024; (11) 21 August 2024, (12) 21 Aug 2024, Q3 of 2027, 2029 of Q3, etc (with removing day of week).
    {domain_requirements}
    - Stop saying, "Here are {predictions_N} unique {prediction_domain} predictions based on the provided templates and examples:" in the prompt.
    - Do not use any of the examples in the prompt.
    - In front of every prodiction, put the template number in the format of "T1:", "T2:", etc. and do not number them like "1.", "2.", etc.
    - Disregard brackets: "[]"
    - Should never say "Here are {predictions_N} unique {prediction_domain} predictions based on the provided templates and examples:" 
    - Be sure to space words when generating the prediction metric ($p_m$) like "from _ to _"""
prediction_requirements_prompt = PromptTemplate.from_template(prediction_requirements_template)

# %%
prediction_templates_template = """Here are some {prediction_domain} templates:

- {prediction_domain} template 1: On [ $p_t$ ], [ $p_p$ ] [ $p_w$ ] that the [ $p_a$ ] at [ $p_o$ ] [ $p_v$ ] [ $p_s$ ] by [ $p_m$ ] in [ $p_f$ ].
- {prediction_domain} template 2: In [ $p_t$ ], [ $p_p$ ] from [ $p_o$ ], [ $p_w$ ] that the [ $p_a$ ] [ $p_v$ ] [ $p_s$ ] from [ $p_m$ ] in [ $p_f$ ].
- {prediction_domain} template 3: [ $p_p $] [ $p_w$ ] on [ $p_t$ ] that the [ $p_a$ ] at [ $p_o$ ] [ $p_v$ ] [ $p_s$ ] under [ $p_m$ ] in [ $p_f$ ].
- {prediction_domain} template 4: According to a [ $p_w$ ] from a [ $p_p$ ] from [ $p_o$ ], on [ $p_t$ ], the [ $p_a$ ] [ $p_v$ ] [ $p_s$ ] beyond [ $p_m$ ] in the time frame of [ $p_f$ ].
- {prediction_domain} template 5: In [ $p_f$ ], the [ $p_a$ ] at [ $p_o$ ] [ $p_v$ ] a [ $p_m$ ] [ $p_s$ ], as [ $p_w$ ] by [ $p_p$ ] on [ $p_t$ ]."""
prediction_templates_prompt = PromptTemplate.from_template(prediction_templates_template)

# %%
prediction_examples_template = """Here are some examples of {prediction_domain} predictions:

{domain_examples}

With the above, generate a unique set of {predictions_N} predictions. Think from the perspective of an {prediction_domain} analyst, expert, top executive, or senior level person."""
prediction_examples_prompt = PromptTemplate.from_template(prediction_examples_template)

# %%
prediction_input_prompts = [
    ("prediction_properties", prediction_properties_prompt),
    ("prediction_requirements", prediction_requirements_prompt),
    ("prediction_templates", prediction_templates_prompt),
    ("prediction_examples", prediction_examples_prompt),
]

pipeline_prompt = PipelinePromptTemplate(
    final_prompt=full_prediction_prompt, pipeline_prompts=prediction_input_prompts
)
# Out:
# /var/folders/fz/zn5r8vq12nv5p23dtlr15sk40000gn/T/ipykernel_93425/3566428802.py:8: LangChainDeprecationWarning: This class is deprecated. Please see the docstring below or at the link for a replacement option: https://python.langchain.com/api_reference/core/prompts/langchain_core.prompts.pipeline.PipelinePromptTemplate.html
#   pipeline_prompt = PipelinePromptTemplate(

# %% [markdown]
# ## Generate Domain Predictions

# %%
predictions_N = 10

# %% [markdown]
# ### Generate Financial Predictions

# %%
financial_attributes = """stock price, net profit, revenue, operating cash flow, research and development expenses, operating income, gross profit."""
financial_requirements = """- Should be based on real-world financial earnings reports.
    - Suppose the time when $p$ was made is during any earning season.
    - Include stocks from all sectors such as consumer staples, energy, finance, health care, industrials, materials, media, real estate, retail, technology, utilities, defense, etc.
    - Include the US Dollar sign ($) before or USD after the amount of the financial attribute."""

# For each template, have a rise, fall, or stable example, respectively.
financial_examples = """
- financial examples for template 1:
    1. On [Monday, December 16, 2024], [Detravious, an investor] [forecasts] that the [revenue] at [Apple] [will likely] [increase] from [$70 to $97 billion] in [2025 Q1].
    2. On [Tue, November 19, 2024], [Ava Lee] [predicts] that the [operating cash flow] at [ExxonMobil] [should] [decrease] by [5 percent to $20 billion] in [08/21/2025].
- financial examples for template 2:
    3. In [October 2024], [Julian Hall] from [Yahoo Finance], [envisions] that the [stock price] [will] [rise] from [$800 to $1,000 per share] in [Quarter 3 of 2028].
    4. In [8/15/2027], [Mrs. Kalia] from [McDonald's], [speculates] that the [net profit] [will] [fall] under [5% to $5 billion] in [January of 2029].
- financial examples for template 3:
    5. [Dija Gabe, a financial expert] [speculates] on [23 October 2024] that the [research and development expenses] at [Alphabet] [may] [stay stable] at [$20 million] in [2027 Quarter 4].
    6. [Mr. Mike] [forecasts] in [Q2 2026] that the [operating income] at [Microsoft] [will] [fall] by [407 percent to $50M] on [Monday, Nov 18, 2026].
- financial examples for template 4:
    7. According to a [prediction] from a [top executive] from [Chevron], on [08/21/2024], the [net profit] [is expected to] [increase] beyond [10,000 USD] in the time frame of [Q3 of 2029].
    8. According to a [envisions] from a [Brittany] from [Tesla], on [Fri, July 12, 2024], the [gross profit] [may] [decrease] as much as [$30,000,000, reflecting a 1209 percent increase] by [21 Aug 2024].
- financial examples for template 5:
    9. In [2025-08-21], the [net profit] at [Amazon] has a [probability] of [11 percent to reach $30k] [decrease], as [speculated] by [Emily Davis, a financial reporter] on [21 Oct 24].
    10. In [Quarter of 2027], the [revenue] at [Facebook] [is expected] to be [$30 billion, which is a 15%] [rise], as [predicted] by [a financial analyst] on [Sun, February 20, 2024]."""

# %%
financial_input_dict = {
    "prediction_domain": "financial",
    "prediction_domain_attribute": financial_attributes,
    "domain_requirements": financial_requirements,
    "domain_examples": financial_examples,
    "predictions_N": predictions_N
}
financial_prompt_output = pipeline_prompt.format(**financial_input_dict)
print(financial_prompt_output)
# prompt_template = "Your prompt here"
# label = 1  # or "0" for non-prediction
# domain = "finance" 


# pd.set_option('max_colwidth', 800)

# llama_versatile_generation_model = LlamaVersatileTextGenerationModel()
# llama_instant_generation_model = LlamaInstantTextGenerationModel()
# llama_70b_8192_generation_model = Llama70B8192TextGenerationModel()
# llama_8b_8192_generation_model = Llama8B8192TextGenerationModel()
# mixtral_generation_model = MixtralTextGenerationModel()


# versatile_financial_df = llama_versatile_generation_model.generate_predictions(financial_prompt_output, label, domain)
# instant_financial_df = llama_instant_generation_model.generate_predictions(financial_prompt_output, label, domain)
# seventy_financial_df = llama_70b_8192_generation_model.generate_predictions(financial_prompt_output, label, domain)
# eight_financial_df = llama_8b_8192_generation_model.generate_predictions(financial_prompt_output, label, domain)
# mixtral_financial_df = mixtral_generation_model.generate_predictions(financial_prompt_output, label, domain)

# financial_df = [versatile_financial_df, instant_financial_df, seventy_financial_df, eight_financial_df, mixtral_financial_df]
# DataProcessing.concat_dfs(financial_df)
# Out:
# A prediction ($p$) consists of the following nine properties:
#
#     1. $p_p$, financial person that predicted $p$
#         - Can be a person (with a name) or a financial person such as a financial reporter, financial analyst, financial expert, financial top executive, financial senior level person, etc).
#     2. $p_o$, financial organization
#         - Can only be an organization or entity that is associated with the financial prediction.
#     3. $p_t$, current time when $p$ was made
#         - Time is the exact moment that can be measured in day, hour, minute, second, etc.
#     4. $p_f$, forecast time when $p$ is expected to come to fruition
#         - Forecast can be from a second to anytime in the future.
#         - Answers the questions: "How far to go out?" or "Where to stop?".
#     5. $p_a$, financial prediction attribute
#         - Measurable domain-specific attributes such as various quantifiable metrics relevant to the financial domain.
#         - Some examples are stock price, net profit, revenue, operating cash flow, research and development expenses, operating income, gross profit..
#     6. $p_s$, slope that indicates the direction of change in $p_a$
#         - Change of directions can be rise/increase/as much as, fall/decrease/as little as, change, stay stable, high/low chance/probability/degree of, etc.
#     7. $p_m$, metric outcome
#         - How much will the $p_a$ $p_s$?
#     8. $p_v$, future verb tense
#         - A verb that is associated with the future such as will, would, be going to, should, etc.
#     9. $p_l$, location
#         - The location is attached to attribute $p_a$ if financial == 'weather'
#
#
# financial requirements to use for each prediction:
#
#     - Should be based on real-world financial data and not hallucinate.
#     - Only a simple sentence (prediction) (and NOT compounding using "and" or "or").
#     - Should diversify all nine properties of the prediction ($p$) meaning to change and not use same (p_p, p_o, p_t, p_f, p_a, p_s, p_m, p_v, p_l) .
#     - Should use synonyms of predicts such as forecasts, speculates, foresee, envision, etc., and not use any of them more than ten times.
#     - The prediction should be unique and not repeated.
#     - The forecast time ($p_f$) should always be after current time ($p_t$) of when forecast ($p$) was made.
#     - Do not number the predictions.
#     - Do not say, "As the financial at organization ($p_o$), I will generate company-based financial predictions using the provided templates." or anything similar.
#     - Should have a forecast time ($p_f$) when $p$ is expected to come to fruition between 2025 to 2050.
#     - Use the five different templates and examples provided.
#     - Change how the current time ($p_t$) and forecast time ($p_f$) are written in the prediction with examples of (1) Wednesday, August 21, 2024; (2) Wed, August 21, 2024; (3) 08/21/2024; (4) 08/21/2024; (5) 21/08/2024; (6) 21 August 2024; (7) 2024/08/21; (8) 2024-08-21; (9) August 21, 2024; (10) Aug 21, 2024; (11) 21 August 2024, (12) 21 Aug 2024, Q3 of 2027, 2029 of Q3, etc (with removing day of week).
#     - Should be based on real-world financial earnings reports.
#     - Suppose the time when $p$ was made is during any earning season.
#     - Include stocks from all sectors such as consumer staples, energy, finance, health care, industrials, materials, media, real estate, retail, technology, utilities, defense, etc.
#     - Include the US Dollar sign ($) before or USD after the amount of the financial attribute.
#     - Stop saying, "Here are 10 unique financial predictions based on the provided templates and examples:" in the prompt.
#     - Do not use any of the examples in the prompt.
#     - In front of every prodiction, put the template number in the format of "T1:", "T2:", etc. and do not number them like "1.", "2.", etc.
#     - Disregard brackets: "[]"
#     - Should never say "Here are 10 unique financial predictions based on the provided templates and examples:"
#     - Be sure to space words when generating the prediction metric ($p_m$) like "from _ to _
#
# Here are some financial templates:
#
# - financial template 1: On [ $p_t$ ], [ $p_p$ ] predicts that the [ $p_a$ ] at [ $p_o$ ] [ $p_v$ ] [ $p_s$ ] by [ $p_m$ ] in [ $p_f$ ].
# - financial template 2: In [ $p_t$ ], [ $p_p$ ] from [ $p_o$ ], predicts that the [ $p_a$ ] [ $p_v$ ] [ $p_s$ ] from [ $p_m$ ] in [ $p_f$ ].
# - financial template 3: [ $p_p $] predicts on [ $p_t$ ] that the [ $p_a$ ] at [ $p_o$ ] [ $p_v$ ] [ $p_s$ ] under [ $p_m$ ] in [ $p_f$ ].
# - financial template 4: According to a [ $p_p$ ] from [ $p_o$ ], on [ $p_t$ ], the [ $p_a$ ] [ $p_v$ ] [ $p_s$ ] beyond [ $p_m$ ] in the time frame of [ $p_f$ ].
# - financial template 5: In [ $p_f$ ], the [ $p_a$ ] at [ $p_o$ ] [ $p_v$ ] a [ $p_m$ ] [ $p_s$ ], as predicted by [ $p_p$ ] on [ $p_t$ ].
#
# Here are some examples of financial predictions:
#
#
# - financial examples for template 1:
#     1. On [Monday, December 16, 2024], [Detravious, an investor] forecasts that the [revenue] at [Apple] [will likely] [decrease] from [$87B to $50 billion] in [2025 Q1].
#     2. On [Tue, November 19, 2024], [Ava Lee] predicts that the [operating cash flow] at [ExxonMobil] [should] [decrease] by [5 percent to $20 billion] in [08/21/2025].
# - financial examples for template 2:
#     3. In [October 2024], [Julian Hall] from [Yahoo Finance], envisions that the [stock price] [will] [rise] from [$800 to $1,000 per share] in [Quarter 3 of 2028].
#     4. In [8/15/2027], [Mrs. Kalia] from [McDonald's], predicts that the [net profit] [will] [fall] under [5% to $5 billion] in [January of 2029].
# - financial examples for template 3:
#     5. [Dija Gabe, a financial expert] predicts on [23 October 2024] that the [research and development expenses] at [Alphabet] [may] [stay stable] at [$20 million] in [2027 Quarter 4].
#     6. [Mr. Mike] predicts in [Q2 2026] that the [operating income] at [Microsoft] [will] [fall] by [407 percent to $50M] on [Monday, Nov 18, 2026].
# - financial examples for template 4:
#     7. According to a [top executive] from [Chevron], on [08/21/2024], the [net profit] [is expected to] [increase] beyond [10,000 USD] in the time frame of [Q3 of 2029].
#     8. According to [Brittany] from [Tesla], on [Fri, July 12, 2024], the [gross profit] [may] [increase] as much as [$30,000,000, reflecting a 1209 percent increase] by [21 Aug 2024].
# - financial examples for template 5:
#     9. In [2025-08-21], the [net profit] at [Amazon] has a [probability] of [11 percent to reach $30k] [decrease], as predicted by [Emily Davis, a financial reporter] on [21 Oct 24].
#     10. In [Quarter of 2027], the [revenue] at [Facebook] [is expected] to be [$30 billion, which is a 15%] [rise], as predicted by [a financial analyst] on [Sun, February 20, 2024].
#
# With the above, generate a unique set of 10 predictions. Think from the perspective of an financial analyst, expert, top executive, or senior level person.

# %%
# gaurd_financial_df

# %% [markdown]
# ### Generate Health Predictions

# %%
health_attributes = """obesity rates, prevalence of chronic illnesses, average physical activity levels, nutritional intake, etc."""
health_requirements = """- Should be based on real-world health reports.
    - Suppose the time when $p$ was made is during any season such as flu season, allergy season, pandemic, epidemic, etc.
    - Include reports from all Health organization, researcher, doctor, physical therapist, physician assistant, nurse practictioners, fitness expert, etc."""

# For each template, have a rise, fall, or stable example, respectively.?
health_examples = """
- health examples for template 1:
    1. On [Monday, December 16, 2024], [Detravious, an investor] forecasts that the [obesity rate] at the [United States] [will likely] [decrease] by [5%] in [2025 Q1].
    2. On [Tue, November 19, 2024], [medical professional Sophia Rodriguez] predicts that the [cancer rate] in [Georgia] [should] [decrease] by [4 percent] in [08/21/2025].
- health examples for template 2:
    3. In [October 2024], [Arjun Patel, Ph.D] from [Florida Department of Health] envisions that the [average daily caloric intake] [may] [rise] from [100 to 300] in [Quarter 3 of 2028].
    4. In [8/15/2027], [Dr. Michael Brown] from the [Centers for Disease Control and Prevention], foresee that the [average daily caloric intake] [will] [fall] [8 percent] in [2027]
- Examples for template 3: .
- health examples for template 3:
    5. [A trusted expert] [speculates] on [23 October 2024] that the [global vaccination rate for measles] in the [US] [should] [stay stable] at [100K people] in [2027 Quarter 4].
    6. [Dr. Sarah Johnson] foresee in [Q2 2026] that the [prevalence of hypertension] in [California] [will] [fall] by [407 percent] by [Monday, Nov 18, 2026].
- health examples for template 4:
    7. According to a [Olivia Martinez] from [Stanford University], on [08/21/2024], the prevalence of [type 2 diabetes in adults] [is expected to] [increase] beyond [8.5 percent] in the time frame of [Q3 of 2029].
    8. According to [Rachel Kim, MD] from the [University of California], on [Fri, July 12, 2024], the prevalence of [type 2 diabetes in adults] [may] [increase] as much as [30,000,000, reflecting a 1209 percent increase] by [21 Aug 2024].
- health examples for template 5:
    9. In [2025-08-21], the [average weekly exercise hours] in [United States] has a [probability] of [20 percent to reach 30k], as predicted by [Emily Davis, Harvard School of Public Health] on [21 Oct 24].
    10. In [Quarter of 2027], the [average weekly walking hours] in [Atlanta] is [expected to rise] by [15%], as predicted by the [Monique, National Institutes of Health] on [Sun, February 20, 2024]."""

# %%
health_input_dict = {
    "prediction_domain": "health",
    "prediction_domain_attribute": health_attributes,
    "domain_requirements": health_requirements,
    "domain_examples": health_examples,
    "predictions_N": predictions_N
}

health_prompt_output = pipeline_prompt.format(**health_input_dict)
# print(health_prompt_output)

# domain = "health" 


# health_df = llama_generation_model.generate_predictions(health_prompt_output, label, domain)
# weather_df

# %% [markdown]
# ### Generate Policy Predictions

# %%
policy_attributes = """election outcomes, economic reforms, legislative impacts."""
policy_requirements = """- Should be based on real-world policy reports.
    - Suppose the time when $p$ was made is during an election cycle or non-election cycles.
    - Include policies & laws, from all sectors such as consumer staples, energy, finance, health care, industrials, materials, media, real estate, retail, technology, utilities, defense, etc."""

policy_examples = """
- policy examples for template 1:
    1. On [Monday, December 16, 2024], [President John Doe] forecasts that the [unemployment rate] at [the United States] [will likely] [decrease] by [2%] in [2025 Q1].
    2. On [Tue, November 19, 2024], [Dr. Jane Smith] foresee that the [population growth rate] in [California] [is likely to] [decrease] by [5 percent to 20 billion] in [08/21/2025].
- policy examples for template 2:
    3. In [October 2024], [Senator Emily Johnson] from [the Senate Committee on Finance], envisions that the [inflation rate] [should] [rise] from [1.3 percent to 89 percen] in [Quarter 3 of 2028].
    4. In [8/15/2027], [Governor Michael Brown] from [the State of Texas], predicts that the [number of registered voters] [will] [fall] under [5B] in [Dec of 2029].
- policy examples for template 3:
    5. [Dija Gabe in the Congressional Budget Office] predicts on [23 October 2024] that [national debt] in [USA] [may] [stay stable] at [20 million] in [2027 Quarter 4].
    6. [Dr. Sarah Lee] foresee in [Q2 2026] that the [median household income] in [NY] [should] [fall] by [629 percent to $15,000] on [Monday, Nov 18, 2026].
- policy examples for template 4:
    7. According to a [General Robert Williams] from [the Department of Defense], on [08/21/2024], the [number of active-duty soldiers] [is expected to] [increase] beyond [$10,000] in the time frame of [Q3 of 2029].
    8. According to [Dr. Olivia Martinez] from [the Census Bureau], on [Fri, July 12, 2024], the [population density] in [urban areas] [is likely to] [increase] as much as [100,000,000, reflecting a 1209 percent increase] by [21 Aug 2024].
- policy examples for template 5:
    9. In [2025-08-21], the [number of citizens] in [Thomson, GA, 30824] has a [probability] of [92 percent to reach 30k] [decrease], as predicted by [Shirly Tisdale, a policy reporter] on [21 Oct 24].
    10. In [Quarter of 2027], the  [number of Navy members] in [the United States] [is expected] to be [300K, which is a 15%] [rise], as predicted by [a policy analyst] on [Sun, February 20, 2024]."""

# %%
policy_input_dict = {
    "prediction_domain": "policy",
    "prediction_domain_attribute": policy_attributes,
    "domain_requirements": policy_requirements,
    "domain_examples": policy_examples,
    "predictions_N": predictions_N
}

policy_prompt_output = pipeline_prompt.format(**policy_input_dict)
# print(policy_prompt_output)
# domain = "policy" 

# policy_df = llama_generation_model.generate_predictions(policy_prompt_output, label, domain)
# policy_df

# %% [markdown]
# ### Generate Weather Predictions

# %%
weather_prediction_templates_template = """Here are some {prediction_domain} templates:

- {prediction_domain} template 1: On [ $p_t$ ], [ $p_p$ ] predicts that the [ $p_a$ ] at [ $p_o$ ] in [ $p_l$ ] [ $p_v$ ] [ $p_s$ ] by [ $p_m$ ] in [ $p_f$ ].
- {prediction_domain} template 2: In [ $p_t$ ], [ $p_p$ ] from [ $p_o$ ] in [ $p_l$ ], predicts that the [ $p_a$ ] [ $p_v$ ] [ $p_s$ ] from [ $p_m$ ] in [ $p_f$ ].
- {prediction_domain} template 3: [ $p_p $] predicts on [ $p_t$ ] that the [ $p_a$ ] at [ $p_o$ ] in [ $p_l$ ] [ $p_v$ ] [ $p_s$ ] under [ $p_m$ ] in [ $p_f$ ].
- {prediction_domain} template 4: According to a [ $p_p$ ] from [ $p_o$ ] in [ $p_l$ ], on [ $p_t$ ], the [ $p_a$ ] [ $p_v$ ] [ $p_s$ ] beyond [ $p_m$ ] in the time frame of [ $p_f$ ].
- {prediction_domain} template 5: In [ $p_f$ ], the [ $p_a$ ] at [ $p_o$ ] in [ $p_l$ ] [ $p_v$ ] a [ $p_m$ ] [ $p_s$ ], as predicted by [ $p_p$ ] on [ $p_t$ ]."""
weather_prediction_templates_prompt = PromptTemplate.from_template(weather_prediction_templates_template)

# %%
weather_attributes = """temperature, precipitation, wind speed, humidity, etc."""
weather_requirements = """- Should be based on real-world weather reports.
    - Suppose the time when $p$ was made is during any season and any location (ie: Florida known for hurricanes, California known for wildfires, etc).
    - Include reports from all meteorologists, weather organizations, or any type of weather entity.."""

# For each template, have a rise, fall, or stable example, respectively.?
weather_examples = """
- weather examples for template 1:
    1. On [Monday, December 16, 2024], [Dr. Melissa Carter] a weather expert at the [National Weather Service], forecasts that the [temperature], in [New York City] [will likely] [decrease] from [5°C to 3°C] on [February 16, 2025 (Fri)].
    2. On [Tue, 19 November 2024], [Ethan James] at the [US Weather Center] predicts that the [precipitation levels], in [San Francisco] [are likely to] [increase] by [20%] in the time frame of [08/21/2025].
- weather examples for template 2:
    3. In [October 2024], [Samantha Lin] from [NOAA], envisions that the [wind speed] [should] [decrease] by [15 mph] in [Chicago] by [Friday, March 22, 2025].
    4. In [8/15/2027], [Carlos Rivera] from [Weather.com] predicts that the [humidity] [will] [rise] by [30%] in [Miami] in [July of 2025].
- weather examples for template 3:
    5. [Amanda Green], a weather reporter from [Bureau of Meteorology]  predicts on [23 October 2024] that the [temperature] in [Seattle], [will] [fall] by [10°F] in [2025 Quarter 1].
    6. [Mr. Tommy Wu], from [US Weather Center] predicts in [Q2 2026] that [snowfall levels], in [Denver] [will likely] [increase] by [8 inches] in [Monday, Nov 18, 2026].
- weather examples for template 4:
    7. According to a [top executive] from [AccuWeather], on [12/21/2024], the [rainfall] in [Portland] [is expected to] [increase] beyond [10 percent] in the time frame of [early 2025].
    8. According to [David Harper] from [Weather Underground, on [Fri, August 9, 2024], the [air quality index] in [Los Angeles] [is likely to] [improve] by [20%] in [21 Aug 2024].
- weather examples for template 5:
    9. In [2025-08-21], the [average temperature] in [Houston] has a [probability] of [5 percent to] [decrease], as predicted by [King, a weather reporter] from [Meteorological Department] on [21 Oct 24].
    10. In [Quarter of 2027], wind chill] in [Minneapolis] [is expected] to be [10°F, which is a 15%] [rise], as predicted by [a weather analyst named Ortiz] on [Sun, February 20, 2024]."""

# %%
weather_input_prompts = [
    ("prediction_properties", prediction_properties_prompt),
    ("prediction_requirements", prediction_requirements_prompt),
    ("prediction_templates", weather_prediction_templates_prompt),
    ("prediction_examples", prediction_examples_prompt),
]

weather_pipeline_prompt = PipelinePromptTemplate(
    final_prompt=full_prediction_prompt, pipeline_prompts=weather_input_prompts
)

weather_input_dict = {
    "prediction_domain": "weather",
    "prediction_domain_attribute": weather_attributes,
    "domain_requirements": weather_requirements,
    "domain_examples": weather_examples,
    "predictions_N": predictions_N
}
weather_prompt_output = weather_pipeline_prompt.format(**weather_input_dict)
# print(weather_prompt_output)


# domain = "weather" 

# weather_df = llama_generation_model.generate_predictions(weather_prompt_output, label, domain)
# weather_df

# %% [markdown]
# ## LangChain Templates for Any Domain Non-Predictions

# %%
full_non_prediction_template = """{non_prediction_properties}

{non_prediction_requirements}

{non_prediction_examples}"""
full_non_prediction_prompt = PromptTemplate.from_template(full_non_prediction_template)

# %%
non_prediction_properties_template = """Generate any sentence that's not a prediction, which we name non-prediction. A prediction is below with variables
    1. $p_p$, {prediction_domain} person that predicted $p$
        - Can be a person (with a name) or a {prediction_domain} person such as a {prediction_domain} reporter, {prediction_domain} analyst, {prediction_domain} expert, {prediction_domain} top executive, {prediction_domain} senior level person, etc).
    2. $p_o$, {prediction_domain} organization 
        - Can only be an organization or entity that is associated with the {prediction_domain} prediction.
    3. $p_t$, current time when $p$ was made
        - Time is the exact moment that can be measured in day, hour, minute, second, etc.
    4. $p_f$, forecast time when $p$ is expected to come to fruition
        - Forecast can be from a second to anytime in the future.
        - Answers the questions: "How far to go out?" or "Where to stop?".
    5. $p_a$, {prediction_domain} prediction attribute
        - Measurable domain-specific attributes such as various quantifiable metrics relevant to the {prediction_domain} domain.
    6. $p_s$, slope that indicates the direction of change in $p_a$
        - Change of directions can be rise/increase/as much as, fall/decrease/as little as, change, stay stable, high/low chance/probability/degree of, etc.
    7. $p_m$, metric outcome
        - How much will the $p_a$ $p_s$?
    8. $p_v$, future verb tense
        - A verb that is associated with the future such as will, would, be going to, should, etc.
    9. $p_l$, location
        - The location is attached to attribute $p_a$ if {prediction_domain} == 'weather'
    """
non_prediction_properties_prompt = PromptTemplate.from_template(non_prediction_properties_template)

# %%
non_prediction_requirements = """ requirements to use for each non-prediction:

    - Should be based on real-world {prediction_domain} data and not hallucinate.
    - Should be a simple sentence (non-prediction) (and NOT compounding using "and" or "or").
    - The prediction should be unique and not repeated.
    - Do not number the non-predictions.
    - Do not say, "Here are {non_predictions_N} unique non-predictions based on the provided templates and examples:" or anything similar in the prompt.
    - Do not use any of the examples in the prompt.
    - In front of every non-prodiction, put the template number in the format of "T0:" and only use "T0:" as the template number.
    - Should be between 10 (ten) to 40 (forty) words."""
non_prediction_requirements_prompt = PromptTemplate.from_template(non_prediction_requirements)

# %%
non_prediction_examples_template = """Here are some examples of {prediction_domain} non-predictions:

{domain_examples}

With the above, generate a unique set of {non_predictions_N} non-predictions. Think from the perspective of an {prediction_domain} person."""
non_prediction_examples_prompt = PromptTemplate.from_template(non_prediction_examples_template)

# %%
non_prediction_input_prompts = [
    ("non_prediction_properties", non_prediction_properties_prompt),
    ("non_prediction_requirements", non_prediction_requirements_prompt),
    ("non_prediction_examples", non_prediction_examples_prompt),
]

non_prediction_pipeline_prompt = PipelinePromptTemplate(
    final_prompt=full_non_prediction_prompt, pipeline_prompts=non_prediction_input_prompts
)

# %% [markdown]
# ## Generate Non-Predictions
#
# - Model isn't generating the specified amount, so will loop for amount wanted.

# %%
non_predictions_N = 5

# %%
non_prediction_attributes = """Any sentence that does not include prediction variables such as $p$, $p_s$, $p_t$, $p_f$, $p_a$, $p_m$, $p_v$."""

non_prediction_examples = """
- non-prediction examples for template 0:
    1. Reading to children helps develop their language skills and fosters a love for books and learning.
    2. She enjoys reading books on a rainy days including mornings and evenings.
    3. The Grand Canyon in Arizona, a natural wonder, is over 277 miles long and up to 18 miles wide, showcasing stunning geological formations.
    4. Programming languages, such as Python, Java, and C++, are essential tools for software development.
    5. As the sun sets in the west, it gradually dips below the horizon, casting a warm, golden glow across the landscape.
    6. Professionals in health informatics work on developing and implementing systems like electronic health records (EHRs), telemedicine platforms, and decision support tools
    7. Juneteenth is celebrated on June 19th as it marks the end of slavery in the United States as in not everyone was free during Emancipation Proclamation signing, known as July 4th.
    8. She baked a cake for her friend's birthday party and they went for a hike in the mountains and enjoyed the view.
    9. The human brain, a complex organ, contains approximately 86 billion neurons, enabling a vast range of cognitive functions and abilities.
    10. He wrote a letter to his mother, grandmother, father, and grandfather, telling her about his new job."""

# %%
non_predictions_input_dict = {
    "prediction_domain": "any",
    "any_non_prediction_domain_attribute": non_prediction_attributes,
    "domain_examples": non_prediction_examples,
    "non_predictions_N": non_predictions_N
}

non_prediction_prompt_output = non_prediction_pipeline_prompt.format(**non_predictions_input_dict)
# print(non_prediction_prompt_output)

# label = 0
# domain = "any"

# non_predictions_df = llama_generation_model.generate_predictions(non_prediction_prompt_output, label, domain)
# non_predictions_df

# %%
# updated_non_predictions_df = DataProcessing.reformat_df_with_template_number(non_predictions_df, col_name="Base Sentence")
# updated_non_predictions_df

# %% [markdown]
# ## Batch Generation Data

# %%
tgmf = TextGenerationModelFactory()

N_batches = 1

# text_generation_models = [llama_versatile_generation_model, llama_instant_generation_model, llama_70b_8192_generation_model, llama_8b_8192_generation_model, mixtral_generation_model]
text_generation_models = [llama_instant_generation_model, llama_8b_8192_generation_model]

# text_generation_models = [llama_versatile_generation_model, llama_70b_8192_generation_model, mixtral_generation_model]

# %%
prediction_domains = ["finance", "health", "policy", "weather"]
prediction_prompt_outputs = {
    "finance": financial_prompt_output,
    "health": health_prompt_output,
    "policy": policy_prompt_output,
    "weather": weather_prompt_output
}
prediction_label = 1

batched_predictions_df = tgmf.batch_generate_predictions(N_batches=N_batches, 
                                text_generation_models=text_generation_models, 
                                domains=prediction_domains,
                                prompt_outputs=prediction_prompt_outputs,
                                sentence_label=prediction_label)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# finance --- <text_generation_models.LlamaInstantTextGenerationModel object at 0x134c2fad0>
# finance --- <text_generation_models.Llama8B8192TextGenerationModel object at 0x1371b6bd0>
#
# health --- <text_generation_models.LlamaInstantTextGenerationModel object at 0x134c2fad0>
# health --- <text_generation_models.Llama8B8192TextGenerationModel object at 0x1371b6bd0>
#
# policy --- <text_generation_models.LlamaInstantTextGenerationModel object at 0x134c2fad0>
# policy --- <text_generation_models.Llama8B8192TextGenerationModel object at 0x1371b6bd0>
#
# weather --- <text_generation_models.LlamaInstantTextGenerationModel object at 0x134c2fad0>
# weather --- <text_generation_models.Llama8B8192TextGenerationModel object at 0x1371b6bd0>
# 100%|██████████| 1/1 [00:45<00:00, 45.68s/it]
# ====================================================================================

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
batched_predictions_df
# Out:
# [                                                                                                                                                                         Base Sentence  \
#  0   T1: On August 21, 2024, Emily Davis, a financial reporter, predicts that the operating cash flow at ExxonMobil will likely decrease from $20 billion to $15 billion in Q3 of 2027.
#  1                           T2: In October 2024, Julian Hall from Yahoo Finance, envisions that the stock price at Apple will rise from $800 to $1,000 per share in Quarter 4 of 2029.
#  2               T3: Dija Gabe, a financial expert, predicts on November 18, 2024, that the research and development expenses at Alphabet may stay stable at $20 million in Q2 of 2028.
#  3                        T4: According to a top executive from Chevron, on August 21, 2024, the net profit is expected to increase beyond $10,000 USD in the time frame of Q3 of 2029.
#  4                                                   T5: In Q2 of 2026, Mr. Mike predicts that the operating income at Microsoft will fall by 407 percent to $50M on November 18, 2026.
#  5                      T1: On August 21, 2024, Ava Lee predicts that the gross profit at Tesla may increase as much as $30,000,000, reflecting a 1209 percent increase, in Q3 of 2027.
#  6                                   T2: In Q4 of 2027, Julian Hall from Yahoo Finance, envisions that the revenue at Facebook will rise from $25 billion to $30 billion in Q2 of 2029.
#  7                T3: Emily Davis, a financial reporter, predicts on August 21, 2024, that the net profit at Amazon has a probability of 11 percent to reach $30,000 USD in Q3 of 2028.
#  8                T4: According to a top executive from McDonald's, on August 21, 2024, the operating income is expected to decrease beyond $5 billion in the time frame of Q2 of 2029.
#  9                            T5: In Q3 of 2028, Dija Gabe, a financial expert, predicts that the stock price at Alphabet will fall from $1,000 to $800 per share on November 18, 2028.
#  10                                      T1: On August 21, 2024, Ava Lee predicts that the research and development expenses at Microsoft may stay stable at $20 million in Q4 of 2027.
#  11                              T2: In Q2 of 2026, Julian Hall from Yahoo Finance, envisions that the net profit at ExxonMobil will rise from $5 billion to $10 billion in Q3 of 2029.
#  12                          T3: Emily Davis, a financial reporter, predicts on August 21, 2024, that the gross profit at Tesla may increase from $10,000 to $50,000 USD in Q3 of 2027.
#  13                            T4: According to a top executive from Apple, on August 21, 2024, the revenue is expected to decrease beyond $50 billion in the time frame of Q2 of 2029.
#  14                             T5: In Q3 of 2028, Dija Gabe, a financial expert, predicts that the operating income at Facebook will fall by 407 percent to $50M on November 18, 2028.
#
#      Sentence Label            Model Name   Domain  Batch Index
#  0                1  llama-3.1-8b-instant  finance            0
#  1                1  llama-3.1-8b-instant  finance            0
#  2                1  llama-3.1-8b-instant  finance            0
#  3                1  llama-3.1-8b-instant  finance            0
#  4                1  llama-3.1-8b-instant  finance            0
#  5                1  llama-3.1-8b-instant  finance            0
#  6                1  llama-3.1-8b-instant  finance            0
#  7                1  llama-3.1-8b-instant  finance            0
#  8                1  llama-3.1-8b-instant  finance            0
#  9                1  llama-3.1-8b-instant  finance            0
#  10               1  llama-3.1-8b-instant  finance            0
#  11               1  llama-3.1-8b-instant  finance            0
#  12               1  llama-3.1-8b-instant  finance            0
#  13               1  llama-3.1-8b-instant  finance            0
#  14               1  llama-3.1-8b-instant  finance            0  ,
#                                                                                                                                                                          Base Sentence  \
#  0                                                                                              Here are 10 unique financial predictions based on the provided templates and examples:
#  1                             T1: On 2024-08-21, Julian Hall from Yahoo Finance predicts that the revenue at Microsoft will likely rise from $150 billion to $180 billion in 2029 Q2.
#  2                                                T2: In Q2 2026, Ava Lee from ExxonMobil envisions that the operating cash flow will fall from $30 billion to $20 billion in 2028 Q3.
#  3                        T3: [Dija Gabe, a financial expert] predicts on 2024-11-15 that the research and development expenses at Alphabet may stay stable at $50 million in 2027 Q4.
#  4                                   T4: According to a top executive from Chevron, on 2024-08-21, the net profit is expected to increase beyond $20,000 in the time frame of 2029 Q3.
#  5   T5: In 2025-08-21, the operating income at Amazon has a probability of 8 percent to reach $10 billion decrease, as predicted by Emily Davis, a financial reporter, on 2024-10-21.
#  6                            T6: On 2024-11-12, [Brittany] from Tesla predicts that the gross profit may increase as much as $40,000, reflecting a 1000 percent increase, in 2027 Q2.
#  7                                        T7: According to a financial analyst, on 2024-02-20, the revenue at Facebook is expected to be $35 billion, which is a 12% rise, in 2027 Q4.
#  8                                                         T8: In 2026 Q2, [Mr. Mike] from Microsoft predicts that the net profit will fall from $10 billion to $5 billion in 2028 Q3.
#  9                                          T9: On 2024-08-21, [Ava Lee] from ExxonMobil predicts that the operating cash flow should decrease by 3 percent to $25 billion in 2027 Q2.
#  10                        T10: According to a financial expert, on 2024-11-15, the research and development expenses at Alphabet may rise from $20 million to $30 million in 2029 Q2.
#  11                                                Note: I've used the provided templates and examples as a reference, but I've generated unique predictions to meet the requirements.
#
#      Sentence Label      Model Name   Domain  Batch Index
#  0                1  llama3-8b-8192  finance            0
#  1                1  llama3-8b-8192  finance            0
#  2                1  llama3-8b-8192  finance            0
#  3                1  llama3-8b-8192  finance            0
#  4                1  llama3-8b-8192  finance            0
#  5                1  llama3-8b-8192  finance            0
#  6                1  llama3-8b-8192  finance            0
#  7                1  llama3-8b-8192  finance            0
#  8                1  llama3-8b-8192  finance            0
#  9                1  llama3-8b-8192  finance            0
#  10               1  llama3-8b-8192  finance            0
#  11               1  llama3-8b-8192  finance            0  ,
#                                                                                                                                                                                                                      Base Sentence  \
#  0                                                     T1: Dr. Maria Rodriguez, a renowned health expert, predicts on 2024-08-21 that the obesity rate at the United States will likely decrease by 4% from 40% to 36% in 2027 Q3.
#  1                                                                 T2: In 2024, Dr. John Lee from the World Health Organization, speculates that the average daily caloric intake may rise from 2000 to 2500 in Quarter 2 of 2029.
#  2                                                                 T3: Dr. Jane Smith, a trusted expert, predicts on 2024/08/21 that the prevalence of hypertension in California will likely fall by 10% from 30% to 27% in 2028.
#  3   T4: According to a report by Dr. Michael Brown from the Centers for Disease Control and Prevention, on 2024-08-21, the prevalence of type 2 diabetes in adults is expected to increase beyond 8.5% in the time frame of 2029.
#  4                              T5: In 2027-09-01, the average weekly exercise hours in the United States has a probability of 25% to reach 25 hours, as predicted by Emily Davis, Harvard School of Public Health, on 2024-08-21.
#  5                                                                               T1: Dr. Sophia Patel, a health analyst, predicts on 2024/08/21 that the cancer rate in Georgia should decrease by 5% from 10% to 9.5% in 2026 Q2.
#  6                                                                        T2: In Q3 of 2027, Dr. Rachel Kim from the University of California, envisions that the average daily caloric intake will fall by 12% from 2500 to 2200.
#  7                                                                   T3: Dr. David Lee, a senior level person, predicts on 2024-08-21 that the prevalence of asthma in children will likely rise by 15% from 10% to 11.5% in 2028.
#  8                       T4: According to a report by Dr. Olivia Martinez from Stanford University, on 2024-08-21, the prevalence of type 2 diabetes in adults may increase as much as 15,000, reflecting a 500% increase by 2029.
#  9                                                           T5: In 2026-08-21, the average weekly walking hours in Atlanta is expected to rise by 20% from 2 hours to 2.4 hours, as predicted by Dr. Michael Brown on 2024-08-21.
#  10                                                                   T1: Dr. Emily Davis, a health expert, predicts on 2024/08/21 that the obesity rate at the United Kingdom will likely decrease by 3% from 25% to 22% in 2028.
#  11                                                     T2: In 2027, Dr. Sophia Rodriguez from the Florida Department of Health, speculates that the average daily caloric intake may rise from 2000 to 2500 in Quarter 4 of 2029.
#  12                                                              T3: Dr. Jane Smith, a trusted expert, predicts on 2024-08-21 that the prevalence of hypertension in California will likely fall by 12% from 30% to 26.4% in 2028.
#  13  T4: According to a report by Dr. Michael Brown from the Centers for Disease Control and Prevention, on 2024-08-21, the prevalence of type 2 diabetes in adults is expected to increase beyond 8.5% in the time frame of 2029.
#  14                                                            T5: In 2027-09-01, the average weekly exercise hours in the United States has a probability of 30% to reach 30 hours, as predicted by Dr. Rachel Kim on 2024-08-21.
#
#      Sentence Label            Model Name  Domain  Batch Index
#  0                1  llama-3.1-8b-instant  health            0
#  1                1  llama-3.1-8b-instant  health            0
#  2                1  llama-3.1-8b-instant  health            0
#  3                1  llama-3.1-8b-instant  health            0
#  4                1  llama-3.1-8b-instant  health            0
#  5                1  llama-3.1-8b-instant  health            0
#  6                1  llama-3.1-8b-instant  health            0
#  7                1  llama-3.1-8b-instant  health            0
#  8                1  llama-3.1-8b-instant  health            0
#  9                1  llama-3.1-8b-instant  health            0
#  10               1  llama-3.1-8b-instant  health            0
#  11               1  llama-3.1-8b-instant  health            0
#  12               1  llama-3.1-8b-instant  health            0
#  13               1  llama-3.1-8b-instant  health            0
#  14               1  llama-3.1-8b-instant  health            0  ,
#                                                                                                                                                                                                          Base Sentence  \
#  0                                                                                                                                 Here are 10 unique health predictions based on the provided templates and examples:
#  1                                                                        T1: On 2024-08-21, Dr. Sophia Patel predicts that the obesity rate at the World Health Organization will likely decrease by 3.5% in 2029 Q2.
#  2                                           T2: In Q1 2027, Dr. Michael Brown from the Centers for Disease Control and Prevention envisions that the average daily caloric intake may rise from 1500 to 2000 in 2030.
#  3                                                                                      T3: [Dr. Rachel Kim] predicts on 2024-11-15 that the global vaccination rate for influenza will stay stable at 80% in 2028 Q4.
#  4             T4: According to a report by Dr. Olivia Martinez from Stanford University, on 2024-09-10, the prevalence of type 2 diabetes in adults is expected to increase beyond 9.2% in the time frame of 2030 Q2.
#  5                   T5: In 2025-03-15, the average weekly exercise hours in the United States has a probability of 25% to reach 35k, as predicted by Dr. Emily Davis, Harvard School of Public Health, on 2024-02-20.
#  6                                                                                               T1: On 2024-12-18, Dr. Arjun Patel predicts that the cancer rate in New York will likely decrease by 2.8% in 2028 Q3.
#  7                                        T2: In 2026-06-15, Dr. Sophia Rodriguez from the American Heart Association predicts that the average daily physical activity levels may rise from 30 to 45 minutes in 2030.
#  8                                                                                           T3: [Dr. Michael Brown] predicts on 2024-10-25 that the prevalence of hypertension in adults will fall by 15% in 2029 Q1.
#  9   T4: According to a report by Dr. Rachel Kim from the University of California, on 2024-07-10, the prevalence of type 2 diabetes in adults may increase as much as 12,000, reflecting a 400% increase, by 2029 Q4.
#  10                                               T5: In 2027-09-15, the average weekly walking hours in London is expected to rise by 12%, as predicted by Dr. Monique, National Institutes of Health, on 2024-01-20.
#  11                                  Note: I've used the provided templates and examples as a guide, but I've also made sure to diversify the properties of each prediction and use unique combinations of attributes.
#
#      Sentence Label      Model Name  Domain  Batch Index
#  0                1  llama3-8b-8192  health            0
#  1                1  llama3-8b-8192  health            0
#  2                1  llama3-8b-8192  health            0
#  3                1  llama3-8b-8192  health            0
#  4                1  llama3-8b-8192  health            0
#  5                1  llama3-8b-8192  health            0
#  6                1  llama3-8b-8192  health            0
#  7                1  llama3-8b-8192  health            0
#  8                1  llama3-8b-8192  health            0
#  9                1  llama3-8b-8192  health            0
#  10               1  llama3-8b-8192  health            0
#  11               1  llama3-8b-8192  health            0  ,
#                                                                                                                                                                                              Base Sentence  \
#  0                                                            T1: On 2024-08-21, President John Doe forecasts that the unemployment rate at the United States will likely decrease by 2% to 4% in 2029 Q3.
#  1                         T2: In Q2 2026, Senator Emily Johnson from the Senate Committee on Finance, envisions that the inflation rate should rise from 1.3 percent to 3.5 percent in Quarter 4 of 2028.
#  2                                                 T3: Dija Gabe in the Congressional Budget Office predicts on 2024-10-23 that the national debt in USA may stay stable at 25 trillion in 2027 Quarter 4.
#  3   T4: According to a General Robert Williams from the Department of Defense, on 2024-08-21, the number of active-duty soldiers is expected to increase beyond 1.5 million in the time frame of 2029 Q3.
#  4                                            T5: In 2027-03-15, the median household income in NY has a probability of 80 percent to fall by 10% to $60,000, as predicted by Dr. Sarah Lee on 2024-11-18.
#  5                                            T1: On 2024-09-10, Governor Michael Brown forecasts that the number of registered voters at the State of Texas will likely increase by 5 million in 2029 Q2.
#  6                         T2: In 2025-02-14, Dr. Jane Smith from the World Health Organization, predicts that the number of COVID-19 cases should fall from 10 million to 5 million in Quarter 2 of 2028.
#  7            T3: Dr. Olivia Martinez in the Census Bureau predicts on 2024-07-12 that the population density in urban areas may increase as much as 50,000, reflecting a 100 percent increase by 2027 Q4.
#  8                                  T4: According to a policy analyst, on 2024-10-25, the number of citizens in Thomson, GA, 30824 has a probability of 90 percent to increase by 5% to 30,000 in 2029 Q1.
#  9                                          T5: In 2027-06-20, the number of Navy members in the United States is expected to be 350K, which is a 15% rise, as predicted by a policy expert on 2024-02-20.
#  10                                                               T1: On 2024-11-19, Senator James Davis forecasts that the GDP growth rate at the European Union will likely rise by 2% to 5% in 2029 Q4.
#  11                                        T2: In 2026-04-15, Dr. John Taylor from the Federal Reserve, envisions that the interest rate should fall from 2.5 percent to 1.5 percent in Quarter 1 of 2028.
#  12                                                T3: Dija Gabe in the Congressional Budget Office predicts on 2024-10-23 that the national debt in USA may stay stable at 25 trillion in 2027 Quarter 4.
#  13  T4: According to a General Robert Williams from the Department of Defense, on 2024-08-21, the number of active-duty soldiers is expected to increase beyond 1.5 million in the time frame of 2029 Q3.
#  14                                           T5: In 2027-03-15, the median household income in NY has a probability of 80 percent to fall by 10% to $60,000, as predicted by Dr. Sarah Lee on 2024-11-18.
#
#      Sentence Label            Model Name  Domain  Batch Index
#  0                1  llama-3.1-8b-instant  policy            0
#  1                1  llama-3.1-8b-instant  policy            0
#  2                1  llama-3.1-8b-instant  policy            0
#  3                1  llama-3.1-8b-instant  policy            0
#  4                1  llama-3.1-8b-instant  policy            0
#  5                1  llama-3.1-8b-instant  policy            0
#  6                1  llama-3.1-8b-instant  policy            0
#  7                1  llama-3.1-8b-instant  policy            0
#  8                1  llama-3.1-8b-instant  policy            0
#  9                1  llama-3.1-8b-instant  policy            0
#  10               1  llama-3.1-8b-instant  policy            0
#  11               1  llama-3.1-8b-instant  policy            0
#  12               1  llama-3.1-8b-instant  policy            0
#  13               1  llama-3.1-8b-instant  policy            0
#  14               1  llama-3.1-8b-instant  policy            0  ,
#                                                                                                                                                                                                                     Base Sentence  \
#  0                                                                                                                                            Here are 10 unique policy predictions based on the provided templates and examples:
#  1                                                                            T1: On Wednesday, August 21, 2024, Senator Emily Johnson predicts that the inflation rate at the United States will likely rise by 2.5% in 2029 Q2.
#  2                                               T2: In October 2024, Dr. Jane Smith from the World Health Organization, envisions that the number of COVID-19 cases in Europe will fall from 10 million to 5 million in 2027 Q3.
#  3                                                                              T3: [Dr. Sarah Lee] predicts on Monday, November 18, 2024, that the median household income in California will stay stable at $80,000 in 2028 Q4.
#  4                                           T4: According to a policy expert from the Federal Reserve, on 08/21/2024, the unemployment rate in the United States is expected to increase beyond 4% in the time frame of 2029 Q2.
#  5                                                           T5: In 2027-08-21, the number of registered voters in Texas has a probability of 85% to reach 15 million, as predicted by Governor Michael Brown on 21 October 2024.
#  6                                                                        T1: On Tuesday, December 16, 2024, President John Doe forecasts that the GDP growth rate at the European Union will likely decrease by 1.5% in 2026 Q2.
#  7                                                    T2: In Q2 2026, Dr. Olivia Martinez from the World Bank, predicts that the number of people living in extreme poverty will rise from 700 million to 800 million in 2030 Q1.
#  8                                                        T3: [Dija Gabe in the Congressional Budget Office] predicts on 23 October 2024, that the national debt in the United States may stay stable at $30 trillion in 2028 Q4.
#  9                                                 T4: According to a policy analyst from the International Monetary Fund, on 08/15/2027, the inflation rate in Asia will likely rise from 2% to 4% in the time frame of 2029 Q3.
#  10                                                             T5: In 2025-08-21, the number of citizens in New York City has a probability of 90% to reach 8.5 million, as predicted by Mayor Bill de Blasio on 21 August 2024.
#  11  Note: I've used the provided templates and examples as a guide, but I've generated unique predictions that are not identical to the examples. I've also made sure to follow the policy requirements and guidelines provided.
#
#      Sentence Label      Model Name  Domain  Batch Index
#  0                1  llama3-8b-8192  policy            0
#  1                1  llama3-8b-8192  policy            0
#  2                1  llama3-8b-8192  policy            0
#  3                1  llama3-8b-8192  policy            0
#  4                1  llama3-8b-8192  policy            0
#  5                1  llama3-8b-8192  policy            0
#  6                1  llama3-8b-8192  policy            0
#  7                1  llama3-8b-8192  policy            0
#  8                1  llama3-8b-8192  policy            0
#  9                1  llama3-8b-8192  policy            0
#  10               1  llama3-8b-8192  policy            0
#  11               1  llama3-8b-8192  policy            0  ,
#                                                                                                                                                                                              Base Sentence  \
#  0   T1: On 2024-08-21, Dr. Maria Rodriguez, a senior meteorologist at the National Weather Service, forecasts that the temperature in New York City will likely decrease from 25°C to 20°C on 2026-02-16.
#  1                                    T2: In Q3 of 2027, Samantha Taylor from Weather.com envisions that the precipitation levels in San Francisco should decrease by 15% in the time frame of 2028-08-21.
#  2                                              T3: Amanda Lee, a weather reporter from the Bureau of Meteorology, predicts on 2024-10-23 that the humidity in Seattle will rise by 20% in 2025-Quarter 1.
#  3                                   T4: According to a top executive from AccuWeather, on 2024-12-21, the rainfall in Portland is expected to increase beyond 15 percent in the time frame of early 2026.
#  4          T5: In 2025-08-21, the average temperature in Houston has a probability of 10 percent to decrease, as predicted by King, a weather reporter from the Meteorological Department, on 2024-10-21.
#  5                           T1: On 2024-09-01, Ethan James, a weather analyst at the US Weather Center, predicts that the wind speed in Chicago will likely increase from 10 mph to 15 mph on 2025-03-22.
#  6                                                                           T2: In 2027-08-15, Carlos Rivera from NOAA predicts that the air quality index in Los Angeles will rise by 25% in 2025-07-21.
#  7                                                T3: Mr. Tommy Wu, from the US Weather Center, predicts in Q2 of 2026 that the snowfall levels in Denver will likely increase by 12 inches in 2026-11-18.
#  8                                            T4: According to a senior meteorologist from the Weather Underground, on 2024-08-09, the temperature in Minneapolis is likely to fall by 15°F in 2024-08-21.
#  9   T5: In 2029 of Q3, the average precipitation in Seattle has a probability of 5 percent to increase, as predicted by David Harper, a weather expert from the Meteorological Department, on 2024-02-20.
#  10                T1: On 2024-11-19, Dr. John Lee, a top executive at the National Weather Service, forecasts that the wind chill in New York City will likely decrease from -5°C to -10°C on 2025-02-16.
#  11                                    T2: In 2027-03-01, Samantha Lin from the Bureau of Meteorology envisions that the rainfall in San Francisco should increase by 20% in the time frame of 2028-08-21.
#  12                                                         T3: Amanda Green, a weather reporter from AccuWeather, predicts on 2024-10-23 that the humidity in Seattle will rise by 25% in 2025-Quarter 1.
#  13                              T4: According to a senior meteorologist from Weather.com, on 2024-12-21, the temperature in Portland is expected to decrease beyond 10°C in the time frame of early 2026.
#  14     T5: In 2025-08-21, the average air quality index in Houston has a probability of 10 percent to improve, as predicted by King, a weather analyst from the Meteorological Department, on 2024-10-21.
#
#      Sentence Label            Model Name   Domain  Batch Index
#  0                1  llama-3.1-8b-instant  weather            0
#  1                1  llama-3.1-8b-instant  weather            0
#  2                1  llama-3.1-8b-instant  weather            0
#  3                1  llama-3.1-8b-instant  weather            0
#  4                1  llama-3.1-8b-instant  weather            0
#  5                1  llama-3.1-8b-instant  weather            0
#  6                1  llama-3.1-8b-instant  weather            0
#  7                1  llama-3.1-8b-instant  weather            0
#  8                1  llama-3.1-8b-instant  weather            0
#  9                1  llama-3.1-8b-instant  weather            0
#  10               1  llama-3.1-8b-instant  weather            0
#  11               1  llama-3.1-8b-instant  weather            0
#  12               1  llama-3.1-8b-instant  weather            0
#  13               1  llama-3.1-8b-instant  weather            0
#  14               1  llama-3.1-8b-instant  weather            0  ,
#                                                                                                                                                                                                                                                                                                Base Sentence  \
#  0                                                                                                                                                                                                                      Here are 10 unique weather predictions based on the provided templates and examples:
#  1                                                                                       T1: On Wednesday, August 21, 2024, Dr. Sophia Patel, a weather expert at the National Weather Service, forecasts that the temperature in New York City will likely decrease from 25°C to 20°C on February 16, 2025.
#  2                                                                                                                                    T2: In Q3 of 2027, Samantha Rodriguez from NOAA predicts that the precipitation levels in San Francisco are likely to increase by 15% in the time frame of 2028-02-15.
#  3                                                                                                                                             T3: Amanda Lee, a weather reporter from the Bureau of Meteorology, predicts on October 12, 2024, that the humidity in Miami will rise by 25% in July of 2025.
#  4                                                                                                                                       T4: According to a top executive from AccuWeather, on August 21, 2024, the rainfall in Portland is expected to increase beyond 12% in the time frame of early 2026.
#  5                                                                                                                  T5: In 2029-03-15, the wind speed in Chicago has a probability of 8% to decrease, as predicted by Dr. Michael Brown, a weather analyst, from the US Weather Center on November 19, 2024.
#  6                                                                                                     T1: On Monday, December 16, 2024, Ethan Kim, a weather expert at the Weather Channel, forecasts that the air quality index in Los Angeles will likely improve by 15% in the time frame of 2025-08-21.
#  7                                                                                                                                                       T2: In Q2 of 2026, Carlos Sanchez from Weather.com predicts that the temperature in Denver will likely rise by 5°C in the time frame of 2026-11-18.
#  8                                                                                                T3: [Mr. James Thompson], a senior level person from the National Weather Service, predicts on October 15, 2024, that the snowfall levels in Boston will likely increase by 10 inches in February of 2025.
#  9                                                                                    T4: According to a weather analyst named Rachel Davis from the Meteorological Department, on August 21, 2024, the average temperature in Houston has a probability of 3% to decrease, in the time frame of 2025-08-21.
#  10                                                                                                  T5: In 2027-02-15, the precipitation levels in Seattle are expected to be 20%, which is a 10% rise, as predicted by Dr. Lisa Nguyen, a weather expert, from the US Weather Center on November 12, 2024.
#  11  Note: I've generated these predictions based on the provided templates and examples, and made sure to diversify the properties of each prediction. I've also followed the guidelines and rules provided, including using real-world weather data, not hallucinating, and not repeating any predictions.
#
#      Sentence Label      Model Name   Domain  Batch Index
#  0                1  llama3-8b-8192  weather            0
#  1                1  llama3-8b-8192  weather            0
#  2                1  llama3-8b-8192  weather            0
#  3                1  llama3-8b-8192  weather            0
#  4                1  llama3-8b-8192  weather            0
#  5                1  llama3-8b-8192  weather            0
#  6                1  llama3-8b-8192  weather            0
#  7                1  llama3-8b-8192  weather            0
#  8                1  llama3-8b-8192  weather            0
#  9                1  llama3-8b-8192  weather            0
#  10               1  llama3-8b-8192  weather            0
#  11               1  llama3-8b-8192  weather            0  ]

# %%
predictions_df = DataProcessing.concat_dfs(batched_predictions_df)
predictions_df
# Out:
#                                                                                                                                                                                                                                                                                                Base Sentence  \
# 0                                                                                                                         T1: On August 21, 2024, Emily Davis, a financial reporter, predicts that the operating cash flow at ExxonMobil will likely decrease from $20 billion to $15 billion in Q3 of 2027.
# 1                                                                                                                                                 T2: In October 2024, Julian Hall from Yahoo Finance, envisions that the stock price at Apple will rise from $800 to $1,000 per share in Quarter 4 of 2029.
# 2                                                                                                                                     T3: Dija Gabe, a financial expert, predicts on November 18, 2024, that the research and development expenses at Alphabet may stay stable at $20 million in Q2 of 2028.
# 3                                                                                                                                              T4: According to a top executive from Chevron, on August 21, 2024, the net profit is expected to increase beyond $10,000 USD in the time frame of Q3 of 2029.
# 4                                                                                                                                                                         T5: In Q2 of 2026, Mr. Mike predicts that the operating income at Microsoft will fall by 407 percent to $50M on November 18, 2026.
# 5                                                                                                                                            T1: On August 21, 2024, Ava Lee predicts that the gross profit at Tesla may increase as much as $30,000,000, reflecting a 1209 percent increase, in Q3 of 2027.
# 6                                                                                                                                                         T2: In Q4 of 2027, Julian Hall from Yahoo Finance, envisions that the revenue at Facebook will rise from $25 billion to $30 billion in Q2 of 2029.
# 7                                                                                                                                      T3: Emily Davis, a financial reporter, predicts on August 21, 2024, that the net profit at Amazon has a probability of 11 percent to reach $30,000 USD in Q3 of 2028.
# 8                                                                                                                                      T4: According to a top executive from McDonald's, on August 21, 2024, the operating income is expected to decrease beyond $5 billion in the time frame of Q2 of 2029.
# 9                                                                                                                                                  T5: In Q3 of 2028, Dija Gabe, a financial expert, predicts that the stock price at Alphabet will fall from $1,000 to $800 per share on November 18, 2028.
# 10                                                                                                                                                            T1: On August 21, 2024, Ava Lee predicts that the research and development expenses at Microsoft may stay stable at $20 million in Q4 of 2027.
# 11                                                                                                                                                    T2: In Q2 of 2026, Julian Hall from Yahoo Finance, envisions that the net profit at ExxonMobil will rise from $5 billion to $10 billion in Q3 of 2029.
# 12                                                                                                                                                T3: Emily Davis, a financial reporter, predicts on August 21, 2024, that the gross profit at Tesla may increase from $10,000 to $50,000 USD in Q3 of 2027.
# 13                                                                                                                                                  T4: According to a top executive from Apple, on August 21, 2024, the revenue is expected to decrease beyond $50 billion in the time frame of Q2 of 2029.
# 14                                                                                                                                                   T5: In Q3 of 2028, Dija Gabe, a financial expert, predicts that the operating income at Facebook will fall by 407 percent to $50M on November 18, 2028.
# 15                                                                                                                                                                                                                    Here are 10 unique financial predictions based on the provided templates and examples:
# 16                                                                                                                                                   T1: On 2024-08-21, Julian Hall from Yahoo Finance predicts that the revenue at Microsoft will likely rise from $150 billion to $180 billion in 2029 Q2.
# 17                                                                                                                                                                      T2: In Q2 2026, Ava Lee from ExxonMobil envisions that the operating cash flow will fall from $30 billion to $20 billion in 2028 Q3.
# 18                                                                                                                                              T3: [Dija Gabe, a financial expert] predicts on 2024-11-15 that the research and development expenses at Alphabet may stay stable at $50 million in 2027 Q4.
# 19                                                                                                                                                         T4: According to a top executive from Chevron, on 2024-08-21, the net profit is expected to increase beyond $20,000 in the time frame of 2029 Q3.
# 20                                                                                                                         T5: In 2025-08-21, the operating income at Amazon has a probability of 8 percent to reach $10 billion decrease, as predicted by Emily Davis, a financial reporter, on 2024-10-21.
# 21                                                                                                                                                  T6: On 2024-11-12, [Brittany] from Tesla predicts that the gross profit may increase as much as $40,000, reflecting a 1000 percent increase, in 2027 Q2.
# 22                                                                                                                                                              T7: According to a financial analyst, on 2024-02-20, the revenue at Facebook is expected to be $35 billion, which is a 12% rise, in 2027 Q4.
# 23                                                                                                                                                                               T8: In 2026 Q2, [Mr. Mike] from Microsoft predicts that the net profit will fall from $10 billion to $5 billion in 2028 Q3.
# 24                                                                                                                                                                T9: On 2024-08-21, [Ava Lee] from ExxonMobil predicts that the operating cash flow should decrease by 3 percent to $25 billion in 2027 Q2.
# 25                                                                                                                                               T10: According to a financial expert, on 2024-11-15, the research and development expenses at Alphabet may rise from $20 million to $30 million in 2029 Q2.
# 26                                                                                                                                                                       Note: I've used the provided templates and examples as a reference, but I've generated unique predictions to meet the requirements.
# 27                                                                                                                               T1: Dr. Maria Rodriguez, a renowned health expert, predicts on 2024-08-21 that the obesity rate at the United States will likely decrease by 4% from 40% to 36% in 2027 Q3.
# 28                                                                                                                                           T2: In 2024, Dr. John Lee from the World Health Organization, speculates that the average daily caloric intake may rise from 2000 to 2500 in Quarter 2 of 2029.
# 29                                                                                                                                           T3: Dr. Jane Smith, a trusted expert, predicts on 2024/08/21 that the prevalence of hypertension in California will likely fall by 10% from 30% to 27% in 2028.
# 30                                                                             T4: According to a report by Dr. Michael Brown from the Centers for Disease Control and Prevention, on 2024-08-21, the prevalence of type 2 diabetes in adults is expected to increase beyond 8.5% in the time frame of 2029.
# 31                                                                                                        T5: In 2027-09-01, the average weekly exercise hours in the United States has a probability of 25% to reach 25 hours, as predicted by Emily Davis, Harvard School of Public Health, on 2024-08-21.
# 32                                                                                                                                                         T1: Dr. Sophia Patel, a health analyst, predicts on 2024/08/21 that the cancer rate in Georgia should decrease by 5% from 10% to 9.5% in 2026 Q2.
# 33                                                                                                                                                  T2: In Q3 of 2027, Dr. Rachel Kim from the University of California, envisions that the average daily caloric intake will fall by 12% from 2500 to 2200.
# 34                                                                                                                                             T3: Dr. David Lee, a senior level person, predicts on 2024-08-21 that the prevalence of asthma in children will likely rise by 15% from 10% to 11.5% in 2028.
# 35                                                                                                 T4: According to a report by Dr. Olivia Martinez from Stanford University, on 2024-08-21, the prevalence of type 2 diabetes in adults may increase as much as 15,000, reflecting a 500% increase by 2029.
# 36                                                                                                                                     T5: In 2026-08-21, the average weekly walking hours in Atlanta is expected to rise by 20% from 2 hours to 2.4 hours, as predicted by Dr. Michael Brown on 2024-08-21.
# 37                                                                                                                                              T1: Dr. Emily Davis, a health expert, predicts on 2024/08/21 that the obesity rate at the United Kingdom will likely decrease by 3% from 25% to 22% in 2028.
# 38                                                                                                                                T2: In 2027, Dr. Sophia Rodriguez from the Florida Department of Health, speculates that the average daily caloric intake may rise from 2000 to 2500 in Quarter 4 of 2029.
# 39                                                                                                                                         T3: Dr. Jane Smith, a trusted expert, predicts on 2024-08-21 that the prevalence of hypertension in California will likely fall by 12% from 30% to 26.4% in 2028.
# 40                                                                             T4: According to a report by Dr. Michael Brown from the Centers for Disease Control and Prevention, on 2024-08-21, the prevalence of type 2 diabetes in adults is expected to increase beyond 8.5% in the time frame of 2029.
# 41                                                                                                                                       T5: In 2027-09-01, the average weekly exercise hours in the United States has a probability of 30% to reach 30 hours, as predicted by Dr. Rachel Kim on 2024-08-21.
# 42                                                                                                                                                                                                                       Here are 10 unique health predictions based on the provided templates and examples:
# 43                                                                                                                                                              T1: On 2024-08-21, Dr. Sophia Patel predicts that the obesity rate at the World Health Organization will likely decrease by 3.5% in 2029 Q2.
# 44                                                                                                                                 T2: In Q1 2027, Dr. Michael Brown from the Centers for Disease Control and Prevention envisions that the average daily caloric intake may rise from 1500 to 2000 in 2030.
# 45                                                                                                                                                                            T3: [Dr. Rachel Kim] predicts on 2024-11-15 that the global vaccination rate for influenza will stay stable at 80% in 2028 Q4.
# 46                                                                                                   T4: According to a report by Dr. Olivia Martinez from Stanford University, on 2024-09-10, the prevalence of type 2 diabetes in adults is expected to increase beyond 9.2% in the time frame of 2030 Q2.
# 47                                                                                                         T5: In 2025-03-15, the average weekly exercise hours in the United States has a probability of 25% to reach 35k, as predicted by Dr. Emily Davis, Harvard School of Public Health, on 2024-02-20.
# 48                                                                                                                                                                                     T1: On 2024-12-18, Dr. Arjun Patel predicts that the cancer rate in New York will likely decrease by 2.8% in 2028 Q3.
# 49                                                                                                                              T2: In 2026-06-15, Dr. Sophia Rodriguez from the American Heart Association predicts that the average daily physical activity levels may rise from 30 to 45 minutes in 2030.
# 50                                                                                                                                                                                 T3: [Dr. Michael Brown] predicts on 2024-10-25 that the prevalence of hypertension in adults will fall by 15% in 2029 Q1.
# 51                                                                                         T4: According to a report by Dr. Rachel Kim from the University of California, on 2024-07-10, the prevalence of type 2 diabetes in adults may increase as much as 12,000, reflecting a 400% increase, by 2029 Q4.
# 52                                                                                                                                      T5: In 2027-09-15, the average weekly walking hours in London is expected to rise by 12%, as predicted by Dr. Monique, National Institutes of Health, on 2024-01-20.
# 53                                                                                                                         Note: I've used the provided templates and examples as a guide, but I've also made sure to diversify the properties of each prediction and use unique combinations of attributes.
# 54                                                                                                                                                              T1: On 2024-08-21, President John Doe forecasts that the unemployment rate at the United States will likely decrease by 2% to 4% in 2029 Q3.
# 55                                                                                                                           T2: In Q2 2026, Senator Emily Johnson from the Senate Committee on Finance, envisions that the inflation rate should rise from 1.3 percent to 3.5 percent in Quarter 4 of 2028.
# 56                                                                                                                                                   T3: Dija Gabe in the Congressional Budget Office predicts on 2024-10-23 that the national debt in USA may stay stable at 25 trillion in 2027 Quarter 4.
# 57                                                                                                     T4: According to a General Robert Williams from the Department of Defense, on 2024-08-21, the number of active-duty soldiers is expected to increase beyond 1.5 million in the time frame of 2029 Q3.
# 58                                                                                                                                              T5: In 2027-03-15, the median household income in NY has a probability of 80 percent to fall by 10% to $60,000, as predicted by Dr. Sarah Lee on 2024-11-18.
# 59                                                                                                                                              T1: On 2024-09-10, Governor Michael Brown forecasts that the number of registered voters at the State of Texas will likely increase by 5 million in 2029 Q2.
# 60                                                                                                                           T2: In 2025-02-14, Dr. Jane Smith from the World Health Organization, predicts that the number of COVID-19 cases should fall from 10 million to 5 million in Quarter 2 of 2028.
# 61                                                                                                              T3: Dr. Olivia Martinez in the Census Bureau predicts on 2024-07-12 that the population density in urban areas may increase as much as 50,000, reflecting a 100 percent increase by 2027 Q4.
# 62                                                                                                                                    T4: According to a policy analyst, on 2024-10-25, the number of citizens in Thomson, GA, 30824 has a probability of 90 percent to increase by 5% to 30,000 in 2029 Q1.
# 63                                                                                                                                            T5: In 2027-06-20, the number of Navy members in the United States is expected to be 350K, which is a 15% rise, as predicted by a policy expert on 2024-02-20.
# 64                                                                                                                                                                  T1: On 2024-11-19, Senator James Davis forecasts that the GDP growth rate at the European Union will likely rise by 2% to 5% in 2029 Q4.
# 65                                                                                                                                           T2: In 2026-04-15, Dr. John Taylor from the Federal Reserve, envisions that the interest rate should fall from 2.5 percent to 1.5 percent in Quarter 1 of 2028.
# 66                                                                                                                                                   T3: Dija Gabe in the Congressional Budget Office predicts on 2024-10-23 that the national debt in USA may stay stable at 25 trillion in 2027 Quarter 4.
# 67                                                                                                     T4: According to a General Robert Williams from the Department of Defense, on 2024-08-21, the number of active-duty soldiers is expected to increase beyond 1.5 million in the time frame of 2029 Q3.
# 68                                                                                                                                              T5: In 2027-03-15, the median household income in NY has a probability of 80 percent to fall by 10% to $60,000, as predicted by Dr. Sarah Lee on 2024-11-18.
# 69                                                                                                                                                                                                                       Here are 10 unique policy predictions based on the provided templates and examples:
# 70                                                                                                                                                       T1: On Wednesday, August 21, 2024, Senator Emily Johnson predicts that the inflation rate at the United States will likely rise by 2.5% in 2029 Q2.
# 71                                                                                                                          T2: In October 2024, Dr. Jane Smith from the World Health Organization, envisions that the number of COVID-19 cases in Europe will fall from 10 million to 5 million in 2027 Q3.
# 72                                                                                                                                                         T3: [Dr. Sarah Lee] predicts on Monday, November 18, 2024, that the median household income in California will stay stable at $80,000 in 2028 Q4.
# 73                                                                                                                      T4: According to a policy expert from the Federal Reserve, on 08/21/2024, the unemployment rate in the United States is expected to increase beyond 4% in the time frame of 2029 Q2.
# 74                                                                                                                                      T5: In 2027-08-21, the number of registered voters in Texas has a probability of 85% to reach 15 million, as predicted by Governor Michael Brown on 21 October 2024.
# 75                                                                                                                                                   T1: On Tuesday, December 16, 2024, President John Doe forecasts that the GDP growth rate at the European Union will likely decrease by 1.5% in 2026 Q2.
# 76                                                                                                                               T2: In Q2 2026, Dr. Olivia Martinez from the World Bank, predicts that the number of people living in extreme poverty will rise from 700 million to 800 million in 2030 Q1.
# 77                                                                                                                                   T3: [Dija Gabe in the Congressional Budget Office] predicts on 23 October 2024, that the national debt in the United States may stay stable at $30 trillion in 2028 Q4.
# 78                                                                                                                            T4: According to a policy analyst from the International Monetary Fund, on 08/15/2027, the inflation rate in Asia will likely rise from 2% to 4% in the time frame of 2029 Q3.
# 79                                                                                                                                         T5: In 2025-08-21, the number of citizens in New York City has a probability of 90% to reach 8.5 million, as predicted by Mayor Bill de Blasio on 21 August 2024.
# 80                                                                              Note: I've used the provided templates and examples as a guide, but I've generated unique predictions that are not identical to the examples. I've also made sure to follow the policy requirements and guidelines provided.
# 81                                                                                                     T1: On 2024-08-21, Dr. Maria Rodriguez, a senior meteorologist at the National Weather Service, forecasts that the temperature in New York City will likely decrease from 25°C to 20°C on 2026-02-16.
# 82                                                                                                                                      T2: In Q3 of 2027, Samantha Taylor from Weather.com envisions that the precipitation levels in San Francisco should decrease by 15% in the time frame of 2028-08-21.
# 83                                                                                                                                                T3: Amanda Lee, a weather reporter from the Bureau of Meteorology, predicts on 2024-10-23 that the humidity in Seattle will rise by 20% in 2025-Quarter 1.
# 84                                                                                                                                     T4: According to a top executive from AccuWeather, on 2024-12-21, the rainfall in Portland is expected to increase beyond 15 percent in the time frame of early 2026.
# 85                                                                                                            T5: In 2025-08-21, the average temperature in Houston has a probability of 10 percent to decrease, as predicted by King, a weather reporter from the Meteorological Department, on 2024-10-21.
# 86                                                                                                                             T1: On 2024-09-01, Ethan James, a weather analyst at the US Weather Center, predicts that the wind speed in Chicago will likely increase from 10 mph to 15 mph on 2025-03-22.
# 87                                                                                                                                                                             T2: In 2027-08-15, Carlos Rivera from NOAA predicts that the air quality index in Los Angeles will rise by 25% in 2025-07-21.
# 88                                                                                                                                                  T3: Mr. Tommy Wu, from the US Weather Center, predicts in Q2 of 2026 that the snowfall levels in Denver will likely increase by 12 inches in 2026-11-18.
# 89                                                                                                                                              T4: According to a senior meteorologist from the Weather Underground, on 2024-08-09, the temperature in Minneapolis is likely to fall by 15°F in 2024-08-21.
# 90                                                                                                     T5: In 2029 of Q3, the average precipitation in Seattle has a probability of 5 percent to increase, as predicted by David Harper, a weather expert from the Meteorological Department, on 2024-02-20.
# 91                                                                                                                   T1: On 2024-11-19, Dr. John Lee, a top executive at the National Weather Service, forecasts that the wind chill in New York City will likely decrease from -5°C to -10°C on 2025-02-16.
# 92                                                                                                                                       T2: In 2027-03-01, Samantha Lin from the Bureau of Meteorology envisions that the rainfall in San Francisco should increase by 20% in the time frame of 2028-08-21.
# 93                                                                                                                                                            T3: Amanda Green, a weather reporter from AccuWeather, predicts on 2024-10-23 that the humidity in Seattle will rise by 25% in 2025-Quarter 1.
# 94                                                                                                                                 T4: According to a senior meteorologist from Weather.com, on 2024-12-21, the temperature in Portland is expected to decrease beyond 10°C in the time frame of early 2026.
# 95                                                                                                        T5: In 2025-08-21, the average air quality index in Houston has a probability of 10 percent to improve, as predicted by King, a weather analyst from the Meteorological Department, on 2024-10-21.
# 96                                                                                                                                                                                                                      Here are 10 unique weather predictions based on the provided templates and examples:
# 97                                                                                       T1: On Wednesday, August 21, 2024, Dr. Sophia Patel, a weather expert at the National Weather Service, forecasts that the temperature in New York City will likely decrease from 25°C to 20°C on February 16, 2025.
# 98                                                                                                                                    T2: In Q3 of 2027, Samantha Rodriguez from NOAA predicts that the precipitation levels in San Francisco are likely to increase by 15% in the time frame of 2028-02-15.
# 99                                                                                                                                             T3: Amanda Lee, a weather reporter from the Bureau of Meteorology, predicts on October 12, 2024, that the humidity in Miami will rise by 25% in July of 2025.
# 100                                                                                                                                      T4: According to a top executive from AccuWeather, on August 21, 2024, the rainfall in Portland is expected to increase beyond 12% in the time frame of early 2026.
# 101                                                                                                                 T5: In 2029-03-15, the wind speed in Chicago has a probability of 8% to decrease, as predicted by Dr. Michael Brown, a weather analyst, from the US Weather Center on November 19, 2024.
# 102                                                                                                    T1: On Monday, December 16, 2024, Ethan Kim, a weather expert at the Weather Channel, forecasts that the air quality index in Los Angeles will likely improve by 15% in the time frame of 2025-08-21.
# 103                                                                                                                                                      T2: In Q2 of 2026, Carlos Sanchez from Weather.com predicts that the temperature in Denver will likely rise by 5°C in the time frame of 2026-11-18.
# 104                                                                                               T3: [Mr. James Thompson], a senior level person from the National Weather Service, predicts on October 15, 2024, that the snowfall levels in Boston will likely increase by 10 inches in February of 2025.
# 105                                                                                   T4: According to a weather analyst named Rachel Davis from the Meteorological Department, on August 21, 2024, the average temperature in Houston has a probability of 3% to decrease, in the time frame of 2025-08-21.
# 106                                                                                                  T5: In 2027-02-15, the precipitation levels in Seattle are expected to be 20%, which is a 10% rise, as predicted by Dr. Lisa Nguyen, a weather expert, from the US Weather Center on November 12, 2024.
# 107  Note: I've generated these predictions based on the provided templates and examples, and made sure to diversify the properties of each prediction. I've also followed the guidelines and rules provided, including using real-world weather data, not hallucinating, and not repeating any predictions.
#
#      Sentence Label            Model Name   Domain  Batch Index
# 0                 1  llama-3.1-8b-instant  finance            0
# 1                 1  llama-3.1-8b-instant  finance            0
# 2                 1  llama-3.1-8b-instant  finance            0
# 3                 1  llama-3.1-8b-instant  finance            0
# 4                 1  llama-3.1-8b-instant  finance            0
# 5                 1  llama-3.1-8b-instant  finance            0
# 6                 1  llama-3.1-8b-instant  finance            0
# 7                 1  llama-3.1-8b-instant  finance            0
# 8                 1  llama-3.1-8b-instant  finance            0
# 9                 1  llama-3.1-8b-instant  finance            0
# 10                1  llama-3.1-8b-instant  finance            0
# 11                1  llama-3.1-8b-instant  finance            0
# 12                1  llama-3.1-8b-instant  finance            0
# 13                1  llama-3.1-8b-instant  finance            0
# 14                1  llama-3.1-8b-instant  finance            0
# 15                1        llama3-8b-8192  finance            0
# 16                1        llama3-8b-8192  finance            0
# 17                1        llama3-8b-8192  finance            0
# 18                1        llama3-8b-8192  finance            0
# 19                1        llama3-8b-8192  finance            0
# 20                1        llama3-8b-8192  finance            0
# 21                1        llama3-8b-8192  finance            0
# 22                1        llama3-8b-8192  finance            0
# 23                1        llama3-8b-8192  finance            0
# 24                1        llama3-8b-8192  finance            0
# 25                1        llama3-8b-8192  finance            0
# 26                1        llama3-8b-8192  finance            0
# 27                1  llama-3.1-8b-instant   health            0
# 28                1  llama-3.1-8b-instant   health            0
# 29                1  llama-3.1-8b-instant   health            0
# 30                1  llama-3.1-8b-instant   health            0
# 31                1  llama-3.1-8b-instant   health            0
# 32                1  llama-3.1-8b-instant   health            0
# 33                1  llama-3.1-8b-instant   health            0
# 34                1  llama-3.1-8b-instant   health            0
# 35                1  llama-3.1-8b-instant   health            0
# 36                1  llama-3.1-8b-instant   health            0
# 37                1  llama-3.1-8b-instant   health            0
# 38                1  llama-3.1-8b-instant   health            0
# 39                1  llama-3.1-8b-instant   health            0
# 40                1  llama-3.1-8b-instant   health            0
# 41                1  llama-3.1-8b-instant   health            0
# 42                1        llama3-8b-8192   health            0
# 43                1        llama3-8b-8192   health            0
# 44                1        llama3-8b-8192   health            0
# 45                1        llama3-8b-8192   health            0
# 46                1        llama3-8b-8192   health            0
# 47                1        llama3-8b-8192   health            0
# 48                1        llama3-8b-8192   health            0
# 49                1        llama3-8b-8192   health            0
# 50                1        llama3-8b-8192   health            0
# 51                1        llama3-8b-8192   health            0
# 52                1        llama3-8b-8192   health            0
# 53                1        llama3-8b-8192   health            0
# 54                1  llama-3.1-8b-instant   policy            0
# 55                1  llama-3.1-8b-instant   policy            0
# 56                1  llama-3.1-8b-instant   policy            0
# 57                1  llama-3.1-8b-instant   policy            0
# 58                1  llama-3.1-8b-instant   policy            0
# 59                1  llama-3.1-8b-instant   policy            0
# 60                1  llama-3.1-8b-instant   policy            0
# 61                1  llama-3.1-8b-instant   policy            0
# 62                1  llama-3.1-8b-instant   policy            0
# 63                1  llama-3.1-8b-instant   policy            0
# 64                1  llama-3.1-8b-instant   policy            0
# 65                1  llama-3.1-8b-instant   policy            0
# 66                1  llama-3.1-8b-instant   policy            0
# 67                1  llama-3.1-8b-instant   policy            0
# 68                1  llama-3.1-8b-instant   policy            0
# 69                1        llama3-8b-8192   policy            0
# 70                1        llama3-8b-8192   policy            0
# 71                1        llama3-8b-8192   policy            0
# 72                1        llama3-8b-8192   policy            0
# 73                1        llama3-8b-8192   policy            0
# 74                1        llama3-8b-8192   policy            0
# 75                1        llama3-8b-8192   policy            0
# 76                1        llama3-8b-8192   policy            0
# 77                1        llama3-8b-8192   policy            0
# 78                1        llama3-8b-8192   policy            0
# 79                1        llama3-8b-8192   policy            0
# 80                1        llama3-8b-8192   policy            0
# 81                1  llama-3.1-8b-instant  weather            0
# 82                1  llama-3.1-8b-instant  weather            0
# 83                1  llama-3.1-8b-instant  weather            0
# 84                1  llama-3.1-8b-instant  weather            0
# 85                1  llama-3.1-8b-instant  weather            0
# 86                1  llama-3.1-8b-instant  weather            0
# 87                1  llama-3.1-8b-instant  weather            0
# 88                1  llama-3.1-8b-instant  weather            0
# 89                1  llama-3.1-8b-instant  weather            0
# 90                1  llama-3.1-8b-instant  weather            0
# 91                1  llama-3.1-8b-instant  weather            0
# 92                1  llama-3.1-8b-instant  weather            0
# 93                1  llama-3.1-8b-instant  weather            0
# 94                1  llama-3.1-8b-instant  weather            0
# 95                1  llama-3.1-8b-instant  weather            0
# 96                1        llama3-8b-8192  weather            0
# 97                1        llama3-8b-8192  weather            0
# 98                1        llama3-8b-8192  weather            0
# 99                1        llama3-8b-8192  weather            0
# 100               1        llama3-8b-8192  weather            0
# 101               1        llama3-8b-8192  weather            0
# 102               1        llama3-8b-8192  weather            0
# 103               1        llama3-8b-8192  weather            0
# 104               1        llama3-8b-8192  weather            0
# 105               1        llama3-8b-8192  weather            0
# 106               1        llama3-8b-8192  weather            0
# 107               1        llama3-8b-8192  weather            0

# %%
logger = DataFrameLogger()
logger.log_df(predictions_df)

# %%
logged_data = logger.load_log()
logged_data

# %%
non_prediction_domains = ["any", "any", "any", "any"]
non_prediction_prompt_outputs = {
    "any": non_prediction_prompt_output,
}
non_prediction_label = 0

batched_non_predictions_df = tgmf.batch_generate_predictions(N_batches=N_batches,
                                text_generation_models=text_generation_models,
                                domains=non_prediction_domains,
                                prompt_outputs=non_prediction_prompt_outputs,
                                sentence_label=non_prediction_label)

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
batched_non_predictions_df

# %%
non_predictions_df = DataProcessing.concat_dfs(batched_non_predictions_df)
non_predictions_df

# %%
non_pred_formatter = DataFrameFormatter('%(asctime)s %(levelname)-8s %(message)s', n_rows=4)
non_pred_formatter.log_df(non_predictions_df, sentence_label=non_prediction_label)

# %% [markdown]
# ## Store Predictions and Non-Predictions

# %%
# %store updated_predictions_df
# %store updated_non_predictions_df
