# %% [markdown]
# # 2-Clean Predictions
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To clean irrelevant things from text generation with LLM
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from pipelines import BasePipeline
from data_processing import DataProcessing

# %%
# %store -r predictions_df
# %store -r non_predictions_df

pd.set_option('max_colwidth', 800)

# %%
predictions_df
# Out:
#                                                                                                                                                                                                                        Base Sentence  \
# 0                                                         On 2024-10-15, Rachel Patel, a financial analyst, predicts that the operating cash flow at General Motors will likely decrease by $5 billion to $10 billion in Q2 of 2026.
# 1                                                                                                             In 2024, Michael Chen from Goldman Sachs envisions that the stock price will rise from $500 to $700 per share in 2028.
# 2                                                                              Emily Taylor, a financial expert, predicts on 08/20/2024 that the research and development expenses at Pfizer may stay stable at $15 million in 2029.
# 3                                                                             According to a senior executive from Boeing, on 21 Aug 2024, the net profit is expected to increase beyond $20 billion in the timeframe of Q4 of 2027.
# 4                                               In 2025-08-20, the revenue at Netflix has a probability of 20 percent to reach $25 billion, which is a 10% increase, as predicted by David Lee, a financial reporter, on 10/10/2024.
# 5                                                      On Wednesday, November 20, 2024, Kevin White, a financial analyst, forecasts that the gross profit at Cisco Systems will likely decrease by 10% to $15 billion in Q1 of 2026.
# 6                                                                                                  In Q3 of 2024, Sophia Rodriguez from JPMorgan Chase predicts that the operating income will fall under 5% to $10 billion in 2027.
# 7                                                                                                           James Davis, a financial expert, predicts on 2024/08/22 that the revenue at Visa may rise by 15% to $25 billion in 2028.
# 8                                                                                  According to a top executive from Intel, on 2024-08-25, the net profit is expected to increase beyond $30 billion in the timeframe of Q2 of 2029.
# 9                                            In 2026-10-15, the operating cash flow at AT&T has a probability of 15% to reach $20 billion, which is a 5% decrease, as predicted by Olivia Brown, a financial analyst, on 08/25/2024.
# 10                                          On 2024-10-15, Dr. Rachel Kim, a senior meteorologist at the National Weather Service, forecasts that the precipitation levels in Los Angeles will likely increase by 15% in Q2 of 2026.
# 11                                                                                                 In 2024-08-20, Michael Davis from the Weather Channel predicts that the humidity in New York City will rise by 12% in 2027-03-15.
# 12                                                                                Emily Chen, a weather expert from the Bureau of Meteorology, predicts on 2024-11-10 that the temperature in Sydney will fall by 8°C in 2025-07-01.
# 13                                                                       According to a top executive from AccuWeather, on 2024-09-18, the air quality index in Beijing will improve by 18% beyond the current levels in 2026-04-01.
# 14                                          In 2028-02-20, the wind speed in Chicago has a probability of 20% to decrease by 10 mph, as predicted by James Lee, a weather analyst from the Meteorological Department, on 2024-06-12.
# 15                              On 2024-12-01, Dr. Lisa Nguyen, a weather researcher at the National Oceanic and Atmospheric Administration, forecasts that the snowfall levels in Denver will likely increase by 20% in 2027-01-01.
# 16                                                                                               In 2025-01-01, David Taylor from the Weather Underground predicts that the cloud cover in Miami will decrease by 15% in 2026-06-01.
# 17                                                                                      Kevin White, a weather forecaster from the UK Met Office, predicts on 2024-07-15 that the rainfall in London will rise by 12% in 2025-10-01.
# 18                                                          According to a senior meteorologist from the European Centre for Medium-Range Weather Forecasts, on 2024-03-20, the temperature in Paris will fall by 5°C in 2025-02-01.
# 19                                  In 2029-09-15, the average temperature in Tokyo has a probability of 15% to increase by 3°C, as predicted by Yui Nakamura, a weather expert from the Japan Meteorological Agency, on 2024-05-10.
# 20                                                    On 2024-10-15, Dr. Thompson, a health expert from the World Health Organization, predicts that the obesity rate at the United States will likely decrease by 3% in Q2 of 2026.
# 21                                                     In Q4 of 2024, Dr. Lee, a researcher from the Centers for Disease Control and Prevention, envisions that the average daily caloric intake may rise from 2000 to 2500 in 2028.
# 22                                                                 Dr. Patel, a trusted expert, predicts on 2024/11/20 that the global vaccination rate for influenza in the European Union should stay stable at 90% in Q1 of 2027.
# 23          According to a report by Dr. Kim, a senior level person from the University of California, on 2024-08-20, the prevalence of type 2 diabetes in adults is expected to increase beyond 10% in the timeframe of Q4 of 2029.
# 24                           In 2025-10-01, the average weekly exercise hours in Australia has a probability of 25% to reach 25k, as predicted by Dr. Davis, a health analyst from the National Institutes of Health, on 2024/10/10.
# 25                                                                                                 On 2024/12/01, Dr. Rodriguez, a medical professional, forecasts that the cancer rate in Canada will decrease by 2% in Q3 of 2027.
# 26                                                                       In Q2 of 2025, Dr. Brown, a researcher from the American Heart Association, foresee that the average daily physical activity levels may fall by 5% in 2029.
# 27                                                                                    Dr. Johnson, a health expert, predicts on 2024-11-15 that the prevalence of hypertension in the United Kingdom will fall by 10% in Q4 of 2028.
# 28  According to a report by Dr. Martin, a top executive from the American Diabetes Association, on 2024/09/10, the prevalence of type 1 diabetes in children is expected to increase as much as 15% in the timeframe of Q2 of 2030.
# 29       In Q1 of 2026, the average weekly walking hours in Germany is expected to rise by 10%, as predicted by Dr. Taylor, a health senior level person from the European Centre for Disease Prevention and Control, on 2024-10-05.
# 30                                                                                                          On 2024-10-15, policy expert, Rachel Kim, predicts that the stock price at Goldman Sachs will rise by 15% in Q2 of 2026.
# 31                                                                                  In 2024/08/20, Senator James Davis from the Senate Committee on Banking, forecasts that the interest rate will increase from 2.5% to 4% in 2028.
# 32                                                                                             Policy analyst, Michael Chen, predicts on 21 August 2024 that the GDP growth rate in the United States may stay stable at 3% in 2027.
# 33                                                        According to a policy reporter, Emily Patel, from the Federal Reserve, on 08/22/2024, the inflation rate is expected to decrease beyond 2% in the timeframe of Q1 of 2029.
# 34                                                              In 2025-08-20, the number of investors in the New York Stock Exchange will likely have a 20% increase, as predicted by policy expert, David Lee, on 20 October 2024.
# 35                                                                  On Wednesday, 21 August 2024, policy senior level person, Kevin White, forecasts that the unemployment rate at JPMorgan Chase will decrease by 5% in Q3 of 2026.
# 36                                                              In Q4 of 2024, policy top executive, Sarah Taylor, from the Bank of America, envisions that the number of customers will rise from 10 million to 15 million in 2027.
# 37                                                                                                    Policy expert, Mark Davis, predicts on 15 October 2024 that the revenue growth rate at Citigroup will increase by 10% in 2028.
# 38            According to a policy analyst, Olivia Brown, from the Securities and Exchange Commission, on 2024-08-21, the number of initial public offerings is expected to increase as much as 50% in the timeframe of Q2 of 2029.
# 39                                                                            In 2026-08-21, the stock price of Apple will have a probability of 80% to reach $200, as predicted by policy reporter, Daniel Kim, on 21 October 2024.
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  1  llama-3.3-70b-versatile  financial                1
# 1                  1  llama-3.3-70b-versatile  financial                2
# 2                  1  llama-3.3-70b-versatile  financial                3
# 3                  1  llama-3.3-70b-versatile  financial                4
# 4                  1  llama-3.3-70b-versatile  financial                5
# 5                  1  llama-3.3-70b-versatile  financial                1
# 6                  1  llama-3.3-70b-versatile  financial                2
# 7                  1  llama-3.3-70b-versatile  financial                3
# 8                  1  llama-3.3-70b-versatile  financial                4
# 9                  1  llama-3.3-70b-versatile  financial                5
# 10                 1  llama-3.3-70b-versatile    weather                1
# 11                 1  llama-3.3-70b-versatile    weather                2
# 12                 1  llama-3.3-70b-versatile    weather                3
# 13                 1  llama-3.3-70b-versatile    weather                4
# 14                 1  llama-3.3-70b-versatile    weather                5
# 15                 1  llama-3.3-70b-versatile    weather                1
# 16                 1  llama-3.3-70b-versatile    weather                2
# 17                 1  llama-3.3-70b-versatile    weather                3
# 18                 1  llama-3.3-70b-versatile    weather                4
# 19                 1  llama-3.3-70b-versatile    weather                5
# 20                 1  llama-3.3-70b-versatile     health                1
# 21                 1  llama-3.3-70b-versatile     health                2
# 22                 1  llama-3.3-70b-versatile     health                3
# 23                 1  llama-3.3-70b-versatile     health                4
# 24                 1  llama-3.3-70b-versatile     health                5
# 25                 1  llama-3.3-70b-versatile     health                1
# 26                 1  llama-3.3-70b-versatile     health                2
# 27                 1  llama-3.3-70b-versatile     health                3
# 28                 1  llama-3.3-70b-versatile     health                4
# 29                 1  llama-3.3-70b-versatile     health                5
# 30                 1  llama-3.3-70b-versatile     policy                1
# 31                 1  llama-3.3-70b-versatile     policy                2
# 32                 1  llama-3.3-70b-versatile     policy                3
# 33                 1  llama-3.3-70b-versatile     policy                4
# 34                 1  llama-3.3-70b-versatile     policy                5
# 35                 1  llama-3.3-70b-versatile     policy                1
# 36                 1  llama-3.3-70b-versatile     policy                2
# 37                 1  llama-3.3-70b-versatile     policy                3
# 38                 1  llama-3.3-70b-versatile     policy                4
# 39                 1  llama-3.3-70b-versatile     policy                5

# %%
non_predictions_df
# Out:
#                                                                               Base Sentence  \
# 0   The company is currently undergoing a major restructuring effort to improve efficiency.
# 1                      The new employee is struggling to learn the complex software system.
# 2                    The manager is reviewing the sales report from last quarter carefully.
# 3                        The team is working diligently to meet the tight project deadline.
# 4                      The customer service department is receiving a high volume of calls.
# 5                 The marketing campaign is focusing on social media platforms exclusively.
# 6                    The company's financial records are being audited by an external firm.
# 7                    The employees are participating in a mandatory training session today.
# 8                      The IT department is troubleshooting the network connectivity issue.
# 9                           The CEO is giving a presentation to the board of directors now.
# 10                     The company is currently hiring new employees for various positions.
# 11                       The manager is reviewing the quarterly sales report carefully now.
# 12                  The marketing team created a successful advertising campaign last year.
# 13                  The financial department is auditing the company's expenses thoroughly.
# 14                       The employees are participating in a team-building workshop today.
# 15                              The CEO is giving a presentation to the board of directors.
# 16                           The research team is conducting experiments in the laboratory.
# 17                  The customer service team is responding to customer inquiries promptly.
# 18                  The IT department is updating the company's software systems regularly.
# 19           The human resources department is developing new training programs constantly.
# 20  The company is currently undergoing a major restructuring effort to improve efficiency.
# 21                     The new employee is struggling to learn the complex software system.
# 22                   The manager is reviewing the sales report from last quarter carefully.
# 23                       The team is working diligently to meet the tight project deadline.
# 24                     The customer service department is receiving a high volume of calls.
# 25                The marketing campaign is focusing on social media platforms exclusively.
# 26         The company's mission statement is to provide excellent customer service always.
# 27               The employees are participating in a mandatory training program this week.
# 28                 The IT department is resolving a major technical issue with the network.
# 29                  The financial report shows a significant increase in revenue last year.
# 30  The company is currently undergoing a major restructuring effort to improve efficiency.
# 31                     The new employee is struggling to learn the complex software system.
# 32                     The manager is meeting with the team to discuss the project details.
# 33                The marketing department is creating a new advertising campaign strategy.
# 34                    The sales team is traveling to attend the annual industry conference.
# 35                   The company's financial reports are being audited by an external firm.
# 36                 The IT department is resolving a major technical issue with the network.
# 37                      The customer service team is handling a high volume of phone calls.
# 38             The research team is conducting experiments to gather more data information.
# 39              The human resources department is recruiting new talent for open positions.
#
#     Prediction Label               Model Name Domain
# 0                  0  llama-3.3-70b-versatile    any
# 1                  0  llama-3.3-70b-versatile    any
# 2                  0  llama-3.3-70b-versatile    any
# 3                  0  llama-3.3-70b-versatile    any
# 4                  0  llama-3.3-70b-versatile    any
# 5                  0  llama-3.3-70b-versatile    any
# 6                  0  llama-3.3-70b-versatile    any
# 7                  0  llama-3.3-70b-versatile    any
# 8                  0  llama-3.3-70b-versatile    any
# 9                  0  llama-3.3-70b-versatile    any
# 10                 0  llama-3.3-70b-versatile    any
# 11                 0  llama-3.3-70b-versatile    any
# 12                 0  llama-3.3-70b-versatile    any
# 13                 0  llama-3.3-70b-versatile    any
# 14                 0  llama-3.3-70b-versatile    any
# 15                 0  llama-3.3-70b-versatile    any
# 16                 0  llama-3.3-70b-versatile    any
# 17                 0  llama-3.3-70b-versatile    any
# 18                 0  llama-3.3-70b-versatile    any
# 19                 0  llama-3.3-70b-versatile    any
# 20                 0  llama-3.3-70b-versatile    any
# 21                 0  llama-3.3-70b-versatile    any
# 22                 0  llama-3.3-70b-versatile    any
# 23                 0  llama-3.3-70b-versatile    any
# 24                 0  llama-3.3-70b-versatile    any
# 25                 0  llama-3.3-70b-versatile    any
# 26                 0  llama-3.3-70b-versatile    any
# 27                 0  llama-3.3-70b-versatile    any
# 28                 0  llama-3.3-70b-versatile    any
# 29                 0  llama-3.3-70b-versatile    any
# 30                 0  llama-3.3-70b-versatile    any
# 31                 0  llama-3.3-70b-versatile    any
# 32                 0  llama-3.3-70b-versatile    any
# 33                 0  llama-3.3-70b-versatile    any
# 34                 0  llama-3.3-70b-versatile    any
# 35                 0  llama-3.3-70b-versatile    any
# 36                 0  llama-3.3-70b-versatile    any
# 37                 0  llama-3.3-70b-versatile    any
# 38                 0  llama-3.3-70b-versatile    any
# 39                 0  llama-3.3-70b-versatile    any

# %%
dfs = [predictions_df, non_predictions_df]
base_df = DataProcessing.concat_dfs(dfs)
base_df
# Out:
#                                                                                                                                                                            Base Sentence  \
# 0             On 2024-10-15, Rachel Patel, a financial analyst, predicts that the operating cash flow at General Motors will likely decrease by $5 billion to $10 billion in Q2 of 2026.
# 1                                                                 In 2024, Michael Chen from Goldman Sachs envisions that the stock price will rise from $500 to $700 per share in 2028.
# 2                                  Emily Taylor, a financial expert, predicts on 08/20/2024 that the research and development expenses at Pfizer may stay stable at $15 million in 2029.
# 3                                 According to a senior executive from Boeing, on 21 Aug 2024, the net profit is expected to increase beyond $20 billion in the timeframe of Q4 of 2027.
# 4   In 2025-08-20, the revenue at Netflix has a probability of 20 percent to reach $25 billion, which is a 10% increase, as predicted by David Lee, a financial reporter, on 10/10/2024.
# ..                                                                                                                                                                                   ...
# 75                                                                                                                The company's financial reports are being audited by an external firm.
# 76                                                                                                              The IT department is resolving a major technical issue with the network.
# 77                                                                                                                   The customer service team is handling a high volume of phone calls.
# 78                                                                                                          The research team is conducting experiments to gather more data information.
# 79                                                                                                           The human resources department is recruiting new talent for open positions.
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  1  llama-3.3-70b-versatile  financial              1.0
# 1                  1  llama-3.3-70b-versatile  financial              2.0
# 2                  1  llama-3.3-70b-versatile  financial              3.0
# 3                  1  llama-3.3-70b-versatile  financial              4.0
# 4                  1  llama-3.3-70b-versatile  financial              5.0
# ..               ...                      ...        ...              ...
# 75                 0  llama-3.3-70b-versatile        any              NaN
# 76                 0  llama-3.3-70b-versatile        any              NaN
# 77                 0  llama-3.3-70b-versatile        any              NaN
# 78                 0  llama-3.3-70b-versatile        any              NaN
# 79                 0  llama-3.3-70b-versatile        any              NaN
#
# [80 rows x 5 columns]

# %%
# %store base_df
# Out:
# Stored 'base_df' (DataFrame)

# %%
base_pipeline = BasePipeline()

cleaned_predictions_df = base_pipeline.clean_predictions(base_df)
cleaned_predictions_df
# Out:
#                                                                                                                                                                            Base Sentence  \
# 0             on 2024-10-15, rachel patel, a financial analyst, predicts that the operating cash flow at general motors will likely decrease by $5 billion to $10 billion in q2 of 2026.
# 1                                                                 in 2024, michael chen from goldman sachs envisions that the stock price will rise from $500 to $700 per share in 2028.
# 2                                  emily taylor, a financial expert, predicts on 08/20/2024 that the research and development expenses at pfizer may stay stable at $15 million in 2029.
# 3                                 according to a senior executive from boeing, on 21 aug 2024, the net profit is expected to increase beyond $20 billion in the timeframe of q4 of 2027.
# 4   in 2025-08-20, the revenue at netflix has a probability of 20 percent to reach $25 billion, which is a 10% increase, as predicted by david lee, a financial reporter, on 10/10/2024.
# ..                                                                                                                                                                                   ...
# 75                                                                                                                the company's financial reports are being audited by an external firm.
# 76                                                                                                              the it department is resolving a major technical issue with the network.
# 77                                                                                                                   the customer service team is handling a high volume of phone calls.
# 78                                                                                                          the research team is conducting experiments to gather more data information.
# 79                                                                                                           the human resources department is recruiting new talent for open positions.
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  1  llama-3.3-70b-versatile  financial              1.0
# 1                  1  llama-3.3-70b-versatile  financial              2.0
# 2                  1  llama-3.3-70b-versatile  financial              3.0
# 3                  1  llama-3.3-70b-versatile  financial              4.0
# 4                  1  llama-3.3-70b-versatile  financial              5.0
# ..               ...                      ...        ...              ...
# 75                 0  llama-3.3-70b-versatile        any              NaN
# 76                 0  llama-3.3-70b-versatile        any              NaN
# 77                 0  llama-3.3-70b-versatile        any              NaN
# 78                 0  llama-3.3-70b-versatile        any              NaN
# 79                 0  llama-3.3-70b-versatile        any              NaN
#
# [80 rows x 5 columns]

# %%
# %store cleaned_predictions_df
# Out:
# Stored 'cleaned_predictions_df' (DataFrame)
