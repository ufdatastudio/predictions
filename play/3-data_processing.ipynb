# %% [markdown]
# # 3-Data Processing
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To manipulate the data how we need
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %%
# %store -r base_df
# %store -r cleaned_predictions_df

pd.set_option('max_colwidth', 800)

# %% [markdown]
# ## Pre-Processing

# %%
shuffled_base_df = DataProcessing.shuffle_df(base_df)
shuffled_base_df
# Out:
#                                                                                                                                                                                                                   Base Sentence  \
# 0                                                                                                                                                                The research team is conducting experiments in the laboratory.
# 1                                                                                                      On 2024-10-15, policy expert, Rachel Kim, predicts that the stock price at Goldman Sachs will rise by 15% in Q2 of 2026.
# 2                                                                                                                                                         The sales team is traveling to attend the annual industry conference.
# 3                              In 2029-09-15, the average temperature in Tokyo has a probability of 15% to increase by 3°C, as predicted by Yui Nakamura, a weather expert from the Japan Meteorological Agency, on 2024-05-10.
# 4                                                                                                                                                      The IT department is resolving a major technical issue with the network.
# ..                                                                                                                                                                                                                          ...
# 75  In Q1 of 2026, the average weekly walking hours in Germany is expected to rise by 10%, as predicted by Dr. Taylor, a health senior level person from the European Centre for Disease Prevention and Control, on 2024-10-05.
# 76                                                             On Wednesday, 21 August 2024, policy senior level person, Kevin White, forecasts that the unemployment rate at JPMorgan Chase will decrease by 5% in Q3 of 2026.
# 77                                                                                                     James Davis, a financial expert, predicts on 2024/08/22 that the revenue at Visa may rise by 15% to $25 billion in 2028.
# 78                                                                                            In 2024-08-20, Michael Davis from the Weather Channel predicts that the humidity in New York City will rise by 12% in 2027-03-15.
# 79                                                                       According to a senior executive from Boeing, on 21 Aug 2024, the net profit is expected to increase beyond $20 billion in the timeframe of Q4 of 2027.
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  0  llama-3.3-70b-versatile        any              NaN
# 1                  1  llama-3.3-70b-versatile     policy              1.0
# 2                  0  llama-3.3-70b-versatile        any              NaN
# 3                  1  llama-3.3-70b-versatile    weather              5.0
# 4                  0  llama-3.3-70b-versatile        any              NaN
# ..               ...                      ...        ...              ...
# 75                 1  llama-3.3-70b-versatile     health              5.0
# 76                 1  llama-3.3-70b-versatile     policy              1.0
# 77                 1  llama-3.3-70b-versatile  financial              3.0
# 78                 1  llama-3.3-70b-versatile    weather              2.0
# 79                 1  llama-3.3-70b-versatile  financial              4.0
#
# [80 rows x 5 columns]

# %%
shuffled_cleaned_df = DataProcessing.shuffle_df(cleaned_predictions_df)
shuffled_cleaned_df
# Out:
#                                                                                                                                                                      Base Sentence  \
# 0                                                                                                          the financial report shows a significant increase in revenue last year.
# 1             in 2025-08-20, the number of investors in the new york stock exchange will likely have a 20% increase, as predicted by policy expert, david lee, on 20 october 2024.
# 2                                                                                                     the research team is conducting experiments to gather more data information.
# 3   on 2024-10-15, dr. thompson, a health expert from the world health organization, predicts that the obesity rate at the united states will likely decrease by 3% in q2 of 2026.
# 4                                                         james davis, a financial expert, predicts on 2024/08/22 that the revenue at visa may rise by 15% to $25 billion in 2028.
# ..                                                                                                                                                                             ...
# 75                                                        on 2024-10-15, policy expert, rachel kim, predicts that the stock price at goldman sachs will rise by 15% in q2 of 2026.
# 76      on 2024-10-15, rachel patel, a financial analyst, predicts that the operating cash flow at general motors will likely decrease by $5 billion to $10 billion in q2 of 2026.
# 77                                                                                                              the manager is reviewing the quarterly sales report carefully now.
# 78                                                                                                            the customer service department is receiving a high volume of calls.
# 79                                                                                                          the manager is reviewing the sales report from last quarter carefully.
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  0  llama-3.3-70b-versatile        any              NaN
# 1                  1  llama-3.3-70b-versatile     policy              5.0
# 2                  0  llama-3.3-70b-versatile        any              NaN
# 3                  1  llama-3.3-70b-versatile     health              1.0
# 4                  1  llama-3.3-70b-versatile  financial              3.0
# ..               ...                      ...        ...              ...
# 75                 1  llama-3.3-70b-versatile     policy              1.0
# 76                 1  llama-3.3-70b-versatile  financial              1.0
# 77                 0  llama-3.3-70b-versatile        any              NaN
# 78                 0  llama-3.3-70b-versatile        any              NaN
# 79                 0  llama-3.3-70b-versatile        any              NaN
#
# [80 rows x 5 columns]

# %%
# %store shuffled_base_df
# %store shuffled_cleaned_df
# Out:
# Stored 'shuffled_base_df' (DataFrame)
# Stored 'shuffled_cleaned_df' (DataFrame)
