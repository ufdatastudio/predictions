# %% [markdown]
# # 3-Data Processing
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To manipulate the data how we need
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %%
# %store -r base_df
# %store -r cleaned_predictions_df

pd.set_option('max_colwidth', 800)

# %% [markdown]
# ## Pre-Processing

# %%
shuffled_df = DataProcessing.shuffle_df(base_df)
shuffled_df
# Out:
#                                                                                                                                                              Base Predictions  \
# 0                   On Friday, August 16, 2024, Logan White predicts that the research and development expenses at Pfizer (PFE) may increase by 8% to $10 billion in FY 2029.
# 1                            On Wednesday, May 15, 2024, Raj Taylor envisions that the gross profit margin at McDonald's (MCD) will likely expand by 1% to 18% in Q3 of 2026.
# 2                                                                                                                               The dog is running quickly around the corner.
# 3                                               On Monday, December 16, 2024, Detravious forecasts that the revenue at Apple will rise by 8% to $120 per share in Q1 of 2025.
# 4                                                                                                                                                The book fell off the table.
# 5                                                                                                                                        The teacher wrote on the blackboard.
# 6                                                                                                                               The sun is shining brightly in the clear sky.
# 7                                                                                                                                        The company has a strong reputation.
# 8                                                                                                                                    The music is playing loudly in the room.
# 9                            On Thursday, April 18, 2024, Jackson Lee forsees that the total debt at Intel (INTC) will probably decrease by 10% to $20 billion in Q1 of 2029.
# 10                                                                                                                          The color blue is often associated with calmness.
# 11                                                                                                                                 The students are working on their project.
# 12                     On Wednesday, October 23, 2024, Julian Hall envisions that the stock price at NVIDIA (NVDA) will likely rise by 25% to $1,000 per share in Q3 of 2028.
# 13  On Monday, July 22, 2024, Hannah Brooks forecasts that the return on equity (ROE) at JPMorgan Chase (JPM) has a high probability of improving by 2% to 15% in Q4 of 2027.
# 14                          On Thursday, September 19, 2024, Mia Patel speculates that the dividend payout ratio at Coca-Cola (KO) will probably remain at 75% in Q1 of 2026.
# 15                       On Tuesday, November 19, 2024, Ava Lee predicts that the operating cash flow at ExxonMobil (XOM) should decrease by 5% to $20 billion in Q2 of 2027.
# 16                                                                                                                                           The city has a large population.
# 17         On Tuesday, June 18, 2024, Detravious Martin predicts that the capital expenditures at UnitedHealth Group (UNH) should decrease by 3% to $2 billion in Q2 of 2028.
#
#     Prediction Label
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# 5                  0
# 6                  0
# 7                  0
# 8                  0
# 9                  1
# 10                 0
# 11                 0
# 12                 1
# 13                 1
# 14                 1
# 15                 1
# 16                 0
# 17                 1

# %%
shuffled_cleaned_df = DataProcessing.shuffle_df(cleaned_predictions_df)
shuffled_cleaned_df
# Out:
#                                                                                                                                                              Base Predictions  \
# 0                           on thursday, september 19, 2024, mia patel speculates that the dividend payout ratio at coca-cola (ko) will probably remain at 75% in q1 of 2026.
# 1                                                                                                                                            the city has a large population.
# 2                            on thursday, april 18, 2024, jackson lee forsees that the total debt at intel (intc) will probably decrease by 10% to $20 billion in q1 of 2029.
# 3                                                                                                                           the color blue is often associated with calmness.
# 4                                                                                                                                    the music is playing loudly in the room.
# 5                                                                                                                                                the book fell off the table.
# 6                        on tuesday, november 19, 2024, ava lee predicts that the operating cash flow at exxonmobil (xom) should decrease by 5% to $20 billion in q2 of 2027.
# 7                                               on monday, december 16, 2024, detravious forecasts that the revenue at apple will rise by 8% to $120 per share in q1 of 2025.
# 8          on tuesday, june 18, 2024, detravious martin predicts that the capital expenditures at unitedhealth group (unh) should decrease by 3% to $2 billion in q2 of 2028.
# 9                   on friday, august 16, 2024, logan white predicts that the research and development expenses at pfizer (pfe) may increase by 8% to $10 billion in fy 2029.
# 10                                                                                                                              the dog is running quickly around the corner.
# 11  on monday, july 22, 2024, hannah brooks forecasts that the return on equity (roe) at jpmorgan chase (jpm) has a high probability of improving by 2% to 15% in q4 of 2027.
# 12                                                                                                                                 the students are working on their project.
# 13                           on wednesday, may 15, 2024, raj taylor envisions that the gross profit margin at mcdonald's (mcd) will likely expand by 1% to 18% in q3 of 2026.
# 14                                                                                                                              the sun is shining brightly in the clear sky.
# 15                                                                                                                                       the company has a strong reputation.
# 16                                                                                                                                       the teacher wrote on the blackboard.
# 17                     on wednesday, october 23, 2024, julian hall envisions that the stock price at nvidia (nvda) will likely rise by 25% to $1,000 per share in q3 of 2028.
#
#     Prediction Label
# 0                  1
# 1                  0
# 2                  1
# 3                  0
# 4                  0
# 5                  0
# 6                  1
# 7                  1
# 8                  1
# 9                  1
# 10                 0
# 11                 1
# 12                 0
# 13                 1
# 14                 0
# 15                 0
# 16                 0
# 17                 1

# %%
# %store shuffled_df
# %store shuffled_cleaned_df
# Out:
# Stored 'shuffled_df' (DataFrame)
# Stored 'shuffled_cleaned_df' (DataFrame)
