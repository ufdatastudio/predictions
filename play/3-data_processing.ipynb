# %% [markdown]
# # 3-Data Processing
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To manipulate the data how we need
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %%
# %store -r base_df
# %store -r cleaned_predictions_df

pd.set_option('max_colwidth', 800)

# %% [markdown]
# ## Pre-Processing

# %%
shuffled_base_df = DataProcessing.shuffle_df(base_df)
shuffled_base_df
# Out:
#                                                                                                                                                                      Base Predictions  \
# 0                                                                                                                The company's financial reports are available for public review now.
# 1                                                                                                             The team is working diligently to resolve the ongoing technical issues.
# 2                                    On Tuesday, April 15, 2025, Samantha Taylor from NOAA forecasts that the precipitation levels will increase by 15% in San Francisco in May 2025.
# 3                                                                                                    The company's mission statement is to provide excellent customer service always.
# 4        In 2027, the average weekly exercise hours in the United States are expected to rise by 18%, as predicted by the National Institutes of Health on Friday, December 13, 2025.
# 5                                    The World Health Organization predicts on Friday, September 12, 2025, that the global vaccination rate for measles will increase by 18% by 2028.
# 6                               The Congressional Budget Office predicts on Friday, May 30, 2025, that the national debt in the United States will increase by $1.2 trillion by 2029.
# 7                                                                                                                           The office is closed due to a holiday today and tomorrow.
# 8        According to Olivia Martinez from Stanford University, on Wednesday, July 10, 2025, the prevalence of type 2 diabetes in adults will decline by 4% in the timeframe of 2029.
# 9                          According to David Harper from AccuWeather, on Friday, August 15, 2024, the rainfall in Portland will decrease by 12% in the timeframe of early June 2025.
# 10                   On Thursday, August 14, 2025, Arjun Patel, Ph.D. from the Florida Department of Health envisions that the average daily caloric intake will rise by 12% by 2027.
# 11                                                                                                        The employees are required to attend a mandatory training session tomorrow.
# 12                                                      On Tuesday, June 11, 2025, Dr. Michael Brown predicts that the obesity rate in the United States will decrease by 4% by 2029.
# 13                                                                                                              The manager is responsible for overseeing daily operations and tasks.
# 14                                                                                                                                                      **Weather-Based Predictions**
# 15                                                                                                                   The current stock price is lower than expected by investors now.
# 16                                                                                                                     The weather today is mostly sunny with some clouds in the sky.
# 17                                                                                                                         The new restaurant is open for lunch and dinner daily now.
# 18                                                                                                                    The product is available for purchase online and in stores now.
# 19                              On Wednesday, March 19, 2025, Senator Emily Johnson from the Senate Committee on Finance forecasts that the inflation rate will fall by 1.8% in 2026.
# 20                                Ava Morales predicts on Friday, August 16, 2024, that the operating cash flow at ExxonMobil (XOM) will decrease by 8% to $15 billion in Q1 of 2028.
# 21                                  In Q2 of 2026, the gross profit at Apple (AAPL) is expected to rise by 15% to $30 billion, as predicted by Sophia Patel on Monday, June 10, 2024.
# 22                                                On Monday, March 17, 2025, Dr. Ethan Kim predicts that the temperature will rise by 3°C in New York City by Friday, March 21, 2025.
# 23                                                                                                                                    I'll provide the predictions for each category.
# 24                                            On Monday, January 13, 2025, President John Doe predicts that the unemployment rate in the United States will decrease by 2.5% by 2027.
# 25                                       In 2027, the number of citizens in the United States is expected to rise by 12%, as predicted by the President on Friday, December 12, 2025.
# 26  According to General Robert Williams from the Department of Defense, on Wednesday, July 16, 2025, the number of active-duty soldiers will decline by 4% in the timeframe of 2028.
# 27                                                 Amanda Green predicts on Wednesday, January 22, 2025, that the wind speed in Chicago will decrease by 10 mph in late January 2025.
# 28                                           In April 2025, the average temperature in Houston is expected to rise by 4°F, as predicted by Emily Cooper on Monday, February 17, 2025.
# 29                                                                                                                       The hotel room was clean and comfortable for guests to stay.
# 30                                                                                                                                                      **Public Policy Predictions**
# 31                        On Thursday, September 12, 2024, David Lee from NVIDIA (NVDA) forecasts that the stock price will likely increase by 20% to $1,200 per share in Q4 of 2027.
# 32                                                                                                           The customer service representative is helpful and knowledgeable always.
# 33                                                                                                 The company is currently hiring new employees for various positions available now.
# 34                                                                                                           The new policy has been implemented to improve customer service quality.
# 35                                                                                                     The meeting will be rescheduled due to unforeseen circumstances that occurred.
# 36                                                                                                                                            **Company-Based Financial Predictions**
# 37                      According to Julian Hall from Microsoft (MSFT), on Tuesday, July 23, 2024, the net profit will increase by 10% to $25 billion in the timeframe of Q3 of 2029.
# 38                                                                                                                                                       **Health-Based Predictions**
# 39                                              On Wednesday, October 25, 2024, Emily Chen predicts that the revenue at Amazon (AMZN) will rise by 12% to $150 billion in Q2 of 2026.
#
#     Prediction Label
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# 5                  1
# 6                  1
# 7                  0
# 8                  1
# 9                  1
# 10                 1
# 11                 0
# 12                 1
# 13                 0
# 14                 1
# 15                 0
# 16                 0
# 17                 0
# 18                 0
# 19                 1
# 20                 1
# 21                 1
# 22                 1
# 23                 1
# 24                 1
# 25                 1
# 26                 1
# 27                 1
# 28                 1
# 29                 0
# 30                 1
# 31                 1
# 32                 0
# 33                 0
# 34                 0
# 35                 0
# 36                 1
# 37                 1
# 38                 1
# 39                 1

# %%
shuffled_cleaned_df = DataProcessing.shuffle_df(cleaned_predictions_df)
shuffled_cleaned_df
# Out:
#                                                                                                                                                                      Base Predictions  \
# 0                                                                                                                      the weather today is mostly sunny with some clouds in the sky.
# 1                          according to david harper from accuweather, on friday, august 15, 2024, the rainfall in portland will decrease by 12% in the timeframe of early june 2025.
# 2                                                                                                                        the hotel room was clean and comfortable for guests to stay.
# 3                                                                                                                                                        **health-based predictions**
# 4        in 2027, the average weekly exercise hours in the united states are expected to rise by 18%, as predicted by the national institutes of health on friday, december 13, 2025.
# 5                                                                                                    the company's mission statement is to provide excellent customer service always.
# 6                                                                                                                                                       **weather-based predictions**
# 7                                                                                                             the team is working diligently to resolve the ongoing technical issues.
# 8                                                                                                      the meeting will be rescheduled due to unforeseen circumstances that occurred.
# 9                       according to julian hall from microsoft (msft), on tuesday, july 23, 2024, the net profit will increase by 10% to $25 billion in the timeframe of q3 of 2029.
# 10                              the congressional budget office predicts on friday, may 30, 2025, that the national debt in the united states will increase by $1.2 trillion by 2029.
# 11                                                                                                                   the current stock price is lower than expected by investors now.
# 12                                           in april 2025, the average temperature in houston is expected to rise by 4°f, as predicted by emily cooper on monday, february 17, 2025.
# 13       according to olivia martinez from stanford university, on wednesday, july 10, 2025, the prevalence of type 2 diabetes in adults will decline by 4% in the timeframe of 2029.
# 14                                                      on tuesday, june 11, 2025, dr. michael brown predicts that the obesity rate in the united states will decrease by 4% by 2029.
# 15                                            on monday, january 13, 2025, president john doe predicts that the unemployment rate in the united states will decrease by 2.5% by 2027.
# 16                                                                                                                    the product is available for purchase online and in stores now.
# 17  according to general robert williams from the department of defense, on wednesday, july 16, 2025, the number of active-duty soldiers will decline by 4% in the timeframe of 2028.
# 18                              on wednesday, march 19, 2025, senator emily johnson from the senate committee on finance forecasts that the inflation rate will fall by 1.8% in 2026.
# 19                                              on wednesday, october 25, 2024, emily chen predicts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 20                                                                                                           the customer service representative is helpful and knowledgeable always.
# 21                                       in 2027, the number of citizens in the united states is expected to rise by 12%, as predicted by the president on friday, december 12, 2025.
# 22                                ava morales predicts on friday, august 16, 2024, that the operating cash flow at exxonmobil (xom) will decrease by 8% to $15 billion in q1 of 2028.
# 23                                                                                                 the company is currently hiring new employees for various positions available now.
# 24                                   the world health organization predicts on friday, september 12, 2025, that the global vaccination rate for measles will increase by 18% by 2028.
# 25                                                                                                           the new policy has been implemented to improve customer service quality.
# 26                                                 amanda green predicts on wednesday, january 22, 2025, that the wind speed in chicago will decrease by 10 mph in late january 2025.
# 27                                  in q2 of 2026, the gross profit at apple (aapl) is expected to rise by 15% to $30 billion, as predicted by sophia patel on monday, june 10, 2024.
# 28                        on thursday, september 12, 2024, david lee from nvidia (nvda) forecasts that the stock price will likely increase by 20% to $1,200 per share in q4 of 2027.
# 29                                                                                                              the manager is responsible for overseeing daily operations and tasks.
# 30                   on thursday, august 14, 2025, arjun patel, ph.d. from the florida department of health envisions that the average daily caloric intake will rise by 12% by 2027.
# 31                                                                                                                                    i'll provide the predictions for each category.
# 32                                                                                                                          the office is closed due to a holiday today and tomorrow.
# 33                                                                                                                         the new restaurant is open for lunch and dinner daily now.
# 34                                                                                                                                            **company-based financial predictions**
# 35                                                on monday, march 17, 2025, dr. ethan kim predicts that the temperature will rise by 3°c in new york city by friday, march 21, 2025.
# 36                                   on tuesday, april 15, 2025, samantha taylor from noaa forecasts that the precipitation levels will increase by 15% in san francisco in may 2025.
# 37                                                                                                                                                      **public policy predictions**
# 38                                                                                                        the employees are required to attend a mandatory training session tomorrow.
# 39                                                                                                               the company's financial reports are available for public review now.
#
#     Prediction Label
# 0                  0
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# 5                  0
# 6                  1
# 7                  0
# 8                  0
# 9                  1
# 10                 1
# 11                 0
# 12                 1
# 13                 1
# 14                 1
# 15                 1
# 16                 0
# 17                 1
# 18                 1
# 19                 1
# 20                 0
# 21                 1
# 22                 1
# 23                 0
# 24                 1
# 25                 0
# 26                 1
# 27                 1
# 28                 1
# 29                 0
# 30                 1
# 31                 1
# 32                 0
# 33                 0
# 34                 1
# 35                 1
# 36                 1
# 37                 1
# 38                 0
# 39                 0

# %%
# %store shuffled_base_df
# %store shuffled_cleaned_df
# Out:
# Stored 'shuffled_base_df' (DataFrame)
# Stored 'shuffled_cleaned_df' (DataFrame)
