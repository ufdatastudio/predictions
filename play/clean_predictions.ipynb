# %% [markdown]
# # Clean Predictions
#
# - **Goal:** Prediction Recognition
# - **Purpose:** To implement step 1 with sub steps of prediction recognition pipeline. See steps
#     - (2) Clean the generated predictions
# - **Misc:**
#     - `%load` and `%run` with cell magic: This allows us to get code from another notebook

# %%
import os
import sys

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from clean_predictions import PredictionDataCleaner

# %%
generate_predictions_notebook = 'generate_prediction.ipynb'
# %run $generate_predictions_notebook

# %%
predictions_df
# Out:
#                                                                                                                                                         Base Predictions
# 0                                   On Friday, November 22, 2024, Emily Chen forecasts that the revenue at Amazon (AMZN) will rise by 12% to $150 billion in Q2 of 2026.
# 1                    On Monday, October 28, 2024, Liam Kim predicts that the operating cash flow at Microsoft (MSFT) should decrease by 2% to $50 billion in Q1 of 2027.
# 2             On Wednesday, September 25, 2024, Sophia Rodriguez envisions that the stock price at Tesla (TSLA) will likely rise by 30% to $500 per share in Q4 of 2028.
# 3                  On Tuesday, August 20, 2024, Ethan Hall speculates that the dividend payout ratio at Procter & Gamble (PG) will probably remain at 60% in Q3 of 2025.
# 4  On Thursday, July 18, 2024, Ava Morales predicts that the research and development expenses at Johnson & Johnson (JNJ) may increase by 10% to $12 billion in FY 2029.
# 5         On Monday, June 17, 2024, Julian Sanchez forecasts that the return on equity (ROE) at Visa (V) has a high probability of improving by 3% to 20% in Q2 of 2027.
# 6                     On Wednesday, May 22, 2024, Mia Garcia predicts that the capital expenditures at Chevron (CVX) should decrease by 5% to $10 billion in Q1 of 2028.
# 7                  On Friday, April 26, 2024, Logan Brooks envisions that the gross profit margin at Cisco Systems (CSCO) will likely expand by 2% to 25% in Q4 of 2026.
# 8                          On Tuesday, March 19, 2024, Hannah Taylor forsees that the total debt at AT&T (T) will probably decrease by 8% to $150 billion in Q3 of 2029.
# 9    On Thursday, February 21, 2024, Jackson White predicts that the earnings before interest and taxes (EBIT) at 3M (MMM) may increase by 6% to $10 billion in FY 2028.

# %%
predictions_col = predictions_df.columns[0]
predictions_col
# Out:
# 'Base Predictions'

# %%
cleaner = PredictionDataCleaner(predictions_df)
cleaner.lower_case(predictions_col)
# Out:
#                                                                                                                                                         Base Predictions
# 0                                   on friday, november 22, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                    on monday, october 28, 2024, liam kim predicts that the operating cash flow at microsoft (msft) should decrease by 2% to $50 billion in q1 of 2027.
# 2             on wednesday, september 25, 2024, sophia rodriguez envisions that the stock price at tesla (tsla) will likely rise by 30% to $500 per share in q4 of 2028.
# 3                  on tuesday, august 20, 2024, ethan hall speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2025.
# 4  on thursday, july 18, 2024, ava morales predicts that the research and development expenses at johnson & johnson (jnj) may increase by 10% to $12 billion in fy 2029.
# 5         on monday, june 17, 2024, julian sanchez forecasts that the return on equity (roe) at visa (v) has a high probability of improving by 3% to 20% in q2 of 2027.
# 6                     on wednesday, may 22, 2024, mia garcia predicts that the capital expenditures at chevron (cvx) should decrease by 5% to $10 billion in q1 of 2028.
# 7                  on friday, april 26, 2024, logan brooks envisions that the gross profit margin at cisco systems (csco) will likely expand by 2% to 25% in q4 of 2026.
# 8                          on tuesday, march 19, 2024, hannah taylor forsees that the total debt at at&t (t) will probably decrease by 8% to $150 billion in q3 of 2029.
# 9    on thursday, february 21, 2024, jackson white predicts that the earnings before interest and taxes (ebit) at 3m (mmm) may increase by 6% to $10 billion in fy 2028.

# %%
cleaner.remove_html_and_urls(predictions_col)
# Out:
#                                                                                                                                                         Base Predictions
# 0                                   on friday, november 22, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                    on monday, october 28, 2024, liam kim predicts that the operating cash flow at microsoft (msft) should decrease by 2% to $50 billion in q1 of 2027.
# 2             on wednesday, september 25, 2024, sophia rodriguez envisions that the stock price at tesla (tsla) will likely rise by 30% to $500 per share in q4 of 2028.
# 3                  on tuesday, august 20, 2024, ethan hall speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2025.
# 4  on thursday, july 18, 2024, ava morales predicts that the research and development expenses at johnson & johnson (jnj) may increase by 10% to $12 billion in fy 2029.
# 5         on monday, june 17, 2024, julian sanchez forecasts that the return on equity (roe) at visa (v) has a high probability of improving by 3% to 20% in q2 of 2027.
# 6                     on wednesday, may 22, 2024, mia garcia predicts that the capital expenditures at chevron (cvx) should decrease by 5% to $10 billion in q1 of 2028.
# 7                  on friday, april 26, 2024, logan brooks envisions that the gross profit margin at cisco systems (csco) will likely expand by 2% to 25% in q4 of 2026.
# 8                          on tuesday, march 19, 2024, hannah taylor forsees that the total debt at at&t (t) will probably decrease by 8% to $150 billion in q3 of 2029.
# 9    on thursday, february 21, 2024, jackson white predicts that the earnings before interest and taxes (ebit) at 3m (mmm) may increase by 6% to $10 billion in fy 2028.

# %%
cleaner.remove_contractions(predictions_col)
# Out:
#                                                                                                                                                         Base Predictions
# 0                                   on friday, november 22, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                    on monday, october 28, 2024, liam kim predicts that the operating cash flow at microsoft (msft) should decrease by 2% to $50 billion in q1 of 2027.
# 2             on wednesday, september 25, 2024, sophia rodriguez envisions that the stock price at tesla (tsla) will likely rise by 30% to $500 per share in q4 of 2028.
# 3                  on tuesday, august 20, 2024, ethan hall speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2025.
# 4  on thursday, july 18, 2024, ava morales predicts that the research and development expenses at johnson & johnson (jnj) may increase by 10% to $12 billion in fy 2029.
# 5         on monday, june 17, 2024, julian sanchez forecasts that the return on equity (roe) at visa (v) has a high probability of improving by 3% to 20% in q2 of 2027.
# 6                     on wednesday, may 22, 2024, mia garcia predicts that the capital expenditures at chevron (cvx) should decrease by 5% to $10 billion in q1 of 2028.
# 7                  on friday, april 26, 2024, logan brooks envisions that the gross profit margin at cisco systems (csco) will likely expand by 2% to 25% in q4 of 2026.
# 8                          on tuesday, march 19, 2024, hannah taylor forsees that the total debt at at&t (t) will probably decrease by 8% to $150 billion in q3 of 2029.
# 9    on thursday, february 21, 2024, jackson white predicts that the earnings before interest and taxes (ebit) at 3m (mmm) may increase by 6% to $10 billion in fy 2028.

# %%
# May need to keep so we don't remove numbers, percentages, etc.
# cleaner.remove_non_alphabetical_characters(predictions_col)

# %%
cleaner.remove_extra_spaces(predictions_col)
# Out:
#                                                                                                                                                         Base Predictions
# 0                                   on friday, november 22, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                    on monday, october 28, 2024, liam kim predicts that the operating cash flow at microsoft (msft) should decrease by 2% to $50 billion in q1 of 2027.
# 2             on wednesday, september 25, 2024, sophia rodriguez envisions that the stock price at tesla (tsla) will likely rise by 30% to $500 per share in q4 of 2028.
# 3                  on tuesday, august 20, 2024, ethan hall speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2025.
# 4  on thursday, july 18, 2024, ava morales predicts that the research and development expenses at johnson & johnson (jnj) may increase by 10% to $12 billion in fy 2029.
# 5         on monday, june 17, 2024, julian sanchez forecasts that the return on equity (roe) at visa (v) has a high probability of improving by 3% to 20% in q2 of 2027.
# 6                     on wednesday, may 22, 2024, mia garcia predicts that the capital expenditures at chevron (cvx) should decrease by 5% to $10 billion in q1 of 2028.
# 7                  on friday, april 26, 2024, logan brooks envisions that the gross profit margin at cisco systems (csco) will likely expand by 2% to 25% in q4 of 2026.
# 8                          on tuesday, march 19, 2024, hannah taylor forsees that the total debt at at&t (t) will probably decrease by 8% to $150 billion in q3 of 2029.
# 9    on thursday, february 21, 2024, jackson white predicts that the earnings before interest and taxes (ebit) at 3m (mmm) may increase by 6% to $10 billion in fy 2028.
