# %% [markdown]
# # Spacy Pipeline
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To extract named entities (NER), part-of-speech (POS), etc.
#     1. Use to train model as feature extraction (ie: TF x IDF) alone isn't enough
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys
import spacy

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from pipelines import BasePipeline
from data_processing import DataProcessing

# %%
pd.set_option('max_colwidth', 800)
nlp = spacy.load("en_core_web_sm")
# %store -r predictions_df
# %store -r non_predictions_df

# %% [markdown]
# python eval() and df.apply()

# %%
predictions_df.head(3)
# Out:
#                                                                                                                                                                 Base Sentence  \
# 0  On 2024-10-15, Rachel Patel, a financial analyst, predicts that the operating cash flow at General Motors will likely decrease by $5 billion to $10 billion in Q2 of 2026.
# 1                                                   In 2024, Julian Sanchez from Bank of America, forecasts that the stock price will rise from $50 to $75 per share in 2028.
# 2                       Emily Wilson, a financial expert, predicts on 20/08/2024 that the research and development expenses at Pfizer may stay stable at $15 million in 2029.
#
#    Prediction Label               Model Name     Domain  Template Number
# 0                 1  llama-3.3-70b-versatile  financial                1
# 1                 1  llama-3.3-70b-versatile  financial                2
# 2                 1  llama-3.3-70b-versatile  financial                3

# %%
base_pipeline = BasePipeline()

cleaned_predictions_df = base_pipeline.clean_predictions(predictions_df)
cleaned_predictions_df
# Out:
#                                                                                                                                                                                                       Base Sentence  \
# 0                                        on 2024-10-15, rachel patel, a financial analyst, predicts that the operating cash flow at general motors will likely decrease by $5 billion to $10 billion in q2 of 2026.
# 1                                                                                         in 2024, julian sanchez from bank of america, forecasts that the stock price will rise from $50 to $75 per share in 2028.
# 2                                                             emily wilson, a financial expert, predicts on 20/08/2024 that the research and development expenses at pfizer may stay stable at $15 million in 2029.
# 3                                                               according to a senior executive from cisco, on 2024/08/20, the net profit is expected to increase beyond $8 billion in the timeframe of q4 of 2027.
# 4                                in 2025-02-18, the revenue at visa has a probability of 20 percent to reach $25 billion, which is a 10% increase, as predicted by david lee, a financial reporter, on 15 oct 2024.
# 5                                               on wednesday, november 20, 2024, michael davis, a financial analyst, predicts that the gross profit at 3m will likely decrease by 15% to $12 billion in q1 of 2026.
# 6                                                                        in q3 of 2024, olivia brown from johnson & johnson, envisions that the operating income will rise from $10 billion to $15 billion in 2028.
# 7                                                                               kevin white, a financial expert, predicts on 10/10/2024 that the revenue at at&t may increase by $5 billion to $20 billion in 2027.
# 8                                                                 according to a top executive from intel, on 2024-07-25, the net profit is expected to increase beyond $12 billion in the timeframe of q2 of 2029.
# 9                                   in 2026-08-25, the stock price at mcdonald's is expected to be $200 per share, which is a 25% increase, as predicted by sophia rodriguez, a financial analyst, on 25 july 2024.
# 10  on 2024-10-15, dr. rachel kim, a senior meteorologist at the national oceanic and atmospheric administration, forecasts that the precipitation levels in los angeles will likely increase by 15% in q2 of 2026.
# 11                                                     in 2024-08, emily chen from the european centre for medium-range weather forecasts envisions that the humidity in beijing should decrease by 12% in 2027-03.
# 12                                              michael davis, a weather expert from the meteorological office, predicts on 2024-09-20 that the temperature in sydney will fall by 8°c in the timeframe of 2025-09.
# 13                                   according to a top executive from the world meteorological organization, on 2024-11-01, the wind speed in tokyo is expected to rise beyond 20 mph in the timeframe of 2026-06.
# 14                in 2028-02, the average sea level in miami has a probability of 10% to increase by 2 inches, as predicted by dr. lisa nguyen, a weather analyst from the national weather service, on 2024-07-15.
# 15                  on 2024-12-25, james lee, a weather reporter from the korean meteorological administration, forecasts that the snowfall levels in new york city will likely decrease by 5 inches in q1 of 2027.
# 16                                                              in 2025-01, david taylor from the australian bureau of meteorology predicts that the air quality index in melbourne will improve by 15% in 2026-10.
# 17                                dr. sophia patel, a weather expert from the indian meteorological department, predicts on 2024-06-01 that the temperature in mumbai will rise by 5°c in the timeframe of 2027-05.
# 18                      according to a senior meteorologist from the chinese meteorological administration, on 2024-03-15, the rainfall in shanghai is expected to increase beyond 20% in the timeframe of 2026-08.
# 19     in 2029-04, the wind chill in chicago has a probability of 12% to decrease by 8°f, as predicted by dr. kevin white, a weather analyst from the national centers for environmental prediction, on 2024-02-20.
# 20                                             on 2024-10-15, dr. david lee, a health expert, predicts that the average blood pressure at the american heart association will likely decrease by 10% in q2 of 2026.
# 21                                                                  in 2024, dr. maria rodriguez from the world health organization envisions that the global life expectancy may rise from 72 to 75 years in 2028.
# 22                                                                     dr. john smith predicts on 08/20/2024 that the prevalence of mental health disorders in the united states should stay stable at 20% in 2027.
# 23  according to a report by dr. emily chen from the centers for disease control and prevention, on 21 aug 2024, the obesity rate among children is expected to increase beyond 25% in the timeframe of q4 of 2029.
# 24                                     in q1 of 2025, the average daily step count in australia is expected to rise by 15%, as predicted by dr. michael brown from the national institutes of health on 2024-10-10.
# 25                                                               on 2024/11/12, dr. sophia patel, a health analyst, forecasts that the cancer survival rate at the mayo clinic will likely increase by 12% in 2026.
# 26                                               in 2025, dr. kevin white from the american cancer society predicts that the average daily caloric intake may fall from 2500 to 2000 calories in quarter 2 of 2028.
# 27                                                                      dr. lisa nguyen predicts on 2024-08-25 that the global vaccination rate for influenza in the european union should increase by 15% in 2027.
# 28     according to a report by dr. daniel kim from the university of california, on 10/15/2024, the prevalence of chronic diseases among adults is expected to decrease beyond 30% in the timeframe of q3 of 2030.
# 29                                    in 2029-08-20, the average weekly exercise hours in canada is expected to rise by 20%, as predicted by dr. olivia martin from the canadian medical association on 2024/10/20.
# 30                                                                                         on 2024-10-15, policy expert, john smith, predicts that the stock price at goldman sachs will rise by 10% in q2 of 2026.
# 31                                                                          in 2024, policy analyst, emily johnson, from the federal reserve, envisions that the interest rate will increase from 2% to 4% in 2028.
# 32                                                                     policy senior level person, michael brown, predicts on 08/20/2024 that the gdp in the united states may stay stable at $20 trillion in 2027.
# 33                       according to a policy top executive, robert williams, from jpmorgan chase, on 2024-08-22, the number of bank branches is expected to decrease beyond 5,000 in the timeframe of q4 of 2029.
# 34                                                         in 2025-08-20, the inflation rate in the european union has a probability of 80% to reach 3%, as predicted by policy reporter, sarah lee, on 2024-10-10.
# 35                                                               on 2024/11/12, policy expert, david white, forecasts that the exchange rate at the european central bank will likely decrease by 5% in q1 of 2027.
# 36                                                           in q3 of 2024, policy analyst, kevin davis, from the international monetary fund, predicts that the unemployment rate will fall from 5% to 3% in 2026.
# 37                                                                                 policy senior level person, olivia martinez, predicts on 2024-09-18 that the national debt in japan may increase by 10% in 2028.
# 38                       according to a policy top executive, james wilson, from citigroup, on 2024-10-25, the number of credit card holders is expected to rise beyond 100 million in the timeframe of q2 of 2030.
# 39                            in q4 of 2027, the number of initial public offerings in the united states is expected to be 500, which is a 20% increase, as predicted by policy analyst, daniel kim, on 2024-08-15.
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  1  llama-3.3-70b-versatile  financial                1
# 1                  1  llama-3.3-70b-versatile  financial                2
# 2                  1  llama-3.3-70b-versatile  financial                3
# 3                  1  llama-3.3-70b-versatile  financial                4
# 4                  1  llama-3.3-70b-versatile  financial                5
# 5                  1  llama-3.3-70b-versatile  financial                1
# 6                  1  llama-3.3-70b-versatile  financial                2
# 7                  1  llama-3.3-70b-versatile  financial                3
# 8                  1  llama-3.3-70b-versatile  financial                4
# 9                  1  llama-3.3-70b-versatile  financial                5
# 10                 1  llama-3.3-70b-versatile    weather                1
# 11                 1  llama-3.3-70b-versatile    weather                2
# 12                 1  llama-3.3-70b-versatile    weather                3
# 13                 1  llama-3.3-70b-versatile    weather                4
# 14                 1  llama-3.3-70b-versatile    weather                5
# 15                 1  llama-3.3-70b-versatile    weather                1
# 16                 1  llama-3.3-70b-versatile    weather                2
# 17                 1  llama-3.3-70b-versatile    weather                3
# 18                 1  llama-3.3-70b-versatile    weather                4
# 19                 1  llama-3.3-70b-versatile    weather                5
# 20                 1  llama-3.3-70b-versatile     health                1
# 21                 1  llama-3.3-70b-versatile     health                2
# 22                 1  llama-3.3-70b-versatile     health                3
# 23                 1  llama-3.3-70b-versatile     health                4
# 24                 1  llama-3.3-70b-versatile     health                5
# 25                 1  llama-3.3-70b-versatile     health                1
# 26                 1  llama-3.3-70b-versatile     health                2
# 27                 1  llama-3.3-70b-versatile     health                3
# 28                 1  llama-3.3-70b-versatile     health                4
# 29                 1  llama-3.3-70b-versatile     health                5
# 30                 1  llama-3.3-70b-versatile     policy                1
# 31                 1  llama-3.3-70b-versatile     policy                2
# 32                 1  llama-3.3-70b-versatile     policy                3
# 33                 1  llama-3.3-70b-versatile     policy                4
# 34                 1  llama-3.3-70b-versatile     policy                5
# 35                 1  llama-3.3-70b-versatile     policy                1
# 36                 1  llama-3.3-70b-versatile     policy                2
# 37                 1  llama-3.3-70b-versatile     policy                3
# 38                 1  llama-3.3-70b-versatile     policy                4
# 39                 1  llama-3.3-70b-versatile     policy                5

# %%
# predictions_df

# %%
only_predictions = DataProcessing.df_to_list(cleaned_predictions_df, 'Base Sentence')
only_predictions
# Out:
# ['on 2024-10-15, rachel patel, a financial analyst, predicts that the operating cash flow at general motors will likely decrease by $5 billion to $10 billion in q2 of 2026.',
#  'in 2024, julian sanchez from bank of america, forecasts that the stock price will rise from $50 to $75 per share in 2028.',
#  'emily wilson, a financial expert, predicts on 20/08/2024 that the research and development expenses at pfizer may stay stable at $15 million in 2029.',
#  'according to a senior executive from cisco, on 2024/08/20, the net profit is expected to increase beyond $8 billion in the timeframe of q4 of 2027.',
#  'in 2025-02-18, the revenue at visa has a probability of 20 percent to reach $25 billion, which is a 10% increase, as predicted by david lee, a financial reporter, on 15 oct 2024.',
#  'on wednesday, november 20, 2024, michael davis, a financial analyst, predicts that the gross profit at 3m will likely decrease by 15% to $12 billion in q1 of 2026.',
#  'in q3 of 2024, olivia brown from johnson & johnson, envisions that the operating income will rise from $10 billion to $15 billion in 2028.',
#  'kevin white, a financial expert, predicts on 10/10/2024 that the revenue at at&t may increase by $5 billion to $20 billion in 2027.',
#  'according to a top executive from intel, on 2024-07-25, the net profit is expected to increase beyond $12 billion in the timeframe of q2 of 2029.',
#  "in 2026-08-25, the stock price at mcdonald's is expected to be $200 per share, which is a 25% increase, as predicted by sophia rodriguez, a financial analyst, on 25 july 2024.",
#  'on 2024-10-15, dr. rachel kim, a senior meteorologist at the national oceanic and atmospheric administration, forecasts that the precipitation levels in los angeles will likely increase by 15% in q2 of 2026.',
#  'in 2024-08, emily chen from the european centre for medium-range weather forecasts envisions that the humidity in beijing should decrease by 12% in 2027-03.',
#  'michael davis, a weather expert from the meteorological office, predicts on 2024-09-20 that the temperature in sydney will fall by 8°c in the timeframe of 2025-09.',
#  'according to a top executive from the world meteorological organization, on 2024-11-01, the wind speed in tokyo is expected to rise beyond 20 mph in the timeframe of 2026-06.',
#  'in 2028-02, the average sea level in miami has a probability of 10% to increase by 2 inches, as predicted by dr. lisa nguyen, a weather analyst from the national weather service, on 2024-07-15.',
#  'on 2024-12-25, james lee, a weather reporter from the korean meteorological administration, forecasts that the snowfall levels in new york city will likely decrease by 5 inches in q1 of 2027.',
#  'in 2025-01, david taylor from the australian bureau of meteorology predicts that the air quality index in melbourne will improve by 15% in 2026-10.',
#  'dr. sophia patel, a weather expert from the indian meteorological department, predicts on 2024-06-01 that the temperature in mumbai will rise by 5°c in the timeframe of 2027-05.',
#  'according to a senior meteorologist from the chinese meteorological administration, on 2024-03-15, the rainfall in shanghai is expected to increase beyond 20% in the timeframe of 2026-08.',
#  'in 2029-04, the wind chill in chicago has a probability of 12% to decrease by 8°f, as predicted by dr. kevin white, a weather analyst from the national centers for environmental prediction, on 2024-02-20.',
#  'on 2024-10-15, dr. david lee, a health expert, predicts that the average blood pressure at the american heart association will likely decrease by 10% in q2 of 2026.',
#  'in 2024, dr. maria rodriguez from the world health organization envisions that the global life expectancy may rise from 72 to 75 years in 2028.',
#  'dr. john smith predicts on 08/20/2024 that the prevalence of mental health disorders in the united states should stay stable at 20% in 2027.',
#  'according to a report by dr. emily chen from the centers for disease control and prevention, on 21 aug 2024, the obesity rate among children is expected to increase beyond 25% in the timeframe of q4 of 2029.',
#  'in q1 of 2025, the average daily step count in australia is expected to rise by 15%, as predicted by dr. michael brown from the national institutes of health on 2024-10-10.',
#  'on 2024/11/12, dr. sophia patel, a health analyst, forecasts that the cancer survival rate at the mayo clinic will likely increase by 12% in 2026.',
#  'in 2025, dr. kevin white from the american cancer society predicts that the average daily caloric intake may fall from 2500 to 2000 calories in quarter 2 of 2028.',
#  'dr. lisa nguyen predicts on 2024-08-25 that the global vaccination rate for influenza in the european union should increase by 15% in 2027.',
#  'according to a report by dr. daniel kim from the university of california, on 10/15/2024, the prevalence of chronic diseases among adults is expected to decrease beyond 30% in the timeframe of q3 of 2030.',
#  'in 2029-08-20, the average weekly exercise hours in canada is expected to rise by 20%, as predicted by dr. olivia martin from the canadian medical association on 2024/10/20.',
#  'on 2024-10-15, policy expert, john smith, predicts that the stock price at goldman sachs will rise by 10% in q2 of 2026.',
#  'in 2024, policy analyst, emily johnson, from the federal reserve, envisions that the interest rate will increase from 2% to 4% in 2028.',
#  'policy senior level person, michael brown, predicts on 08/20/2024 that the gdp in the united states may stay stable at $20 trillion in 2027.',
#  'according to a policy top executive, robert williams, from jpmorgan chase, on 2024-08-22, the number of bank branches is expected to decrease beyond 5,000 in the timeframe of q4 of 2029.',
#  'in 2025-08-20, the inflation rate in the european union has a probability of 80% to reach 3%, as predicted by policy reporter, sarah lee, on 2024-10-10.',
#  'on 2024/11/12, policy expert, david white, forecasts that the exchange rate at the european central bank will likely decrease by 5% in q1 of 2027.',
#  'in q3 of 2024, policy analyst, kevin davis, from the international monetary fund, predicts that the unemployment rate will fall from 5% to 3% in 2026.',
#  'policy senior level person, olivia martinez, predicts on 2024-09-18 that the national debt in japan may increase by 10% in 2028.',
#  'according to a policy top executive, james wilson, from citigroup, on 2024-10-25, the number of credit card holders is expected to rise beyond 100 million in the timeframe of q2 of 2030.',
#  'in q4 of 2027, the number of initial public offerings in the united states is expected to be 500, which is a 20% increase, as predicted by policy analyst, daniel kim, on 2024-08-15.']

# %%
initialize_spacy = DataProcessing.setup_spacy()

disable_components = ["parser", "lemmatizer"]
tags, all_pos_tags, entities, all_ner_entities = DataProcessing.extract_entities(only_predictions, initialize_spacy, disable_components)

# %%
tags
# Out:
# [[('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   (',', 'PUNCT'),
#   ('rachel', 'PROPN'),
#   ('patel', 'NOUN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('financial', 'ADJ'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('operating', 'VERB'),
#   ('cash', 'NOUN'),
#   ('flow', 'NOUN'),
#   ('at', 'ADP'),
#   ('general', 'ADJ'),
#   ('motors', 'NOUN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('$', 'SYM'),
#   ('5', 'NUM'),
#   ('billion', 'NUM'),
#   ('to', 'PART'),
#   ('$', 'SYM'),
#   ('10', 'NUM'),
#   ('billion', 'NUM'),
#   ('in', 'ADP'),
#   ('q2', 'NOUN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('julian', 'ADJ'),
#   ('sanchez', 'PROPN'),
#   ('from', 'ADP'),
#   ('bank', 'PROPN'),
#   ('of', 'ADP'),
#   ('america', 'PROPN'),
#   (',', 'PUNCT'),
#   ('forecasts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('stock', 'NOUN'),
#   ('price', 'NOUN'),
#   ('will', 'AUX'),
#   ('rise', 'VERB'),
#   ('from', 'ADP'),
#   ('$', 'SYM'),
#   ('50', 'NUM'),
#   ('to', 'PART'),
#   ('$', 'SYM'),
#   ('75', 'NUM'),
#   ('per', 'ADP'),
#   ('share', 'NOUN'),
#   ('in', 'ADP'),
#   ('2028', 'NUM'),
#   ('.', 'PUNCT')],
#  [('emily', 'PROPN'),
#   ('wilson', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('financial', 'ADJ'),
#   ('expert', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('20/08/2024', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('research', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('development', 'NOUN'),
#   ('expenses', 'NOUN'),
#   ('at', 'ADP'),
#   ('pfizer', 'NOUN'),
#   ('may', 'AUX'),
#   ('stay', 'VERB'),
#   ('stable', 'ADJ'),
#   ('at', 'ADP'),
#   ('$', 'SYM'),
#   ('15', 'NUM'),
#   ('million', 'NUM'),
#   ('in', 'ADP'),
#   ('2029', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('senior', 'ADJ'),
#   ('executive', 'NOUN'),
#   ('from', 'ADP'),
#   ('cisco', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024/08/20', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('net', 'ADJ'),
#   ('profit', 'NOUN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('increase', 'VERB'),
#   ('beyond', 'ADP'),
#   ('$', 'SYM'),
#   ('8', 'NUM'),
#   ('billion', 'NUM'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('q4', 'PROPN'),
#   ('of', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2025', 'NUM'),
#   ('-', 'SYM'),
#   ('02', 'NUM'),
#   ('-', 'SYM'),
#   ('18', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('revenue', 'NOUN'),
#   ('at', 'ADP'),
#   ('visa', 'NOUN'),
#   ('has', 'AUX'),
#   ('a', 'DET'),
#   ('probability', 'NOUN'),
#   ('of', 'ADP'),
#   ('20', 'NUM'),
#   ('percent', 'NOUN'),
#   ('to', 'PART'),
#   ('reach', 'VERB'),
#   ('$', 'SYM'),
#   ('25', 'NUM'),
#   ('billion', 'NUM'),
#   (',', 'PUNCT'),
#   ('which', 'DET'),
#   ('is', 'AUX'),
#   ('a', 'DET'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   ('increase', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('david', 'PROPN'),
#   ('lee', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('financial', 'ADJ'),
#   ('reporter', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('15', 'NUM'),
#   ('oct', 'PROPN'),
#   ('2024', 'NUM'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('wednesday', 'PROPN'),
#   (',', 'PUNCT'),
#   ('november', 'PROPN'),
#   ('20', 'NUM'),
#   (',', 'PUNCT'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('michael', 'PROPN'),
#   ('davis', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('financial', 'ADJ'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('gross', 'ADJ'),
#   ('profit', 'NOUN'),
#   ('at', 'ADP'),
#   ('3', 'NUM'),
#   ('m', 'NOUN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('15', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PART'),
#   ('$', 'SYM'),
#   ('12', 'NUM'),
#   ('billion', 'NUM'),
#   ('in', 'ADP'),
#   ('q1', 'PROPN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('q3', 'PROPN'),
#   ('of', 'ADP'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('olivia', 'ADJ'),
#   ('brown', 'NOUN'),
#   ('from', 'ADP'),
#   ('johnson', 'PROPN'),
#   ('&', 'CCONJ'),
#   ('johnson', 'PROPN'),
#   (',', 'PUNCT'),
#   ('envisions', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('operating', 'NOUN'),
#   ('income', 'NOUN'),
#   ('will', 'AUX'),
#   ('rise', 'VERB'),
#   ('from', 'ADP'),
#   ('$', 'SYM'),
#   ('10', 'NUM'),
#   ('billion', 'NUM'),
#   ('to', 'PART'),
#   ('$', 'SYM'),
#   ('15', 'NUM'),
#   ('billion', 'NUM'),
#   ('in', 'ADP'),
#   ('2028', 'NUM'),
#   ('.', 'PUNCT')],
#  [('kevin', 'PROPN'),
#   ('white', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('financial', 'ADJ'),
#   ('expert', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('10/10/2024', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('revenue', 'NOUN'),
#   ('at', 'ADP'),
#   ('at&t', 'PROPN'),
#   ('may', 'AUX'),
#   ('increase', 'VERB'),
#   ('by', 'ADP'),
#   ('$', 'SYM'),
#   ('5', 'NUM'),
#   ('billion', 'NUM'),
#   ('to', 'PART'),
#   ('$', 'SYM'),
#   ('20', 'NUM'),
#   ('billion', 'NUM'),
#   ('in', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('top', 'ADJ'),
#   ('executive', 'NOUN'),
#   ('from', 'ADP'),
#   ('intel', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'PUNCT'),
#   ('07', 'NUM'),
#   ('-', 'SYM'),
#   ('25', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('net', 'ADJ'),
#   ('profit', 'NOUN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('increase', 'VERB'),
#   ('beyond', 'ADP'),
#   ('$', 'SYM'),
#   ('12', 'NUM'),
#   ('billion', 'NUM'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('q2', 'NOUN'),
#   ('of', 'ADP'),
#   ('2029', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2026', 'NUM'),
#   ('-', 'PUNCT'),
#   ('08', 'NUM'),
#   ('-', 'SYM'),
#   ('25', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('stock', 'NOUN'),
#   ('price', 'NOUN'),
#   ('at', 'ADP'),
#   ('mcdonald', 'PROPN'),
#   ("'s", 'PART'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('$', 'SYM'),
#   ('200', 'NUM'),
#   ('per', 'ADP'),
#   ('share', 'NOUN'),
#   (',', 'PUNCT'),
#   ('which', 'DET'),
#   ('is', 'AUX'),
#   ('a', 'DET'),
#   ('25', 'NUM'),
#   ('%', 'NOUN'),
#   ('increase', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('sophia', 'PROPN'),
#   ('rodriguez', 'NOUN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('financial', 'ADJ'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('25', 'NUM'),
#   ('july', 'PROPN'),
#   ('2024', 'NUM'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   (',', 'PUNCT'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('rachel', 'PROPN'),
#   ('kim', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('senior', 'ADJ'),
#   ('meteorologist', 'NOUN'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('national', 'PROPN'),
#   ('oceanic', 'PROPN'),
#   ('and', 'CCONJ'),
#   ('atmospheric', 'ADJ'),
#   ('administration', 'NOUN'),
#   (',', 'PUNCT'),
#   ('forecasts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('precipitation', 'NOUN'),
#   ('levels', 'NOUN'),
#   ('in', 'ADP'),
#   ('los', 'PROPN'),
#   ('angeles', 'PROPN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('increase', 'VERB'),
#   ('by', 'ADP'),
#   ('15', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('q2', 'NOUN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   (',', 'PUNCT'),
#   ('emily', 'ADV'),
#   ('chen', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('european', 'PROPN'),
#   ('centre', 'PROPN'),
#   ('for', 'ADP'),
#   ('medium', 'ADJ'),
#   ('-', 'PUNCT'),
#   ('range', 'NOUN'),
#   ('weather', 'NOUN'),
#   ('forecasts', 'NOUN'),
#   ('envisions', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('humidity', 'NOUN'),
#   ('in', 'ADP'),
#   ('beijing', 'PROPN'),
#   ('should', 'AUX'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('12', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2027', 'NUM'),
#   ('-', 'SYM'),
#   ('03', 'NUM'),
#   ('.', 'PUNCT')],
#  [('michael', 'PROPN'),
#   ('davis', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('weather', 'NOUN'),
#   ('expert', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('meteorological', 'ADJ'),
#   ('office', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('09', 'NUM'),
#   ('-', 'SYM'),
#   ('20', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('temperature', 'NOUN'),
#   ('in', 'ADP'),
#   ('sydney', 'NOUN'),
#   ('will', 'AUX'),
#   ('fall', 'VERB'),
#   ('by', 'ADP'),
#   ('8', 'NUM'),
#   ('°', 'NOUN'),
#   ('c', 'PROPN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('2025', 'NUM'),
#   ('-', 'SYM'),
#   ('09', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('top', 'ADJ'),
#   ('executive', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('world', 'NOUN'),
#   ('meteorological', 'ADJ'),
#   ('organization', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('11', 'NUM'),
#   ('-', 'SYM'),
#   ('01', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('wind', 'NOUN'),
#   ('speed', 'NOUN'),
#   ('in', 'ADP'),
#   ('tokyo', 'PROPN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('rise', 'VERB'),
#   ('beyond', 'ADP'),
#   ('20', 'NUM'),
#   ('mph', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('-', 'SYM'),
#   ('06', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2028', 'NUM'),
#   ('-', 'SYM'),
#   ('02', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('average', 'ADJ'),
#   ('sea', 'NOUN'),
#   ('level', 'NOUN'),
#   ('in', 'ADP'),
#   ('miami', 'PROPN'),
#   ('has', 'AUX'),
#   ('a', 'DET'),
#   ('probability', 'NOUN'),
#   ('of', 'ADP'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PART'),
#   ('increase', 'VERB'),
#   ('by', 'ADP'),
#   ('2', 'NUM'),
#   ('inches', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('lisa', 'PROPN'),
#   ('nguyen', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('weather', 'NOUN'),
#   ('analyst', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('national', 'ADJ'),
#   ('weather', 'NOUN'),
#   ('service', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('07', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('12', 'NUM'),
#   ('-', 'SYM'),
#   ('25', 'NUM'),
#   (',', 'PUNCT'),
#   ('james', 'PROPN'),
#   ('lee', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('weather', 'NOUN'),
#   ('reporter', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('korean', 'PROPN'),
#   ('meteorological', 'ADJ'),
#   ('administration', 'NOUN'),
#   (',', 'PUNCT'),
#   ('forecasts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('snowfall', 'NOUN'),
#   ('levels', 'NOUN'),
#   ('in', 'ADP'),
#   ('new', 'PROPN'),
#   ('york', 'PROPN'),
#   ('city', 'PROPN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('5', 'NUM'),
#   ('inches', 'NOUN'),
#   ('in', 'ADP'),
#   ('q1', 'PROPN'),
#   ('of', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2025', 'NUM'),
#   ('-', 'SYM'),
#   ('01', 'NUM'),
#   (',', 'PUNCT'),
#   ('david', 'PROPN'),
#   ('taylor', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('australian', 'ADJ'),
#   ('bureau', 'NOUN'),
#   ('of', 'ADP'),
#   ('meteorology', 'PROPN'),
#   ('predicts', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('air', 'NOUN'),
#   ('quality', 'NOUN'),
#   ('index', 'NOUN'),
#   ('in', 'ADP'),
#   ('melbourne', 'NOUN'),
#   ('will', 'AUX'),
#   ('improve', 'VERB'),
#   ('by', 'ADP'),
#   ('15', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2026', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('.', 'PUNCT')],
#  [('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('sophia', 'PROPN'),
#   ('patel', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('weather', 'NOUN'),
#   ('expert', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('indian', 'PROPN'),
#   ('meteorological', 'PROPN'),
#   ('department', 'PROPN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('06', 'NUM'),
#   ('-', 'SYM'),
#   ('01', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('temperature', 'NOUN'),
#   ('in', 'ADP'),
#   ('mumbai', 'NOUN'),
#   ('will', 'AUX'),
#   ('rise', 'VERB'),
#   ('by', 'ADP'),
#   ('5', 'NUM'),
#   ('°', 'NOUN'),
#   ('c', 'PROPN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('2027', 'NUM'),
#   ('-', 'SYM'),
#   ('05', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('senior', 'ADJ'),
#   ('meteorologist', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('chinese', 'PROPN'),
#   ('meteorological', 'ADJ'),
#   ('administration', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('03', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('rainfall', 'NOUN'),
#   ('in', 'ADP'),
#   ('shanghai', 'PROPN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('increase', 'VERB'),
#   ('beyond', 'ADP'),
#   ('20', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2029', 'NUM'),
#   ('-', 'SYM'),
#   ('04', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('wind', 'NOUN'),
#   ('chill', 'NOUN'),
#   ('in', 'ADP'),
#   ('chicago', 'PROPN'),
#   ('has', 'AUX'),
#   ('a', 'DET'),
#   ('probability', 'NOUN'),
#   ('of', 'ADP'),
#   ('12', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PART'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('8', 'NUM'),
#   ('°', 'NUM'),
#   ('f', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('kevin', 'PROPN'),
#   ('white', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('weather', 'NOUN'),
#   ('analyst', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('national', 'ADJ'),
#   ('centers', 'NOUN'),
#   ('for', 'ADP'),
#   ('environmental', 'ADJ'),
#   ('prediction', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('02', 'NUM'),
#   ('-', 'SYM'),
#   ('20', 'NUM'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   (',', 'PUNCT'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('david', 'PROPN'),
#   ('lee', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('health', 'NOUN'),
#   ('expert', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('average', 'ADJ'),
#   ('blood', 'NOUN'),
#   ('pressure', 'NOUN'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('american', 'PROPN'),
#   ('heart', 'NOUN'),
#   ('association', 'NOUN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('q2', 'NOUN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('maria', 'PROPN'),
#   ('rodriguez', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('world', 'NOUN'),
#   ('health', 'NOUN'),
#   ('organization', 'NOUN'),
#   ('envisions', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('global', 'ADJ'),
#   ('life', 'NOUN'),
#   ('expectancy', 'NOUN'),
#   ('may', 'AUX'),
#   ('rise', 'VERB'),
#   ('from', 'ADP'),
#   ('72', 'NUM'),
#   ('to', 'PART'),
#   ('75', 'NUM'),
#   ('years', 'NOUN'),
#   ('in', 'ADP'),
#   ('2028', 'NUM'),
#   ('.', 'PUNCT')],
#  [('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('john', 'PROPN'),
#   ('smith', 'PROPN'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('08/20/2024', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('prevalence', 'NOUN'),
#   ('of', 'ADP'),
#   ('mental', 'ADJ'),
#   ('health', 'NOUN'),
#   ('disorders', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('united', 'PROPN'),
#   ('states', 'PROPN'),
#   ('should', 'AUX'),
#   ('stay', 'VERB'),
#   ('stable', 'ADJ'),
#   ('at', 'ADP'),
#   ('20', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('report', 'NOUN'),
#   ('by', 'ADP'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('emily', 'PROPN'),
#   ('chen', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('centers', 'NOUN'),
#   ('for', 'ADP'),
#   ('disease', 'NOUN'),
#   ('control', 'NOUN'),
#   ('and', 'CCONJ'),
#   ('prevention', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('21', 'NUM'),
#   ('aug', 'NOUN'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('obesity', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('among', 'ADP'),
#   ('children', 'NOUN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('increase', 'VERB'),
#   ('beyond', 'ADP'),
#   ('25', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('q4', 'PROPN'),
#   ('of', 'ADP'),
#   ('2029', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('q1', 'PROPN'),
#   ('of', 'ADP'),
#   ('2025', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('average', 'ADJ'),
#   ('daily', 'ADJ'),
#   ('step', 'NOUN'),
#   ('count', 'NOUN'),
#   ('in', 'ADP'),
#   ('australia', 'PROPN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('rise', 'VERB'),
#   ('by', 'ADP'),
#   ('15', 'NUM'),
#   ('%', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('michael', 'PROPN'),
#   ('brown', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('national', 'PROPN'),
#   ('institutes', 'PROPN'),
#   ('of', 'ADP'),
#   ('health', 'NOUN'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('2024/11/12', 'NUM'),
#   (',', 'PUNCT'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('sophia', 'PROPN'),
#   ('patel', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('health', 'NOUN'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('forecasts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('cancer', 'NOUN'),
#   ('survival', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('mayo', 'PROPN'),
#   ('clinic', 'NOUN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('increase', 'VERB'),
#   ('by', 'ADP'),
#   ('12', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2025', 'NUM'),
#   (',', 'PUNCT'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('kevin', 'PROPN'),
#   ('white', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('american', 'ADJ'),
#   ('cancer', 'NOUN'),
#   ('society', 'NOUN'),
#   ('predicts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('average', 'ADJ'),
#   ('daily', 'ADJ'),
#   ('caloric', 'NOUN'),
#   ('intake', 'NOUN'),
#   ('may', 'AUX'),
#   ('fall', 'VERB'),
#   ('from', 'ADP'),
#   ('2500', 'NUM'),
#   ('to', 'ADP'),
#   ('2000', 'NUM'),
#   ('calories', 'NOUN'),
#   ('in', 'ADP'),
#   ('quarter', 'NOUN'),
#   ('2', 'NUM'),
#   ('of', 'ADP'),
#   ('2028', 'NUM'),
#   ('.', 'PUNCT')],
#  [('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('lisa', 'PROPN'),
#   ('nguyen', 'PROPN'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   ('-', 'SYM'),
#   ('25', 'NUM'),
#   ('that', 'PRON'),
#   ('the', 'DET'),
#   ('global', 'ADJ'),
#   ('vaccination', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('for', 'ADP'),
#   ('influenza', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('european', 'PROPN'),
#   ('union', 'PROPN'),
#   ('should', 'AUX'),
#   ('increase', 'VERB'),
#   ('by', 'ADP'),
#   ('15', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('report', 'NOUN'),
#   ('by', 'ADP'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('daniel', 'PROPN'),
#   ('kim', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('university', 'PROPN'),
#   ('of', 'ADP'),
#   ('california', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('10/15/2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('prevalence', 'NOUN'),
#   ('of', 'ADP'),
#   ('chronic', 'ADJ'),
#   ('diseases', 'NOUN'),
#   ('among', 'ADP'),
#   ('adults', 'NOUN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('decrease', 'VERB'),
#   ('beyond', 'ADP'),
#   ('30', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('q3', 'PROPN'),
#   ('of', 'ADP'),
#   ('2030', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2029', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   ('-', 'SYM'),
#   ('20', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('average', 'ADJ'),
#   ('weekly', 'ADJ'),
#   ('exercise', 'NOUN'),
#   ('hours', 'NOUN'),
#   ('in', 'ADP'),
#   ('canada', 'PROPN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('rise', 'VERB'),
#   ('by', 'ADP'),
#   ('20', 'NUM'),
#   ('%', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('dr', 'PROPN'),
#   ('.', 'PROPN'),
#   ('olivia', 'PROPN'),
#   ('martin', 'PROPN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('canadian', 'PROPN'),
#   ('medical', 'ADJ'),
#   ('association', 'NOUN'),
#   ('on', 'ADP'),
#   ('2024/10/20', 'PROPN'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   (',', 'PUNCT'),
#   ('policy', 'NOUN'),
#   ('expert', 'NOUN'),
#   (',', 'PUNCT'),
#   ('john', 'PROPN'),
#   ('smith', 'PROPN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('stock', 'NOUN'),
#   ('price', 'NOUN'),
#   ('at', 'ADP'),
#   ('goldman', 'NOUN'),
#   ('sachs', 'NOUN'),
#   ('will', 'AUX'),
#   ('rise', 'VERB'),
#   ('by', 'ADP'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('q2', 'NOUN'),
#   ('of', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('policy', 'NOUN'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('emily', 'PROPN'),
#   ('johnson', 'PROPN'),
#   (',', 'PUNCT'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('federal', 'PROPN'),
#   ('reserve', 'PROPN'),
#   (',', 'PUNCT'),
#   ('envisions', 'NOUN'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('interest', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('will', 'AUX'),
#   ('increase', 'VERB'),
#   ('from', 'ADP'),
#   ('2', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PART'),
#   ('4', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2028', 'NUM'),
#   ('.', 'PUNCT')],
#  [('policy', 'NOUN'),
#   ('senior', 'ADJ'),
#   ('level', 'NOUN'),
#   ('person', 'NOUN'),
#   (',', 'PUNCT'),
#   ('michael', 'PROPN'),
#   ('brown', 'PROPN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('08/20/2024', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('gdp', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('united', 'PROPN'),
#   ('states', 'PROPN'),
#   ('may', 'AUX'),
#   ('stay', 'VERB'),
#   ('stable', 'ADJ'),
#   ('at', 'ADP'),
#   ('$', 'SYM'),
#   ('20', 'NUM'),
#   ('trillion', 'NUM'),
#   ('in', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('policy', 'NOUN'),
#   ('top', 'ADJ'),
#   ('executive', 'NOUN'),
#   (',', 'PUNCT'),
#   ('robert', 'PROPN'),
#   ('williams', 'PROPN'),
#   (',', 'PUNCT'),
#   ('from', 'ADP'),
#   ('jpmorgan', 'PROPN'),
#   ('chase', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   ('-', 'SYM'),
#   ('22', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('number', 'NOUN'),
#   ('of', 'ADP'),
#   ('bank', 'NOUN'),
#   ('branches', 'NOUN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('decrease', 'VERB'),
#   ('beyond', 'ADP'),
#   ('5,000', 'NUM'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('q4', 'PROPN'),
#   ('of', 'ADP'),
#   ('2029', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('2025', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   ('-', 'SYM'),
#   ('20', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('inflation', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('european', 'PROPN'),
#   ('union', 'PROPN'),
#   ('has', 'AUX'),
#   ('a', 'DET'),
#   ('probability', 'NOUN'),
#   ('of', 'ADP'),
#   ('80', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PART'),
#   ('reach', 'VERB'),
#   ('3', 'NUM'),
#   ('%', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('policy', 'NOUN'),
#   ('reporter', 'NOUN'),
#   (',', 'PUNCT'),
#   ('sarah', 'PROPN'),
#   ('lee', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('.', 'PUNCT')],
#  [('on', 'ADP'),
#   ('2024/11/12', 'NUM'),
#   (',', 'PUNCT'),
#   ('policy', 'NOUN'),
#   ('expert', 'NOUN'),
#   (',', 'PUNCT'),
#   ('david', 'PROPN'),
#   ('white', 'PROPN'),
#   (',', 'PUNCT'),
#   ('forecasts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('exchange', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('european', 'PROPN'),
#   ('central', 'PROPN'),
#   ('bank', 'NOUN'),
#   ('will', 'AUX'),
#   ('likely', 'ADV'),
#   ('decrease', 'VERB'),
#   ('by', 'ADP'),
#   ('5', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('q1', 'PROPN'),
#   ('of', 'ADP'),
#   ('2027', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('q3', 'PROPN'),
#   ('of', 'ADP'),
#   ('2024', 'NUM'),
#   (',', 'PUNCT'),
#   ('policy', 'NOUN'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('kevin', 'PROPN'),
#   ('davis', 'PROPN'),
#   (',', 'PUNCT'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('international', 'ADJ'),
#   ('monetary', 'ADJ'),
#   ('fund', 'NOUN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('unemployment', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('will', 'AUX'),
#   ('fall', 'VERB'),
#   ('from', 'ADP'),
#   ('5', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PART'),
#   ('3', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2026', 'NUM'),
#   ('.', 'PUNCT')],
#  [('policy', 'NOUN'),
#   ('senior', 'ADJ'),
#   ('level', 'NOUN'),
#   ('person', 'NOUN'),
#   (',', 'PUNCT'),
#   ('olivia', 'ADJ'),
#   ('martinez', 'PROPN'),
#   (',', 'PUNCT'),
#   ('predicts', 'VERB'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('09', 'NUM'),
#   ('-', 'SYM'),
#   ('18', 'NUM'),
#   ('that', 'SCONJ'),
#   ('the', 'DET'),
#   ('national', 'ADJ'),
#   ('debt', 'NOUN'),
#   ('in', 'ADP'),
#   ('japan', 'PROPN'),
#   ('may', 'AUX'),
#   ('increase', 'VERB'),
#   ('by', 'ADP'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   ('in', 'ADP'),
#   ('2028', 'NUM'),
#   ('.', 'PUNCT')],
#  [('according', 'VERB'),
#   ('to', 'ADP'),
#   ('a', 'DET'),
#   ('policy', 'NOUN'),
#   ('top', 'ADJ'),
#   ('executive', 'NOUN'),
#   (',', 'PUNCT'),
#   ('james', 'PROPN'),
#   ('wilson', 'PROPN'),
#   (',', 'PUNCT'),
#   ('from', 'ADP'),
#   ('citigroup', 'NOUN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('10', 'NUM'),
#   ('-', 'SYM'),
#   ('25', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('number', 'NOUN'),
#   ('of', 'ADP'),
#   ('credit', 'NOUN'),
#   ('card', 'NOUN'),
#   ('holders', 'NOUN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('rise', 'VERB'),
#   ('beyond', 'ADP'),
#   ('100', 'NUM'),
#   ('million', 'NUM'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('timeframe', 'NOUN'),
#   ('of', 'ADP'),
#   ('q2', 'NOUN'),
#   ('of', 'ADP'),
#   ('2030', 'NUM'),
#   ('.', 'PUNCT')],
#  [('in', 'ADP'),
#   ('q4', 'PROPN'),
#   ('of', 'ADP'),
#   ('2027', 'NUM'),
#   (',', 'PUNCT'),
#   ('the', 'DET'),
#   ('number', 'NOUN'),
#   ('of', 'ADP'),
#   ('initial', 'ADJ'),
#   ('public', 'ADJ'),
#   ('offerings', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('united', 'PROPN'),
#   ('states', 'PROPN'),
#   ('is', 'AUX'),
#   ('expected', 'VERB'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('500', 'NUM'),
#   (',', 'PUNCT'),
#   ('which', 'DET'),
#   ('is', 'AUX'),
#   ('a', 'DET'),
#   ('20', 'NUM'),
#   ('%', 'NOUN'),
#   ('increase', 'NOUN'),
#   (',', 'PUNCT'),
#   ('as', 'ADP'),
#   ('predicted', 'VERB'),
#   ('by', 'ADP'),
#   ('policy', 'NOUN'),
#   ('analyst', 'NOUN'),
#   (',', 'PUNCT'),
#   ('daniel', 'PROPN'),
#   ('kim', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'ADP'),
#   ('2024', 'NUM'),
#   ('-', 'SYM'),
#   ('08', 'NUM'),
#   ('-', 'SYM'),
#   ('15', 'NUM'),
#   ('.', 'PUNCT')]]

# %%
all_pos_tags
# Out:
# {'ADJ',
#  'ADP',
#  'ADV',
#  'AUX',
#  'CCONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PROPN',
#  'PUNCT',
#  'SCONJ',
#  'SYM',
#  'VERB'}

# %%
entities
# Out:
# [[('2024-10-15', 'DATE_1'),
#   ('rachel patel', 'PERSON_1'),
#   ('$5 billion to $10 billion', 'MONEY_1'),
#   ('2026', 'DATE_2')],
#  [('2024', 'DATE_1'),
#   ('julian sanchez', 'PERSON_1'),
#   ('bank of america', 'ORG_1'),
#   ('$50 to $75', 'MONEY_1'),
#   ('2028', 'DATE_2')],
#  [('emily wilson', 'PERSON_1'),
#   ('20/08/2024', 'DATE_1'),
#   ('$15 million', 'MONEY_1'),
#   ('2029', 'DATE_2')],
#  [('cisco', 'GPE_1'),
#   ('2024/08/20', 'CARDINAL_1'),
#   ('$8 billion', 'MONEY_1'),
#   ('2027', 'DATE_1')],
#  [('2025-02-18', 'DATE_1'),
#   ('20 percent', 'PERCENT_1'),
#   ('$25 billion', 'MONEY_1'),
#   ('10%', 'PERCENT_2'),
#   ('david lee', 'PERSON_1'),
#   ('15 oct 2024', 'DATE_2')],
#  [('wednesday, november 20, 2024', 'DATE_1'),
#   ('michael davis', 'PERSON_1'),
#   ('3', 'CARDINAL_1'),
#   ('15%', 'PERCENT_1'),
#   ('$12 billion', 'MONEY_1'),
#   ('2026', 'DATE_2')],
#  [('q3 of 2024', 'DATE_1'),
#   ('johnson & johnson', 'ORG_1'),
#   ('$10 billion to $15 billion', 'MONEY_1'),
#   ('2028', 'DATE_2')],
#  [('kevin white', 'PERSON_1'),
#   ('10/10/2024', 'DATE_1'),
#   ('at&t', 'ORG_1'),
#   ('$5 billion to $20 billion', 'MONEY_1'),
#   ('2027', 'DATE_2')],
#  [('intel', 'ORG_1'),
#   ('2024-07-25', 'DATE_1'),
#   ('$12 billion', 'MONEY_1'),
#   ('2029', 'DATE_2')],
#  [('2026-08-25', 'DATE_1'),
#   ("mcdonald's", 'ORG_1'),
#   ('200', 'MONEY_1'),
#   ('25%', 'PERCENT_1'),
#   ('25 july 2024', 'DATE_2')],
#  [('2024-10-15', 'DATE_1'),
#   ('rachel kim', 'PERSON_1'),
#   ('los angeles', 'GPE_1'),
#   ('15%', 'PERCENT_1'),
#   ('2026', 'DATE_2')],
#  [('2024-08', 'DATE_1'),
#   ('the european centre', 'ORG_1'),
#   ('beijing', 'GPE_1'),
#   ('12%', 'PERCENT_1'),
#   ('2027-03', 'DATE_2')],
#  [('michael davis', 'PERSON_1'),
#   ('2024-09-20', 'DATE_1'),
#   ('sydney', 'GPE_1'),
#   ('8°', 'CARDINAL_1'),
#   ('2025-09', 'DATE_2')],
#  [('2024-11-01', 'DATE_1'),
#   ('tokyo', 'GPE_1'),
#   ('20 mph', 'QUANTITY_1'),
#   ('2026-06', 'DATE_2')],
#  [('2028-02', 'DATE_1'),
#   ('miami', 'GPE_1'),
#   ('10%', 'PERCENT_1'),
#   ('2 inches', 'QUANTITY_1'),
#   ('lisa nguyen', 'PERSON_1'),
#   ('2024-07-15', 'DATE_2')],
#  [('2024-12-25', 'DATE_1'),
#   ('james lee', 'PERSON_1'),
#   ('korean', 'NORP_1'),
#   ('new york city', 'GPE_1'),
#   ('5 inches', 'QUANTITY_1'),
#   ('2027', 'DATE_2')],
#  [('2025-01', 'DATE_1'),
#   ('david taylor', 'PERSON_1'),
#   ('the australian bureau', 'ORG_1'),
#   ('15%', 'PERCENT_1'),
#   ('2026-10', 'DATE_2')],
#  [('sophia patel', 'PERSON_1'),
#   ('indian', 'NORP_1'),
#   ('2024-06-01', 'DATE_1'),
#   ('mumbai', 'GPE_1'),
#   ('5°', 'CARDINAL_1'),
#   ('2027-05', 'DATE_2')],
#  [('chinese', 'NORP_1'),
#   ('2024-03-15', 'DATE_1'),
#   ('shanghai', 'GPE_1'),
#   ('20%', 'PERCENT_1'),
#   ('2026-08', 'DATE_2')],
#  [('2029-04', 'DATE_1'),
#   ('chicago', 'GPE_1'),
#   ('12%', 'PERCENT_1'),
#   ('8°f', 'CARDINAL_1'),
#   ('kevin white', 'PERSON_1'),
#   ('2024-02-20', 'DATE_2')],
#  [('2024-10-15', 'DATE_1'),
#   ('david lee', 'PERSON_1'),
#   ('american', 'NORP_1'),
#   ('10%', 'PERCENT_1'),
#   ('2026', 'DATE_2')],
#  [('2024', 'DATE_1'),
#   ('maria', 'PERSON_1'),
#   ('72 to 75 years', 'DATE_2'),
#   ('2028', 'DATE_3')],
#  [('dr.', 'PERSON_1'),
#   ('john smith', 'PERSON_2'),
#   ('the united states', 'GPE_1'),
#   ('20%', 'PERCENT_1'),
#   ('2027', 'DATE_1')],
#  [('emily chen', 'PERSON_1'),
#   ('21', 'CARDINAL_1'),
#   ('2024', 'DATE_1'),
#   ('25%', 'PERCENT_1'),
#   ('2029', 'DATE_2')],
#  [('2025', 'DATE_1'),
#   ('daily', 'DATE_2'),
#   ('australia', 'GPE_1'),
#   ('15%', 'PERCENT_1'),
#   ('michael brown', 'PERSON_1'),
#   ('2024-10-10', 'DATE_3')],
#  [('2024/11/12', 'DATE_1'),
#   ('sophia patel', 'PERSON_1'),
#   ('the mayo clinic', 'ORG_1'),
#   ('12%', 'PERCENT_1'),
#   ('2026', 'DATE_2')],
#  [('2025', 'DATE_1'),
#   ('kevin white', 'PERSON_1'),
#   ('american', 'NORP_1'),
#   ('daily', 'DATE_2'),
#   ('2500 to', 'CARDINAL_1'),
#   ('2000', 'DATE_3'),
#   ('quarter 2 of 2028', 'DATE_4')],
#  [('dr.', 'PERSON_1'),
#   ('lisa nguyen', 'PERSON_2'),
#   ('2024-08-25', 'DATE_1'),
#   ('the european union', 'ORG_1'),
#   ('15%', 'PERCENT_1'),
#   ('2027', 'DATE_2')],
#  [('daniel kim', 'PERSON_1'),
#   ('the university of california', 'ORG_1'),
#   ('10/15/2024', 'DATE_1'),
#   ('30%', 'PERCENT_1'),
#   ('2030', 'DATE_2')],
#  [('2029-08-20', 'DATE_1'),
#   ('weekly', 'DATE_2'),
#   ('canada', 'GPE_1'),
#   ('20%', 'PERCENT_1'),
#   ('dr.', 'PERSON_1'),
#   ('olivia martin', 'PERSON_2'),
#   ('the canadian medical association', 'ORG_1'),
#   ('2024/10/20', 'CARDINAL_1')],
#  [('2024-10-15', 'DATE_1'),
#   ('john smith', 'PERSON_1'),
#   ('10%', 'PERCENT_1'),
#   ('2026', 'DATE_2')],
#  [('2024', 'DATE_1'),
#   ('emily johnson', 'PERSON_1'),
#   ('the federal reserve', 'ORG_1'),
#   ('2% to 4%', 'PERCENT_1'),
#   ('2028', 'DATE_2')],
#  [('michael brown', 'PERSON_1'),
#   ('the united states', 'GPE_1'),
#   ('$20 trillion', 'MONEY_1'),
#   ('2027', 'DATE_1')],
#  [('robert williams', 'PERSON_1'),
#   ('jpmorgan chase', 'ORG_1'),
#   ('2024-08-22', 'DATE_1'),
#   ('5,000', 'CARDINAL_1'),
#   ('2029', 'DATE_2')],
#  [('2025-08-20', 'DATE_1'),
#   ('the european union', 'ORG_1'),
#   ('80%', 'PERCENT_1'),
#   ('3%', 'PERCENT_2'),
#   ('sarah lee', 'PERSON_1'),
#   ('2024-10-10', 'DATE_2')],
#  [('2024/11/12', 'DATE_1'),
#   ('david white', 'PERSON_1'),
#   ('the european central bank', 'ORG_1'),
#   ('5%', 'PERCENT_1'),
#   ('2027', 'DATE_2')],
#  [('q3 of 2024', 'DATE_1'),
#   ('kevin davis', 'PERSON_1'),
#   ('5% to 3%', 'PERCENT_1'),
#   ('2026', 'DATE_2')],
#  [('olivia martinez', 'PERSON_1'),
#   ('2024-09-18', 'DATE_1'),
#   ('japan', 'GPE_1'),
#   ('10%', 'PERCENT_1'),
#   ('2028', 'DATE_2')],
#  [('james wilson', 'PERSON_1'),
#   ('2024-10-25', 'DATE_1'),
#   ('100 million', 'CARDINAL_1'),
#   ('2030', 'DATE_2')],
#  [('2027', 'DATE_1'),
#   ('the united states', 'GPE_1'),
#   ('500', 'CARDINAL_1'),
#   ('20%', 'PERCENT_1'),
#   ('daniel kim', 'PERSON_1'),
#   ('2024-08-15', 'DATE_2')]]

# %%
all_ner_entities
# Out:
# {'CARDINAL_1',
#  'DATE_1',
#  'DATE_2',
#  'DATE_3',
#  'DATE_4',
#  'GPE_1',
#  'MONEY_1',
#  'NORP_1',
#  'ORG_1',
#  'PERCENT_1',
#  'PERCENT_2',
#  'PERSON_1',
#  'PERSON_2',
#  'QUANTITY_1'}

# %%
# ['on 2024-10-15, rachel patel, a financial analyst, predicts that the operating cash flow at general motors will likely decrease by $5 billion to $10 billion in q2 of 2026.',

# ['on 2024-10-15,  patel, a financial analyst, predicts that  operating cash flow at  motors    by 5 billion to $10 billion in   .',

# %% [markdown]
# "to" isn't in "on 2024-10-15, rachel patel, a financial analyst, predicts that the operating cash flow at general motors will likely decrease by $5 billion to $10 billion in q2 of 2026."

# %%
pos_df = DataProcessing.tags_to_dataframe(tags, all_pos_tags)
pos_df
# Out:
#     DET   NUM     ADV  SYM             ADJ CCONJ ADP SCONJ         NOUN PUNCT  \
# 0   the  2026  likely    $         general   NaN  of  that           q2     .
# 1   the  2028     NaN    $          julian   NaN  in  that        share     .
# 2   the  2029     NaN    $          stable   and  in  that       pfizer     .
# 3   the  2027     NaN    $             net   NaN  of   NaN    timeframe     .
# 4     a  2024     NaN    $       financial   NaN  on   NaN     reporter     .
# 5   the  2026  likely    $           gross   NaN  of  that            %     .
# 6   the  2028     NaN    $          olivia     &  in  that       income     .
# 7   the  2027     NaN    $       financial   NaN  in  that      revenue     .
# 8   the  2029     NaN    $             net   NaN  of   NaN           q2     .
# 9     a  2024     NaN    $       financial   NaN  on   NaN      analyst     .
# 10  the  2026  likely    -     atmospheric   and  of  that           q2     .
# 11  the    03   emily    -          medium   NaN  in  that            %     .
# 12  the    09     NaN    -  meteorological   NaN  of  that    timeframe     .
# 13  the    06     NaN    -  meteorological   NaN  of   NaN    timeframe     .
# 14  the    15     NaN    -        national   NaN  on   NaN      service     .
# 15  the  2027  likely    -  meteorological   NaN  of  that       inches     .
# 16  the    10     NaN    -      australian   NaN  in  that            %     .
# 17  the    05     NaN    -             NaN   NaN  of  that    timeframe     .
# 18  the    08     NaN    -  meteorological   NaN  of   NaN    timeframe     .
# 19  the    20     NaN    -   environmental   NaN  on   NaN   prediction     .
# 20  the  2026  likely    -         average   NaN  of  that           q2     .
# 21  the  2028     NaN  NaN          global   NaN  in  that        years     .
# 22  the  2027     NaN  NaN          stable   NaN  in  that            %     .
# 23  the  2029     NaN  NaN             NaN   and  of   NaN    timeframe     .
# 24  the    10     NaN    -           daily   NaN  on   NaN       health     .
# 25  the  2026  likely  NaN             NaN   NaN  in  that            %     .
# 26  the  2028     NaN  NaN           daily   NaN  of  that      quarter     .
# 27  the  2027     NaN    -          global   NaN  in   NaN            %     .
# 28  the  2030     NaN  NaN         chronic   NaN  of   NaN    timeframe     .
# 29  the    20     NaN    -         medical   NaN  on   NaN  association     .
# 30  the  2026     NaN    -             NaN   NaN  of  that           q2     .
# 31  the  2028     NaN  NaN             NaN   NaN  in  that            %     .
# 32  the  2027     NaN    $          stable   NaN  in  that          gdp     .
# 33  the  2029     NaN    -             top   NaN  of   NaN    timeframe     .
# 34    a    10     NaN    -             NaN   NaN  on   NaN     reporter     .
# 35  the  2027  likely  NaN             NaN   NaN  of  that            %     .
# 36  the  2026     NaN  NaN        monetary   NaN  in  that            %     .
# 37  the  2028     NaN    -        national   NaN  in  that            %     .
# 38  the  2030     NaN    -             top   NaN  of   NaN           q2     .
# 39    a    15     NaN    -          public   NaN  on   NaN      analyst     .
#
#        AUX  PRON       VERB        PROPN PART
# 0     will   NaN   decrease       rachel   to
# 1     will   NaN       rise      america   to
# 2      may   NaN       stay       wilson  NaN
# 3       is   NaN   increase           q4   to
# 4       is   NaN  predicted          oct   to
# 5     will   NaN   decrease           q1   to
# 6     will   NaN       rise      johnson   to
# 7      may   NaN   increase         at&t   to
# 8       is   NaN   increase        intel   to
# 9       is   NaN  predicted         july   to
# 10    will   NaN   increase      angeles  NaN
# 11  should   NaN   decrease      beijing  NaN
# 12    will   NaN       fall            c  NaN
# 13      is   NaN       rise        tokyo   to
# 14     has   NaN  predicted       nguyen   to
# 15    will   NaN   decrease           q1  NaN
# 16    will   NaN    improve  meteorology  NaN
# 17    will   NaN       rise            c  NaN
# 18      is   NaN   increase     shanghai   to
# 19     has   NaN  predicted        white   to
# 20    will   NaN   decrease     american  NaN
# 21     may   NaN       rise    rodriguez   to
# 22  should   NaN       stay       states  NaN
# 23      is   NaN   increase           q4   to
# 24      is   NaN  predicted   institutes   to
# 25    will   NaN   increase         mayo  NaN
# 26     may   NaN       fall        white  NaN
# 27  should  that   increase        union  NaN
# 28      is   NaN   decrease           q3   to
# 29      is   NaN  predicted   2024/10/20   to
# 30    will   NaN       rise        smith  NaN
# 31    will   NaN   increase      reserve   to
# 32     may   NaN       stay       states  NaN
# 33      is   NaN   decrease           q4   to
# 34     has   NaN  predicted          lee   to
# 35    will   NaN   decrease           q1  NaN
# 36    will   NaN       fall        davis   to
# 37     may   NaN   increase        japan  NaN
# 38      is   NaN       rise       wilson   to
# 39      is   NaN  predicted          kim   to

# %%
ner_df = DataProcessing.entities_to_dataframe(entities, all_ner_entities)
ner_df
# Out:
#      CARDINAL_1    NORP_1                        DATE_1      DATE_3  \
# 0           NaN       NaN                    2024-10-15         NaN
# 1           NaN       NaN                          2024         NaN
# 2           NaN       NaN                    20/08/2024         NaN
# 3    2024/08/20       NaN                          2027         NaN
# 4           NaN       NaN                    2025-02-18         NaN
# 5             3       NaN  wednesday, november 20, 2024         NaN
# 6           NaN       NaN                    q3 of 2024         NaN
# 7           NaN       NaN                    10/10/2024         NaN
# 8           NaN       NaN                    2024-07-25         NaN
# 9           NaN       NaN                    2026-08-25         NaN
# 10          NaN       NaN                    2024-10-15         NaN
# 11          NaN       NaN                       2024-08         NaN
# 12           8°       NaN                    2024-09-20         NaN
# 13          NaN       NaN                    2024-11-01         NaN
# 14          NaN       NaN                       2028-02         NaN
# 15          NaN    korean                    2024-12-25         NaN
# 16          NaN       NaN                       2025-01         NaN
# 17           5°    indian                    2024-06-01         NaN
# 18          NaN   chinese                    2024-03-15         NaN
# 19          8°f       NaN                       2029-04         NaN
# 20          NaN  american                    2024-10-15         NaN
# 21          NaN       NaN                          2024        2028
# 22          NaN       NaN                          2027         NaN
# 23           21       NaN                          2024         NaN
# 24          NaN       NaN                          2025  2024-10-10
# 25          NaN       NaN                    2024/11/12         NaN
# 26      2500 to  american                          2025        2000
# 27          NaN       NaN                    2024-08-25         NaN
# 28          NaN       NaN                    10/15/2024         NaN
# 29   2024/10/20       NaN                    2029-08-20         NaN
# 30          NaN       NaN                    2024-10-15         NaN
# 31          NaN       NaN                          2024         NaN
# 32          NaN       NaN                          2027         NaN
# 33        5,000       NaN                    2024-08-22         NaN
# 34          NaN       NaN                    2025-08-20         NaN
# 35          NaN       NaN                    2024/11/12         NaN
# 36          NaN       NaN                    q3 of 2024         NaN
# 37          NaN       NaN                    2024-09-18         NaN
# 38  100 million       NaN                    2024-10-25         NaN
# 39          500       NaN                          2027         NaN
#
#             DATE_2         PERSON_1                             ORG_1  \
# 0             2026     rachel patel                               NaN
# 1             2028   julian sanchez                   bank of america
# 2             2029     emily wilson                               NaN
# 3              NaN              NaN                               NaN
# 4      15 oct 2024        david lee                               NaN
# 5             2026    michael davis                               NaN
# 6             2028              NaN                 johnson & johnson
# 7             2027      kevin white                              at&t
# 8             2029              NaN                             intel
# 9     25 july 2024              NaN                        mcdonald's
# 10            2026       rachel kim                               NaN
# 11         2027-03              NaN               the european centre
# 12         2025-09    michael davis                               NaN
# 13         2026-06              NaN                               NaN
# 14      2024-07-15      lisa nguyen                               NaN
# 15            2027        james lee                               NaN
# 16         2026-10     david taylor             the australian bureau
# 17         2027-05     sophia patel                               NaN
# 18         2026-08              NaN                               NaN
# 19      2024-02-20      kevin white                               NaN
# 20            2026        david lee                               NaN
# 21  72 to 75 years            maria                               NaN
# 22             NaN              dr.                               NaN
# 23            2029       emily chen                               NaN
# 24           daily    michael brown                               NaN
# 25            2026     sophia patel                   the mayo clinic
# 26           daily      kevin white                               NaN
# 27            2027              dr.                the european union
# 28            2030       daniel kim      the university of california
# 29          weekly              dr.  the canadian medical association
# 30            2026       john smith                               NaN
# 31            2028    emily johnson               the federal reserve
# 32             NaN    michael brown                               NaN
# 33            2029  robert williams                    jpmorgan chase
# 34      2024-10-10        sarah lee                the european union
# 35            2027      david white         the european central bank
# 36            2026      kevin davis                               NaN
# 37            2028  olivia martinez                               NaN
# 38            2030     james wilson                               NaN
# 39      2024-08-15       daniel kim                               NaN
#
#    QUANTITY_1             DATE_4   PERCENT_1              GPE_1 PERCENT_2  \
# 0         NaN                NaN         NaN                NaN       NaN
# 1         NaN                NaN         NaN                NaN       NaN
# 2         NaN                NaN         NaN                NaN       NaN
# 3         NaN                NaN         NaN              cisco       NaN
# 4         NaN                NaN  20 percent                NaN       10%
# 5         NaN                NaN         15%                NaN       NaN
# 6         NaN                NaN         NaN                NaN       NaN
# 7         NaN                NaN         NaN                NaN       NaN
# 8         NaN                NaN         NaN                NaN       NaN
# 9         NaN                NaN         25%                NaN       NaN
# 10        NaN                NaN         15%        los angeles       NaN
# 11        NaN                NaN         12%            beijing       NaN
# 12        NaN                NaN         NaN             sydney       NaN
# 13     20 mph                NaN         NaN              tokyo       NaN
# 14   2 inches                NaN         10%              miami       NaN
# 15   5 inches                NaN         NaN      new york city       NaN
# 16        NaN                NaN         15%                NaN       NaN
# 17        NaN                NaN         NaN             mumbai       NaN
# 18        NaN                NaN         20%           shanghai       NaN
# 19        NaN                NaN         12%            chicago       NaN
# 20        NaN                NaN         10%                NaN       NaN
# 21        NaN                NaN         NaN                NaN       NaN
# 22        NaN                NaN         20%  the united states       NaN
# 23        NaN                NaN         25%                NaN       NaN
# 24        NaN                NaN         15%          australia       NaN
# 25        NaN                NaN         12%                NaN       NaN
# 26        NaN  quarter 2 of 2028         NaN                NaN       NaN
# 27        NaN                NaN         15%                NaN       NaN
# 28        NaN                NaN         30%                NaN       NaN
# 29        NaN                NaN         20%             canada       NaN
# 30        NaN                NaN         10%                NaN       NaN
# 31        NaN                NaN    2% to 4%                NaN       NaN
# 32        NaN                NaN         NaN  the united states       NaN
# 33        NaN                NaN         NaN                NaN       NaN
# 34        NaN                NaN         80%                NaN        3%
# 35        NaN                NaN          5%                NaN       NaN
# 36        NaN                NaN    5% to 3%                NaN       NaN
# 37        NaN                NaN         10%              japan       NaN
# 38        NaN                NaN         NaN                NaN       NaN
# 39        NaN                NaN         20%  the united states       NaN
#
#          PERSON_2                     MONEY_1
# 0             NaN   $5 billion to $10 billion
# 1             NaN                  $50 to $75
# 2             NaN                 $15 million
# 3             NaN                  $8 billion
# 4             NaN                 $25 billion
# 5             NaN                 $12 billion
# 6             NaN  $10 billion to $15 billion
# 7             NaN   $5 billion to $20 billion
# 8             NaN                 $12 billion
# 9             NaN                         200
# 10            NaN                         NaN
# 11            NaN                         NaN
# 12            NaN                         NaN
# 13            NaN                         NaN
# 14            NaN                         NaN
# 15            NaN                         NaN
# 16            NaN                         NaN
# 17            NaN                         NaN
# 18            NaN                         NaN
# 19            NaN                         NaN
# 20            NaN                         NaN
# 21            NaN                         NaN
# 22     john smith                         NaN
# 23            NaN                         NaN
# 24            NaN                         NaN
# 25            NaN                         NaN
# 26            NaN                         NaN
# 27    lisa nguyen                         NaN
# 28            NaN                         NaN
# 29  olivia martin                         NaN
# 30            NaN                         NaN
# 31            NaN                         NaN
# 32            NaN                $20 trillion
# 33            NaN                         NaN
# 34            NaN                         NaN
# 35            NaN                         NaN
# 36            NaN                         NaN
# 37            NaN                         NaN
# 38            NaN                         NaN
# 39            NaN                         NaN

# %% [markdown]
# - Need to clean. I don't think we're capturing all of the words for both POS and NER.

# %%
sentence_level_tags_entities = [pos_df, ner_df]
sentence_level_tags_entities_df = DataProcessing.concat_dfs(sentence_level_tags_entities, axis=1, ignore_index=False)
sentence_level_tags_entities_df
# Out:
#     DET   NUM     ADV  SYM             ADJ CCONJ ADP SCONJ         NOUN PUNCT  \
# 0   the  2026  likely    $         general   NaN  of  that           q2     .
# 1   the  2028     NaN    $          julian   NaN  in  that        share     .
# 2   the  2029     NaN    $          stable   and  in  that       pfizer     .
# 3   the  2027     NaN    $             net   NaN  of   NaN    timeframe     .
# 4     a  2024     NaN    $       financial   NaN  on   NaN     reporter     .
# 5   the  2026  likely    $           gross   NaN  of  that            %     .
# 6   the  2028     NaN    $          olivia     &  in  that       income     .
# 7   the  2027     NaN    $       financial   NaN  in  that      revenue     .
# 8   the  2029     NaN    $             net   NaN  of   NaN           q2     .
# 9     a  2024     NaN    $       financial   NaN  on   NaN      analyst     .
# 10  the  2026  likely    -     atmospheric   and  of  that           q2     .
# 11  the    03   emily    -          medium   NaN  in  that            %     .
# 12  the    09     NaN    -  meteorological   NaN  of  that    timeframe     .
# 13  the    06     NaN    -  meteorological   NaN  of   NaN    timeframe     .
# 14  the    15     NaN    -        national   NaN  on   NaN      service     .
# 15  the  2027  likely    -  meteorological   NaN  of  that       inches     .
# 16  the    10     NaN    -      australian   NaN  in  that            %     .
# 17  the    05     NaN    -             NaN   NaN  of  that    timeframe     .
# 18  the    08     NaN    -  meteorological   NaN  of   NaN    timeframe     .
# 19  the    20     NaN    -   environmental   NaN  on   NaN   prediction     .
# 20  the  2026  likely    -         average   NaN  of  that           q2     .
# 21  the  2028     NaN  NaN          global   NaN  in  that        years     .
# 22  the  2027     NaN  NaN          stable   NaN  in  that            %     .
# 23  the  2029     NaN  NaN             NaN   and  of   NaN    timeframe     .
# 24  the    10     NaN    -           daily   NaN  on   NaN       health     .
# 25  the  2026  likely  NaN             NaN   NaN  in  that            %     .
# 26  the  2028     NaN  NaN           daily   NaN  of  that      quarter     .
# 27  the  2027     NaN    -          global   NaN  in   NaN            %     .
# 28  the  2030     NaN  NaN         chronic   NaN  of   NaN    timeframe     .
# 29  the    20     NaN    -         medical   NaN  on   NaN  association     .
# 30  the  2026     NaN    -             NaN   NaN  of  that           q2     .
# 31  the  2028     NaN  NaN             NaN   NaN  in  that            %     .
# 32  the  2027     NaN    $          stable   NaN  in  that          gdp     .
# 33  the  2029     NaN    -             top   NaN  of   NaN    timeframe     .
# 34    a    10     NaN    -             NaN   NaN  on   NaN     reporter     .
# 35  the  2027  likely  NaN             NaN   NaN  of  that            %     .
# 36  the  2026     NaN  NaN        monetary   NaN  in  that            %     .
# 37  the  2028     NaN    -        national   NaN  in  that            %     .
# 38  the  2030     NaN    -             top   NaN  of   NaN           q2     .
# 39    a    15     NaN    -          public   NaN  on   NaN      analyst     .
#
#     ...          DATE_2         PERSON_1                             ORG_1  \
# 0   ...            2026     rachel patel                               NaN
# 1   ...            2028   julian sanchez                   bank of america
# 2   ...            2029     emily wilson                               NaN
# 3   ...             NaN              NaN                               NaN
# 4   ...     15 oct 2024        david lee                               NaN
# 5   ...            2026    michael davis                               NaN
# 6   ...            2028              NaN                 johnson & johnson
# 7   ...            2027      kevin white                              at&t
# 8   ...            2029              NaN                             intel
# 9   ...    25 july 2024              NaN                        mcdonald's
# 10  ...            2026       rachel kim                               NaN
# 11  ...         2027-03              NaN               the european centre
# 12  ...         2025-09    michael davis                               NaN
# 13  ...         2026-06              NaN                               NaN
# 14  ...      2024-07-15      lisa nguyen                               NaN
# 15  ...            2027        james lee                               NaN
# 16  ...         2026-10     david taylor             the australian bureau
# 17  ...         2027-05     sophia patel                               NaN
# 18  ...         2026-08              NaN                               NaN
# 19  ...      2024-02-20      kevin white                               NaN
# 20  ...            2026        david lee                               NaN
# 21  ...  72 to 75 years            maria                               NaN
# 22  ...             NaN              dr.                               NaN
# 23  ...            2029       emily chen                               NaN
# 24  ...           daily    michael brown                               NaN
# 25  ...            2026     sophia patel                   the mayo clinic
# 26  ...           daily      kevin white                               NaN
# 27  ...            2027              dr.                the european union
# 28  ...            2030       daniel kim      the university of california
# 29  ...          weekly              dr.  the canadian medical association
# 30  ...            2026       john smith                               NaN
# 31  ...            2028    emily johnson               the federal reserve
# 32  ...             NaN    michael brown                               NaN
# 33  ...            2029  robert williams                    jpmorgan chase
# 34  ...      2024-10-10        sarah lee                the european union
# 35  ...            2027      david white         the european central bank
# 36  ...            2026      kevin davis                               NaN
# 37  ...            2028  olivia martinez                               NaN
# 38  ...            2030     james wilson                               NaN
# 39  ...      2024-08-15       daniel kim                               NaN
#
#    QUANTITY_1             DATE_4   PERCENT_1              GPE_1 PERCENT_2  \
# 0         NaN                NaN         NaN                NaN       NaN
# 1         NaN                NaN         NaN                NaN       NaN
# 2         NaN                NaN         NaN                NaN       NaN
# 3         NaN                NaN         NaN              cisco       NaN
# 4         NaN                NaN  20 percent                NaN       10%
# 5         NaN                NaN         15%                NaN       NaN
# 6         NaN                NaN         NaN                NaN       NaN
# 7         NaN                NaN         NaN                NaN       NaN
# 8         NaN                NaN         NaN                NaN       NaN
# 9         NaN                NaN         25%                NaN       NaN
# 10        NaN                NaN         15%        los angeles       NaN
# 11        NaN                NaN         12%            beijing       NaN
# 12        NaN                NaN         NaN             sydney       NaN
# 13     20 mph                NaN         NaN              tokyo       NaN
# 14   2 inches                NaN         10%              miami       NaN
# 15   5 inches                NaN         NaN      new york city       NaN
# 16        NaN                NaN         15%                NaN       NaN
# 17        NaN                NaN         NaN             mumbai       NaN
# 18        NaN                NaN         20%           shanghai       NaN
# 19        NaN                NaN         12%            chicago       NaN
# 20        NaN                NaN         10%                NaN       NaN
# 21        NaN                NaN         NaN                NaN       NaN
# 22        NaN                NaN         20%  the united states       NaN
# 23        NaN                NaN         25%                NaN       NaN
# 24        NaN                NaN         15%          australia       NaN
# 25        NaN                NaN         12%                NaN       NaN
# 26        NaN  quarter 2 of 2028         NaN                NaN       NaN
# 27        NaN                NaN         15%                NaN       NaN
# 28        NaN                NaN         30%                NaN       NaN
# 29        NaN                NaN         20%             canada       NaN
# 30        NaN                NaN         10%                NaN       NaN
# 31        NaN                NaN    2% to 4%                NaN       NaN
# 32        NaN                NaN         NaN  the united states       NaN
# 33        NaN                NaN         NaN                NaN       NaN
# 34        NaN                NaN         80%                NaN        3%
# 35        NaN                NaN          5%                NaN       NaN
# 36        NaN                NaN    5% to 3%                NaN       NaN
# 37        NaN                NaN         10%              japan       NaN
# 38        NaN                NaN         NaN                NaN       NaN
# 39        NaN                NaN         20%  the united states       NaN
#
#          PERSON_2                     MONEY_1
# 0             NaN   $5 billion to $10 billion
# 1             NaN                  $50 to $75
# 2             NaN                 $15 million
# 3             NaN                  $8 billion
# 4             NaN                 $25 billion
# 5             NaN                 $12 billion
# 6             NaN  $10 billion to $15 billion
# 7             NaN   $5 billion to $20 billion
# 8             NaN                 $12 billion
# 9             NaN                         200
# 10            NaN                         NaN
# 11            NaN                         NaN
# 12            NaN                         NaN
# 13            NaN                         NaN
# 14            NaN                         NaN
# 15            NaN                         NaN
# 16            NaN                         NaN
# 17            NaN                         NaN
# 18            NaN                         NaN
# 19            NaN                         NaN
# 20            NaN                         NaN
# 21            NaN                         NaN
# 22     john smith                         NaN
# 23            NaN                         NaN
# 24            NaN                         NaN
# 25            NaN                         NaN
# 26            NaN                         NaN
# 27    lisa nguyen                         NaN
# 28            NaN                         NaN
# 29  olivia martin                         NaN
# 30            NaN                         NaN
# 31            NaN                         NaN
# 32            NaN                $20 trillion
# 33            NaN                         NaN
# 34            NaN                         NaN
# 35            NaN                         NaN
# 36            NaN                         NaN
# 37            NaN                         NaN
# 38            NaN                         NaN
# 39            NaN                         NaN
#
# [40 rows x 29 columns]

# %% [markdown]
# ## Play
#
# - Remove once finalized

# %%
pos_col_names = list(pos_df.columns)
for pos_col_name in pos_col_names:
    print(f"pos_col_name: {spacy.explain(pos_col_name)}")

# %%
list(ner_df.columns)

# %%
ner_col_names = list(ner_df.columns)
for ner_col_name in ner_col_names:
    print(ner_col_name)
    print(f"ner_col_name: {spacy.explain(ner_col_name)}")

# %% [markdown]
# - Patterns:
#     - P1 goes to ?
#         - $: SYM
#         - 10: NUM
#     - P2 goes to ?
#         - 2024: NUM
#         - -: SYM
#         - 10: NUM
#         - -: SYM
#         - 20: NUM
# - Write regex for \$\d+ and \d+-\d+-\d+? -> Manually label?
#
# - Create new function in clean_predictions.py called `remove_symbols`

# %%
texts = ["On [2024-10-20], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [10 percent to $25 billion] in [2026 Q2]"]

texts_2 = "On [2024-10-20], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [$10 percent to $25 billion] in [2026 Q2]"

texts_2 = "On [2024-10-20] $10 percent to $25 billion]"

texts_2_no_brackets = [texts_2.replace('[', '').replace(']', '')]
# ",".join(texts_2_no_brackets)
# print(texts_2_no_brackets)

# text_join = texts_2_no_brackets.split()
# print(text_join)

nlp = spacy.load("en_core_web_sm")
def extract_entities(data: pd.Series, nlp: spacy.Language):
    """
    Extract entities using the provided SpaCy NLP model.

    Parameters:
    -----------
    data : `pd.Series`
        A Series containing textual data for entity extraction.
    nlp : `spacy.Language`
        A SpaCy NLP model.

    Returns:
    --------
    tuple
        A tuple containing a list of entities and a set of unique NER tags.
    """
    entities = []
    all_ner_tags = set()
    label_counts = {}

    for doc in nlp.pipe(data, disable=["ner"]):
        # doc_entities = []
        # for ent in doc.ents:
        #     label = ent.label_
        #     text = ent.text
        #     print(label, text)
        print(doc)
        for token in doc:
            print(f"{token.text}: {token.pos_}")

        # entities.append(doc_entities)

    return entities, all_ner_tags

# extract_entities(texts, nlp)
# print()
print(texts_2_no_brackets)
extract_entities(texts_2_no_brackets, nlp)

# %% [markdown]
# 2024: NUM
# -: SYM
# 10: NUM
# -: SYM
# 20: NUM
#
#
# Create NER DATE from this
#
# 10: NUM
# percent: NOUN
#
# Johnson: PROPN
# &: CCONJ
# Johnson: PROPN
