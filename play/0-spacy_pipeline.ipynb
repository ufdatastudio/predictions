# %% [markdown]
# # Spacy Pipeline
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To extract named entities (NER), part-of-speech (POS), etc.
#     1. Use to train model as feature extraction (ie: TF x IDF) alone isn't enough
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys
import spacy

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %%
pd.set_option('max_colwidth', 800)
nlp = spacy.load("en_core_web_sm")
# %store -r predictions_df
# %store -r non_predictions_df

# %%
predictions_df
# Out:
#                                                                                                                                                                                                                            Base Sentence  \
# 0                                     T1: On [2024-10-15], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [10 percent to $20 billion] in [2026 Q2].
# 1                                                                                          T2: In [Q4 of 2024], [Ethan Kim] from [Bloomberg], forecasts that the [stock price] [will] [fall] from [$500 to $300 per share] in [2028 Q1].
# 2                                                              T3: [Ava Morales, a financial expert] predicts on [2024/08/20] that the [research and development expenses] at [Intel] [may] [stay stable] at [$15 million] in [2027 Q3].
# 3                                                                  T4: According to a [senior executive] from [Coca-Cola], on [21 Aug 2024], the [net profit] [is expected to] [rise] beyond [$5 billion] in the timeframe of [2029 Q4].
# 4                                                     T5: In [2025-02-15], the [revenue] at [Visa] [is expected] to [increase] by [15 percent to $25 billion] [rise], as predicted by [Liam Chen, a financial reporter] on [2024-08-22].
# 5                                         T1: On [Wednesday, November 20, 2024], [Julian Lee, an investor] predicts that the [gross profit] at [UnitedHealth Group] [will likely] [decrease] by [5 percent to $10 billion] in [2026 Q4].
# 6                                                                        T2: In [2027 Q2], [Sophia Patel] from [Morgan Stanley], envisions that the [operating income] [will] [increase] from [$10 billion to $15 billion] in [2028 Q3].
# 7                                                                   T3: [Noah Brooks, a financial analyst] predicts on [2024/10/18] that the [net profit] at [Procter & Gamble] [may] [fall] by [10 percent to $5 billion] in [2027 Q2].
# 8                                                                          T4: According to a [top executive] from [AT&T], on [2024-08-25], the [revenue] [is expected to] [stay stable] at [$40 billion] in the timeframe of [2029 Q1].
# 9                                        T5: In [2026-08-20], the [stock price] at [McDonald's] [has a probability] of [20 percent to reach $250 per share] [rise], as predicted by [Jackson Brown, a financial expert] on [2024-10-12].
# 10  T1: On [2024-10-20], [Emily Chen], a senior meteorologist at [National Weather Service], forecasts that the [precipitation levels] at [National Weather Service] in [Los Angeles] [will likely] [increase] by [15%] in [2025-02-15].
# 11                                                                     T2: In [Q4 of 2024], [Michael Brown] from [Weather.com] in [New York City], predicts that the [temperature] [will] [decrease] from [10°C to 5°C] in [2025-01-10].
# 12                                                                     T3: [Sarah Taylor], a weather expert from [Bureau of Meteorology], predicts on [2024/08/25] that the [humidity] in [Chicago] [will] [rise] by [20%] in [2025 Q2].
# 13                                                   T4: According to a [weather analyst] from [AccuWeather], on [2024-08-18], the [wind speed] in [Miami] [is expected to] [increase] beyond [10 mph] in the timeframe of [2025-03-01].
# 14                                 T5: In [2027-08-20], the [average precipitation] in [Seattle] [is likely to] [decrease] by [5%], as predicted by [James Davis], a weather reporter from [Meteorological Department], on [2024-09-15].
# 15                         T1: On [21 Aug 2024], [Lisa Nguyen], a top executive at [US Weather Center], forecasts that the [snowfall levels] at [US Weather Center] in [Denver] [will likely] [increase] by [10 inches] in [2025-11-20].
# 16                                                                                             T2: In [2025 Q1], [Kevin White] from [NOAA] in [Boston], predicts that the [air quality index] [will] [improve] by [15%] in [2025-04-01].
# 17                                                      T3: [Jessica Lee], a weather senior level person from [Weather Underground], predicts on [2024-10-10] that the [temperature] in [Dallas] [will] [fall] by [8°F] in [2025-02-01].
# 18                             T4: According to a [weather expert] from [National Weather Service], on [2024/09/01], the [rainfall] in [San Francisco] [is expected to] [increase] beyond [15 percent] in the timeframe of [2025-06-01].
# 19                        T5: In [2026-09-15], the [wind chill] in [Minneapolis] [is expected] to be [5°F, which is a 10%] [decrease], as predicted by [Mark Hall], a weather analyst from [Meteorological Department], on [2024-08-22].
# 20                                                                   T1: On [2024-10-15], [Dr. Rachel Lee, a health expert] predicts that the [average blood pressure] at [New York City] [will likely] [decrease] by [3%] in [2026 Q2].
# 21                                      T2: In [Q4 of 2024], [Dr. David Kim, a researcher] from [Johns Hopkins University] forecasts that the [prevalence of heart disease] [may] [rise] from [200 to 250 per 100,000 people] in [2028].
# 22                                                           T3: [Dr. Maria Rodriguez, a senior health analyst] predicts on [2024/08/20] that the [obesity rate among children] in [Texas] [should] [stay stable] at [12%] in [2027 Q1].
# 23                 T4: According to a [Dr. John Taylor, a physician] from [Cedars-Sinai Medical Center], on [2024-08-22], the [average daily step count] [is expected to] [increase] beyond [8,000 steps] in the timeframe of [2029 Q3].
# 24                                                      T5: In [2025-10-01], the [average weekly fruit consumption] in [California] [will likely] [rise] by [15%], as predicted by [Dr. Emily Chen, a nutrition expert] on [2024-09-15].
# 25                                                                                 T1: On [21 Aug 2024], [Dr. Kevin White, a health expert] predicts that the [prevalence of diabetes] at [Florida] [will] [decrease] by [2%] in [2026].
# 26                                              T2: In [2027 Q1], [Dr. Sophia Patel, a researcher] from [Harvard University] envisions that the [average daily caloric intake] [may] [fall] from [2,500 to 2,000 calories] in [2028 Q2].
# 27                                                T3: [Dr. Michael Brown, a senior health executive] predicts on [2024-11-01] that the [vaccination rate for influenza] in [United States] [should] [stay stable] at [50%] in [2027 Q4].
# 28         T4: According to a [Dr. Lisa Nguyen, a physician assistant] from [Stanford Health Care], on [2024/09/10], the [prevalence of mental health disorders] [is expected to] [increase] beyond [20%] in the timeframe of [2030 Q1].
# 29                                                       T5: In [2028-07-01], the [average weekly exercise hours] in [New York State] [will likely] [rise] by [10%], as predicted by [Dr. Daniel Lee, a fitness expert] on [2024-10-01].
# 30                                                                     T1: On [2024-10-15], [Chief Financial Officer, Michael Davis] predicts that the [stock market index] at [Wall Street] [will likely] [rise] by [10%] in [2026 Q2].
# 31                                                             T2: In [Q4 of 2024], [Senior Policy Analyst, Emily Chen] from [the Federal Reserve], envisions that the [interest rate] [should] [fall] from [2.5% to 1.8%] in [2028 Q1].
# 32                                                                                 T3: [Policy Expert, David Lee] predicts on [2024/08/20] that the [GDP growth rate] in [the United States] [may] [stay stable] at [2.2%] in [2027 Q3].
# 33                       T4: According to a [Financial Advisor, Sarah Taylor] from [JPMorgan Chase], on [21 Aug 2024], the [number of mortgage applications] [is expected to] [increase] beyond [500,000] in the timeframe of [2029 Q4].
# 34                                                                        T5: In [2025-08-20], the [unemployment rate] in [New York City] [will] [decrease] by [1.5%] [fall], as predicted by [Economist, James Wilson] on [2024-08-15].
# 35                                                                  T1: On [Wednesday, November 20, 2024], [CEO, Mark Zuckerberg] forecasts that the [cryptocurrency market] at [NASDAQ] [will likely] [decrease] by [15%] in [2026 Q4].
# 36                                                                                T2: In [2027 Q1], [Policy Reporter, Rachel Kim] from [Bloomberg], predicts that the [inflation rate] [should] [rise] from [1.8% to 3.2%] in [2028 Q2].
# 37                                                                         T3: [Senior Economist, Kevin White] predicts on [2024/09/10] that the [consumer price index] in [the European Union] [may] [increase] by [2.5%] in [2027 Q2].
# 38                                T4: According to a [Financial Analyst, Lisa Nguyen] from [Goldman Sachs], on [2024-09-15], the [number of initial public offerings] [is expected to] [fall] below [100] in the timeframe of [2029 Q1].
# 39                                                     T5: In [2026-08-21], the [number of bankruptcies] in [the retail sector] [is likely to] [decrease] by [20%] [fall], as predicted by [Policy Expert, Daniel Hall] on [2024-08-20].
#
#     Prediction Label               Model Name     Domain
# 0                  1  llama-3.3-70b-versatile  financial
# 1                  1  llama-3.3-70b-versatile  financial
# 2                  1  llama-3.3-70b-versatile  financial
# 3                  1  llama-3.3-70b-versatile  financial
# 4                  1  llama-3.3-70b-versatile  financial
# 5                  1  llama-3.3-70b-versatile  financial
# 6                  1  llama-3.3-70b-versatile  financial
# 7                  1  llama-3.3-70b-versatile  financial
# 8                  1  llama-3.3-70b-versatile  financial
# 9                  1  llama-3.3-70b-versatile  financial
# 10                 1  llama-3.3-70b-versatile    weather
# 11                 1  llama-3.3-70b-versatile    weather
# 12                 1  llama-3.3-70b-versatile    weather
# 13                 1  llama-3.3-70b-versatile    weather
# 14                 1  llama-3.3-70b-versatile    weather
# 15                 1  llama-3.3-70b-versatile    weather
# 16                 1  llama-3.3-70b-versatile    weather
# 17                 1  llama-3.3-70b-versatile    weather
# 18                 1  llama-3.3-70b-versatile    weather
# 19                 1  llama-3.3-70b-versatile    weather
# 20                 1  llama-3.3-70b-versatile     health
# 21                 1  llama-3.3-70b-versatile     health
# 22                 1  llama-3.3-70b-versatile     health
# 23                 1  llama-3.3-70b-versatile     health
# 24                 1  llama-3.3-70b-versatile     health
# 25                 1  llama-3.3-70b-versatile     health
# 26                 1  llama-3.3-70b-versatile     health
# 27                 1  llama-3.3-70b-versatile     health
# 28                 1  llama-3.3-70b-versatile     health
# 29                 1  llama-3.3-70b-versatile     health
# 30                 1  llama-3.3-70b-versatile     policy
# 31                 1  llama-3.3-70b-versatile     policy
# 32                 1  llama-3.3-70b-versatile     policy
# 33                 1  llama-3.3-70b-versatile     policy
# 34                 1  llama-3.3-70b-versatile     policy
# 35                 1  llama-3.3-70b-versatile     policy
# 36                 1  llama-3.3-70b-versatile     policy
# 37                 1  llama-3.3-70b-versatile     policy
# 38                 1  llama-3.3-70b-versatile     policy
# 39                 1  llama-3.3-70b-versatile     policy

# %%
only_predictions = DataProcessing.df_to_list(predictions_df, 'Base Sentence')
only_predictions
# Out:
# ['T1: On [2024-10-15], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [10 percent to $20 billion] in [2026 Q2].',
#  'T2: In [Q4 of 2024], [Ethan Kim] from [Bloomberg], forecasts that the [stock price] [will] [fall] from [$500 to $300 per share] in [2028 Q1].',
#  'T3: [Ava Morales, a financial expert] predicts on [2024/08/20] that the [research and development expenses] at [Intel] [may] [stay stable] at [$15 million] in [2027 Q3].',
#  'T4: According to a [senior executive] from [Coca-Cola], on [21 Aug 2024], the [net profit] [is expected to] [rise] beyond [$5 billion] in the timeframe of [2029 Q4].',
#  'T5: In [2025-02-15], the [revenue] at [Visa] [is expected] to [increase] by [15 percent to $25 billion] [rise], as predicted by [Liam Chen, a financial reporter] on [2024-08-22].',
#  'T1: On [Wednesday, November 20, 2024], [Julian Lee, an investor] predicts that the [gross profit] at [UnitedHealth Group] [will likely] [decrease] by [5 percent to $10 billion] in [2026 Q4].',
#  'T2: In [2027 Q2], [Sophia Patel] from [Morgan Stanley], envisions that the [operating income] [will] [increase] from [$10 billion to $15 billion] in [2028 Q3].',
#  'T3: [Noah Brooks, a financial analyst] predicts on [2024/10/18] that the [net profit] at [Procter & Gamble] [may] [fall] by [10 percent to $5 billion] in [2027 Q2].',
#  'T4: According to a [top executive] from [AT&T], on [2024-08-25], the [revenue] [is expected to] [stay stable] at [$40 billion] in the timeframe of [2029 Q1].',
#  "T5: In [2026-08-20], the [stock price] at [McDonald's] [has a probability] of [20 percent to reach $250 per share] [rise], as predicted by [Jackson Brown, a financial expert] on [2024-10-12].",
#  'T1: On [2024-10-20], [Emily Chen], a senior meteorologist at [National Weather Service], forecasts that the [precipitation levels] at [National Weather Service] in [Los Angeles] [will likely] [increase] by [15%] in [2025-02-15].',
#  'T2: In [Q4 of 2024], [Michael Brown] from [Weather.com] in [New York City], predicts that the [temperature] [will] [decrease] from [10°C to 5°C] in [2025-01-10].',
#  'T3: [Sarah Taylor], a weather expert from [Bureau of Meteorology], predicts on [2024/08/25] that the [humidity] in [Chicago] [will] [rise] by [20%] in [2025 Q2].',
#  'T4: According to a [weather analyst] from [AccuWeather], on [2024-08-18], the [wind speed] in [Miami] [is expected to] [increase] beyond [10 mph] in the timeframe of [2025-03-01].',
#  'T5: In [2027-08-20], the [average precipitation] in [Seattle] [is likely to] [decrease] by [5%], as predicted by [James Davis], a weather reporter from [Meteorological Department], on [2024-09-15].',
#  'T1: On [21 Aug 2024], [Lisa Nguyen], a top executive at [US Weather Center], forecasts that the [snowfall levels] at [US Weather Center] in [Denver] [will likely] [increase] by [10 inches] in [2025-11-20].',
#  'T2: In [2025 Q1], [Kevin White] from [NOAA] in [Boston], predicts that the [air quality index] [will] [improve] by [15%] in [2025-04-01].',
#  'T3: [Jessica Lee], a weather senior level person from [Weather Underground], predicts on [2024-10-10] that the [temperature] in [Dallas] [will] [fall] by [8°F] in [2025-02-01].',
#  'T4: According to a [weather expert] from [National Weather Service], on [2024/09/01], the [rainfall] in [San Francisco] [is expected to] [increase] beyond [15 percent] in the timeframe of [2025-06-01].',
#  'T5: In [2026-09-15], the [wind chill] in [Minneapolis] [is expected] to be [5°F, which is a 10%] [decrease], as predicted by [Mark Hall], a weather analyst from [Meteorological Department], on [2024-08-22].',
#  'T1: On [2024-10-15], [Dr. Rachel Lee, a health expert] predicts that the [average blood pressure] at [New York City] [will likely] [decrease] by [3%] in [2026 Q2].',
#  'T2: In [Q4 of 2024], [Dr. David Kim, a researcher] from [Johns Hopkins University] forecasts that the [prevalence of heart disease] [may] [rise] from [200 to 250 per 100,000 people] in [2028].',
#  'T3: [Dr. Maria Rodriguez, a senior health analyst] predicts on [2024/08/20] that the [obesity rate among children] in [Texas] [should] [stay stable] at [12%] in [2027 Q1].',
#  'T4: According to a [Dr. John Taylor, a physician] from [Cedars-Sinai Medical Center], on [2024-08-22], the [average daily step count] [is expected to] [increase] beyond [8,000 steps] in the timeframe of [2029 Q3].',
#  'T5: In [2025-10-01], the [average weekly fruit consumption] in [California] [will likely] [rise] by [15%], as predicted by [Dr. Emily Chen, a nutrition expert] on [2024-09-15].',
#  'T1: On [21 Aug 2024], [Dr. Kevin White, a health expert] predicts that the [prevalence of diabetes] at [Florida] [will] [decrease] by [2%] in [2026].',
#  'T2: In [2027 Q1], [Dr. Sophia Patel, a researcher] from [Harvard University] envisions that the [average daily caloric intake] [may] [fall] from [2,500 to 2,000 calories] in [2028 Q2].',
#  'T3: [Dr. Michael Brown, a senior health executive] predicts on [2024-11-01] that the [vaccination rate for influenza] in [United States] [should] [stay stable] at [50%] in [2027 Q4].',
#  'T4: According to a [Dr. Lisa Nguyen, a physician assistant] from [Stanford Health Care], on [2024/09/10], the [prevalence of mental health disorders] [is expected to] [increase] beyond [20%] in the timeframe of [2030 Q1].',
#  'T5: In [2028-07-01], the [average weekly exercise hours] in [New York State] [will likely] [rise] by [10%], as predicted by [Dr. Daniel Lee, a fitness expert] on [2024-10-01].',
#  'T1: On [2024-10-15], [Chief Financial Officer, Michael Davis] predicts that the [stock market index] at [Wall Street] [will likely] [rise] by [10%] in [2026 Q2].',
#  'T2: In [Q4 of 2024], [Senior Policy Analyst, Emily Chen] from [the Federal Reserve], envisions that the [interest rate] [should] [fall] from [2.5% to 1.8%] in [2028 Q1].',
#  'T3: [Policy Expert, David Lee] predicts on [2024/08/20] that the [GDP growth rate] in [the United States] [may] [stay stable] at [2.2%] in [2027 Q3].',
#  'T4: According to a [Financial Advisor, Sarah Taylor] from [JPMorgan Chase], on [21 Aug 2024], the [number of mortgage applications] [is expected to] [increase] beyond [500,000] in the timeframe of [2029 Q4].',
#  'T5: In [2025-08-20], the [unemployment rate] in [New York City] [will] [decrease] by [1.5%] [fall], as predicted by [Economist, James Wilson] on [2024-08-15].',
#  'T1: On [Wednesday, November 20, 2024], [CEO, Mark Zuckerberg] forecasts that the [cryptocurrency market] at [NASDAQ] [will likely] [decrease] by [15%] in [2026 Q4].',
#  'T2: In [2027 Q1], [Policy Reporter, Rachel Kim] from [Bloomberg], predicts that the [inflation rate] [should] [rise] from [1.8% to 3.2%] in [2028 Q2].',
#  'T3: [Senior Economist, Kevin White] predicts on [2024/09/10] that the [consumer price index] in [the European Union] [may] [increase] by [2.5%] in [2027 Q2].',
#  'T4: According to a [Financial Analyst, Lisa Nguyen] from [Goldman Sachs], on [2024-09-15], the [number of initial public offerings] [is expected to] [fall] below [100] in the timeframe of [2029 Q1].',
#  'T5: In [2026-08-21], the [number of bankruptcies] in [the retail sector] [is likely to] [decrease] by [20%] [fall], as predicted by [Policy Expert, Daniel Hall] on [2024-08-20].']

# %%
ner_dfs = []
for doc in nlp.pipe(only_predictions, disable=["tok2vec", "parser", "attribute_ruler", "lemmatizer"]):
    # print(f"sentence: {doc}")
    columns = []
    values = []
    for ent in doc.ents:
        columns.append(ent.label_)
        values.append(ent.text)
        # print(f"    cols_name: {ent.label_}")
        # print(f"        text: {ent.text}")
    ner_df = pd.DataFrame([values], columns=columns)
    # print(ner_df)
    ner_dfs.append(ner_df)
ner_dfs
# Out:
# [  CARDINAL        DATE             PERSON                ORG     PERCENT  \
#  0       T1  2024-10-15  Samantha Thompson  Johnson & Johnson  10 percent
#
#           MONEY  DATE
#  0  $20 billion  2026  ,
#    CARDINAL WORK_OF_ART     PERSON     PERSON MONEY MONEY  DATE
#  0       T2  Q4 of 2024  Ethan Kim  Bloomberg   500   300  2028,
#          PERSON    CARDINAL    ORG        MONEY  DATE
#  0  Ava Morales  2024/08/20  Intel  $15 million  2027,
#    ORG        ORG CARDINAL  DATE       MONEY  DATE
#  0  T4  Coca-Cola       21  2024  $5 billion  2029,
#    CARDINAL        DATE     PERCENT        MONEY     PERSON        DATE
#  0       T5  2025-02-15  15 percent  $25 billion  Liam Chen  2024-08-22,
#    CARDINAL                          DATE      PERSON                 ORG  \
#  0       T1  Wednesday, November 20, 2024  Julian Lee  UnitedHealth Group
#
#       PERCENT        MONEY  DATE
#  0  5 percent  $10 billion  2026  ,
#    CARDINAL  DATE        PERSON             ORG                       MONEY  \
#  0       T2  2027  Sophia Patel  Morgan Stanley  $10 billion to $15 billion
#
#     DATE
#  0  2028  ,
#          PERSON    CARDINAL               ORG     PERCENT       MONEY  DATE
#  0  Noah Brooks  2024/10/18  Procter & Gamble  10 percent  $5 billion  2027,
#    ORG   ORG        DATE        MONEY WORK_OF_ART
#  0  T4  AT&T  2024-08-25  $40 billion     2029 Q1,
#    CARDINAL        DATE       ORG     PERCENT MONEY         PERSON        DATE
#  0       T5  2026-08-20  McDonald  20 percent   250  Jackson Brown  2024-10-12,
#    CARDINAL        DATE      PERSON                       ORG  \
#  0       T1  2024-10-20  Emily Chen  National Weather Service
#
#                          ORG          GPE PERCENT        DATE
#  0  National Weather Service  Los Angeles     15%  2025-02-15  ,
#    CARDINAL WORK_OF_ART         PERSON          ORG            GPE CARDINAL  \
#  0       T2  Q4 of 2024  Michael Brown  Weather.com  New York City       10
#
#           DATE
#  0  2025-01-10  ,
#           PERSON                    ORG    CARDINAL      GPE PERCENT  DATE
#  0  Sarah Taylor  Bureau of Meteorology  2024/08/25  Chicago     20%  2025,
#    ORG          ORG        DATE    GPE QUANTITY        DATE
#  0  T4  AccuWeather  2024-08-18  Miami   10 mph  2025-03-01,
#    CARDINAL        DATE      GPE PERCENT       PERSON  \
#  0       T5  2027-08-20  Seattle      5%  James Davis
#
#                           ORG        DATE
#  0  Meteorological Department  2024-09-15  ,
#    CARDINAL CARDINAL  DATE       PERSON GPE GPE     GPE   QUANTITY        DATE
#  0       T1       21  2024  Lisa Nguyen  US  US  Denver  10 inches  2025-11-20,
#    CARDINAL  DATE       PERSON WORK_OF_ART     GPE PERCENT        DATE
#  0       T2  2025  Kevin White        NOAA  Boston     15%  2025-04-01,
#          PERSON          WORK_OF_ART        DATE     GPE CARDINAL        DATE
#  0  Jessica Lee  Weather Underground  2024-10-10  Dallas        8  2025-02-01,
#    ORG                       ORG    CARDINAL            GPE     PERCENT  \
#  0  T4  National Weather Service  2024/09/01  San Francisco  15 percent
#
#           DATE
#  0  2025-06-01  ,
#    CARDINAL        DATE          GPE CARDINAL PERCENT     PERSON  \
#  0       T5  2026-09-15  Minneapolis        5     10%  Mark Hall
#
#                           ORG        DATE
#  0  Meteorological Department  2024-08-22  ,
#    CARDINAL        DATE      PERSON            GPE PERCENT  DATE
#  0       T1  2024-10-15  Rachel Lee  New York City      3%  2026,
#    CARDINAL WORK_OF_ART     PERSON                       ORG CARDINAL CARDINAL  \
#  0       T2  Q4 of 2024  David Kim  Johns Hopkins University      200      250
#
#    CARDINAL CARDINAL
#  0  100,000     2028  ,
#              PERSON    CARDINAL    GPE PERCENT  DATE
#  0  Maria Rodriguez  2024/08/20  Texas     12%  2027,
#    ORG       PERSON                          ORG        DATE   DATE CARDINAL
#  0  T4  John Taylor  Cedars-Sinai Medical Center  2024-08-22  daily    8,000,
#    CARDINAL        DATE    DATE         GPE PERCENT      PERSON        DATE
#  0       T5  2025-10-01  weekly  California     15%  Emily Chen  2024-09-15,
#    CARDINAL CARDINAL  DATE       PERSON      GPE PERCENT  DATE
#  0       T1       21  2024  Kevin White  Florida      2%  2026,
#    CARDINAL  DATE        PERSON                 ORG   DATE CARDINAL CARDINAL  \
#  0       T2  2027  Sophia Patel  Harvard University  daily    2,500    2,000
#
#     DATE
#  0  2028  ,
#            PERSON        DATE            GPE PERCENT  DATE
#  0  Michael Brown  2024-11-01  United States     50%  2027,
#    ORG       PERSON                    ORG    CARDINAL PERCENT WORK_OF_ART
#  0  T4  Lisa Nguyen  Stanford Health Care]  2024/09/10     20%     2030 Q1,
#    CARDINAL        DATE    DATE             GPE PERCENT      PERSON        DATE
#  0       T5  2028-07-01  weekly  New York State     10%  Daniel Lee  2024-10-01,
#    CARDINAL        DATE         PERSON PERCENT  DATE
#  0       T1  2024-10-15  Michael Davis     10%  2026,
#    CARDINAL WORK_OF_ART      PERSON                  ORG       PERCENT  DATE
#  0       T2  Q4 of 2024  Emily Chen  the Federal Reserve  2.5% to 1.8%  2028,
#        PERSON    CARDINAL                GPE PERCENT  DATE
#  0  David Lee  2024/08/20  the United States    2.2%  2027,
#    ORG                ORG        PERSON             ORG CARDINAL  DATE  \
#  0  T4  Financial Advisor  Sarah Taylor  JPMorgan Chase       21  2024
#
#    CARDINAL  DATE
#  0  500,000  2029  ,
#    CARDINAL        DATE            GPE PERCENT        ORG        PERSON  \
#  0       T5  2025-08-20  New York City    1.5%  Economist  James Wilson
#
#           DATE
#  0  2024-08-15  ,
#    CARDINAL                          DATE           PERSON PERCENT  DATE
#  0       T1  Wednesday, November 20, 2024  Mark Zuckerberg     15%  2026,
#    CARDINAL  DATE      PERSON     PERSON       PERCENT  DATE
#  0       T2  2027  Rachel Kim  Bloomberg  1.8% to 3.2%  2028,
#          PERSON    CARDINAL                 ORG PERCENT  DATE
#  0  Kevin White  2024/09/10  the European Union    2.5%  2027,
#    ORG                ORG       PERSON            ORG        DATE CARDINAL  \
#  0  T4  Financial Analyst  Lisa Nguyen  Goldman Sachs  2024-09-15      100
#
#    WORK_OF_ART
#  0     2029 Q1  ,
#    CARDINAL        DATE PERCENT       PERSON        DATE
#  0       T5  2026-08-21     20%  Daniel Hall  2024-08-20]

# %%
ner_dfs[3]
# Out:
#   ORG        ORG CARDINAL  DATE       MONEY  DATE
# 0  T4  Coca-Cola       21  2024  $5 billion  2029

# %%
# %store ner_dfs
