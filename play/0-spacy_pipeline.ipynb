# %% [markdown]
# # Spacy Pipeline
#
# - **Goal:** Prediction Recognition
#
# - **Purpose:** To extract named entities (NER), part-of-speech (POS), etc.
#     1. Use to train model as feature extraction (ie: TF x IDF) alone isn't enough
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os
import sys
import spacy

import pandas as pd
# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing

# %%
pd.set_option('max_colwidth', 800)
nlp = spacy.load("en_core_web_sm")
# %store -r predictions_df
# %store -r non_predictions_df

# %%
predictions_df
# Out:
#                                                                                                                                                                                                                                  Base Sentence  \
# 0                                           T1: On [2024-10-20], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [10 percent to $25 billion] in [2026 Q2].
# 1                                                                                             T2: In [Q4 of 2024], [Ethan Kim] from [Goldman Sachs], forecasts that the [stock price] [will] [fall] from [$120 to $90 per share] in [2028 Q1].
# 2                                                          T3: [Alexander Brown, a financial expert] predicts on [15 November 2024] that the [research and development expenses] at [Intel] [may] [stay stable] at [$15 million] in [2027 Q3].
# 3                                                                     T4: According to a [senior executive] from [Coca-Cola], on [2024/08/25], the [net profit] [is expected to] [increase] beyond [$5 billion] in the timeframe of [2029 Q4].
# 4                                                                     T5: In [2025-02-15], the [revenue] at [Visa] [will] [rise] by [15 percent to $30 billion] [increase], as predicted by [David Lee, a financial reporter] on [2024-10-10].
# 5                                                    T1: On [Wednesday, August 28, 2024], [Olivia Patel, an investor] predicts that the [gross profit] at [UnitedHealth Group] [should] [decrease] by [5 percent to $10 billion] in [2026 Q4].
# 6                                                                                 T2: In [2027 Q1], [Jackson Davis] from [Morgan Stanley], envisions that the [operating income] [will] [rise] from [$10 billion to $15 billion] in [2028 Q2].
# 7                                                                      T3: [Ava Morales, a financial analyst] predicts on [2024-09-20] that the [net profit] at [Procter & Gamble] [may] [fall] under [10 percent to $5 billion] in [2027 Q1].
# 8                                      T4: According to [Emily Chen] from [Cisco Systems], on [2024/11/15], the [research and development expenses] [may] [increase] as much as [$500 million, reflecting a 20 percent increase] by [2026 Q3].
# 9                                                         T5: In [2029 Q3], the [stock price] at [3M] [is expected to] [decrease] by [10 percent to $100 per share] [fall], as predicted by [Michael Kim, a financial expert] on [2024-08-10].
# 10         T1: On [2024-10-20], [Emily Chen], a senior meteorologist at [National Weather Service], predicts that the [precipitation levels] at [National Weather Service] in [Los Angeles] [will likely] [increase] by [15%] in [2025-03-15].
# 11                                                                           T2: In [Q4 of 2024], [Michael Brown] from [Weather.com] in [New York City], predicts that the [temperature] [will] [decrease] from [10°C to 5°C] in [2025-02-10].
# 12                                                                       T3: [Sarah Lee], a weather expert from [Bureau of Meteorology], predicts on [2024/08/25] that the [humidity] in [Chicago] [will] [rise] by [20%] in [2025 Quarter 2].
# 13                                                         T4: According to a [weather analyst] from [AccuWeather], on [2024-08-18], the [wind speed] in [Miami] [is expected to] [increase] beyond [10 mph] in the timeframe of [2025-06-01].
# 14                    T5: In [2027-09-20], the [snowfall levels] at [National Weather Service] in [Denver] [will likely] [increase] by [10 inches], as predicted by [David Kim], a weather reporter from [US Weather Center], on [2024-10-12].
# 15            T1: On [21 Aug 2024], [Olivia Patel], a weather senior level person at [Meteorological Department], predicts that the [air quality index] at [Meteorological Department] in [Seattle] [will] [improve] by [15%] in [2025-04-15].
# 16                                                                      T2: In [2026-01-01], [Kevin White] from [Weather Underground] in [Boston], predicts that the [rainfall] [will] [decrease] from [5 inches to 3 inches] in [2026-07-01].
# 17                                    T3: [Rebecca Hall], a weather top executive from [National Oceanic and Atmospheric Administration], predicts on [2024-09-15] that the [temperature] in [Dallas] [will] [fall] by [12°F] in [2025-01-01].
# 18                                  T4: According to a [weather expert] from [The Weather Channel], on [2024/11/20], the [precipitation levels] in [San Francisco] [are expected to] [increase] beyond [20%] in the timeframe of [2026-03-01].
# 19    T5: In [2028-10-15], the [average temperature] at [National Weather Service] in [Washington D.C.] [is likely to] [decrease] by [5°F], as predicted by [James Davis], a weather analyst from [National Weather Service], on [2024-09-10].
# 20                                                       T1: On [2024-10-15], [Dr. Rachel Lee, a health expert] predicts that the [prevalence of chronic diseases] at [Johns Hopkins Hospital] [will likely] [increase] by [10%] in [2028 Q2].
# 21                                                                          T2: In [Q4 of 2024], [David Kim, Ph.D] from [World Health Organization] forecasts that the [average life expectancy] [may] [rise] from [75 to 80 years] in [2030].
# 22                                                                                      T3: [Dr. Maria Rodriguez] predicts on [2024/08/20] that the [obesity rate among children] in [New York City] [should] [decrease] by [8%] in [2026 Q1].
# 23  T4: According to a [health analyst, Michael Chen] from [Centers for Disease Control and Prevention], on [21 Aug 2024], the [prevalence of mental health disorders] [is expected to] [increase] beyond [15%] in the timeframe of [2029 Q3].
# 24                                                    T5: In [2025-08-15], the [average daily physical activity levels] in [Australia] [will likely] [increase] by [20%], as predicted by [Dr. Sophia Patel, a health expert] on [2024-10-10].
# 25                                                  T1: On [Wednesday, November 20, 2024], [Dr. John Smith, a senior health executive] predicts that the [prevalence of infectious diseases] at [WHO] [will] [decrease] by [12%] in [2027 Q4].
# 26                                               T2: In [2027 Q1], [Emily Taylor, a health researcher] from [Harvard School of Public Health] envisions that the [average weekly exercise hours] [may] [rise] from [10 to 15 hours] in [2028].
# 27                                                                                   T3: [Dr. James Davis] predicts on [2024/11/15] that the [global vaccination rate for influenza] in [Europe] [should] [stay stable] at [90%] in [2026 Q2].
# 28              T4: According to a [health expert, Dr. Lisa Nguyen] from [National Institutes of Health], on [2024-08-25], the [prevalence of cardiovascular diseases] [is expected to] [increase] beyond [25%] in the timeframe of [2030 Q1].
# 29                                                                 T5: In [2026-08-20], the [average daily caloric intake] in [Canada] [will likely] [decrease] by [10%], as predicted by [Dr. David Brown, a health analyst] on [2024-10-05].
# 30                                                           T1: On [2024-10-15], [Chief Financial Officer, Michael Davis] predicts that the [stock market index] at [the New York Stock Exchange] [will likely] [rise] by [10%] in [2026 Q2].
# 31                                                                  T2: In [Q4 of 2024], [Senior Policy Analyst, Emily Chen] from [the Federal Reserve], envisions that the [interest rates] [should] [fall] from [2.5% to 1.8%] in [2028 Q1].
# 32                                                                                        T3: [Policy Expert, David Lee] predicts on [2024/08/20] that the [inflation rate] at [the United States] [may] [stay stable] at [2.2%] in [2027 Q3].
# 33                                T4: According to a [Top Executive, Sarah Taylor] from [JPMorgan Chase], on [2024-08-22], the [number of mortgage applications] [is expected to] [increase] beyond [1 million] in the timeframe of [2029 Q4].
# 34                                                                   T5: In [2025-08-20], the [unemployment rate] in [California] [is likely to] [decrease] by [1.5%] [fall], as predicted by [Policy Reporter, James Wilson] on [2024/10/12].
# 35                                                              T1: On [Wednesday, 2024/11/06], [Financial Analyst, Kevin White] forecasts that the [GDP growth rate] at [the European Union] [will likely] [increase] by [2.8%] in [2026 Q4].
# 36                                                                                  T2: In [2024/10/01], [Senior Economist, Lisa Nguyen] from [the World Bank], predicts that the [poverty rate] [will] [fall] from [15% to 10%] in [2028 Q2].
# 37                                                                                      T3: [Policy Advisor, Mark Davis] predicts on [2024/09/18] that the [consumer price index] at [the United Kingdom] [may] [rise] by [1.2%] in [2027 Q1].
# 38                          T4: According to a [Chief Economist, Daniel Kim] from [the International Monetary Fund], on [2024/08/25], the [number of bankruptcies] [is expected to] [decrease] beyond [500,000] in the timeframe of [2029 Q3].
# 39                                   T5: In [2026 Q1], the [number of initial public offerings] in [the United States] [is expected] to be [200, which is a 25%] [increase], as predicted by [Financial Expert, Rachel Brown] on [2024/10/20].
#
#     Prediction Label               Model Name     Domain
# 0                  1  llama-3.3-70b-versatile  financial
# 1                  1  llama-3.3-70b-versatile  financial
# 2                  1  llama-3.3-70b-versatile  financial
# 3                  1  llama-3.3-70b-versatile  financial
# 4                  1  llama-3.3-70b-versatile  financial
# 5                  1  llama-3.3-70b-versatile  financial
# 6                  1  llama-3.3-70b-versatile  financial
# 7                  1  llama-3.3-70b-versatile  financial
# 8                  1  llama-3.3-70b-versatile  financial
# 9                  1  llama-3.3-70b-versatile  financial
# 10                 1  llama-3.3-70b-versatile    weather
# 11                 1  llama-3.3-70b-versatile    weather
# 12                 1  llama-3.3-70b-versatile    weather
# 13                 1  llama-3.3-70b-versatile    weather
# 14                 1  llama-3.3-70b-versatile    weather
# 15                 1  llama-3.3-70b-versatile    weather
# 16                 1  llama-3.3-70b-versatile    weather
# 17                 1  llama-3.3-70b-versatile    weather
# 18                 1  llama-3.3-70b-versatile    weather
# 19                 1  llama-3.3-70b-versatile    weather
# 20                 1  llama-3.3-70b-versatile     health
# 21                 1  llama-3.3-70b-versatile     health
# 22                 1  llama-3.3-70b-versatile     health
# 23                 1  llama-3.3-70b-versatile     health
# 24                 1  llama-3.3-70b-versatile     health
# 25                 1  llama-3.3-70b-versatile     health
# 26                 1  llama-3.3-70b-versatile     health
# 27                 1  llama-3.3-70b-versatile     health
# 28                 1  llama-3.3-70b-versatile     health
# 29                 1  llama-3.3-70b-versatile     health
# 30                 1  llama-3.3-70b-versatile     policy
# 31                 1  llama-3.3-70b-versatile     policy
# 32                 1  llama-3.3-70b-versatile     policy
# 33                 1  llama-3.3-70b-versatile     policy
# 34                 1  llama-3.3-70b-versatile     policy
# 35                 1  llama-3.3-70b-versatile     policy
# 36                 1  llama-3.3-70b-versatile     policy
# 37                 1  llama-3.3-70b-versatile     policy
# 38                 1  llama-3.3-70b-versatile     policy
# 39                 1  llama-3.3-70b-versatile     policy

# %%
data_processing = DataProcessing
updated_predictions_df = data_processing.reformat_df_with_template_number(predictions_df, col_name="Base Sentence")
updated_predictions_df
# Out:
#                                                                                                                                                                                                                              Base Sentence  \
# 0                                           On [2024-10-20], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [10 percent to $25 billion] in [2026 Q2].
# 1                                                                                             In [Q4 of 2024], [Ethan Kim] from [Goldman Sachs], forecasts that the [stock price] [will] [fall] from [$120 to $90 per share] in [2028 Q1].
# 2                                                          [Alexander Brown, a financial expert] predicts on [15 November 2024] that the [research and development expenses] at [Intel] [may] [stay stable] at [$15 million] in [2027 Q3].
# 3                                                                     According to a [senior executive] from [Coca-Cola], on [2024/08/25], the [net profit] [is expected to] [increase] beyond [$5 billion] in the timeframe of [2029 Q4].
# 4                                                                     In [2025-02-15], the [revenue] at [Visa] [will] [rise] by [15 percent to $30 billion] [increase], as predicted by [David Lee, a financial reporter] on [2024-10-10].
# 5                                                    On [Wednesday, August 28, 2024], [Olivia Patel, an investor] predicts that the [gross profit] at [UnitedHealth Group] [should] [decrease] by [5 percent to $10 billion] in [2026 Q4].
# 6                                                                                 In [2027 Q1], [Jackson Davis] from [Morgan Stanley], envisions that the [operating income] [will] [rise] from [$10 billion to $15 billion] in [2028 Q2].
# 7                                                                      [Ava Morales, a financial analyst] predicts on [2024-09-20] that the [net profit] at [Procter & Gamble] [may] [fall] under [10 percent to $5 billion] in [2027 Q1].
# 8                                      According to [Emily Chen] from [Cisco Systems], on [2024/11/15], the [research and development expenses] [may] [increase] as much as [$500 million, reflecting a 20 percent increase] by [2026 Q3].
# 9                                                         In [2029 Q3], the [stock price] at [3M] [is expected to] [decrease] by [10 percent to $100 per share] [fall], as predicted by [Michael Kim, a financial expert] on [2024-08-10].
# 10         On [2024-10-20], [Emily Chen], a senior meteorologist at [National Weather Service], predicts that the [precipitation levels] at [National Weather Service] in [Los Angeles] [will likely] [increase] by [15%] in [2025-03-15].
# 11                                                                           In [Q4 of 2024], [Michael Brown] from [Weather.com] in [New York City], predicts that the [temperature] [will] [decrease] from [10°C to 5°C] in [2025-02-10].
# 12                                                                       [Sarah Lee], a weather expert from [Bureau of Meteorology], predicts on [2024/08/25] that the [humidity] in [Chicago] [will] [rise] by [20%] in [2025 Quarter 2].
# 13                                                         According to a [weather analyst] from [AccuWeather], on [2024-08-18], the [wind speed] in [Miami] [is expected to] [increase] beyond [10 mph] in the timeframe of [2025-06-01].
# 14                    In [2027-09-20], the [snowfall levels] at [National Weather Service] in [Denver] [will likely] [increase] by [10 inches], as predicted by [David Kim], a weather reporter from [US Weather Center], on [2024-10-12].
# 15            On [21 Aug 2024], [Olivia Patel], a weather senior level person at [Meteorological Department], predicts that the [air quality index] at [Meteorological Department] in [Seattle] [will] [improve] by [15%] in [2025-04-15].
# 16                                                                      In [2026-01-01], [Kevin White] from [Weather Underground] in [Boston], predicts that the [rainfall] [will] [decrease] from [5 inches to 3 inches] in [2026-07-01].
# 17                                    [Rebecca Hall], a weather top executive from [National Oceanic and Atmospheric Administration], predicts on [2024-09-15] that the [temperature] in [Dallas] [will] [fall] by [12°F] in [2025-01-01].
# 18                                  According to a [weather expert] from [The Weather Channel], on [2024/11/20], the [precipitation levels] in [San Francisco] [are expected to] [increase] beyond [20%] in the timeframe of [2026-03-01].
# 19    In [2028-10-15], the [average temperature] at [National Weather Service] in [Washington D.C.] [is likely to] [decrease] by [5°F], as predicted by [James Davis], a weather analyst from [National Weather Service], on [2024-09-10].
# 20                                                       On [2024-10-15], [Dr. Rachel Lee, a health expert] predicts that the [prevalence of chronic diseases] at [Johns Hopkins Hospital] [will likely] [increase] by [10%] in [2028 Q2].
# 21                                                                          In [Q4 of 2024], [David Kim, Ph.D] from [World Health Organization] forecasts that the [average life expectancy] [may] [rise] from [75 to 80 years] in [2030].
# 22                                                                                      [Dr. Maria Rodriguez] predicts on [2024/08/20] that the [obesity rate among children] in [New York City] [should] [decrease] by [8%] in [2026 Q1].
# 23  According to a [health analyst, Michael Chen] from [Centers for Disease Control and Prevention], on [21 Aug 2024], the [prevalence of mental health disorders] [is expected to] [increase] beyond [15%] in the timeframe of [2029 Q3].
# 24                                                    In [2025-08-15], the [average daily physical activity levels] in [Australia] [will likely] [increase] by [20%], as predicted by [Dr. Sophia Patel, a health expert] on [2024-10-10].
# 25                                                  On [Wednesday, November 20, 2024], [Dr. John Smith, a senior health executive] predicts that the [prevalence of infectious diseases] at [WHO] [will] [decrease] by [12%] in [2027 Q4].
# 26                                               In [2027 Q1], [Emily Taylor, a health researcher] from [Harvard School of Public Health] envisions that the [average weekly exercise hours] [may] [rise] from [10 to 15 hours] in [2028].
# 27                                                                                   [Dr. James Davis] predicts on [2024/11/15] that the [global vaccination rate for influenza] in [Europe] [should] [stay stable] at [90%] in [2026 Q2].
# 28              According to a [health expert, Dr. Lisa Nguyen] from [National Institutes of Health], on [2024-08-25], the [prevalence of cardiovascular diseases] [is expected to] [increase] beyond [25%] in the timeframe of [2030 Q1].
# 29                                                                 In [2026-08-20], the [average daily caloric intake] in [Canada] [will likely] [decrease] by [10%], as predicted by [Dr. David Brown, a health analyst] on [2024-10-05].
# 30                                                           On [2024-10-15], [Chief Financial Officer, Michael Davis] predicts that the [stock market index] at [the New York Stock Exchange] [will likely] [rise] by [10%] in [2026 Q2].
# 31                                                                  In [Q4 of 2024], [Senior Policy Analyst, Emily Chen] from [the Federal Reserve], envisions that the [interest rates] [should] [fall] from [2.5% to 1.8%] in [2028 Q1].
# 32                                                                                        [Policy Expert, David Lee] predicts on [2024/08/20] that the [inflation rate] at [the United States] [may] [stay stable] at [2.2%] in [2027 Q3].
# 33                                According to a [Top Executive, Sarah Taylor] from [JPMorgan Chase], on [2024-08-22], the [number of mortgage applications] [is expected to] [increase] beyond [1 million] in the timeframe of [2029 Q4].
# 34                                                                   In [2025-08-20], the [unemployment rate] in [California] [is likely to] [decrease] by [1.5%] [fall], as predicted by [Policy Reporter, James Wilson] on [2024/10/12].
# 35                                                              On [Wednesday, 2024/11/06], [Financial Analyst, Kevin White] forecasts that the [GDP growth rate] at [the European Union] [will likely] [increase] by [2.8%] in [2026 Q4].
# 36                                                                                  In [2024/10/01], [Senior Economist, Lisa Nguyen] from [the World Bank], predicts that the [poverty rate] [will] [fall] from [15% to 10%] in [2028 Q2].
# 37                                                                                      [Policy Advisor, Mark Davis] predicts on [2024/09/18] that the [consumer price index] at [the United Kingdom] [may] [rise] by [1.2%] in [2027 Q1].
# 38                          According to a [Chief Economist, Daniel Kim] from [the International Monetary Fund], on [2024/08/25], the [number of bankruptcies] [is expected to] [decrease] beyond [500,000] in the timeframe of [2029 Q3].
# 39                                   In [2026 Q1], the [number of initial public offerings] in [the United States] [is expected] to be [200, which is a 25%] [increase], as predicted by [Financial Expert, Rachel Brown] on [2024/10/20].
#
#     Prediction Label               Model Name     Domain  Template Number
# 0                  1  llama-3.3-70b-versatile  financial                1
# 1                  1  llama-3.3-70b-versatile  financial                2
# 2                  1  llama-3.3-70b-versatile  financial                3
# 3                  1  llama-3.3-70b-versatile  financial                4
# 4                  1  llama-3.3-70b-versatile  financial                5
# 5                  1  llama-3.3-70b-versatile  financial                1
# 6                  1  llama-3.3-70b-versatile  financial                2
# 7                  1  llama-3.3-70b-versatile  financial                3
# 8                  1  llama-3.3-70b-versatile  financial                4
# 9                  1  llama-3.3-70b-versatile  financial                5
# 10                 1  llama-3.3-70b-versatile    weather                1
# 11                 1  llama-3.3-70b-versatile    weather                2
# 12                 1  llama-3.3-70b-versatile    weather                3
# 13                 1  llama-3.3-70b-versatile    weather                4
# 14                 1  llama-3.3-70b-versatile    weather                5
# 15                 1  llama-3.3-70b-versatile    weather                1
# 16                 1  llama-3.3-70b-versatile    weather                2
# 17                 1  llama-3.3-70b-versatile    weather                3
# 18                 1  llama-3.3-70b-versatile    weather                4
# 19                 1  llama-3.3-70b-versatile    weather                5
# 20                 1  llama-3.3-70b-versatile     health                1
# 21                 1  llama-3.3-70b-versatile     health                2
# 22                 1  llama-3.3-70b-versatile     health                3
# 23                 1  llama-3.3-70b-versatile     health                4
# 24                 1  llama-3.3-70b-versatile     health                5
# 25                 1  llama-3.3-70b-versatile     health                1
# 26                 1  llama-3.3-70b-versatile     health                2
# 27                 1  llama-3.3-70b-versatile     health                3
# 28                 1  llama-3.3-70b-versatile     health                4
# 29                 1  llama-3.3-70b-versatile     health                5
# 30                 1  llama-3.3-70b-versatile     policy                1
# 31                 1  llama-3.3-70b-versatile     policy                2
# 32                 1  llama-3.3-70b-versatile     policy                3
# 33                 1  llama-3.3-70b-versatile     policy                4
# 34                 1  llama-3.3-70b-versatile     policy                5
# 35                 1  llama-3.3-70b-versatile     policy                1
# 36                 1  llama-3.3-70b-versatile     policy                2
# 37                 1  llama-3.3-70b-versatile     policy                3
# 38                 1  llama-3.3-70b-versatile     policy                4
# 39                 1  llama-3.3-70b-versatile     policy                5

# %%
only_predictions = DataProcessing.df_to_list(updated_predictions_df, 'Base Sentence')
only_predictions
# Out:
# ['On [2024-10-20], [Samantha Thompson, a financial analyst] predicts that the [operating cash flow] at [Johnson & Johnson] [will likely] [increase] by [10 percent to $25 billion] in [2026 Q2].',
#  'In [Q4 of 2024], [Ethan Kim] from [Goldman Sachs], forecasts that the [stock price] [will] [fall] from [$120 to $90 per share] in [2028 Q1].',
#  '[Alexander Brown, a financial expert] predicts on [15 November 2024] that the [research and development expenses] at [Intel] [may] [stay stable] at [$15 million] in [2027 Q3].',
#  'According to a [senior executive] from [Coca-Cola], on [2024/08/25], the [net profit] [is expected to] [increase] beyond [$5 billion] in the timeframe of [2029 Q4].',
#  'In [2025-02-15], the [revenue] at [Visa] [will] [rise] by [15 percent to $30 billion] [increase], as predicted by [David Lee, a financial reporter] on [2024-10-10].',
#  'On [Wednesday, August 28, 2024], [Olivia Patel, an investor] predicts that the [gross profit] at [UnitedHealth Group] [should] [decrease] by [5 percent to $10 billion] in [2026 Q4].',
#  'In [2027 Q1], [Jackson Davis] from [Morgan Stanley], envisions that the [operating income] [will] [rise] from [$10 billion to $15 billion] in [2028 Q2].',
#  '[Ava Morales, a financial analyst] predicts on [2024-09-20] that the [net profit] at [Procter & Gamble] [may] [fall] under [10 percent to $5 billion] in [2027 Q1].',
#  'According to [Emily Chen] from [Cisco Systems], on [2024/11/15], the [research and development expenses] [may] [increase] as much as [$500 million, reflecting a 20 percent increase] by [2026 Q3].',
#  'In [2029 Q3], the [stock price] at [3M] [is expected to] [decrease] by [10 percent to $100 per share] [fall], as predicted by [Michael Kim, a financial expert] on [2024-08-10].',
#  'On [2024-10-20], [Emily Chen], a senior meteorologist at [National Weather Service], predicts that the [precipitation levels] at [National Weather Service] in [Los Angeles] [will likely] [increase] by [15%] in [2025-03-15].',
#  'In [Q4 of 2024], [Michael Brown] from [Weather.com] in [New York City], predicts that the [temperature] [will] [decrease] from [10°C to 5°C] in [2025-02-10].',
#  '[Sarah Lee], a weather expert from [Bureau of Meteorology], predicts on [2024/08/25] that the [humidity] in [Chicago] [will] [rise] by [20%] in [2025 Quarter 2].',
#  'According to a [weather analyst] from [AccuWeather], on [2024-08-18], the [wind speed] in [Miami] [is expected to] [increase] beyond [10 mph] in the timeframe of [2025-06-01].',
#  'In [2027-09-20], the [snowfall levels] at [National Weather Service] in [Denver] [will likely] [increase] by [10 inches], as predicted by [David Kim], a weather reporter from [US Weather Center], on [2024-10-12].',
#  'On [21 Aug 2024], [Olivia Patel], a weather senior level person at [Meteorological Department], predicts that the [air quality index] at [Meteorological Department] in [Seattle] [will] [improve] by [15%] in [2025-04-15].',
#  'In [2026-01-01], [Kevin White] from [Weather Underground] in [Boston], predicts that the [rainfall] [will] [decrease] from [5 inches to 3 inches] in [2026-07-01].',
#  '[Rebecca Hall], a weather top executive from [National Oceanic and Atmospheric Administration], predicts on [2024-09-15] that the [temperature] in [Dallas] [will] [fall] by [12°F] in [2025-01-01].',
#  'According to a [weather expert] from [The Weather Channel], on [2024/11/20], the [precipitation levels] in [San Francisco] [are expected to] [increase] beyond [20%] in the timeframe of [2026-03-01].',
#  'In [2028-10-15], the [average temperature] at [National Weather Service] in [Washington D.C.] [is likely to] [decrease] by [5°F], as predicted by [James Davis], a weather analyst from [National Weather Service], on [2024-09-10].',
#  'On [2024-10-15], [Dr. Rachel Lee, a health expert] predicts that the [prevalence of chronic diseases] at [Johns Hopkins Hospital] [will likely] [increase] by [10%] in [2028 Q2].',
#  'In [Q4 of 2024], [David Kim, Ph.D] from [World Health Organization] forecasts that the [average life expectancy] [may] [rise] from [75 to 80 years] in [2030].',
#  '[Dr. Maria Rodriguez] predicts on [2024/08/20] that the [obesity rate among children] in [New York City] [should] [decrease] by [8%] in [2026 Q1].',
#  'According to a [health analyst, Michael Chen] from [Centers for Disease Control and Prevention], on [21 Aug 2024], the [prevalence of mental health disorders] [is expected to] [increase] beyond [15%] in the timeframe of [2029 Q3].',
#  'In [2025-08-15], the [average daily physical activity levels] in [Australia] [will likely] [increase] by [20%], as predicted by [Dr. Sophia Patel, a health expert] on [2024-10-10].',
#  'On [Wednesday, November 20, 2024], [Dr. John Smith, a senior health executive] predicts that the [prevalence of infectious diseases] at [WHO] [will] [decrease] by [12%] in [2027 Q4].',
#  'In [2027 Q1], [Emily Taylor, a health researcher] from [Harvard School of Public Health] envisions that the [average weekly exercise hours] [may] [rise] from [10 to 15 hours] in [2028].',
#  '[Dr. James Davis] predicts on [2024/11/15] that the [global vaccination rate for influenza] in [Europe] [should] [stay stable] at [90%] in [2026 Q2].',
#  'According to a [health expert, Dr. Lisa Nguyen] from [National Institutes of Health], on [2024-08-25], the [prevalence of cardiovascular diseases] [is expected to] [increase] beyond [25%] in the timeframe of [2030 Q1].',
#  'In [2026-08-20], the [average daily caloric intake] in [Canada] [will likely] [decrease] by [10%], as predicted by [Dr. David Brown, a health analyst] on [2024-10-05].',
#  'On [2024-10-15], [Chief Financial Officer, Michael Davis] predicts that the [stock market index] at [the New York Stock Exchange] [will likely] [rise] by [10%] in [2026 Q2].',
#  'In [Q4 of 2024], [Senior Policy Analyst, Emily Chen] from [the Federal Reserve], envisions that the [interest rates] [should] [fall] from [2.5% to 1.8%] in [2028 Q1].',
#  '[Policy Expert, David Lee] predicts on [2024/08/20] that the [inflation rate] at [the United States] [may] [stay stable] at [2.2%] in [2027 Q3].',
#  'According to a [Top Executive, Sarah Taylor] from [JPMorgan Chase], on [2024-08-22], the [number of mortgage applications] [is expected to] [increase] beyond [1 million] in the timeframe of [2029 Q4].',
#  'In [2025-08-20], the [unemployment rate] in [California] [is likely to] [decrease] by [1.5%] [fall], as predicted by [Policy Reporter, James Wilson] on [2024/10/12].',
#  'On [Wednesday, 2024/11/06], [Financial Analyst, Kevin White] forecasts that the [GDP growth rate] at [the European Union] [will likely] [increase] by [2.8%] in [2026 Q4].',
#  'In [2024/10/01], [Senior Economist, Lisa Nguyen] from [the World Bank], predicts that the [poverty rate] [will] [fall] from [15% to 10%] in [2028 Q2].',
#  '[Policy Advisor, Mark Davis] predicts on [2024/09/18] that the [consumer price index] at [the United Kingdom] [may] [rise] by [1.2%] in [2027 Q1].',
#  'According to a [Chief Economist, Daniel Kim] from [the International Monetary Fund], on [2024/08/25], the [number of bankruptcies] [is expected to] [decrease] beyond [500,000] in the timeframe of [2029 Q3].',
#  'In [2026 Q1], the [number of initial public offerings] in [the United States] [is expected] to be [200, which is a 25%] [increase], as predicted by [Financial Expert, Rachel Brown] on [2024/10/20].']

# %%
ner_dfs = []
for doc in nlp.pipe(only_predictions, disable=["tok2vec", "parser", "attribute_ruler", "lemmatizer"]):
    # print(f"sentence: {doc}")
    columns = []
    values = []
    for ent in doc.ents:
        if ent.label_ in columns:
            columns.append(f"{ent.label_}_2")
        else:
            columns.append(ent.label_)
        values.append(ent.text)
        # print(f"    cols_name: {ent.label_}")
        # print(f"        text: {ent.text}")
    ner_df = pd.DataFrame([values], columns=columns)
    # print(ner_df)
    ner_dfs.append(ner_df)

# %%
ner_dfs[4]
# Out:
#          DATE     PERCENT        MONEY     PERSON      DATE_2
# 0  2025-02-15  15 percent  $30 billion  David Lee  2024-10-10

# %%
import spacy
import pandas as pd

# Load English tokenizer, tagger, parser, and NER
nlp = spacy.load("en_core_web_sm")

# Define the data
texts = [
    "Apple is looking at buying U.K. startup for $1 billion",
    "San Francisco considers banning sidewalk delivery robots",
    "London is a big city in the United Kingdom."
]

# Create an empty list to store the NER results
ner_results = []

# Process the texts and extract named entities
for doc in nlp.pipe(only_predictions, disable=["tok2vec", "tagger", "parser", "lemmatizer"]):
    doc_ents = [(ent.text, ent.label_) for ent in doc.ents]
    ner_results.append(doc_ents)

# Find all unique NER tags and convert the set to a list
all_tags = list(set([ent[1] for doc_ents in ner_results for ent in doc_ents]))

# Create a DataFrame with one column for each tag and rows corresponding to each document
df_ner = pd.DataFrame(columns=all_tags)

for i, doc_ents in enumerate(ner_results):
    for ent in doc_ents:
        df_ner.at[i, ent[1]] = ent[0]

# Display the DataFrame with ner results
print(df_ner)
# Out:
#       CARDINAL        DATE           WORK_OF_ART                GPE  \
# 0          NaN        2026                   NaN                NaN
# 1          NaN        2028            Q4 of 2024                NaN
# 2           15        2027                   NaN                NaN
# 3   2024/08/25        2029                   NaN                NaN
# 4          NaN  2024-10-10                   NaN                NaN
# 5          NaN        2026                   NaN                NaN
# 6          NaN        2028                   NaN                NaN
# 7          NaN        2027                   NaN                NaN
# 8   2024/11/15        2026                   NaN                NaN
# 9          NaN  2024-08-10                   NaN                NaN
# 10         NaN  2025-03-15                   NaN        Los Angeles
# 11          10  2025-02-10            Q4 of 2024      New York City
# 12  2024/08/25        2025             Quarter 2            Chicago
# 13         NaN  2025-06-01                   NaN              Miami
# 14         NaN  2024-10-12                   NaN                 US
# 15          21  2025-04-15                   NaN            Seattle
# 16         NaN  2026-07-01   Weather Underground             Boston
# 17          12  2025-01-01                   NaN             Dallas
# 18  2024/11/20  2026-03-01  The Weather Channel]      San Francisco
# 19           5  2024-09-10                   NaN    Washington D.C.
# 20         NaN        2028                   NaN                NaN
# 21         NaN        2030            Q4 of 2024                NaN
# 22  2024/08/20        2026                   NaN      New York City
# 23          21        2024                   NaN                NaN
# 24         NaN  2024-10-10                   NaN          Australia
# 25         NaN        2027                   NaN                NaN
# 26        2028      weekly                   NaN                NaN
# 27  2024/11/15        2026                   NaN                NaN
# 28         NaN  2024-08-25               2030 Q1                NaN
# 29         NaN  2024-10-05                   NaN             Canada
# 30         NaN        2026                   NaN                NaN
# 31         NaN        2028            Q4 of 2024                NaN
# 32  2024/08/20        2027                   NaN  the United States
# 33   1 million        2029                   NaN                NaN
# 34  2024/10/12  2025-08-20                   NaN         California
# 35  2024/11/06        2026                   NaN                NaN
# 36         NaN        2028                   NaN                NaN
# 37  2024/09/18        2027                   NaN     United Kingdom
# 38     500,000         NaN                   NaN                NaN
# 39  2024/10/20        2026                   NaN  the United States
#
#                PERSON            TIME              QUANTITY  \
# 0   Samantha Thompson             NaN                   NaN
# 1           Ethan Kim             NaN                   NaN
# 2     Alexander Brown             NaN                   NaN
# 3                 NaN             NaN                   NaN
# 4           David Lee             NaN                   NaN
# 5        Olivia Patel             NaN                   NaN
# 6       Jackson Davis             NaN                   NaN
# 7         Ava Morales             NaN                   NaN
# 8          Emily Chen             NaN                   NaN
# 9         Michael Kim             NaN                   NaN
# 10         Emily Chen             NaN                   NaN
# 11      Michael Brown             NaN                   NaN
# 12          Sarah Lee             NaN                   NaN
# 13                NaN             NaN                10 mph
# 14          David Kim             NaN             10 inches
# 15       Olivia Patel             NaN                   NaN
# 16        Kevin White             NaN  5 inches to 3 inches
# 17                NaN             NaN                   NaN
# 18                NaN             NaN                   NaN
# 19        James Davis             NaN                   NaN
# 20         Rachel Lee             NaN                   NaN
# 21          David Kim             NaN                   NaN
# 22    Maria Rodriguez             NaN                   NaN
# 23       Michael Chen             NaN                   NaN
# 24       Sophia Patel             NaN                   NaN
# 25         John Smith             NaN                   NaN
# 26       Emily Taylor  10 to 15 hours                   NaN
# 27        James Davis             NaN                   NaN
# 28        Lisa Nguyen             NaN                   NaN
# 29        David Brown             NaN                   NaN
# 30      Michael Davis             NaN                   NaN
# 31         Emily Chen             NaN                   NaN
# 32          David Lee             NaN                   NaN
# 33       Sarah Taylor             NaN                   NaN
# 34       James Wilson             NaN                   NaN
# 35        Kevin White             NaN                   NaN
# 36        Lisa Nguyen             NaN                   NaN
# 37         Mark Davis             NaN                   NaN
# 38         Daniel Kim             NaN                   NaN
# 39       Rachel Brown             NaN                   NaN
#
#                          MONEY       PERCENT     LOC           FAC  \
# 0                  $25 billion    10 percent     NaN           NaN
# 1                           90           NaN     NaN           NaN
# 2                  $15 million           NaN     NaN           NaN
# 3                   $5 billion           NaN     NaN           NaN
# 4                  $30 billion    15 percent     NaN           NaN
# 5                  $10 billion     5 percent     NaN           NaN
# 6   $10 billion to $15 billion           NaN     NaN           NaN
# 7                   $5 billion    10 percent     NaN           NaN
# 8                 $500 million    20 percent     NaN           NaN
# 9                          100    10 percent     NaN           NaN
# 10                         NaN           15%     NaN           NaN
# 11                         NaN           NaN     NaN           NaN
# 12                         NaN           20%     NaN           NaN
# 13                         NaN           NaN     NaN           NaN
# 14                         NaN           NaN     NaN           NaN
# 15                         NaN           15%     NaN           NaN
# 16                         NaN           NaN     NaN           NaN
# 17                         NaN           NaN     NaN  Rebecca Hall
# 18                         NaN           20%     NaN           NaN
# 19                         NaN           NaN     NaN           NaN
# 20                         NaN           10%     NaN           NaN
# 21                         NaN           NaN     NaN           NaN
# 22                         NaN            8%     NaN           NaN
# 23                         NaN           15%     NaN           NaN
# 24                         NaN           20%     NaN           NaN
# 25                         NaN           12%     NaN           NaN
# 26                         NaN           NaN     NaN           NaN
# 27                         NaN           90%  Europe           NaN
# 28                         NaN           25%     NaN           NaN
# 29                         NaN           10%     NaN           NaN
# 30                         NaN           10%     NaN           NaN
# 31                         NaN  2.5% to 1.8%     NaN           NaN
# 32                         NaN          2.2%     NaN           NaN
# 33                         NaN           NaN     NaN           NaN
# 34                         NaN          1.5%     NaN           NaN
# 35                         NaN          2.8%     NaN           NaN
# 36                         NaN    15% to 10%     NaN           NaN
# 37                         NaN          1.2%     NaN           NaN
# 38                         NaN           NaN     NaN           NaN
# 39                         NaN           25%     NaN           NaN
#
#                                                 ORG
# 0                                 Johnson & Johnson
# 1                                     Goldman Sachs
# 2                                             Intel
# 3                                         Coca-Cola
# 4                                               NaN
# 5                                UnitedHealth Group
# 6                                    Morgan Stanley
# 7                                  Procter & Gamble
# 8                                     Cisco Systems
# 9                                               NaN
# 10                         National Weather Service
# 11                                      Weather.com
# 12                            Bureau of Meteorology
# 13                                      AccuWeather
# 14                         National Weather Service
# 15                        Meteorological Department
# 16                                              NaN
# 17  National Oceanic and Atmospheric Administration
# 18                                              NaN
# 19                         National Weather Service
# 20                           Johns Hopkins Hospital
# 21                        World Health Organization
# 22                                              NaN
# 23       Centers for Disease Control and Prevention
# 24                                              NaN
# 25                                              NaN
# 26                  Harvard School of Public Health
# 27                                              NaN
# 28                    National Institutes of Health
# 29                                              NaN
# 30                      the New York Stock Exchange
# 31                              the Federal Reserve
# 32                                              NaN
# 33                                   JPMorgan Chase
# 34                                              NaN
# 35                               the European Union
# 36                                   the World Bank
# 37                                              NaN
# 38                  the International Monetary Fund
# 39                                 Financial Expert

# %%
df_ner
# Out:
#       CARDINAL        DATE           WORK_OF_ART                GPE  \
# 0          NaN        2026                   NaN                NaN
# 1          NaN        2028            Q4 of 2024                NaN
# 2           15        2027                   NaN                NaN
# 3   2024/08/25        2029                   NaN                NaN
# 4          NaN  2024-10-10                   NaN                NaN
# 5          NaN        2026                   NaN                NaN
# 6          NaN        2028                   NaN                NaN
# 7          NaN        2027                   NaN                NaN
# 8   2024/11/15        2026                   NaN                NaN
# 9          NaN  2024-08-10                   NaN                NaN
# 10         NaN  2025-03-15                   NaN        Los Angeles
# 11          10  2025-02-10            Q4 of 2024      New York City
# 12  2024/08/25        2025             Quarter 2            Chicago
# 13         NaN  2025-06-01                   NaN              Miami
# 14         NaN  2024-10-12                   NaN                 US
# 15          21  2025-04-15                   NaN            Seattle
# 16         NaN  2026-07-01   Weather Underground             Boston
# 17          12  2025-01-01                   NaN             Dallas
# 18  2024/11/20  2026-03-01  The Weather Channel]      San Francisco
# 19           5  2024-09-10                   NaN    Washington D.C.
# 20         NaN        2028                   NaN                NaN
# 21         NaN        2030            Q4 of 2024                NaN
# 22  2024/08/20        2026                   NaN      New York City
# 23          21        2024                   NaN                NaN
# 24         NaN  2024-10-10                   NaN          Australia
# 25         NaN        2027                   NaN                NaN
# 26        2028      weekly                   NaN                NaN
# 27  2024/11/15        2026                   NaN                NaN
# 28         NaN  2024-08-25               2030 Q1                NaN
# 29         NaN  2024-10-05                   NaN             Canada
# 30         NaN        2026                   NaN                NaN
# 31         NaN        2028            Q4 of 2024                NaN
# 32  2024/08/20        2027                   NaN  the United States
# 33   1 million        2029                   NaN                NaN
# 34  2024/10/12  2025-08-20                   NaN         California
# 35  2024/11/06        2026                   NaN                NaN
# 36         NaN        2028                   NaN                NaN
# 37  2024/09/18        2027                   NaN     United Kingdom
# 38     500,000         NaN                   NaN                NaN
# 39  2024/10/20        2026                   NaN  the United States
#
#                PERSON            TIME              QUANTITY  \
# 0   Samantha Thompson             NaN                   NaN
# 1           Ethan Kim             NaN                   NaN
# 2     Alexander Brown             NaN                   NaN
# 3                 NaN             NaN                   NaN
# 4           David Lee             NaN                   NaN
# 5        Olivia Patel             NaN                   NaN
# 6       Jackson Davis             NaN                   NaN
# 7         Ava Morales             NaN                   NaN
# 8          Emily Chen             NaN                   NaN
# 9         Michael Kim             NaN                   NaN
# 10         Emily Chen             NaN                   NaN
# 11      Michael Brown             NaN                   NaN
# 12          Sarah Lee             NaN                   NaN
# 13                NaN             NaN                10 mph
# 14          David Kim             NaN             10 inches
# 15       Olivia Patel             NaN                   NaN
# 16        Kevin White             NaN  5 inches to 3 inches
# 17                NaN             NaN                   NaN
# 18                NaN             NaN                   NaN
# 19        James Davis             NaN                   NaN
# 20         Rachel Lee             NaN                   NaN
# 21          David Kim             NaN                   NaN
# 22    Maria Rodriguez             NaN                   NaN
# 23       Michael Chen             NaN                   NaN
# 24       Sophia Patel             NaN                   NaN
# 25         John Smith             NaN                   NaN
# 26       Emily Taylor  10 to 15 hours                   NaN
# 27        James Davis             NaN                   NaN
# 28        Lisa Nguyen             NaN                   NaN
# 29        David Brown             NaN                   NaN
# 30      Michael Davis             NaN                   NaN
# 31         Emily Chen             NaN                   NaN
# 32          David Lee             NaN                   NaN
# 33       Sarah Taylor             NaN                   NaN
# 34       James Wilson             NaN                   NaN
# 35        Kevin White             NaN                   NaN
# 36        Lisa Nguyen             NaN                   NaN
# 37         Mark Davis             NaN                   NaN
# 38         Daniel Kim             NaN                   NaN
# 39       Rachel Brown             NaN                   NaN
#
#                          MONEY       PERCENT     LOC           FAC  \
# 0                  $25 billion    10 percent     NaN           NaN
# 1                           90           NaN     NaN           NaN
# 2                  $15 million           NaN     NaN           NaN
# 3                   $5 billion           NaN     NaN           NaN
# 4                  $30 billion    15 percent     NaN           NaN
# 5                  $10 billion     5 percent     NaN           NaN
# 6   $10 billion to $15 billion           NaN     NaN           NaN
# 7                   $5 billion    10 percent     NaN           NaN
# 8                 $500 million    20 percent     NaN           NaN
# 9                          100    10 percent     NaN           NaN
# 10                         NaN           15%     NaN           NaN
# 11                         NaN           NaN     NaN           NaN
# 12                         NaN           20%     NaN           NaN
# 13                         NaN           NaN     NaN           NaN
# 14                         NaN           NaN     NaN           NaN
# 15                         NaN           15%     NaN           NaN
# 16                         NaN           NaN     NaN           NaN
# 17                         NaN           NaN     NaN  Rebecca Hall
# 18                         NaN           20%     NaN           NaN
# 19                         NaN           NaN     NaN           NaN
# 20                         NaN           10%     NaN           NaN
# 21                         NaN           NaN     NaN           NaN
# 22                         NaN            8%     NaN           NaN
# 23                         NaN           15%     NaN           NaN
# 24                         NaN           20%     NaN           NaN
# 25                         NaN           12%     NaN           NaN
# 26                         NaN           NaN     NaN           NaN
# 27                         NaN           90%  Europe           NaN
# 28                         NaN           25%     NaN           NaN
# 29                         NaN           10%     NaN           NaN
# 30                         NaN           10%     NaN           NaN
# 31                         NaN  2.5% to 1.8%     NaN           NaN
# 32                         NaN          2.2%     NaN           NaN
# 33                         NaN           NaN     NaN           NaN
# 34                         NaN          1.5%     NaN           NaN
# 35                         NaN          2.8%     NaN           NaN
# 36                         NaN    15% to 10%     NaN           NaN
# 37                         NaN          1.2%     NaN           NaN
# 38                         NaN           NaN     NaN           NaN
# 39                         NaN           25%     NaN           NaN
#
#                                                 ORG
# 0                                 Johnson & Johnson
# 1                                     Goldman Sachs
# 2                                             Intel
# 3                                         Coca-Cola
# 4                                               NaN
# 5                                UnitedHealth Group
# 6                                    Morgan Stanley
# 7                                  Procter & Gamble
# 8                                     Cisco Systems
# 9                                               NaN
# 10                         National Weather Service
# 11                                      Weather.com
# 12                            Bureau of Meteorology
# 13                                      AccuWeather
# 14                         National Weather Service
# 15                        Meteorological Department
# 16                                              NaN
# 17  National Oceanic and Atmospheric Administration
# 18                                              NaN
# 19                         National Weather Service
# 20                           Johns Hopkins Hospital
# 21                        World Health Organization
# 22                                              NaN
# 23       Centers for Disease Control and Prevention
# 24                                              NaN
# 25                                              NaN
# 26                  Harvard School of Public Health
# 27                                              NaN
# 28                    National Institutes of Health
# 29                                              NaN
# 30                      the New York Stock Exchange
# 31                              the Federal Reserve
# 32                                              NaN
# 33                                   JPMorgan Chase
# 34                                              NaN
# 35                               the European Union
# 36                                   the World Bank
# 37                                              NaN
# 38                  the International Monetary Fund
# 39                                 Financial Expert

# %%
# %store ner_dfs
