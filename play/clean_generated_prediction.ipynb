# %% [markdown]
# # Clean Predictions
#
# - **Goal:** Prediction Recognition
# - **Purpose:** To implement step 1 with sub steps of prediction recognition pipeline. See steps
#     - (2) Clean the generated predictions
# - **Misc:**
#     - `%load` and `%run` with cell magic: This allows us to get code from another notebook

# %%
import os
import sys

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from clean_predictions import PredictionDataCleaner

# %%
generate_predictions_notebook = 'generate_prediction.ipynb'
# %run $generate_predictions_notebook

# %%
predictions_df
# Out:
#                                                                                                                                                                                Base Predictions  \
# 0                                                          On Friday, November 15, 2024, Emily Chen forecasts that the revenue at Amazon (AMZN) will rise by 12% to $150 billion in Q2 of 2026.
# 1                                On Wednesday, October 23, 2024, Julian Sanchez envisions that the stock price at Microsoft (MSFT) will likely increase by 20% to $400 per share in Q4 of 2027.
# 2                                           On Monday, September 16, 2024, David Kim predicts that the operating cash flow at Chevron (CVX) should decrease by 4% to $15 billion in Q1 of 2028.
# 3                                   On Tuesday, August 20, 2024, Sophia Rodriguez speculates that the dividend payout ratio at Procter & Gamble (PG) will probably remain at 60% in Q3 of 2026.
# 4  On Thursday, July 18, 2024, Michael Davis forecasts that the research and development expenses at Johnson & Johnson (JNJ) have a high chance of increasing by 10% to $12 billion in FY 2029.
# 5                                                        On Wednesday, June 19, 2024, Olivia Brown predicts that the return on equity (ROE) at Visa (V) may improve by 3% to 25% in Q2 of 2028.
# 6                                            On Friday, May 17, 2024, William White envisions that the capital expenditures at AT&T (T) will likely decrease by 5% to $3 billion in Q4 of 2027.
# 7                                           On Monday, April 15, 2024, Ava Moreno forsees that the gross profit margin at Cisco Systems (CSCO) will probably expand by 2% to 20% in Q1 of 2029.
# 8                                                              On Tuesday, March 19, 2024, Ethan Hall predicts that the total debt at 3M (MMM) may decrease by 8% to $10 billion in Q3 of 2028.
# 9                   On Thursday, February 21, 2024, Logan Brooks forecasts that the earnings before interest and taxes (EBIT) at Walmart (WMT) should increase by 6% to $25 billion in FY 2028.
#
#    Prediction Label
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True

# %%
non_predictions_df
# Out:
#                                    Base Predictions  Prediction Label
# 1                     1. The sun rises in the east.             False
# 2                      2. The book is on the table.             False
# 3      3. The company has a strong management team.             False
# 4     4. The city is very crowded during rush hour.             False
# 5      5. The teacher is writing on the blackboard.             False
# 6        6. The flowers are blooming in the garden.             False
# 7       7. The music is playing loudly in the room.             False
# 8  8. The dog is running quickly around the corner.             False
# 9     9. The coffee is hot and steaming in the cup.             False

# %%
predictions_df = pd.concat([predictions_df, non_predictions_df], ignore_index=True)
predictions_df
# Out:
#                                                                                                                                                                                 Base Predictions  \
# 0                                                           On Friday, November 15, 2024, Emily Chen forecasts that the revenue at Amazon (AMZN) will rise by 12% to $150 billion in Q2 of 2026.
# 1                                 On Wednesday, October 23, 2024, Julian Sanchez envisions that the stock price at Microsoft (MSFT) will likely increase by 20% to $400 per share in Q4 of 2027.
# 2                                            On Monday, September 16, 2024, David Kim predicts that the operating cash flow at Chevron (CVX) should decrease by 4% to $15 billion in Q1 of 2028.
# 3                                    On Tuesday, August 20, 2024, Sophia Rodriguez speculates that the dividend payout ratio at Procter & Gamble (PG) will probably remain at 60% in Q3 of 2026.
# 4   On Thursday, July 18, 2024, Michael Davis forecasts that the research and development expenses at Johnson & Johnson (JNJ) have a high chance of increasing by 10% to $12 billion in FY 2029.
# 5                                                         On Wednesday, June 19, 2024, Olivia Brown predicts that the return on equity (ROE) at Visa (V) may improve by 3% to 25% in Q2 of 2028.
# 6                                             On Friday, May 17, 2024, William White envisions that the capital expenditures at AT&T (T) will likely decrease by 5% to $3 billion in Q4 of 2027.
# 7                                            On Monday, April 15, 2024, Ava Moreno forsees that the gross profit margin at Cisco Systems (CSCO) will probably expand by 2% to 20% in Q1 of 2029.
# 8                                                               On Tuesday, March 19, 2024, Ethan Hall predicts that the total debt at 3M (MMM) may decrease by 8% to $10 billion in Q3 of 2028.
# 9                    On Thursday, February 21, 2024, Logan Brooks forecasts that the earnings before interest and taxes (EBIT) at Walmart (WMT) should increase by 6% to $25 billion in FY 2028.
# 10                                                                                                                                                                 1. The sun rises in the east.
# 11                                                                                                                                                                  2. The book is on the table.
# 12                                                                                                                                                  3. The company has a strong management team.
# 13                                                                                                                                                 4. The city is very crowded during rush hour.
# 14                                                                                                                                                  5. The teacher is writing on the blackboard.
# 15                                                                                                                                                    6. The flowers are blooming in the garden.
# 16                                                                                                                                                   7. The music is playing loudly in the room.
# 17                                                                                                                                              8. The dog is running quickly around the corner.
# 18                                                                                                                                                 9. The coffee is hot and steaming in the cup.
#
#     Prediction Label
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False

# %%
predictions_col = predictions_df.columns[0]
predictions_col
# Out:
# 'Base Predictions'

# %%
cleaner = PredictionDataCleaner(predictions_df)
cleaner.lower_case(predictions_col)
# Out:
#                                                                                                                                                                                 Base Predictions  \
# 0                                                           on friday, november 15, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                                 on wednesday, october 23, 2024, julian sanchez envisions that the stock price at microsoft (msft) will likely increase by 20% to $400 per share in q4 of 2027.
# 2                                            on monday, september 16, 2024, david kim predicts that the operating cash flow at chevron (cvx) should decrease by 4% to $15 billion in q1 of 2028.
# 3                                    on tuesday, august 20, 2024, sophia rodriguez speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2026.
# 4   on thursday, july 18, 2024, michael davis forecasts that the research and development expenses at johnson & johnson (jnj) have a high chance of increasing by 10% to $12 billion in fy 2029.
# 5                                                         on wednesday, june 19, 2024, olivia brown predicts that the return on equity (roe) at visa (v) may improve by 3% to 25% in q2 of 2028.
# 6                                             on friday, may 17, 2024, william white envisions that the capital expenditures at at&t (t) will likely decrease by 5% to $3 billion in q4 of 2027.
# 7                                            on monday, april 15, 2024, ava moreno forsees that the gross profit margin at cisco systems (csco) will probably expand by 2% to 20% in q1 of 2029.
# 8                                                               on tuesday, march 19, 2024, ethan hall predicts that the total debt at 3m (mmm) may decrease by 8% to $10 billion in q3 of 2028.
# 9                    on thursday, february 21, 2024, logan brooks forecasts that the earnings before interest and taxes (ebit) at walmart (wmt) should increase by 6% to $25 billion in fy 2028.
# 10                                                                                                                                                                 1. the sun rises in the east.
# 11                                                                                                                                                                  2. the book is on the table.
# 12                                                                                                                                                  3. the company has a strong management team.
# 13                                                                                                                                                 4. the city is very crowded during rush hour.
# 14                                                                                                                                                  5. the teacher is writing on the blackboard.
# 15                                                                                                                                                    6. the flowers are blooming in the garden.
# 16                                                                                                                                                   7. the music is playing loudly in the room.
# 17                                                                                                                                              8. the dog is running quickly around the corner.
# 18                                                                                                                                                 9. the coffee is hot and steaming in the cup.
#
#     Prediction Label
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False

# %%
cleaner.remove_html_and_urls(predictions_col)
# Out:
#                                                                                                                                                                                 Base Predictions  \
# 0                                                           on friday, november 15, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                                 on wednesday, october 23, 2024, julian sanchez envisions that the stock price at microsoft (msft) will likely increase by 20% to $400 per share in q4 of 2027.
# 2                                            on monday, september 16, 2024, david kim predicts that the operating cash flow at chevron (cvx) should decrease by 4% to $15 billion in q1 of 2028.
# 3                                    on tuesday, august 20, 2024, sophia rodriguez speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2026.
# 4   on thursday, july 18, 2024, michael davis forecasts that the research and development expenses at johnson & johnson (jnj) have a high chance of increasing by 10% to $12 billion in fy 2029.
# 5                                                         on wednesday, june 19, 2024, olivia brown predicts that the return on equity (roe) at visa (v) may improve by 3% to 25% in q2 of 2028.
# 6                                             on friday, may 17, 2024, william white envisions that the capital expenditures at at&t (t) will likely decrease by 5% to $3 billion in q4 of 2027.
# 7                                            on monday, april 15, 2024, ava moreno forsees that the gross profit margin at cisco systems (csco) will probably expand by 2% to 20% in q1 of 2029.
# 8                                                               on tuesday, march 19, 2024, ethan hall predicts that the total debt at 3m (mmm) may decrease by 8% to $10 billion in q3 of 2028.
# 9                    on thursday, february 21, 2024, logan brooks forecasts that the earnings before interest and taxes (ebit) at walmart (wmt) should increase by 6% to $25 billion in fy 2028.
# 10                                                                                                                                                                 1. the sun rises in the east.
# 11                                                                                                                                                                  2. the book is on the table.
# 12                                                                                                                                                  3. the company has a strong management team.
# 13                                                                                                                                                 4. the city is very crowded during rush hour.
# 14                                                                                                                                                  5. the teacher is writing on the blackboard.
# 15                                                                                                                                                    6. the flowers are blooming in the garden.
# 16                                                                                                                                                   7. the music is playing loudly in the room.
# 17                                                                                                                                              8. the dog is running quickly around the corner.
# 18                                                                                                                                                 9. the coffee is hot and steaming in the cup.
#
#     Prediction Label
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False

# %%
cleaner.remove_contractions(predictions_col)
# Out:
#                                                                                                                                                                                 Base Predictions  \
# 0                                                           on friday, november 15, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                                 on wednesday, october 23, 2024, julian sanchez envisions that the stock price at microsoft (msft) will likely increase by 20% to $400 per share in q4 of 2027.
# 2                                            on monday, september 16, 2024, david kim predicts that the operating cash flow at chevron (cvx) should decrease by 4% to $15 billion in q1 of 2028.
# 3                                    on tuesday, august 20, 2024, sophia rodriguez speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2026.
# 4   on thursday, july 18, 2024, michael davis forecasts that the research and development expenses at johnson & johnson (jnj) have a high chance of increasing by 10% to $12 billion in fy 2029.
# 5                                                         on wednesday, june 19, 2024, olivia brown predicts that the return on equity (roe) at visa (v) may improve by 3% to 25% in q2 of 2028.
# 6                                             on friday, may 17, 2024, william white envisions that the capital expenditures at at&t (t) will likely decrease by 5% to $3 billion in q4 of 2027.
# 7                                            on monday, april 15, 2024, ava moreno forsees that the gross profit margin at cisco systems (csco) will probably expand by 2% to 20% in q1 of 2029.
# 8                                                               on tuesday, march 19, 2024, ethan hall predicts that the total debt at 3m (mmm) may decrease by 8% to $10 billion in q3 of 2028.
# 9                    on thursday, february 21, 2024, logan brooks forecasts that the earnings before interest and taxes (ebit) at walmart (wmt) should increase by 6% to $25 billion in fy 2028.
# 10                                                                                                                                                                 1. the sun rises in the east.
# 11                                                                                                                                                                  2. the book is on the table.
# 12                                                                                                                                                  3. the company has a strong management team.
# 13                                                                                                                                                 4. the city is very crowded during rush hour.
# 14                                                                                                                                                  5. the teacher is writing on the blackboard.
# 15                                                                                                                                                    6. the flowers are blooming in the garden.
# 16                                                                                                                                                   7. the music is playing loudly in the room.
# 17                                                                                                                                              8. the dog is running quickly around the corner.
# 18                                                                                                                                                 9. the coffee is hot and steaming in the cup.
#
#     Prediction Label
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False

# %%
# May need to keep so we don't remove numbers, percentages, etc.
# cleaner.remove_non_alphabetical_characters(predictions_col)

# %%
cleaner.remove_extra_spaces(predictions_col)
# Out:
#                                                                                                                                                                                 Base Predictions  \
# 0                                                           on friday, november 15, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                                 on wednesday, october 23, 2024, julian sanchez envisions that the stock price at microsoft (msft) will likely increase by 20% to $400 per share in q4 of 2027.
# 2                                            on monday, september 16, 2024, david kim predicts that the operating cash flow at chevron (cvx) should decrease by 4% to $15 billion in q1 of 2028.
# 3                                    on tuesday, august 20, 2024, sophia rodriguez speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2026.
# 4   on thursday, july 18, 2024, michael davis forecasts that the research and development expenses at johnson & johnson (jnj) have a high chance of increasing by 10% to $12 billion in fy 2029.
# 5                                                         on wednesday, june 19, 2024, olivia brown predicts that the return on equity (roe) at visa (v) may improve by 3% to 25% in q2 of 2028.
# 6                                             on friday, may 17, 2024, william white envisions that the capital expenditures at at&t (t) will likely decrease by 5% to $3 billion in q4 of 2027.
# 7                                            on monday, april 15, 2024, ava moreno forsees that the gross profit margin at cisco systems (csco) will probably expand by 2% to 20% in q1 of 2029.
# 8                                                               on tuesday, march 19, 2024, ethan hall predicts that the total debt at 3m (mmm) may decrease by 8% to $10 billion in q3 of 2028.
# 9                    on thursday, february 21, 2024, logan brooks forecasts that the earnings before interest and taxes (ebit) at walmart (wmt) should increase by 6% to $25 billion in fy 2028.
# 10                                                                                                                                                                 1. the sun rises in the east.
# 11                                                                                                                                                                  2. the book is on the table.
# 12                                                                                                                                                  3. the company has a strong management team.
# 13                                                                                                                                                 4. the city is very crowded during rush hour.
# 14                                                                                                                                                  5. the teacher is writing on the blackboard.
# 15                                                                                                                                                    6. the flowers are blooming in the garden.
# 16                                                                                                                                                   7. the music is playing loudly in the room.
# 17                                                                                                                                              8. the dog is running quickly around the corner.
# 18                                                                                                                                                 9. the coffee is hot and steaming in the cup.
#
#     Prediction Label
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False

# %%
cleaner.df
# Out:
#                                                                                                                                                                                 Base Predictions  \
# 0                                                           on friday, november 15, 2024, emily chen forecasts that the revenue at amazon (amzn) will rise by 12% to $150 billion in q2 of 2026.
# 1                                 on wednesday, october 23, 2024, julian sanchez envisions that the stock price at microsoft (msft) will likely increase by 20% to $400 per share in q4 of 2027.
# 2                                            on monday, september 16, 2024, david kim predicts that the operating cash flow at chevron (cvx) should decrease by 4% to $15 billion in q1 of 2028.
# 3                                    on tuesday, august 20, 2024, sophia rodriguez speculates that the dividend payout ratio at procter & gamble (pg) will probably remain at 60% in q3 of 2026.
# 4   on thursday, july 18, 2024, michael davis forecasts that the research and development expenses at johnson & johnson (jnj) have a high chance of increasing by 10% to $12 billion in fy 2029.
# 5                                                         on wednesday, june 19, 2024, olivia brown predicts that the return on equity (roe) at visa (v) may improve by 3% to 25% in q2 of 2028.
# 6                                             on friday, may 17, 2024, william white envisions that the capital expenditures at at&t (t) will likely decrease by 5% to $3 billion in q4 of 2027.
# 7                                            on monday, april 15, 2024, ava moreno forsees that the gross profit margin at cisco systems (csco) will probably expand by 2% to 20% in q1 of 2029.
# 8                                                               on tuesday, march 19, 2024, ethan hall predicts that the total debt at 3m (mmm) may decrease by 8% to $10 billion in q3 of 2028.
# 9                    on thursday, february 21, 2024, logan brooks forecasts that the earnings before interest and taxes (ebit) at walmart (wmt) should increase by 6% to $25 billion in fy 2028.
# 10                                                                                                                                                                 1. the sun rises in the east.
# 11                                                                                                                                                                  2. the book is on the table.
# 12                                                                                                                                                  3. the company has a strong management team.
# 13                                                                                                                                                 4. the city is very crowded during rush hour.
# 14                                                                                                                                                  5. the teacher is writing on the blackboard.
# 15                                                                                                                                                    6. the flowers are blooming in the garden.
# 16                                                                                                                                                   7. the music is playing loudly in the room.
# 17                                                                                                                                              8. the dog is running quickly around the corner.
# 18                                                                                                                                                 9. the coffee is hot and steaming in the cup.
#
#     Prediction Label
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10             False
# 11             False
# 12             False
# 13             False
# 14             False
# 15             False
# 16             False
# 17             False
# 18             False
