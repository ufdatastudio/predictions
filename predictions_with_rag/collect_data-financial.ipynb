# %% [markdown]
# # Collect Data
#
# - [Financial Phrasebank](https://huggingface.co/datasets/takala/financial_phrasebank) consists of 4840 sentences from English language financial news categorised by sentiment.

# %%
import os
import sys

import pandas as pd
from tqdm import tqdm

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# print(notebook_dir)
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from data_processing import DataProcessing
from text_generation_models import TextGenerationModelFactory

# %%
pd.set_option('max_colwidth', 800)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Load Data

# %%
base_path = os.path.join(notebook_dir, '../data/', 'financial_phrase_bank/')
full_path = os.path.join(base_path, 'all_data-adjusted_header.csv')

# df = DataProcessing.load_from_file(full_path, 'csv')
# df

# %%
df = pd.read_csv(full_path, encoding_errors = 'ignore')
df
# Out:
#      sentiment  \
# 0      neutral
# 1      neutral
# 2     negative
# 3     positive
# 4     positive
# ...        ...
# 4841  negative
# 4842   neutral
# 4843  negative
# 4844  negative
# 4845  negative
#
#                                                                                                                                                                                                                                   sentence
# 0                                                                                                          According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 1                                           Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .
# 2     The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .
# 3                           With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .
# 4                              According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .
# ...                                                                                                                                                                                                                                    ...
# 4841                                                                                      LONDON MarketWatch -- Share prices ended lower in London Monday as a rebound in bank stocks failed to offset broader weakness for the FTSE 100 .
# 4842                                                                                  Rinkuskiai 's beer sales fell by 6.5 per cent to 4.16 million litres , while Kauno Alus ' beer sales jumped by 6.9 per cent to 2.48 million litres .
# 4843                                                                                                                          Operating profit fell to EUR 35.4 mn from EUR 68.8 mn in 2007 , including vessel sales gain of EUR 12.3 mn .
# 4844    Net sales of the Paper segment decreased to EUR 221.6 mn in the second quarter of 2009 from EUR 241.1 mn in the second quarter of 2008 , while operating profit excluding non-recurring items rose to EUR 8.0 mn from EUR 7.6 mn .
# 4845                                                                                                                                       Sales in Finland decreased by 10.5 % in January , while sales outside Finland dropped by 17 % .
#
# [4846 rows x 2 columns]

# %%
sentences = DataProcessing.df_to_list(df, 'sentence')
sentences[: 3]
# Out:
# ['According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .',
#  'Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .',
#  'The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .']

# %%
prediction_properties = """A prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:

    1. <p_s>, any source entity in the domain.
        - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc), civilian.
        - Can only be an organization that is associated with the  prediction.
    2. <p_t>, any target entity in the domain.
	    - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc).
        - Can only be an organization that is associated with the  prediction.
    3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.
        - Forecast can range from a second to anytime in the future.
        - Answers the questions: "How far to go out from today?" or "Where to stop?".
    4. <p_o>,  prediction outcome.
        - Details relevant details such as outcome, a quantifiable metric, or slope.

Additionally, two main requirements of a prediction are (1) for it to be future tense (simple tense with simple future, continuous tense with future continuous, perfect tense with future perfect, and perfect continuous tense with future perfect continuous) and (2) it can NOT be past tense.   
"""

# %%
tgmf = TextGenerationModelFactory()

# Groq Cloud (https://console.groq.com/docs/overview)
gemma_29b_generation_model = tgmf.create_instance('gemma2-9b-it') 
llama_318b_instant_generation_model = tgmf.create_instance('llama-3.1-8b-instant') 
llama_3370b_versatile_generation_model = tgmf.create_instance('llama-3.3-70b-versatile')  
llama_guard_4_12b_generation_model = tgmf.create_instance('meta-llama/llama-guard-4-12b')  

models = [gemma_29b_generation_model, llama_318b_instant_generation_model, llama_3370b_versatile_generation_model, llama_guard_4_12b_generation_model]

# %%
def llm_as_a_judge(sentences: list, prediction_properties: str):
    
    labels = []
    for sentences_idx in tqdm(range(len(sentences))):
        sentence = sentences[sentences_idx]

        prompt = f"Classify the sentence: '{sentence}' as a prediction or non-prediction. I define a prediction with the following properties: {prediction_properties}. Only state a binary label of prediction or non-prediction and nothing else. Do NOT use the word 'safe." 
        if sentences_idx < 3:
            print(f"Prompt: {prompt}")
            # print()

        for model in models:  
            input_prompt = model.user(prompt)
            raw_text_llm_generation = model.chat_completion([input_prompt])
    
            for label in raw_text_llm_generation.split("\n"):
                if label.strip():
                    sentence_to_label = (sentence, label, model.__name__())
            labels.append(sentence_to_label)
    return labels

# %%
sentence_label = llm_as_a_judge(sentences[:33], prediction_properties)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# Prompt: Classify the sentence: 'According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .' as a prediction or non-prediction. I define a prediction with the following properties: A prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:
#
#     1. <p_s>, any source entity in the domain.
#         - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc), civilian.
#         - Can only be an organization that is associated with the  prediction.
#     2. <p_t>, any target entity in the domain.
# 	    - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc).
#         - Can only be an organization that is associated with the  prediction.
#     3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.
#         - Forecast can range from a second to anytime in the future.
#         - Answers the questions: "How far to go out from today?" or "Where to stop?".
#     4. <p_o>,  prediction outcome.
#         - Details relevant details such as outcome, a quantifiable metric, or slope.
#
# Additionally, two main requirements of a prediction are (1) for it to be future tense (simple tense with simple future, continuous tense with future continuous, perfect tense with future perfect, and perfect continuous tense with future perfect continuous) and (2) it can NOT be past tense.
# . Only state a binary label of prediction or non-prediction and nothing else. Do NOT use the word 'safe.
#   3%|▎         | 1/33 [00:02<01:10,  2.21s/it]
# Prompt: Classify the sentence: 'Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .' as a prediction or non-prediction. I define a prediction with the following properties: A prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:
#
#     1. <p_s>, any source entity in the domain.
#         - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc), civilian.
#         - Can only be an organization that is associated with the  prediction.
#     2. <p_t>, any target entity in the domain.
# 	    - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc).
#         - Can only be an organization that is associated with the  prediction.
#     3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.
#         - Forecast can range from a second to anytime in the future.
#         - Answers the questions: "How far to go out from today?" or "Where to stop?".
#     4. <p_o>,  prediction outcome.
#         - Details relevant details such as outcome, a quantifiable metric, or slope.
#
# Additionally, two main requirements of a prediction are (1) for it to be future tense (simple tense with simple future, continuous tense with future continuous, perfect tense with future perfect, and perfect continuous tense with future perfect continuous) and (2) it can NOT be past tense.
# . Only state a binary label of prediction or non-prediction and nothing else. Do NOT use the word 'safe.
#   6%|▌         | 2/33 [00:03<00:55,  1.80s/it]
# Prompt: Classify the sentence: 'The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .' as a prediction or non-prediction. I define a prediction with the following properties: A prediction <p> = (<p_s>, <p_t>, <p_d>, <p_o>), where it consists of the following four properties:
#
#     1. <p_s>, any source entity in the domain.
#         - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc), civilian.
#         - Can only be an organization that is associated with the  prediction.
#     2. <p_t>, any target entity in the domain.
# 	    - Can be a person (with a name) or a  person such as a  reporter,  analyst,  expert,  top executive,  senior level person, etc).
#         - Can only be an organization that is associated with the  prediction.
#     3. <p_d>, date or time range when <p> is expected to come to fruition or when one should observe the <p>.
#         - Forecast can range from a second to anytime in the future.
#         - Answers the questions: "How far to go out from today?" or "Where to stop?".
#     4. <p_o>,  prediction outcome.
#         - Details relevant details such as outcome, a quantifiable metric, or slope.
#
# Additionally, two main requirements of a prediction are (1) for it to be future tense (simple tense with simple future, continuous tense with future continuous, perfect tense with future perfect, and perfect continuous tense with future perfect continuous) and (2) it can NOT be past tense.
# . Only state a binary label of prediction or non-prediction and nothing else. Do NOT use the word 'safe.
# 100%|██████████| 33/33 [01:33<00:00,  2.83s/it]

# %%
sentence_label
# Out:
# [('According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .',
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ('According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .',
#   'prediction ',
#   'gemma2-9b-it'),
#  ('Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .',
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ('Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .',
#   'Prediction',
#   'llama-3.3-70b-versatile'),
#  ('Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .',
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ('The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .',
#   'prediction ',
#   'gemma2-9b-it'),
#  ('With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .',
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ('With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .',
#   'Prediction',
#   'llama-3.3-70b-versatile'),
#  ('With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .",
#   'prediction ',
#   'gemma2-9b-it'),
#  ("According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .",
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ("According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .",
#   'Prediction',
#   'llama-3.3-70b-versatile'),
#  ("According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is aggressively pursuing its growth strategy by increasingly focusing on technologically more demanding HDI printed circuit boards PCBs .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is aggressively pursuing its growth strategy by increasingly focusing on technologically more demanding HDI printed circuit boards PCBs .",
#   'Prediction',
#   'llama-3.1-8b-instant'),
#  ("FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is aggressively pursuing its growth strategy by increasingly focusing on technologically more demanding HDI printed circuit boards PCBs .",
#   'Prediction',
#   'llama-3.3-70b-versatile'),
#  ("FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is aggressively pursuing its growth strategy by increasingly focusing on technologically more demanding HDI printed circuit boards PCBs .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ("For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('In the third quarter of 2010 , net sales increased by 5.2 % to EUR 205.5 mn , and operating profit by 34.9 % to EUR 23.5 mn .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('In the third quarter of 2010 , net sales increased by 5.2 % to EUR 205.5 mn , and operating profit by 34.9 % to EUR 23.5 mn .',
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ('In the third quarter of 2010 , net sales increased by 5.2 % to EUR 205.5 mn , and operating profit by 34.9 % to EUR 23.5 mn .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('In the third quarter of 2010 , net sales increased by 5.2 % to EUR 205.5 mn , and operating profit by 34.9 % to EUR 23.5 mn .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .',
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ('Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Operating profit totalled EUR 21.1 mn , up from EUR 18.6 mn in 2007 , representing 9.7 % of net sales .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Operating profit totalled EUR 21.1 mn , up from EUR 18.6 mn in 2007 , representing 9.7 % of net sales .',
#   'Non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Operating profit totalled EUR 21.1 mn , up from EUR 18.6 mn in 2007 , representing 9.7 % of net sales .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Operating profit totalled EUR 21.1 mn , up from EUR 18.6 mn in 2007 , representing 9.7 % of net sales .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("TeliaSonera TLSN said the offer is in line with its strategy to increase its ownership in core business holdings and would strengthen Eesti Telekom 's offering to its customers .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("TeliaSonera TLSN said the offer is in line with its strategy to increase its ownership in core business holdings and would strengthen Eesti Telekom 's offering to its customers .",
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ("TeliaSonera TLSN said the offer is in line with its strategy to increase its ownership in core business holdings and would strengthen Eesti Telekom 's offering to its customers .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("TeliaSonera TLSN said the offer is in line with its strategy to increase its ownership in core business holdings and would strengthen Eesti Telekom 's offering to its customers .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('STORA ENSO , NORSKE SKOG , M-REAL , UPM-KYMMENE Credit Suisse First Boston ( CFSB ) raised the fair value for shares in four of the largest Nordic forestry groups .',
#   'prediction ',
#   'gemma2-9b-it'),
#  ('STORA ENSO , NORSKE SKOG , M-REAL , UPM-KYMMENE Credit Suisse First Boston ( CFSB ) raised the fair value for shares in four of the largest Nordic forestry groups .',
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ('STORA ENSO , NORSKE SKOG , M-REAL , UPM-KYMMENE Credit Suisse First Boston ( CFSB ) raised the fair value for shares in four of the largest Nordic forestry groups .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('STORA ENSO , NORSKE SKOG , M-REAL , UPM-KYMMENE Credit Suisse First Boston ( CFSB ) raised the fair value for shares in four of the largest Nordic forestry groups .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('A purchase agreement for 7,200 tons of gasoline with delivery at the Hamina terminal , Finland , was signed with Neste Oil OYj at the average Platts index for this September plus eight US dollars per month .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('A purchase agreement for 7,200 tons of gasoline with delivery at the Hamina terminal , Finland , was signed with Neste Oil OYj at the average Platts index for this September plus eight US dollars per month .',
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ('A purchase agreement for 7,200 tons of gasoline with delivery at the Hamina terminal , Finland , was signed with Neste Oil OYj at the average Platts index for this September plus eight US dollars per month .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('A purchase agreement for 7,200 tons of gasoline with delivery at the Hamina terminal , Finland , was signed with Neste Oil OYj at the average Platts index for this September plus eight US dollars per month .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Finnish Talentum reports its operating profit increased to EUR 20.5 mn in 2005 from EUR 9.3 mn in 2004 , and net sales totaled EUR 103.3 mn , up from EUR 96.4 mn .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Finnish Talentum reports its operating profit increased to EUR 20.5 mn in 2005 from EUR 9.3 mn in 2004 , and net sales totaled EUR 103.3 mn , up from EUR 96.4 mn .',
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ('Finnish Talentum reports its operating profit increased to EUR 20.5 mn in 2005 from EUR 9.3 mn in 2004 , and net sales totaled EUR 103.3 mn , up from EUR 96.4 mn .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Finnish Talentum reports its operating profit increased to EUR 20.5 mn in 2005 from EUR 9.3 mn in 2004 , and net sales totaled EUR 103.3 mn , up from EUR 96.4 mn .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("Clothing retail chain Sepp+Æl+Æ 's sales increased by 8 % to EUR 155.2 mn , and operating profit rose to EUR 31.1 mn from EUR 17.1 mn in 2004 .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("Clothing retail chain Sepp+Æl+Æ 's sales increased by 8 % to EUR 155.2 mn , and operating profit rose to EUR 31.1 mn from EUR 17.1 mn in 2004 .",
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ("Clothing retail chain Sepp+Æl+Æ 's sales increased by 8 % to EUR 155.2 mn , and operating profit rose to EUR 31.1 mn from EUR 17.1 mn in 2004 .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("Clothing retail chain Sepp+Æl+Æ 's sales increased by 8 % to EUR 155.2 mn , and operating profit rose to EUR 31.1 mn from EUR 17.1 mn in 2004 .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Consolidated net sales increased 16 % to reach EUR74 .8 m , while operating profit amounted to EUR0 .9 m compared to a loss of EUR0 .7 m in the prior year period .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Consolidated net sales increased 16 % to reach EUR74 .8 m , while operating profit amounted to EUR0 .9 m compared to a loss of EUR0 .7 m in the prior year period .',
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ('Consolidated net sales increased 16 % to reach EUR74 .8 m , while operating profit amounted to EUR0 .9 m compared to a loss of EUR0 .7 m in the prior year period .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Consolidated net sales increased 16 % to reach EUR74 .8 m , while operating profit amounted to EUR0 .9 m compared to a loss of EUR0 .7 m in the prior year period .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Foundries division reports its sales increased by 9.7 % to EUR 63.1 mn from EUR 57.5 mn in the corresponding period in 2006 , and sales of the Machine Shop division increased by 16.4 % to EUR 41.2 mn from EUR 35.4 mn in the corresponding period in 2006 .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Foundries division reports its sales increased by 9.7 % to EUR 63.1 mn from EUR 57.5 mn in the corresponding period in 2006 , and sales of the Machine Shop division increased by 16.4 % to EUR 41.2 mn from EUR 35.4 mn in the corresponding period in 2006 .',
#   'Non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Foundries division reports its sales increased by 9.7 % to EUR 63.1 mn from EUR 57.5 mn in the corresponding period in 2006 , and sales of the Machine Shop division increased by 16.4 % to EUR 41.2 mn from EUR 35.4 mn in the corresponding period in 2006 .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Foundries division reports its sales increased by 9.7 % to EUR 63.1 mn from EUR 57.5 mn in the corresponding period in 2006 , and sales of the Machine Shop division increased by 16.4 % to EUR 41.2 mn from EUR 35.4 mn in the corresponding period in 2006 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("HELSINKI ( AFX ) - Shares closed higher , led by Nokia after it announced plans to team up with Sanyo to manufacture 3G handsets , and by Nokian Tyres after its fourth-quarter earnings report beat analysts ' expectations , dealers said .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("HELSINKI ( AFX ) - Shares closed higher , led by Nokia after it announced plans to team up with Sanyo to manufacture 3G handsets , and by Nokian Tyres after its fourth-quarter earnings report beat analysts ' expectations , dealers said .",
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ("HELSINKI ( AFX ) - Shares closed higher , led by Nokia after it announced plans to team up with Sanyo to manufacture 3G handsets , and by Nokian Tyres after its fourth-quarter earnings report beat analysts ' expectations , dealers said .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("HELSINKI ( AFX ) - Shares closed higher , led by Nokia after it announced plans to team up with Sanyo to manufacture 3G handsets , and by Nokian Tyres after its fourth-quarter earnings report beat analysts ' expectations , dealers said .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Incap Contract Manufacturing Services Pvt Ltd , a subsidiary of Incap Corporation of Finland , plans to double its revenues by 2007-2008 .',
#   'prediction ',
#   'gemma2-9b-it'),
#  ('Incap Contract Manufacturing Services Pvt Ltd , a subsidiary of Incap Corporation of Finland , plans to double its revenues by 2007-2008 .',
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ('Incap Contract Manufacturing Services Pvt Ltd , a subsidiary of Incap Corporation of Finland , plans to double its revenues by 2007-2008 .',
#   'Prediction',
#   'llama-3.3-70b-versatile'),
#  ('Incap Contract Manufacturing Services Pvt Ltd , a subsidiary of Incap Corporation of Finland , plans to double its revenues by 2007-2008 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Its board of directors will propose a dividend of EUR0 .12 per share for 2010 , up from the EUR0 .08 per share paid in 2009 .',
#   'prediction ',
#   'gemma2-9b-it'),
#  ('Its board of directors will propose a dividend of EUR0 .12 per share for 2010 , up from the EUR0 .08 per share paid in 2009 .',
#   'prediction',
#   'llama-3.1-8b-instant'),
#  ('Its board of directors will propose a dividend of EUR0 .12 per share for 2010 , up from the EUR0 .08 per share paid in 2009 .',
#   'Prediction',
#   'llama-3.3-70b-versatile'),
#  ('Its board of directors will propose a dividend of EUR0 .12 per share for 2010 , up from the EUR0 .08 per share paid in 2009 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Lifetree was founded in 2000 , and its revenues have risen on an average by 40 % with margins in late 30s .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Lifetree was founded in 2000 , and its revenues have risen on an average by 40 % with margins in late 30s .',
#   'Non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Lifetree was founded in 2000 , and its revenues have risen on an average by 40 % with margins in late 30s .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Lifetree was founded in 2000 , and its revenues have risen on an average by 40 % with margins in late 30s .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('( Filippova ) A trilateral agreement on investment in the construction of a technology park in St Petersburg was to have been signed in the course of the forum , Days of the Russian Economy , that opened in Helsinki today .',
#   'prediction ',
#   'gemma2-9b-it'),
#  ('( Filippova ) A trilateral agreement on investment in the construction of a technology park in St Petersburg was to have been signed in the course of the forum , Days of the Russian Economy , that opened in Helsinki today .',
#   'Prediction.',
#   'llama-3.1-8b-instant'),
#  ('( Filippova ) A trilateral agreement on investment in the construction of a technology park in St Petersburg was to have been signed in the course of the forum , Days of the Russian Economy , that opened in Helsinki today .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('( Filippova ) A trilateral agreement on investment in the construction of a technology park in St Petersburg was to have been signed in the course of the forum , Days of the Russian Economy , that opened in Helsinki today .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("MegaFon 's subscriber base increased 16.1 % in 2009 to 50.5 million users as of December 31 , while its market share by the number of customers amounted to 24 % as of late 2009 , up from 23 % as of late 2008 , according to TeliaSonera estimates .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("MegaFon 's subscriber base increased 16.1 % in 2009 to 50.5 million users as of December 31 , while its market share by the number of customers amounted to 24 % as of late 2009 , up from 23 % as of late 2008 , according to TeliaSonera estimates .",
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ("MegaFon 's subscriber base increased 16.1 % in 2009 to 50.5 million users as of December 31 , while its market share by the number of customers amounted to 24 % as of late 2009 , up from 23 % as of late 2008 , according to TeliaSonera estimates .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("MegaFon 's subscriber base increased 16.1 % in 2009 to 50.5 million users as of December 31 , while its market share by the number of customers amounted to 24 % as of late 2009 , up from 23 % as of late 2008 , according to TeliaSonera estimates .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Net income from life insurance doubled to EUR 6.8 mn from EUR 3.2 mn , and net income from non-life insurance rose to EUR 5.2 mn from EUR 1.5 mn in the corresponding period in 2009 .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Net income from life insurance doubled to EUR 6.8 mn from EUR 3.2 mn , and net income from non-life insurance rose to EUR 5.2 mn from EUR 1.5 mn in the corresponding period in 2009 .',
#   'Non-prediction.',
#   'llama-3.1-8b-instant'),
#  ('Net income from life insurance doubled to EUR 6.8 mn from EUR 3.2 mn , and net income from non-life insurance rose to EUR 5.2 mn from EUR 1.5 mn in the corresponding period in 2009 .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Net income from life insurance doubled to EUR 6.8 mn from EUR 3.2 mn , and net income from non-life insurance rose to EUR 5.2 mn from EUR 1.5 mn in the corresponding period in 2009 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Net sales increased to EUR193 .3 m from EUR179 .9 m and pretax profit rose by 34.2 % to EUR43 .1 m. ( EUR1 = USD1 .4 )',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Net sales increased to EUR193 .3 m from EUR179 .9 m and pretax profit rose by 34.2 % to EUR43 .1 m. ( EUR1 = USD1 .4 )',
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Net sales increased to EUR193 .3 m from EUR179 .9 m and pretax profit rose by 34.2 % to EUR43 .1 m. ( EUR1 = USD1 .4 )',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Net sales increased to EUR193 .3 m from EUR179 .9 m and pretax profit rose by 34.2 % to EUR43 .1 m. ( EUR1 = USD1 .4 )',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Net sales surged by 18.5 % to EUR167 .8 m. Teleste said that EUR20 .4 m , or 12.2 % , of the sales came from the acquisitions made in 2009 .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Net sales surged by 18.5 % to EUR167 .8 m. Teleste said that EUR20 .4 m , or 12.2 % , of the sales came from the acquisitions made in 2009 .',
#   'Non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Net sales surged by 18.5 % to EUR167 .8 m. Teleste said that EUR20 .4 m , or 12.2 % , of the sales came from the acquisitions made in 2009 .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Net sales surged by 18.5 % to EUR167 .8 m. Teleste said that EUR20 .4 m , or 12.2 % , of the sales came from the acquisitions made in 2009 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("Nordea Group 's operating profit increased in 2010 by 18 percent year-on-year to 3.64 billion euros and total revenue by 3 percent to 9.33 billion euros .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("Nordea Group 's operating profit increased in 2010 by 18 percent year-on-year to 3.64 billion euros and total revenue by 3 percent to 9.33 billion euros .",
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ("Nordea Group 's operating profit increased in 2010 by 18 percent year-on-year to 3.64 billion euros and total revenue by 3 percent to 9.33 billion euros .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("Nordea Group 's operating profit increased in 2010 by 18 percent year-on-year to 3.64 billion euros and total revenue by 3 percent to 9.33 billion euros .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Operating profit for the nine-month period increased from EUR13 .6 m , while net sales increased from EUR394 .7 m , as compared to the corresponding period in 2005 .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Operating profit for the nine-month period increased from EUR13 .6 m , while net sales increased from EUR394 .7 m , as compared to the corresponding period in 2005 .',
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Operating profit for the nine-month period increased from EUR13 .6 m , while net sales increased from EUR394 .7 m , as compared to the corresponding period in 2005 .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Operating profit for the nine-month period increased from EUR13 .6 m , while net sales increased from EUR394 .7 m , as compared to the corresponding period in 2005 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Operating profit for the nine-month period increased from EUR3 .1 m and net sales increased from EUR61 .5 m , as compared to the corresponding period in 2007 .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Operating profit for the nine-month period increased from EUR3 .1 m and net sales increased from EUR61 .5 m , as compared to the corresponding period in 2007 .',
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Operating profit for the nine-month period increased from EUR3 .1 m and net sales increased from EUR61 .5 m , as compared to the corresponding period in 2007 .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Operating profit for the nine-month period increased from EUR3 .1 m and net sales increased from EUR61 .5 m , as compared to the corresponding period in 2007 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ('Operating profit for the three-month period increased from EUR1 .2 m , while revenue increased from EUR20 .2 m , as compared to the corresponding period in 2005 .',
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ('Operating profit for the three-month period increased from EUR1 .2 m , while revenue increased from EUR20 .2 m , as compared to the corresponding period in 2005 .',
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ('Operating profit for the three-month period increased from EUR1 .2 m , while revenue increased from EUR20 .2 m , as compared to the corresponding period in 2005 .',
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ('Operating profit for the three-month period increased from EUR1 .2 m , while revenue increased from EUR20 .2 m , as compared to the corresponding period in 2005 .',
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+_o , as saying .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+_o , as saying .",
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ("The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+_o , as saying .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("The Brazilian unit of Finnish security solutions provider F-Secure signed up 1,500 new clients last year , online news source Reseller Web quoted the division 's commercial director , Vladimir Brand+_o , as saying .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("The company 's net profit rose 11.4 % on the year to 82.2 million euros in 2005 on sales of 686.5 million euros , 13.8 % up on the year , the company said earlier .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("The company 's net profit rose 11.4 % on the year to 82.2 million euros in 2005 on sales of 686.5 million euros , 13.8 % up on the year , the company said earlier .",
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ("The company 's net profit rose 11.4 % on the year to 82.2 million euros in 2005 on sales of 686.5 million euros , 13.8 % up on the year , the company said earlier .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("The company 's net profit rose 11.4 % on the year to 82.2 million euros in 2005 on sales of 686.5 million euros , 13.8 % up on the year , the company said earlier .",
#   'safe',
#   'meta-llama/llama-guard-4-12b'),
#  ("The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .",
#   'non-prediction ',
#   'gemma2-9b-it'),
#  ("The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .",
#   'non-prediction',
#   'llama-3.1-8b-instant'),
#  ("The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .",
#   'Non-prediction',
#   'llama-3.3-70b-versatile'),
#  ("The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .",
#   'safe',
#   'meta-llama/llama-guard-4-12b')]

# %%
sentence_label_df = pd.DataFrame(sentence_label, columns=['Sentence', 'Label', 'Model'])
sentence_label_df
# Out:
#                                                                                                                                                                                                            Sentence  \
# 0                                                                                   According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 1                                                                                   According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 2                                                                                   According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 3                                                                                   According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 4                    Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .
# ..                                                                                                                                                                                                              ...
# 127                                            The company 's net profit rose 11.4 % on the year to 82.2 million euros in 2005 on sales of 686.5 million euros , 13.8 % up on the year , the company said earlier .
# 128  The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .
# 129  The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .
# 130  The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .
# 131  The Lithuanian beer market made up 14.41 million liters in January , a rise of 0.8 percent from the year-earlier figure , the Lithuanian Brewers ' Association reporting citing the results from its members .
#
#                Label                         Model
# 0    non-prediction                   gemma2-9b-it
# 1         prediction          llama-3.1-8b-instant
# 2     Non-prediction       llama-3.3-70b-versatile
# 3               safe  meta-llama/llama-guard-4-12b
# 4        prediction                   gemma2-9b-it
# ..               ...                           ...
# 127             safe  meta-llama/llama-guard-4-12b
# 128  non-prediction                   gemma2-9b-it
# 129   non-prediction          llama-3.1-8b-instant
# 130   Non-prediction       llama-3.3-70b-versatile
# 131             safe  meta-llama/llama-guard-4-12b
#
# [132 rows x 3 columns]

# %%
filt_prediction = (sentence_label_df.Label == 'prediction')
sentence_label_df[filt_prediction]
# Out:
#                                                                                                                                                                                                           Sentence  \
# 1                                                                                  According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 5                   Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .
# 13  With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .
# 17     According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .
# 25               For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .
# 61                                             Consolidated net sales increased 16 % to reach EUR74 .8 m , while operating profit amounted to EUR0 .9 m compared to a loss of EUR0 .7 m in the prior year period .
# 73                                                                      Incap Contract Manufacturing Services Pvt Ltd , a subsidiary of Incap Corporation of Finland , plans to double its revenues by 2007-2008 .
# 77                                                                                   Its board of directors will propose a dividend of EUR0 .12 per share for 2010 , up from the EUR0 .08 per share paid in 2009 .
#
#          Label                 Model
# 1   prediction  llama-3.1-8b-instant
# 5   prediction  llama-3.1-8b-instant
# 13  prediction  llama-3.1-8b-instant
# 17  prediction  llama-3.1-8b-instant
# 25  prediction  llama-3.1-8b-instant
# 61  prediction  llama-3.1-8b-instant
# 73  prediction  llama-3.1-8b-instant
# 77  prediction  llama-3.1-8b-instant
