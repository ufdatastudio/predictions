# %% [markdown]
# # Read CSV and Log File
#
# - [x] Read and load csv
# - [ ] Read and load log

# %%
import os, sys, pathlib

import pandas as pd

from tqdm import tqdm
from langchain_core.prompts import PipelinePromptTemplate, PromptTemplate

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from log_files import LogData
from data_processing import DataProcessing
from text_generation_models import TextGenerationModelFactory

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
print("Start logging batch")

# base_path = os.path.abspath('')
# print(f"base_path: {base_path}")
base_path = os.path.join(notebook_dir, '../')
# print(f"base_path: {base_path}")

log_file_path = "data/prediction_logs"
log_directory = os.path.join(base_path, log_file_path)
# print(f"log_directory: {log_directory}")

dfs = []
for i in range(11, 13):
    print(i)

    batch_i = f"batch_{i}"
    save_batch_directory = os.path.join(log_directory, f"{batch_i}-predictions")
    save_batch_name = f"{batch_i}-info.log"
    save_from_df_name = f"{batch_i}-from_df.csv"
    save_from_csv_name = f"{batch_i}-from_csv.log"
    ignore_patterns = ['INFO', 'DEBUG', 'ERROR', 'WARNING', 'CSV Row: ']
    logger = LogData(base_path, log_file_path, save_batch_directory, save_batch_name)
    # logger.log_to_csv(save_from_csv_name, save_from_df_name, ignore_patterns)
    df = logger.csv_to_dataframe(save_from_df_name)
    dfs.append(df)
predictions_df = DataProcessing.concat_dfs(dfs)
predictions_df
# Out:
# Start logging batch
# 11
# CSV to DF
# Load saved csv: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/prediction_correctness/../data/prediction_logs/batch_11-predictions/batch_11-from_df.csv
# 12
# CSV to DF
# Load saved csv: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/prediction_correctness/../data/prediction_logs/batch_12-predictions/batch_12-from_df.csv
#                                                                                                                                                                              Base Sentence  \
# 0                                                                                                Goldman Sachs forecasts that the revenue at Microsoft will likely increase in Q3 of 2027.
# 1                                                                        JPMorgan Chase predicts that the net profit at Amazon should rise as much as $15 USD in 2024-08-21 to 2024-11-21.
# 2                                                                               Mr. Thompson, a financial analyst forecasts that the net profit at Amazon will likely decrease in 2027 Q3.
# 3                                            The financial team at Goldman Sachs predicts that the research and development expenses at Microsoft should increase in Wed, August 21, 2024.
# 4                                                                                                    Goldman Sachs forecasts that the revenue at Tesla will likely increase in Q2 of 2024.
# 5                                                                  Financial expert, Rachel Johnson predicts that the net profit at Johnson & Johnson will stay stable in August 21, 2024.
# 6                                                                                                  Morgan Stanley forecasts that the revenue at Amazon will likely increase in Q3 of 2027.
# 7                                           Dr. Sophia Patel, a financial expert, predicts that the net profit at Johnson & Johnson will likely stay stable from 2024-08-21 to 2025-08-21.
# 8                                                                            Financial expert, Sarah Johnson, speculates that the net profit at Amazon will likely increase in Q4 of 2026.
# 9                                                                Senior financial analyst, Michael Thompson, envisions that the revenue at Google will likely decrease in August 21, 2027.
# 10                                                                                                 Goldman Sachs predicts that the net profit at Tesla will likely decrease in Q4 of 2024.
# 11                                                                                                    Morgan Stanley forecasts that the revenue at Amazon will likely decrease in 2025 Q2.
# 12                                             Goldman Sachs' Chief Financial Officer, Daniele Novelli, envisions that the net profit at Microsoft will rise as much as 10% in Q2 of 2024.
# 13                                                              Mr. Warren Buffett, the CEO of Berkshire Hathaway, speculates that the stock price at Amazon would stay stable in 2027 Q3.
# 14                                                                                               Goldman Sachs forecasts that the revenue at Microsoft will likely increase in Q3 of 2027.
# 15                                                               JPMorgan Chase predicts that the net profit at Johnson & Johnson should rise in the period from 2024-08-21 to 2025-02-21.
# 16                                                                           Mr. Thompson, a financial analyst, forecasts that the net profit at Tesla will likely increase in Q3 of 2027.
# 17                                                                      The financial team at Goldman Sachs speculates that the revenue at Amazon will be going to decrease in 2029 of Q3.
# 18                                                                                 Goldman Sachs' financial expert envisions that the revenue at Tesla will likely increase in Q2 of 2026.
# 19                          Morgan Stanley's senior analyst speculates that the net profit at Johnson & Johnson will stay stable in the period from August 15, 2024, to November 15, 2024.
# 20                                                                                                  Goldman Sachs forecasts that the revenue at Amazon will likely increase in Q3 of 2027.
# 21                                                                     Dr. Sophia Patel speculates that the net profit at Microsoft will likely stay stable from 2024-08-21 to 2025-08-21.
# 22                                                                          Financial analyst, Sarah Johnson, speculates that the net profit at Amazon will likely decrease in Q4 of 2026.
# 23                                                                          Senior financial executive, Michael Thompson, foresees that the revenue at Google will decrease in 08/21/2027.
# 24                                                                                                Morgan Stanley foresees that the net profit at Tesla will likely decrease in Q4 of 2024.
# 25                                                                                                 Goldman Sachs speculates that the revenue at Amazon will likely decrease in 2025-08-21.
# 26  Goldman Sachs' CFO, Mr. Stephen Scherr, envisions a decrease in the net profit of Microsoft Corporation, projected to be around $100 billion, for the fiscal year ending in June 2024.
# 27  Mr. Warren Buffett, the CEO of Berkshire Hathaway, foresees a stabilization in the research and development expenses of Amazon, estimated to be around $42 billion, during Q4 of 2027.
#
#     Sentence Label   Domain               Model Name    API Name  \
# 0                1  finance  llama-3.3-70b-versatile  GROQ_CLOUD
# 1                1  finance  llama-3.3-70b-versatile  GROQ_CLOUD
# 2                1  finance     llama-3.1-8b-instant  GROQ_CLOUD
# 3                1  finance     llama-3.1-8b-instant  GROQ_CLOUD
# 4                1  finance          llama3-70b-8192  GROQ_CLOUD
# 5                1  finance          llama3-70b-8192  GROQ_CLOUD
# 6                1  finance           llama3-8b-8192  GROQ_CLOUD
# 7                1  finance           llama3-8b-8192  GROQ_CLOUD
# 8                1  finance            gpt-3.5-turbo  NAVI_GATOR
# 9                1  finance            gpt-3.5-turbo  NAVI_GATOR
# 10               1  finance                   gpt-4o  NAVI_GATOR
# 11               1  finance                   gpt-4o  NAVI_GATOR
# 12               1  finance    mixtral-8x7b-instruct  NAVI_GATOR
# 13               1  finance    mixtral-8x7b-instruct  NAVI_GATOR
# 14               1  finance  llama-3.3-70b-versatile  GROQ_CLOUD
# 15               1  finance  llama-3.3-70b-versatile  GROQ_CLOUD
# 16               1  finance     llama-3.1-8b-instant  GROQ_CLOUD
# 17               1  finance     llama-3.1-8b-instant  GROQ_CLOUD
# 18               1  finance          llama3-70b-8192  GROQ_CLOUD
# 19               1  finance          llama3-70b-8192  GROQ_CLOUD
# 20               1  finance           llama3-8b-8192  GROQ_CLOUD
# 21               1  finance           llama3-8b-8192  GROQ_CLOUD
# 22               1  finance            gpt-3.5-turbo  NAVI_GATOR
# 23               1  finance            gpt-3.5-turbo  NAVI_GATOR
# 24               1  finance                   gpt-4o  NAVI_GATOR
# 25               1  finance                   gpt-4o  NAVI_GATOR
# 26               1  finance    mixtral-8x7b-instruct  NAVI_GATOR
# 27               1  finance    mixtral-8x7b-instruct  NAVI_GATOR
#
#     Template Number
# 0                 1
# 1                 2
# 2                 1
# 3                 2
# 4                 1
# 5                 2
# 6                 1
# 7                 2
# 8                 1
# 9                 2
# 10                1
# 11                1
# 12                1
# 13                2
# 14                1
# 15                2
# 16                1
# 17                2
# 18                1
# 19                2
# 20                1
# 21                2
# 22                1
# 23                2
# 24                1
# 25                1
# 26                1
# 27                2
