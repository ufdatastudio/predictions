# %% [markdown]
# # 1-Generate Observations using LangChain
#
# - **Goal:** observation Recognition
#
# - **Purpose:** To implement step 1 with sub steps of observation recognition pipeline. See steps
#     1. Generate observations
#         1. Create several observation prompts templates
#         2. Utilize open-source LLMs to generate observations
#
# - **Misc:**
#     - `%store`: Cell magic will store the variable of interest so we can load in another notebook

# %%
import os, sys

import pandas as pd

from tqdm import tqdm
from langchain_core.prompts import PipelinePromptTemplate, PromptTemplate

# Get the current working directory of the notebook
notebook_dir = os.getcwd()
# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

from log_files import LogData
from data_processing import DataProcessing
from text_generation_models import TextGenerationModelFactory

# %% [markdown]
# ## Text Generation Models

# %%
tgmf = TextGenerationModelFactory()

llama_versatile_generation_model = tgmf.create_instance(model_name='llama-3.3-70b-versatile')
llama_instant_generation_model = tgmf.create_instance('llama-3.1-8b-instant')
llama_70b_8192_generation_model = tgmf.create_instance('llama3-70b-8192')
llama_8b_8192_generation_model = tgmf.create_instance('llama3-8b-8192')

gpt_35_turbo_generation_model = tgmf.create_instance('gpt-3.5-turbo')
gpt_4_o_generation_model = tgmf.create_instance('gpt-4o')
mixtral_87b_instruct_generation_model = tgmf.create_instance('mixtral-8x7b-instruct')

# %% [markdown]
# ## Base Templates for Domain Observations

# %%
full_observation_template = """{observation_properties}

{observation_requirements}

{observation_templates}

{observation_examples}
"""

full_observation_prompt = PromptTemplate.from_template(full_observation_template)

# %%
observation_properties_template = """An observation <o> = (<o_s>, <o_t>, <o_d>, <o_a>), where it consists of the following four properties:

    1. <o_s>, any source entity in the {observation_domain} domain.
        - Can be a person (with a name) or a {observation_domain} person such as a {observation_domain} reporter, {observation_domain} analyst, {observation_domain} expert, {observation_domain} top executive, {observation_domain} senior level person, etc), civilian.
        - Can only be an organization that is associated with the {observation_domain} observation.
    2. <o_t>, any target entity in the {observation_domain} domain.
	    - Can be a person (with a name) or a {observation_domain} person such as a {observation_domain} reporter, {observation_domain} analyst, {observation_domain} expert, {observation_domain} top executive, {observation_domain} senior level person, etc).
        - Can only be an organization that is associated with the {observation_domain} observation.
    3. <o_d>, date or time range when <o> is expected to come to fruition or when one should observe the <o>.
        - Forecast can range from a second to anytime in the future.
        - Answers the questions: "How far to go out from today?" or "Where to stop?".
    4. <o_a>, {observation_domain} observation attribute.
        - Characteristics of a domain-specific attributes such as various quantifiable metrics relevant to the {observation_domain} domain.
        - Some examples are {observation_domain_attribute}.  
"""
observation_properties_prompt = PromptTemplate.from_template(observation_properties_template)

# %%
observation_requirements_template = """requirements to use for each observation:

    - Should be based on real-world {observation_domain} data and not hallucinate.
    - Must be a simple sentence (observation) (and NOT compounding using "and" or "or").
    - Should diversify all four properties of the observation (<o>) as in change and not use same for <o_s>, <o_t>, <o_d>, <o_a>.
    - The observation should be unique and not repeated.
    - Do not number the observations.
    - Do not say, "Here are {observations_N} unique observation based on the provided templates and examples:" or anything similar in the prompt.
    - Change how the current date (<o_d>) written in the observation with examples of (1) Wednesday, August 21, 2024; (2) Wed, August 21, 2024; (3) 08/21/2024; (4) 08/21/2024; (5) 21/08/2024; (6) 21 August 2024; (7) 2024/08/21; (8) 2024-08-21; (9) August 21, 2024; (10) Aug 21, 2024; (11) 21 August 2024, (12) 21 Aug 2024, Q3 of 2027, 2029 of Q3, etc (with removing day of week).
    - Do not use any of the examples in the prompt.
    - In front of every prediction, put the template number in the format of "T1:", "T2:", etc. and do not number them like "1.", "2.", etc.
    - Do not put template number on line by itself. Always pair with a prediction.
    - Disregard brackets: "<>"
    - Do not use person name of entity name more than once as in don't use name Joe as both the <o_s> and <o_t>, unless like Mr. Sach and Goldman Sach or Mr. Sam Walton and Sam's Club, etc.
    - The source entity (<o_s>) is rarely the same as the target entity (<o_t>) and if same, the <o_s> is making a observation on itself in the <o_t>.
    - Should variate the slope of rise/increase/as much as, fall/decrease/as little as, change, stay stable, high/low chance/probability/degree of, etc.
    - Must be past tense as in already occurred and not future tense.
    - Don't leave out {observation_domain} domain, so specifically generate for this ({observation_domain}) domain."""
observation_requirements_prompt = PromptTemplate.from_template(observation_requirements_template)

# %%
observation_templates_template = """Here are some {observation_domain} templates:

    - {observation_domain} template 1: <o_s> saw the <o_a> at <o_t> plummeted in <o_d>.
    - {observation_domain} template 2: From <p_d>, <p_s> speculated the <p_a> at <p_t> was drastically different.
    - {observation_domain} template 5: <p_d>, <p_s> heard that the <p_t> <p_a> remained stable.
    - {observation_domain} template 6: <p_t> <p_a> generally rose in <p_d>, according to <p_s>. 

"""
observation_templates_prompt = PromptTemplate.from_template(observation_templates_template)

# %%
observation_examples_template = """Here are some examples of {observation_domain} observations:
{domain_examples}

With the above, generate a unique set of {observations_N} observations per template following the examples. Think from the perspective of an {observation_domain} analyst, expert, top executive, or senior level person and even a college student, professional, research advisor, etc."""
observation_examples_prompt = PromptTemplate.from_template(observation_examples_template)

# %%
observation_input_prompts = [
    ("observation_properties", observation_properties_prompt),
    ("observation_requirements", observation_requirements_prompt),
    ("observation_templates", observation_templates_prompt),
    ("observation_examples", observation_examples_prompt),
]

pipeline_prompt = PipelinePromptTemplate(
    final_prompt=full_observation_prompt, pipeline_prompts=observation_input_prompts
)

# %% [markdown]
# ## Specific Templates for Domain observations

# %% [markdown]
# - For now, generating 1 observation per template. From here, I'll try 3 and increase by increments/multiples of 3.
#
# - With 1 observation per template,
#     - 1 observation per template x 6 examples per domain so 6 observations per domain
#     - 6 observations per domain x 4 domains = 24 observations per model
#     - 24 observations per model x 2 models = 48 observations across all models
#     - 48 observations across all models x 2 batches = 96 across all batches

# %%
examples_per_template = 1
generate_N_observations_per_template = 1 * examples_per_template

# %% [markdown]
# ### Template for Financial observations

# %%
financial_attributes = """stock price, net profit, revenue, operating cash flow, research and development expenses, operating income, gross profit."""
financial_requirements = """- Should be based on real-world financial earnings reports.
    - Suppose the time when <o> was made is during any earning season.
    - Include stocks from all sectors such as consumer staples, energy, finance, health care, industrials, materials, media, real estate, retail, technology, utilities, defense, etc.
    - Include the US Dollar sign ($) before or USD after the amount of the financial attribute."""

financial_examples = """
   - financial examples for template 1:
      1. Joseph, the young entrepreneur, observed that the revenue at FUBU (his parents clothing line) had increased for Q3 2028.
      2. BJ saw that the operating cash flow at UF's school of Engineering decrease in 05/2025.
      3. An fresh investor noticed the ETFs in his portfolio exponentially grew from Apr 7, 1997 to Apr 7, 2025.
 """

financial_input_dict = {
    "observation_domain": "financial",
    "observation_domain_attribute": financial_attributes,
    "domain_requirements": financial_requirements,
    "domain_examples": financial_examples,
    "observations_N": generate_N_observations_per_template
}
financial_prompt_output = pipeline_prompt.format(**financial_input_dict)
print(financial_prompt_output)
# Out:
# An observation <o> = (<o_s>, <o_t>, <o_d>, <o_a>), where it consists of the following four properties:
#
#     1. <o_s>, any source entity in the financial domain.
#         - Can be a person (with a name) or a financial person such as a financial reporter, financial analyst, financial expert, financial top executive, financial senior level person, etc), civilian.
#         - Can only be an organization that is associated with the financial observation.
#     2. <o_t>, any target entity in the financial domain.
# 	    - Can be a person (with a name) or a financial person such as a financial reporter, financial analyst, financial expert, financial top executive, financial senior level person, etc).
#         - Can only be an organization that is associated with the financial observation.
#     3. <o_d>, date or time range when <o> is expected to come to fruition or when one should observe the <o>.
#         - Forecast can range from a second to anytime in the future.
#         - Answers the questions: "How far to go out from today?" or "Where to stop?".
#     4. <o_a>, financial observation attribute.
#         - Characteristics of a domain-specific attributes such as various quantifiable metrics relevant to the financial domain.
#         - Some examples are stock price, net profit, revenue, operating cash flow, research and development expenses, operating income, gross profit..
#
#
# requirements to use for each observation:
#
#     - Should be based on real-world financial data and not hallucinate.
#     - Must be a simple sentence (observation) (and NOT compounding using "and" or "or").
#     - Should diversify all four properties of the observation (<o>) as in change and not use same for <o_s>, <o_t>, <o_d>, <o_a>.
#     - The observation should be unique and not repeated.
#     - Do not number the observations.
#     - Do not say, "Here are 1 unique observation based on the provided templates and examples:" or anything similar in the prompt.
#     - Change how the current date (<o_d>) written in the observation with examples of (1) Wednesday, August 21, 2024; (2) Wed, August 21, 2024; (3) 08/21/2024; (4) 08/21/2024; (5) 21/08/2024; (6) 21 August 2024; (7) 2024/08/21; (8) 2024-08-21; (9) August 21, 2024; (10) Aug 21, 2024; (11) 21 August 2024, (12) 21 Aug 2024, Q3 of 2027, 2029 of Q3, etc (with removing day of week).
#     - Do not use any of the examples in the prompt.
#     - In front of every prediction, put the template number in the format of "T1:", "T2:", etc. and do not number them like "1.", "2.", etc.
#     - Do not put template number on line by itself. Always pair with a prediction.
#     - Disregard brackets: "<>"
#     - Do not use person name of entity name more than once as in don't use name Joe as both the <o_s> and <o_t>, unless like Mr. Sach and Goldman Sach or Mr. Sam Walton and Sam's Club, etc.
#     - The source entity (<o_s>) is rarely the same as the target entity (<o_t>) and if same, the <o_s> is making a observation on itself in the <o_t>.
#     - Should variate the slope of rise/increase/as much as, fall/decrease/as little as, change, stay stable, high/low chance/probability/degree of, etc.
#     - Must be past tense as in already occurred and not future tense.
#     - Don't leave out financial domain, so specifically generate for this (financial) domain.
#
# Here are some financial templates:
#
#     - financial template 1: <o_s> saw the <o_a> at <o_t> plummeted in <o_d>.
#     - financial template 2: From <p_d>, <p_s> speculated the <p_a> at <p_t> was drastically different.
#     - financial template 5: <p_d>, <p_s> heard that the <p_t> <p_a> remained stable.
#     - financial template 6: <p_t> <p_a> generally rose in <p_d>, according to <p_s>.
#
#
#
# Here are some examples of financial observations:
#
#    - financial examples for template 1:
#       1. Joseph, the young entrepreneur, observed that the revenue at FUBU (his parents clothing line) had increased for Q3 2028.
#       2. BJ saw that the operating cash flow at UF's school of Engineering decrease in 05/2025.
#       3. An fresh investor noticed the ETFs in his portfolio exponentially grew from Apr 7, 1997 to Apr 7, 2025.
#
#
# With the above, generate a unique set of 1 observations per template following the examples. Think from the perspective of an financial analyst, expert, top executive, or senior level person and even a college student, professional, research advisor, etc.

# %% [markdown]
# ###  Template for Health observations

# %%
health_attributes = """obesity rates, prevalence of chronic illnesses, average physical activity levels, nutritional intake, etc."""
health_requirements = """- Should be based on real-world health reports.
    - Suppose the time when <o> was made is during any season such as flu season, allergy season, pandemic, epidemic, etc.
    - Include reports from all Health organization, researcher, doctor, physical therapist, physician assistant, nurse practictioners, fitness expert, etc."""

# On <p_d>, <p_s> speculates that the <p_a> at <p_t> will likely increase.

health_examples = """
- health examples for template 1:
    1. WellFlorida caught that the patients' blood glucose at all hospitals in Florida improved from Q1 2021 to Q3 2021.
    2. Nurse John observed that the heart rate in patients at Alaska's General Hospital had stabilized from 2023 January to 2023 Dec.
    3. I noted that the number of visits my patients in Piscataway, NJ decreased from start of week to end of week.
- health exmples for template 2:
    1. On 12Feb13, Dr. Darah decomposed the blood pressure at NY's General Hospital decreased.
    2. From 2011 to 2016, Health Insights Inc. speculated physical activity levels at Los Angeles Clinic to be stablized.
    3. Yesterday, I pointed out the heart rate at my own neurosurgeon practice to keep level.
- health exmples for template 6:
    1. Patients' cholesterol levels exponentially exploded in 1999, according to HeathWatch.
    2. Patients at Ohio's clinic blood glucose levels remained stable in 2023, accoriding to anonymous source.
    3. My staff hours of work was optimal in 2013, according to my company reports.
"""

health_input_dict = {
    "observation_domain": "health",
    "observation_domain_attribute": health_attributes,
    "domain_requirements": health_requirements,
    "domain_examples": health_examples,
    "observations_N": generate_N_observations_per_template
}

health_prompt_output = pipeline_prompt.format(**health_input_dict)

# %% [markdown]
# ###  Template for Policy observations

# %%
policy_attributes = """election outcomes, economic reforms, legislative impacts."""
policy_requirements = """- Should be based on real-world policy reports.
    - Suppose the time when <o> was made is during an election cycle or non-election cycles.
    - Include policies & laws, from all sectors such as consumer staples, energy, finance, health care, industrials, materials, media, real estate, retail, technology, utilities, defense, etc."""

policy_examples = """
   - policy examples for template 1:
      1. Local journalist, Aaron, identified economic reforms in Thomson, GA rose jan 2023.
      2. Policy analyst, Michael (Ph.D), remarked that the home tax in Austin, TX had increased on 7/9/18.
      3. DCR noted that company employment rates in her city San Francisco had risen from Q1 2025 to Q3 2025.
    - policy examples for template 2:
      1. Last week, I pointed out that the education funding in my local district skyrocketed.
      2. From 2001 to 2005, Economic Insights speculated employment rates in San Francisco to be steady.
      3. 08/12/07, citizens ravelled that the tax rates in Austin, TX dropped.
    - policy examples for template 6:
      1. US Marines recruits drastically enriched after Sept 1, 2001, according to Paul (a highly interviewed former US Marine).
      2. Public undergraduate education cost are more affordable in Q4 2021, according to BMB.
      3. Protests rose in 2020, according to policy maker Sarah.
"""

policy_input_dict = {
    "observation_domain": "policy",
    "observation_domain_attribute": policy_attributes,
    "domain_requirements": policy_requirements,
    "domain_examples": policy_examples,
    "observations_N": generate_N_observations_per_template
}

policy_prompt_output = pipeline_prompt.format(**policy_input_dict)

# %% [markdown]
# ###  Template for Weather observations

# %%
weather_attributes = """temperature, precipitation, wind speed, humidity, etc."""
weather_requirements = """- Should be based on real-world weather reports.
    - Suppose the time when <o> was made is during any season and any location (ie: Florida known for hurricanes, California known for wildfires, etc).
    - Include reports from all meteorologists, weather organizations, or any type of weather entity.."""

weather_examples = """
    - weather examples for template 1:
        1. The street cleaner watched the snow in Minnesota increase from 12/8/9 to 2/8/10.
        2. Jade, a farmer, caught that the rainfall in Kansas had decreased at midnight.
        3. I felt the wind speed in North Dakota (city of Fargo) picked up drastically today.
    - weather examples for template 2:
        1. From 2005 to 2010, Climate Watch speculated rainfall levels in Seattle to be consistent.
        2. 03-03-03, Meteorologist Jane analyzed that the temperature in Denver plummeted.
        3. On my birthday, I saw the humidity in my hometown surged.
    - weather examples for template 5:  
        1. In 15Aug17, weather analyst Mark observed that Chicago's wind speed picked up.
        2. Q3 2009, I Dr. Lesusan whitnessed my lands's ground pressure dropping.
        3. Mid day yesterday, Meteorologist Lisa felt Phoenix's humidity blasting.
    - weather examples for template 6:
        1. In Yellowstone the temperature slightly changed at dawn, according to the park ranger.
        2. In Phoenix, the humidity increased from March 2005 to April 2005, according to meteorologist Bisa.
        3. Our team successfully navigated the flooding in spring, according to my manager.
"""

weather_input_dict = {
    "observation_domain": "weather",
    "observation_domain_attribute": weather_attributes,
    "domain_requirements": weather_requirements,
    "domain_examples": weather_examples,
    "observations_N": generate_N_observations_per_template
}

weather_prompt_output = pipeline_prompt.format(**weather_input_dict)

# %% [markdown]
# ## Generate observations

# %%
N_batches = 1
# text_generation_models = [gpt_4_o_generation_model]
# text_generation_models = [llama_versatile_generation_model]
text_generation_models = [llama_versatile_generation_model, llama_instant_generation_model, llama_70b_8192_generation_model, 
                          llama_8b_8192_generation_model, gpt_35_turbo_generation_model, gpt_4_o_generation_model, 
                          mixtral_87b_instruct_generation_model]

# text_generation_models = [gpt_4_o_generation_model]

# text_generation_models = [llama_versatile_generation_model, llama_instant_generation_model, llama_70b_8192_generation_model, 
#                           llama_8b_8192_generation_model, gpt_35_turbo_generation_model]

# %%
observation_domains = ["finance", "health", "policy", "weather"]
observation_prompt_outputs = {
    "finance": financial_prompt_output,
    "health": health_prompt_output,
    "policy": policy_prompt_output,
    "weather": weather_prompt_output,
}
observation_label = 0

batched_observations_df = tgmf.batch_generate_data(N_batches=N_batches, 
                                text_generation_models=text_generation_models, 
                                domains=observation_domains,
                                prompt_outputs=observation_prompt_outputs,
                                sentence_label=observation_label)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================================== Batch 0 ===============================================
# finance --- llama-3.3-70b-versatile --- GROQ_CLOUD
# finance --- llama-3.1-8b-instant --- GROQ_CLOUD
# finance --- llama3-70b-8192 --- GROQ_CLOUD
# finance --- llama3-8b-8192 --- GROQ_CLOUD
# finance --- gpt-3.5-turbo --- NAVI_GATOR
# finance --- gpt-4-turbo --- NAVI_GATOR
# finance --- mixtral-8x7b-instruct --- NAVI_GATOR
#
# health --- llama-3.3-70b-versatile --- GROQ_CLOUD
# health --- llama-3.1-8b-instant --- GROQ_CLOUD
# health --- llama3-70b-8192 --- GROQ_CLOUD
# health --- llama3-8b-8192 --- GROQ_CLOUD
# health --- gpt-3.5-turbo --- NAVI_GATOR
# health --- gpt-4-turbo --- NAVI_GATOR
# health --- mixtral-8x7b-instruct --- NAVI_GATOR
#
# policy --- llama-3.3-70b-versatile --- GROQ_CLOUD
# policy --- llama-3.1-8b-instant --- GROQ_CLOUD
# policy --- llama3-70b-8192 --- GROQ_CLOUD
# policy --- llama3-8b-8192 --- GROQ_CLOUD
# policy --- gpt-3.5-turbo --- NAVI_GATOR
# policy --- gpt-4-turbo --- NAVI_GATOR
# policy --- mixtral-8x7b-instruct --- NAVI_GATOR
#
# weather --- llama-3.3-70b-versatile --- GROQ_CLOUD
# weather --- llama-3.1-8b-instant --- GROQ_CLOUD
# weather --- llama3-70b-8192 --- GROQ_CLOUD
# weather --- llama3-8b-8192 --- GROQ_CLOUD
# weather --- gpt-3.5-turbo --- NAVI_GATOR
# weather --- gpt-4-turbo --- NAVI_GATOR
# weather --- mixtral-8x7b-instruct --- NAVI_GATOR
# 100%|██████████| 1/1 [00:39<00:00, 39.15s/it]
# Start logging batch
# log_directory: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/data/observation_logs
# Save CSV: /Users/detraviousjamaribrinkley/Documents/Development/research_labs/uf_ds/predictions/data/observation_logs/batch_2-observation/batch_2-from_df.csv
#
# CSV to Log
#                                                                                                                                                                           Base Sentence  \
# 0                                                                                            A financial analyst at Goldman Sachs saw the stock price at Tesla plummeted in 2024-02-15.
# 1                                                            From 2020-01-01, a senior level executive at JPMorgan Chase speculated the net profit at Amazon was drastically different.
# 2                                                   2023-08-10, a research advisor at Harvard University heard that the research and development expenses at Microsoft remained stable.
# 3                                                                                         Apple's gross profit generally rose in Q2 2022, according to a financial expert at Bloomberg.
# 4                                                                                        Mr. Johnson, a financial analyst, observed that the stock price at Apple plummeted in Q2 2023.
# 5                                                                                                 From last week, Rachel speculated the net profit at Google was drastically different.
# 6                                                                                                Rachel, a financial expert, heard that the operating income at Amazon remained stable.
# 7                                                                                                             Amazon's operating income generally rose in Q4 2022, according to Rachel.
# 8                                                                                                 Rachel heard that the research and development expenses at Microsoft remained stable.
# 9                                                                                         Microsoft's research and development expenses generally rose in Q3 2025, according to Rachel.
# 55                                                                                             The financial expert at Goldman Sachs saw the stock price at Tesla plummeted in Q2 2026.
# 56                                                                 From 2023, the research advisor at Harvard University speculated the net profit at Amazon was drastically different.
# 57                                                                   2025, the senior financial analyst at JPMorgan Chase heard that the operating income at Microsoft remained stable.
# 58                                                                      The gross profit at Walmart generally rose in 2022, according to the financial top executive at Morgan Stanley.
# 61                                                                                                             Goldman Sachs saw the stock price at Apple plummeted in August 21, 2024.
# 62                                                                            From January 1, 2020, Dr. Smith speculated the net profit at Johnson & Johnson was drastically different.
# 63                                                                          August 21, 2024, Dr. Johnson heard that the research and development expenses at Microsoft remained stable.
# 64                                                                                                     Microsoft's operating income generally rose in Q3 of 2027, according to Dr. Lee.
# 66                                                                                                                Ms. Smith witnessed the stock price at Tesla plummeted in Q2 of 2023.
# 67                                                                                        From May 15, 2024, Mr. Johnson speculated the net profit at Amazon was drastically different.
# 68                                                                                                On July 1, 2027, a financial expert heard that the revenue at Google remained stable.
# 69                                                                                            Apple's operating income generally rose in 2026, according to a senior financial analyst.
# 70                                                                                                                   Goldman Sachs saw the net profit at Tesla plummeted in 2023-11-15.
# 71                                                                                       From 12/03/2022, Morgan Stanley speculated the stock price at Apple was drastically different.
# 72                                                                                                    2022/07/30, a financial analyst heard that the revenue at Amazon remained stable.
# 73                                                                                     Microsoft operating income generally rose in 2021-09-15, according to a senior financial expert.
# 74                                                              Noticing a concerning trend, the financial analyst observed that the net profit at TechCo plummeted on August 21, 2024.
# 75                                    From Q3 of 2027, the research and development expenses at GreenEnergy Inc. were speculated to be significantly different by the financial expert.
# 76                                                                        In 2029 of Q3, the financial senior level person heard that the stock price of BlueChip Inc. remained stable.
# 77                                                              For the past decade, the operating income at InnovativeMotors generally rose, according to the financial top executive.
# 78                                                                       American Heart Association saw the obesity rates at children's hospitals in California plummeted in 2022-2024.
# 79                                         From 2015 to 2020, Health Research Institute speculated the average life expectancy at senior centers in New York was drastically different.
# 80                                                        2024-07-15, Centers for Disease Control and Prevention heard that the vaccination rates at community clinics remained stable.
# 81                                                                          Patients' mental health issues generally rose in Q2 2022, according to National Institute of Mental Health.
# 82                                                                WellFlorida observed that the patients' blood pressure at all hospitals in Florida decreased from Q2 2022 to Q4 2022.
# 83                                                                  On 15Jun20, Dr. Lee speculated the number of COVID-19 cases at New York's General Hospital was significantly lower.
# 84                                                     From 2018 to 2020, Health Insights Inc. heard that the patients' physical activity levels at Los Angeles Clinic remained stable.
# 85                                                      The World Health Organization noted that the number of deaths from influenza at all hospitals worldwide generally rose in 2019.
# 86                                                              From 2015 to 2019, Dr. Patel heard that the patients' blood glucose levels at India's General Hospital remained stable.
# 87                                     Patients' obesity rates at all clinics in the United States generally rose in 2020, according to the Centers for Disease Control and Prevention.
# 103                                                                The American Heart Association saw the cardiovascular disease rates at hospitals in California plummeted in Q2 2022.
# 104                                                                 From 2015 to 2020, Dr. Patel speculated the obesity rates at pediatric clinics in Texas were drastically different.
# 105                                    2024, August 15, the Centers for Disease Control and Prevention heard that the influenza vaccination rates in the United States remained stable.
# 106                                                                                Patients' average sleep duration generally rose in 2020, according to the National Sleep Foundation.
# 108                                                                 WellFlorida caught that the patients' blood pressure at all hospitals in Florida increased from Q2 2022 to Q4 2022.
# 109                                                 On 15Mar20, Dr. Patel decomposed the number of patients with diabetes at New York's Hospital for Special Surgery to have decreased.
# 110                                                                   From 2018 to 2022, Health Insights Inc. speculated the prevalence of obesity at Los Angeles Clinic to have risen.
# 111                                            I noted that the average physical activity levels of patients at my own primary care clinic in Boston remained stable from 2020 to 2022.
# 112                                                      From 2015 to 2020, the World Health Organization heard that the number of reported cases of malaria in Africa remained stable.
# 113                                                                 Patients' body mass index generally decreased in 2019, according to the Centers for Disease Control and Prevention.
# 115                                                                          Dr. Smith witnessed the obesity rates at the local community center plummeted in the last quarter of 2022.
# 116                                       From 2018 to 2021, Health Trends Institute speculated the prevalence of chronic illnesses at the regional hospital was drastically different.
# 117                                                                            Last month, a health reporter heard that the nutritional intake at the school cafeteria remained stable.
# 118                                                        The physical activity levels at the fitness center generally rose in the first half of 2023, according to the health expert.
# 119                                                                                                     Dr. Smith saw the obesity rates at the downtown clinic plummeted in 2025-07-15.
# 120                                                        From Q4 2020, HealthWatch speculated the average physical activity levels at the community center was drastically different.
# 121                                                                                       2022/11/30, Nurse Jane heard that the children's hospital nutritional intake remained stable.
# 122                                                                    City Health Department's chronic illness prevalence generally rose in 2023 Q2, according to Health Analyst John.
# 123                                          Dr. Smith noticed a significant drop in obesity rates among school-aged children in the Midwest region from January 2023 to December 2023.
# 124            A recent study by the CDC speculated that the prevalence of diabetes among adults over 65 in the Southern states was considerably higher in Q2 2024 compared to Q2 2023.
# 125                                                                     According to a WHO report published in 2022, the global average life expectancy has remained relatively stable.
# 126                                          From 2018 to 2022, the number of organ donors in the United States generally increased, according to the United Network for Organ Sharing.
# 127                                                            The policy expert witnessed the election outcomes at the Democratic National Committee plummeted in 4th quarter of 2022.
# 128                                                       From 2010 to 2015, the senior policy analyst speculated the legislative impacts at the White House was drastically different.
# 129                                                                            2022-07-15, the research advisor heard that the economic reforms at the Federal Reserve remained stable.
# 130                                                                               Healthcare costs at the local hospital generally rose in 2023, according to the policy top executive.
# 131                                                                   Policy expert, Dr. Rachel Kim, observed that the unemployment rate in New York City plummeted on August 15, 2024.
# 132                                                                    From 2018, research advisor, Mr. Thompson, speculated the poverty rate in Los Angeles was drastically different.
# 133                                                                                             2027, policy analyst, Emily Chen, heard that the crime rate in Chicago remained stable.
# 134                                                                                    US Congress members' salaries generally rose in Q2 2022, according to policy advisor, Mr. Patel.
# 136                                                                                  Policy reporter, Rachel, saw the election outcomes at Democratic Party plummeted in November 2022.
# 137                                                                       From 2015 to 2020, Policy expert, Dr. Lee, speculated the economic growth at China was drastically different.
# 138                                                                 August 15, 2023, Policy senior level person, James, heard that the legislative impacts at Congress remained stable.
# 139                                                                                Healthcare costs at private hospitals generally rose in Q2 2024, according to Policy analyst, Emily.
# 143                                                                            The policy expert, Dr. Patel, saw the unemployment rate at the city of Chicago plummeted in August 2022.
# 145                                        From Q2 2018, the research advisor, Dr. Rodriguez, speculated the economic growth rate at the state of California was drastically different.
# 147                                                                    On 21 August 2024, the policy analyst, Emily, heard that the crime rate in the city of New York remained stable.
# 149                                                                                           The education funding generally rose in Q3 2025, according to the policy expert, Dr. Lee.
# 151                                                                                 The unemployment rate in Chicago plummeted in Q2 of 2023, according to economic analyst, Dr. Patel.
# 152                                                       From 2018 to 2020, the budget deficit in New York City was drastically different, as noted by financial expert, Ms. Thompson.
# 153                                                                                                  In 09/15/2021, residents heard that the crime rate in Los Angeles remained stable.
# 154                                                               Public transportation ridership generally rose in Q3 of 2022, according to transportation policy expert, Mr. Johnson.
# 155                                                                               Policy analyst, Dr. Smith, observed that healthcare funding in New York City plummeted on 2024-08-21.
# 156                                                                     From Q2 2022, Policy Insights speculated the legislative impacts in Washington D.C. were drastically different.
# 157                                                                         2023/07/15, a senior policy advisor heard that the environmental regulations in California remained stable.
# 158                                                                                                The unemployment rate generally rose in Q1 of 2020, according to policy expert Jane.
# 159                                                                                       Policy analyst, Claire, observed the unemployment rate in New York City plummeted in Q2 2024.
# 160                                                     From 2018 to 2022, the National Economic Council speculated the GDP growth rate in the United States was drastically different.
# 161                                                                                      In 2027, a research advisor, John, heard that the poverty rate in rural areas remained stable.
# 162                                                                              The number of renewable energy projects generally rose in 2029, according to the Department of Energy.
# 163                                                                                      The National Weather Service observed the precipitation in California plummeted in 2024-07-15.
# 164                                                       From 2015 to 2020, the American Meteorological Society speculated the temperature at Mount Everest was drastically different.
# 165                                                                              4th quarter of 2022, the Weather Channel heard that the wind speed in Hurricane Alley remained stable.
# 166                                         The atmospheric pressure in the Gulf of Mexico generally rose in September 2023, according to a research team from the University of Miami.
# 167                                                                                         The weather reporter watched the temperature in New York City plummeted on August 25, 2024.
# 168                                                   From 2015 to 2020, Dr. Maria, a climate scientist, speculated the precipitation levels in Los Angeles were drastically different.
# 169                                                                                          In Q2 2018, I, a research assistant, heard that the wind speed in Chicago remained stable.
# 170                                                          The storm chaser generally saw the humidity in Oklahoma rose in September 2027, according to the National Weather Service.
# 172                                                                                        Weather Forecaster Emma saw the precipitation in New York City plummeted on August 15, 2022.
# 173                                                                      From 2015 to 2020, Climate Researcher Dr. Patel speculated the temperature in Miami was drastically different.
# 174                                                                                   On October 12, 2021, Meteorologist Ryan heard that the wind speed in Los Angeles remained stable.
# 175                                                                             In Dallas, the humidity generally rose from June 2020 to July 2020, according to Weather Analyst David.
# 178                                                                                              The weather forecaster observed the temperature in Tokyo plummeted on August 25, 2024.
# 179                                                                         From 2015 to 2020, Climate Research speculated the precipitation in New York City was significantly higher.
# 180                                                                                      On September 12, 2022, Dr. Patel witnessed the atmospheric pressure in Mumbai remained stable.
# 181                                                                  In the Amazon rainforest, the humidity generally rose from June 2020 to July 2020, according to the research team.
# 183                                                                                                   The weather reporter noticed the temperature in Miami plummeted in the past week.
# 184                                                                          From 2015 to 2020, Climate Watch speculated wind speed levels in New York City were drastically different.
# 185                                                                                       On 12th June 2023, the meteorologist heard that the precipitation in Seattle remained stable.
# 186                                                                                      The weather expert observed that the humidity in Los Angeles generally rose in the last month.
# 187                                                                                                The weather analyst saw the humidity at the coastal regions plummeted in 2024-08-21.
# 188                                                                            From Q1 2023, the meteorologist speculated the wind speed at the Great Plains was drastically different.
# 189                                                                                         2023/07/15, the weather expert heard that the temperature in New York City remained stable.
# 190                                                                   The weather reporter noted that rainfall generally rose in 2022/11/30, according to the National Weather Service.
# 191                       Noticing the recent heatwave, the meteorologist in the local weather station observed the temperature in Dallas, Texas, soar to new heights on June 23, 2023.
# 192                     From Q2 2022 to Q1 2023, the weather expert at the climate research center predicted that the precipitation levels in Florida would see a significant decrease.
# 193              During her visit to the Grand Canyon in May 2024, the environmental science professor noticed that the wind speed had remained stable compared to her previous visits.
# 194  In the first two weeks of January 2025, the senior meteorologist reported that the snowfall in New York generally rose, providing a white winter experience for the city dwellers.
#
#      Sentence Label   Domain               Model Name    API Name  Batch ID  \
# 0                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 1                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 2                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 3                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 4                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 5                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 6                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 7                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 8                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 9                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 55                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 56                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 57                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 58                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 61                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 62                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 63                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 64                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 66                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 67                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 68                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 69                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 70                0  finance                   gpt-4o  NAVI_GATOR         0
# 71                0  finance                   gpt-4o  NAVI_GATOR         0
# 72                0  finance                   gpt-4o  NAVI_GATOR         0
# 73                0  finance                   gpt-4o  NAVI_GATOR         0
# 74                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 75                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 76                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 77                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 78                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 79                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 80                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 81                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 82                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 83                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 84                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 85                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 86                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 87                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 103               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 104               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 105               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 106               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 108               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 109               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 110               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 111               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 112               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 113               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 115               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 116               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 117               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 118               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 119               0   health                   gpt-4o  NAVI_GATOR         0
# 120               0   health                   gpt-4o  NAVI_GATOR         0
# 121               0   health                   gpt-4o  NAVI_GATOR         0
# 122               0   health                   gpt-4o  NAVI_GATOR         0
# 123               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 124               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 125               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 126               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 127               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 128               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 129               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 130               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 131               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 132               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 133               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 134               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 136               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 137               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 138               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 139               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 143               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 145               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 147               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 149               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 151               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 152               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 153               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 154               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 155               0   policy                   gpt-4o  NAVI_GATOR         0
# 156               0   policy                   gpt-4o  NAVI_GATOR         0
# 157               0   policy                   gpt-4o  NAVI_GATOR         0
# 158               0   policy                   gpt-4o  NAVI_GATOR         0
# 159               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 160               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 161               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 162               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 163               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 164               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 165               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 166               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 167               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 168               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 169               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 170               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 172               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 173               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 174               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 175               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 178               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 179               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 180               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 181               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 183               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 184               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 185               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 186               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 187               0  weather                   gpt-4o  NAVI_GATOR         0
# 188               0  weather                   gpt-4o  NAVI_GATOR         0
# 189               0  weather                   gpt-4o  NAVI_GATOR         0
# 190               0  weather                   gpt-4o  NAVI_GATOR         0
# 191               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 192               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 193               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 194               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
#
#      Template Number
# 0                  1
# 1                  2
# 2                  5
# 3                  6
# 4                  1
# 5                  2
# 6                  3
# 7                  4
# 8                  5
# 9                  6
# 55                 1
# 56                 2
# 57                 5
# 58                 6
# 61                 1
# 62                 2
# 63                 5
# 64                 6
# 66                 1
# 67                 2
# 68                 5
# 69                 6
# 70                 1
# 71                 2
# 72                 5
# 73                 6
# 74                 1
# 75                 2
# 76                 5
# 77                 6
# 78                 1
# 79                 2
# 80                 5
# 81                 6
# 82                 1
# 83                 2
# 84                 3
# 85                 4
# 86                 5
# 87                 6
# 103                1
# 104                2
# 105                5
# 106                6
# 108                1
# 109                2
# 110                3
# 111                4
# 112                5
# 113                6
# 115                1
# 116                2
# 117                5
# 118                6
# 119                1
# 120                2
# 121                5
# 122                6
# 123                1
# 124                2
# 125                5
# 126                6
# 127                1
# 128                2
# 129                5
# 130                6
# 131                1
# 132                2
# 133                5
# 134                6
# 136                1
# 137                2
# 138                5
# 139                6
# 143                1
# 145                2
# 147                5
# 149                6
# 151                1
# 152                2
# 153                5
# 154                6
# 155                1
# 156                2
# 157                5
# 158                6
# 159                1
# 160                2
# 161                5
# 162                6
# 163                1
# 164                2
# 165                5
# 166                6
# 167                1
# 168                2
# 169                3
# 170                4
# 172                1
# 173                2
# 174                5
# 175                6
# 178                1
# 179                2
# 180                5
# 181                6
# 183                1
# 184                2
# 185                5
# 186                6
# 187                1
# 188                2
# 189                5
# 190                6
# 191                1
# 192                2
# 193                5
# 194                6
# [                                                                                                                                                                          Base Sentence  \
# 0                                                                                            A financial analyst at Goldman Sachs saw the stock price at Tesla plummeted in 2024-02-15.
# 1                                                            From 2020-01-01, a senior level executive at JPMorgan Chase speculated the net profit at Amazon was drastically different.
# 2                                                   2023-08-10, a research advisor at Harvard University heard that the research and development expenses at Microsoft remained stable.
# 3                                                                                         Apple's gross profit generally rose in Q2 2022, according to a financial expert at Bloomberg.
# 4                                                                                        Mr. Johnson, a financial analyst, observed that the stock price at Apple plummeted in Q2 2023.
# 5                                                                                                 From last week, Rachel speculated the net profit at Google was drastically different.
# 6                                                                                                Rachel, a financial expert, heard that the operating income at Amazon remained stable.
# 7                                                                                                             Amazon's operating income generally rose in Q4 2022, according to Rachel.
# 8                                                                                                 Rachel heard that the research and development expenses at Microsoft remained stable.
# 9                                                                                         Microsoft's research and development expenses generally rose in Q3 2025, according to Rachel.
# 55                                                                                             The financial expert at Goldman Sachs saw the stock price at Tesla plummeted in Q2 2026.
# 56                                                                 From 2023, the research advisor at Harvard University speculated the net profit at Amazon was drastically different.
# 57                                                                   2025, the senior financial analyst at JPMorgan Chase heard that the operating income at Microsoft remained stable.
# 58                                                                      The gross profit at Walmart generally rose in 2022, according to the financial top executive at Morgan Stanley.
# 61                                                                                                             Goldman Sachs saw the stock price at Apple plummeted in August 21, 2024.
# 62                                                                            From January 1, 2020, Dr. Smith speculated the net profit at Johnson & Johnson was drastically different.
# 63                                                                          August 21, 2024, Dr. Johnson heard that the research and development expenses at Microsoft remained stable.
# 64                                                                                                     Microsoft's operating income generally rose in Q3 of 2027, according to Dr. Lee.
# 66                                                                                                                Ms. Smith witnessed the stock price at Tesla plummeted in Q2 of 2023.
# 67                                                                                        From May 15, 2024, Mr. Johnson speculated the net profit at Amazon was drastically different.
# 68                                                                                                On July 1, 2027, a financial expert heard that the revenue at Google remained stable.
# 69                                                                                            Apple's operating income generally rose in 2026, according to a senior financial analyst.
# 70                                                                                                                   Goldman Sachs saw the net profit at Tesla plummeted in 2023-11-15.
# 71                                                                                       From 12/03/2022, Morgan Stanley speculated the stock price at Apple was drastically different.
# 72                                                                                                    2022/07/30, a financial analyst heard that the revenue at Amazon remained stable.
# 73                                                                                     Microsoft operating income generally rose in 2021-09-15, according to a senior financial expert.
# 74                                                              Noticing a concerning trend, the financial analyst observed that the net profit at TechCo plummeted on August 21, 2024.
# 75                                    From Q3 of 2027, the research and development expenses at GreenEnergy Inc. were speculated to be significantly different by the financial expert.
# 76                                                                        In 2029 of Q3, the financial senior level person heard that the stock price of BlueChip Inc. remained stable.
# 77                                                              For the past decade, the operating income at InnovativeMotors generally rose, according to the financial top executive.
# 78                                                                       American Heart Association saw the obesity rates at children's hospitals in California plummeted in 2022-2024.
# 79                                         From 2015 to 2020, Health Research Institute speculated the average life expectancy at senior centers in New York was drastically different.
# 80                                                        2024-07-15, Centers for Disease Control and Prevention heard that the vaccination rates at community clinics remained stable.
# 81                                                                          Patients' mental health issues generally rose in Q2 2022, according to National Institute of Mental Health.
# 82                                                                WellFlorida observed that the patients' blood pressure at all hospitals in Florida decreased from Q2 2022 to Q4 2022.
# 83                                                                  On 15Jun20, Dr. Lee speculated the number of COVID-19 cases at New York's General Hospital was significantly lower.
# 84                                                     From 2018 to 2020, Health Insights Inc. heard that the patients' physical activity levels at Los Angeles Clinic remained stable.
# 85                                                      The World Health Organization noted that the number of deaths from influenza at all hospitals worldwide generally rose in 2019.
# 86                                                              From 2015 to 2019, Dr. Patel heard that the patients' blood glucose levels at India's General Hospital remained stable.
# 87                                     Patients' obesity rates at all clinics in the United States generally rose in 2020, according to the Centers for Disease Control and Prevention.
# 103                                                                The American Heart Association saw the cardiovascular disease rates at hospitals in California plummeted in Q2 2022.
# 104                                                                 From 2015 to 2020, Dr. Patel speculated the obesity rates at pediatric clinics in Texas were drastically different.
# 105                                    2024, August 15, the Centers for Disease Control and Prevention heard that the influenza vaccination rates in the United States remained stable.
# 106                                                                                Patients' average sleep duration generally rose in 2020, according to the National Sleep Foundation.
# 108                                                                 WellFlorida caught that the patients' blood pressure at all hospitals in Florida increased from Q2 2022 to Q4 2022.
# 109                                                 On 15Mar20, Dr. Patel decomposed the number of patients with diabetes at New York's Hospital for Special Surgery to have decreased.
# 110                                                                   From 2018 to 2022, Health Insights Inc. speculated the prevalence of obesity at Los Angeles Clinic to have risen.
# 111                                            I noted that the average physical activity levels of patients at my own primary care clinic in Boston remained stable from 2020 to 2022.
# 112                                                      From 2015 to 2020, the World Health Organization heard that the number of reported cases of malaria in Africa remained stable.
# 113                                                                 Patients' body mass index generally decreased in 2019, according to the Centers for Disease Control and Prevention.
# 115                                                                          Dr. Smith witnessed the obesity rates at the local community center plummeted in the last quarter of 2022.
# 116                                       From 2018 to 2021, Health Trends Institute speculated the prevalence of chronic illnesses at the regional hospital was drastically different.
# 117                                                                            Last month, a health reporter heard that the nutritional intake at the school cafeteria remained stable.
# 118                                                        The physical activity levels at the fitness center generally rose in the first half of 2023, according to the health expert.
# 119                                                                                                     Dr. Smith saw the obesity rates at the downtown clinic plummeted in 2025-07-15.
# 120                                                        From Q4 2020, HealthWatch speculated the average physical activity levels at the community center was drastically different.
# 121                                                                                       2022/11/30, Nurse Jane heard that the children's hospital nutritional intake remained stable.
# 122                                                                    City Health Department's chronic illness prevalence generally rose in 2023 Q2, according to Health Analyst John.
# 123                                          Dr. Smith noticed a significant drop in obesity rates among school-aged children in the Midwest region from January 2023 to December 2023.
# 124            A recent study by the CDC speculated that the prevalence of diabetes among adults over 65 in the Southern states was considerably higher in Q2 2024 compared to Q2 2023.
# 125                                                                     According to a WHO report published in 2022, the global average life expectancy has remained relatively stable.
# 126                                          From 2018 to 2022, the number of organ donors in the United States generally increased, according to the United Network for Organ Sharing.
# ...
# 172                                                                                        Weather Forecaster Emma saw the precipitation in New York City plummeted on August 15, 2022.
# 173                                                                      From 2015 to 2020, Climate Researcher Dr. Patel speculated the temperature in Miami was drastically different.
# 174                                                                                   On October 12, 2021, Meteorologist Ryan heard that the wind speed in Los Angeles remained stable.
# 175                                                                             In Dallas, the humidity generally rose from June 2020 to July 2020, according to Weather Analyst David.
# 178                                                                                              The weather forecaster observed the temperature in Tokyo plummeted on August 25, 2024.
# 179                                                                         From 2015 to 2020, Climate Research speculated the precipitation in New York City was significantly higher.
# 180                                                                                      On September 12, 2022, Dr. Patel witnessed the atmospheric pressure in Mumbai remained stable.
# 181                                                                  In the Amazon rainforest, the humidity generally rose from June 2020 to July 2020, according to the research team.
# 183                                                                                                   The weather reporter noticed the temperature in Miami plummeted in the past week.
# 184                                                                          From 2015 to 2020, Climate Watch speculated wind speed levels in New York City were drastically different.
# 185                                                                                       On 12th June 2023, the meteorologist heard that the precipitation in Seattle remained stable.
# 186                                                                                      The weather expert observed that the humidity in Los Angeles generally rose in the last month.
# 187                                                                                                The weather analyst saw the humidity at the coastal regions plummeted in 2024-08-21.
# 188                                                                            From Q1 2023, the meteorologist speculated the wind speed at the Great Plains was drastically different.
# 189                                                                                         2023/07/15, the weather expert heard that the temperature in New York City remained stable.
# 190                                                                   The weather reporter noted that rainfall generally rose in 2022/11/30, according to the National Weather Service.
# 191                       Noticing the recent heatwave, the meteorologist in the local weather station observed the temperature in Dallas, Texas, soar to new heights on June 23, 2023.
# 192                     From Q2 2022 to Q1 2023, the weather expert at the climate research center predicted that the precipitation levels in Florida would see a significant decrease.
# 193              During her visit to the Grand Canyon in May 2024, the environmental science professor noticed that the wind speed had remained stable compared to her previous visits.
# 194  In the first two weeks of January 2025, the senior meteorologist reported that the snowfall in New York generally rose, providing a white winter experience for the city dwellers.
#
#      Sentence Label   Domain               Model Name    API Name  Batch ID  \
# 0                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 1                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 2                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 3                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 4                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 5                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 6                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 7                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 8                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 9                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 55                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 56                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 57                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 58                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 61                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 62                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 63                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 64                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 66                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 67                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 68                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 69                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 70                0  finance                   gpt-4o  NAVI_GATOR         0
# 71                0  finance                   gpt-4o  NAVI_GATOR         0
# 72                0  finance                   gpt-4o  NAVI_GATOR         0
# 73                0  finance                   gpt-4o  NAVI_GATOR         0
# 74                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 75                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 76                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 77                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 78                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 79                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 80                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 81                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 82                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 83                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 84                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 85                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 86                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 87                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 103               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 104               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 105               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 106               0   health          llama3-70b-8192  GROQ_CLOUD         0
# 108               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 109               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 110               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 111               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 112               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 113               0   health           llama3-8b-8192  GROQ_CLOUD         0
# 115               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 116               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 117               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 118               0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 119               0   health                   gpt-4o  NAVI_GATOR         0
# 120               0   health                   gpt-4o  NAVI_GATOR         0
# 121               0   health                   gpt-4o  NAVI_GATOR         0
# 122               0   health                   gpt-4o  NAVI_GATOR         0
# 123               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 124               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 125               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 126               0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 127               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 128               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 129               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 130               0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 131               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 132               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 133               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 134               0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 136               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 137               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 138               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 139               0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 143               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 145               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 147               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 149               0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 151               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 152               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 153               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 154               0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 155               0   policy                   gpt-4o  NAVI_GATOR         0
# 156               0   policy                   gpt-4o  NAVI_GATOR         0
# 157               0   policy                   gpt-4o  NAVI_GATOR         0
# 158               0   policy                   gpt-4o  NAVI_GATOR         0
# 159               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 160               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 161               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 162               0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 163               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 164               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 165               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 166               0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 167               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 168               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 169               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 170               0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 172               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 173               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 174               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 175               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 178               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 179               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 180               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 181               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 183               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 184               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 185               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 186               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 187               0  weather                   gpt-4o  NAVI_GATOR         0
# 188               0  weather                   gpt-4o  NAVI_GATOR         0
# 189               0  weather                   gpt-4o  NAVI_GATOR         0
# 190               0  weather                   gpt-4o  NAVI_GATOR         0
# 191               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 192               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 193               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 194               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
#
#      Template Number
# 0                  1
# 1                  2
# 2                  5
# 3                  6
# 4                  1
# 5                  2
# 6                  3
# 7                  4
# 8                  5
# 9                  6
# 55                 1
# 56                 2
# 57                 5
# 58                 6
# 61                 1
# 62                 2
# 63                 5
# 64                 6
# 66                 1
# 67                 2
# 68                 5
# 69                 6
# 70                 1
# 71                 2
# 72                 5
# 73                 6
# 74                 1
# 75                 2
# 76                 5
# 77                 6
# 78                 1
# 79                 2
# 80                 5
# 81                 6
# 82                 1
# 83                 2
# 84                 3
# 85                 4
# 86                 5
# 87                 6
# 103                1
# 104                2
# 105                5
# 106                6
# 108                1
# 109                2
# 110                3
# 111                4
# 112                5
# 113                6
# 115                1
# 116                2
# 117                5
# 118                6
# 119                1
# 120                2
# 121                5
# 122                6
# 123                1
# 124                2
# 125                5
# 126                6
# 127                1
# 128                2
# 129                5
# 130                6
# 131                1
# 132                2
# 133                5
# 134                6
# 136                1
# 137                2
# 138                5
# 139                6
# 143                1
# 145                2
# 147                5
# 149                6
# 151                1
# 152                2
# 153                5
# 154                6
# 155                1
# 156                2
# 157                5
# 158                6
# 159                1
# 160                2
# 161                5
# 162                6
# 163                1
# 164                2
# 165                5
# 166                6
# 167                1
# 168                2
# 169                3
# 170                4
# 172                1
# 173                2
# 174                5
# 175                6
# 178                1
# 179                2
# 180                5
# 181                6
# 183                1
# 184                2
# 185                5
# 186                6
# 187                1
# 188                2
# 189                5
# 190                6
# 191                1
# 192                2
# 193                5
# 194                6  ]

# %%
pd.set_option('max_colwidth', 800)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
batched_observations_df
# Out:
#                                                                                                                                                                           Base Sentence  \
# 0                                                                                            A financial analyst at Goldman Sachs saw the stock price at Tesla plummeted in 2024-02-15.
# 1                                                            From 2020-01-01, a senior level executive at JPMorgan Chase speculated the net profit at Amazon was drastically different.
# 2                                                   2023-08-10, a research advisor at Harvard University heard that the research and development expenses at Microsoft remained stable.
# 3                                                                                         Apple's gross profit generally rose in Q2 2022, according to a financial expert at Bloomberg.
# 4                                                                                        Mr. Johnson, a financial analyst, observed that the stock price at Apple plummeted in Q2 2023.
# 5                                                                                                 From last week, Rachel speculated the net profit at Google was drastically different.
# 6                                                                                                Rachel, a financial expert, heard that the operating income at Amazon remained stable.
# 7                                                                                                             Amazon's operating income generally rose in Q4 2022, according to Rachel.
# 8                                                                                                 Rachel heard that the research and development expenses at Microsoft remained stable.
# 9                                                                                         Microsoft's research and development expenses generally rose in Q3 2025, according to Rachel.
# 10                                                                                             The financial expert at Goldman Sachs saw the stock price at Tesla plummeted in Q2 2026.
# 11                                                                 From 2023, the research advisor at Harvard University speculated the net profit at Amazon was drastically different.
# 12                                                                   2025, the senior financial analyst at JPMorgan Chase heard that the operating income at Microsoft remained stable.
# 13                                                                      The gross profit at Walmart generally rose in 2022, according to the financial top executive at Morgan Stanley.
# 14                                                                                                             Goldman Sachs saw the stock price at Apple plummeted in August 21, 2024.
# 15                                                                            From January 1, 2020, Dr. Smith speculated the net profit at Johnson & Johnson was drastically different.
# 16                                                                          August 21, 2024, Dr. Johnson heard that the research and development expenses at Microsoft remained stable.
# 17                                                                                                     Microsoft's operating income generally rose in Q3 of 2027, according to Dr. Lee.
# 18                                                                                                                Ms. Smith witnessed the stock price at Tesla plummeted in Q2 of 2023.
# 19                                                                                        From May 15, 2024, Mr. Johnson speculated the net profit at Amazon was drastically different.
# 20                                                                                                On July 1, 2027, a financial expert heard that the revenue at Google remained stable.
# 21                                                                                            Apple's operating income generally rose in 2026, according to a senior financial analyst.
# 22                                                                                                                   Goldman Sachs saw the net profit at Tesla plummeted in 2023-11-15.
# 23                                                                                       From 12/03/2022, Morgan Stanley speculated the stock price at Apple was drastically different.
# 24                                                                                                    2022/07/30, a financial analyst heard that the revenue at Amazon remained stable.
# 25                                                                                     Microsoft operating income generally rose in 2021-09-15, according to a senior financial expert.
# 26                                                              Noticing a concerning trend, the financial analyst observed that the net profit at TechCo plummeted on August 21, 2024.
# 27                                    From Q3 of 2027, the research and development expenses at GreenEnergy Inc. were speculated to be significantly different by the financial expert.
# 28                                                                        In 2029 of Q3, the financial senior level person heard that the stock price of BlueChip Inc. remained stable.
# 29                                                              For the past decade, the operating income at InnovativeMotors generally rose, according to the financial top executive.
# 30                                                                       American Heart Association saw the obesity rates at children's hospitals in California plummeted in 2022-2024.
# 31                                         From 2015 to 2020, Health Research Institute speculated the average life expectancy at senior centers in New York was drastically different.
# 32                                                        2024-07-15, Centers for Disease Control and Prevention heard that the vaccination rates at community clinics remained stable.
# 33                                                                          Patients' mental health issues generally rose in Q2 2022, according to National Institute of Mental Health.
# 34                                                                WellFlorida observed that the patients' blood pressure at all hospitals in Florida decreased from Q2 2022 to Q4 2022.
# 35                                                                  On 15Jun20, Dr. Lee speculated the number of COVID-19 cases at New York's General Hospital was significantly lower.
# 36                                                     From 2018 to 2020, Health Insights Inc. heard that the patients' physical activity levels at Los Angeles Clinic remained stable.
# 37                                                      The World Health Organization noted that the number of deaths from influenza at all hospitals worldwide generally rose in 2019.
# 38                                                              From 2015 to 2019, Dr. Patel heard that the patients' blood glucose levels at India's General Hospital remained stable.
# 39                                     Patients' obesity rates at all clinics in the United States generally rose in 2020, according to the Centers for Disease Control and Prevention.
# 40                                                                 The American Heart Association saw the cardiovascular disease rates at hospitals in California plummeted in Q2 2022.
# 41                                                                  From 2015 to 2020, Dr. Patel speculated the obesity rates at pediatric clinics in Texas were drastically different.
# 42                                     2024, August 15, the Centers for Disease Control and Prevention heard that the influenza vaccination rates in the United States remained stable.
# 43                                                                                 Patients' average sleep duration generally rose in 2020, according to the National Sleep Foundation.
# 44                                                                  WellFlorida caught that the patients' blood pressure at all hospitals in Florida increased from Q2 2022 to Q4 2022.
# 45                                                  On 15Mar20, Dr. Patel decomposed the number of patients with diabetes at New York's Hospital for Special Surgery to have decreased.
# 46                                                                    From 2018 to 2022, Health Insights Inc. speculated the prevalence of obesity at Los Angeles Clinic to have risen.
# 47                                             I noted that the average physical activity levels of patients at my own primary care clinic in Boston remained stable from 2020 to 2022.
# 48                                                       From 2015 to 2020, the World Health Organization heard that the number of reported cases of malaria in Africa remained stable.
# 49                                                                  Patients' body mass index generally decreased in 2019, according to the Centers for Disease Control and Prevention.
# 50                                                                           Dr. Smith witnessed the obesity rates at the local community center plummeted in the last quarter of 2022.
# 51                                        From 2018 to 2021, Health Trends Institute speculated the prevalence of chronic illnesses at the regional hospital was drastically different.
# 52                                                                             Last month, a health reporter heard that the nutritional intake at the school cafeteria remained stable.
# 53                                                         The physical activity levels at the fitness center generally rose in the first half of 2023, according to the health expert.
# 54                                                                                                      Dr. Smith saw the obesity rates at the downtown clinic plummeted in 2025-07-15.
# 55                                                         From Q4 2020, HealthWatch speculated the average physical activity levels at the community center was drastically different.
# 56                                                                                        2022/11/30, Nurse Jane heard that the children's hospital nutritional intake remained stable.
# 57                                                                     City Health Department's chronic illness prevalence generally rose in 2023 Q2, according to Health Analyst John.
# 58                                           Dr. Smith noticed a significant drop in obesity rates among school-aged children in the Midwest region from January 2023 to December 2023.
# 59             A recent study by the CDC speculated that the prevalence of diabetes among adults over 65 in the Southern states was considerably higher in Q2 2024 compared to Q2 2023.
# 60                                                                      According to a WHO report published in 2022, the global average life expectancy has remained relatively stable.
# 61                                           From 2018 to 2022, the number of organ donors in the United States generally increased, according to the United Network for Organ Sharing.
# 62                                                             The policy expert witnessed the election outcomes at the Democratic National Committee plummeted in 4th quarter of 2022.
# 63                                                        From 2010 to 2015, the senior policy analyst speculated the legislative impacts at the White House was drastically different.
# 64                                                                             2022-07-15, the research advisor heard that the economic reforms at the Federal Reserve remained stable.
# 65                                                                                Healthcare costs at the local hospital generally rose in 2023, according to the policy top executive.
# 66                                                                    Policy expert, Dr. Rachel Kim, observed that the unemployment rate in New York City plummeted on August 15, 2024.
# 67                                                                     From 2018, research advisor, Mr. Thompson, speculated the poverty rate in Los Angeles was drastically different.
# 68                                                                                              2027, policy analyst, Emily Chen, heard that the crime rate in Chicago remained stable.
# 69                                                                                     US Congress members' salaries generally rose in Q2 2022, according to policy advisor, Mr. Patel.
# 70                                                                                   Policy reporter, Rachel, saw the election outcomes at Democratic Party plummeted in November 2022.
# 71                                                                        From 2015 to 2020, Policy expert, Dr. Lee, speculated the economic growth at China was drastically different.
# 72                                                                  August 15, 2023, Policy senior level person, James, heard that the legislative impacts at Congress remained stable.
# 73                                                                                 Healthcare costs at private hospitals generally rose in Q2 2024, according to Policy analyst, Emily.
# 74                                                                             The policy expert, Dr. Patel, saw the unemployment rate at the city of Chicago plummeted in August 2022.
# 75                                         From Q2 2018, the research advisor, Dr. Rodriguez, speculated the economic growth rate at the state of California was drastically different.
# 76                                                                     On 21 August 2024, the policy analyst, Emily, heard that the crime rate in the city of New York remained stable.
# 77                                                                                            The education funding generally rose in Q3 2025, according to the policy expert, Dr. Lee.
# 78                                                                                  The unemployment rate in Chicago plummeted in Q2 of 2023, according to economic analyst, Dr. Patel.
# 79                                                        From 2018 to 2020, the budget deficit in New York City was drastically different, as noted by financial expert, Ms. Thompson.
# 80                                                                                                   In 09/15/2021, residents heard that the crime rate in Los Angeles remained stable.
# 81                                                                Public transportation ridership generally rose in Q3 of 2022, according to transportation policy expert, Mr. Johnson.
# 82                                                                                Policy analyst, Dr. Smith, observed that healthcare funding in New York City plummeted on 2024-08-21.
# 83                                                                      From Q2 2022, Policy Insights speculated the legislative impacts in Washington D.C. were drastically different.
# 84                                                                          2023/07/15, a senior policy advisor heard that the environmental regulations in California remained stable.
# 85                                                                                                 The unemployment rate generally rose in Q1 of 2020, according to policy expert Jane.
# 86                                                                                        Policy analyst, Claire, observed the unemployment rate in New York City plummeted in Q2 2024.
# 87                                                      From 2018 to 2022, the National Economic Council speculated the GDP growth rate in the United States was drastically different.
# 88                                                                                       In 2027, a research advisor, John, heard that the poverty rate in rural areas remained stable.
# 89                                                                               The number of renewable energy projects generally rose in 2029, according to the Department of Energy.
# 90                                                                                       The National Weather Service observed the precipitation in California plummeted in 2024-07-15.
# 91                                                        From 2015 to 2020, the American Meteorological Society speculated the temperature at Mount Everest was drastically different.
# 92                                                                               4th quarter of 2022, the Weather Channel heard that the wind speed in Hurricane Alley remained stable.
# 93                                          The atmospheric pressure in the Gulf of Mexico generally rose in September 2023, according to a research team from the University of Miami.
# 94                                                                                          The weather reporter watched the temperature in New York City plummeted on August 25, 2024.
# 95                                                    From 2015 to 2020, Dr. Maria, a climate scientist, speculated the precipitation levels in Los Angeles were drastically different.
# 96                                                                                           In Q2 2018, I, a research assistant, heard that the wind speed in Chicago remained stable.
# 97                                                           The storm chaser generally saw the humidity in Oklahoma rose in September 2027, according to the National Weather Service.
# 98                                                                                         Weather Forecaster Emma saw the precipitation in New York City plummeted on August 15, 2022.
# 99                                                                       From 2015 to 2020, Climate Researcher Dr. Patel speculated the temperature in Miami was drastically different.
# 100                                                                                   On October 12, 2021, Meteorologist Ryan heard that the wind speed in Los Angeles remained stable.
# 101                                                                             In Dallas, the humidity generally rose from June 2020 to July 2020, according to Weather Analyst David.
# 102                                                                                              The weather forecaster observed the temperature in Tokyo plummeted on August 25, 2024.
# 103                                                                         From 2015 to 2020, Climate Research speculated the precipitation in New York City was significantly higher.
# 104                                                                                      On September 12, 2022, Dr. Patel witnessed the atmospheric pressure in Mumbai remained stable.
# 105                                                                  In the Amazon rainforest, the humidity generally rose from June 2020 to July 2020, according to the research team.
# 106                                                                                                   The weather reporter noticed the temperature in Miami plummeted in the past week.
# 107                                                                          From 2015 to 2020, Climate Watch speculated wind speed levels in New York City were drastically different.
# 108                                                                                       On 12th June 2023, the meteorologist heard that the precipitation in Seattle remained stable.
# 109                                                                                      The weather expert observed that the humidity in Los Angeles generally rose in the last month.
# 110                                                                                                The weather analyst saw the humidity at the coastal regions plummeted in 2024-08-21.
# 111                                                                            From Q1 2023, the meteorologist speculated the wind speed at the Great Plains was drastically different.
# 112                                                                                         2023/07/15, the weather expert heard that the temperature in New York City remained stable.
# 113                                                                   The weather reporter noted that rainfall generally rose in 2022/11/30, according to the National Weather Service.
# 114                       Noticing the recent heatwave, the meteorologist in the local weather station observed the temperature in Dallas, Texas, soar to new heights on June 23, 2023.
# 115                     From Q2 2022 to Q1 2023, the weather expert at the climate research center predicted that the precipitation levels in Florida would see a significant decrease.
# 116              During her visit to the Grand Canyon in May 2024, the environmental science professor noticed that the wind speed had remained stable compared to her previous visits.
# 117  In the first two weeks of January 2025, the senior meteorologist reported that the snowfall in New York generally rose, providing a white winter experience for the city dwellers.
#
#      Sentence Label   Domain               Model Name    API Name  Batch ID  \
# 0                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 1                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 2                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 3                 0  finance  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 4                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 5                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 6                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 7                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 8                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 9                 0  finance     llama-3.1-8b-instant  GROQ_CLOUD         0
# 10                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 11                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 12                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 13                0  finance          llama3-70b-8192  GROQ_CLOUD         0
# 14                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 15                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 16                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 17                0  finance           llama3-8b-8192  GROQ_CLOUD         0
# 18                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 19                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 20                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 21                0  finance            gpt-3.5-turbo  NAVI_GATOR         0
# 22                0  finance                   gpt-4o  NAVI_GATOR         0
# 23                0  finance                   gpt-4o  NAVI_GATOR         0
# 24                0  finance                   gpt-4o  NAVI_GATOR         0
# 25                0  finance                   gpt-4o  NAVI_GATOR         0
# 26                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 27                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 28                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 29                0  finance    mixtral-8x7b-instruct  NAVI_GATOR         0
# 30                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 31                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 32                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 33                0   health  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 34                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 35                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 36                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 37                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 38                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 39                0   health     llama-3.1-8b-instant  GROQ_CLOUD         0
# 40                0   health          llama3-70b-8192  GROQ_CLOUD         0
# 41                0   health          llama3-70b-8192  GROQ_CLOUD         0
# 42                0   health          llama3-70b-8192  GROQ_CLOUD         0
# 43                0   health          llama3-70b-8192  GROQ_CLOUD         0
# 44                0   health           llama3-8b-8192  GROQ_CLOUD         0
# 45                0   health           llama3-8b-8192  GROQ_CLOUD         0
# 46                0   health           llama3-8b-8192  GROQ_CLOUD         0
# 47                0   health           llama3-8b-8192  GROQ_CLOUD         0
# 48                0   health           llama3-8b-8192  GROQ_CLOUD         0
# 49                0   health           llama3-8b-8192  GROQ_CLOUD         0
# 50                0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 51                0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 52                0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 53                0   health            gpt-3.5-turbo  NAVI_GATOR         0
# 54                0   health                   gpt-4o  NAVI_GATOR         0
# 55                0   health                   gpt-4o  NAVI_GATOR         0
# 56                0   health                   gpt-4o  NAVI_GATOR         0
# 57                0   health                   gpt-4o  NAVI_GATOR         0
# 58                0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 59                0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 60                0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 61                0   health    mixtral-8x7b-instruct  NAVI_GATOR         0
# 62                0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 63                0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 64                0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 65                0   policy  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 66                0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 67                0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 68                0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 69                0   policy     llama-3.1-8b-instant  GROQ_CLOUD         0
# 70                0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 71                0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 72                0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 73                0   policy          llama3-70b-8192  GROQ_CLOUD         0
# 74                0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 75                0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 76                0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 77                0   policy           llama3-8b-8192  GROQ_CLOUD         0
# 78                0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 79                0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 80                0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 81                0   policy            gpt-3.5-turbo  NAVI_GATOR         0
# 82                0   policy                   gpt-4o  NAVI_GATOR         0
# 83                0   policy                   gpt-4o  NAVI_GATOR         0
# 84                0   policy                   gpt-4o  NAVI_GATOR         0
# 85                0   policy                   gpt-4o  NAVI_GATOR         0
# 86                0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 87                0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 88                0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 89                0   policy    mixtral-8x7b-instruct  NAVI_GATOR         0
# 90                0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 91                0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 92                0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 93                0  weather  llama-3.3-70b-versatile  GROQ_CLOUD         0
# 94                0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 95                0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 96                0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 97                0  weather     llama-3.1-8b-instant  GROQ_CLOUD         0
# 98                0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 99                0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 100               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 101               0  weather          llama3-70b-8192  GROQ_CLOUD         0
# 102               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 103               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 104               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 105               0  weather           llama3-8b-8192  GROQ_CLOUD         0
# 106               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 107               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 108               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 109               0  weather            gpt-3.5-turbo  NAVI_GATOR         0
# 110               0  weather                   gpt-4o  NAVI_GATOR         0
# 111               0  weather                   gpt-4o  NAVI_GATOR         0
# 112               0  weather                   gpt-4o  NAVI_GATOR         0
# 113               0  weather                   gpt-4o  NAVI_GATOR         0
# 114               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 115               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 116               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
# 117               0  weather    mixtral-8x7b-instruct  NAVI_GATOR         0
#
#      Template Number
# 0                  1
# 1                  2
# 2                  5
# 3                  6
# 4                  1
# 5                  2
# 6                  3
# 7                  4
# 8                  5
# 9                  6
# 10                 1
# 11                 2
# 12                 5
# 13                 6
# 14                 1
# 15                 2
# 16                 5
# 17                 6
# 18                 1
# 19                 2
# 20                 5
# 21                 6
# 22                 1
# 23                 2
# 24                 5
# 25                 6
# 26                 1
# 27                 2
# 28                 5
# 29                 6
# 30                 1
# 31                 2
# 32                 5
# 33                 6
# 34                 1
# 35                 2
# 36                 3
# 37                 4
# 38                 5
# 39                 6
# 40                 1
# 41                 2
# 42                 5
# 43                 6
# 44                 1
# 45                 2
# 46                 3
# 47                 4
# 48                 5
# 49                 6
# 50                 1
# 51                 2
# 52                 5
# 53                 6
# 54                 1
# 55                 2
# 56                 5
# 57                 6
# 58                 1
# 59                 2
# 60                 5
# 61                 6
# 62                 1
# 63                 2
# 64                 5
# 65                 6
# 66                 1
# 67                 2
# 68                 5
# 69                 6
# 70                 1
# 71                 2
# 72                 5
# 73                 6
# 74                 1
# 75                 2
# 76                 5
# 77                 6
# 78                 1
# 79                 2
# 80                 5
# 81                 6
# 82                 1
# 83                 2
# 84                 5
# 85                 6
# 86                 1
# 87                 2
# 88                 5
# 89                 6
# 90                 1
# 91                 2
# 92                 5
# 93                 6
# 94                 1
# 95                 2
# 96                 3
# 97                 4
# 98                 1
# 99                 2
# 100                5
# 101                6
# 102                1
# 103                2
# 104                5
# 105                6
# 106                1
# 107                2
# 108                5
# 109                6
# 110                1
# 111                2
# 112                5
# 113                6
# 114                1
# 115                2
# 116                5
# 117                6
